# %% [markdown]
# VAEs dynamiques : https://arxiv.org/abs/2008.12595
#
# # Training Deep Kalman Filter

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# from tests.unit_tests import test_brick_1, test_brick_2, test_brick_3, test_brick_4, test_brick_5, test_brick_6
# from libs.dkf import DeepKalmanFilter, loss_function

# %%
def seed_everything(seed=42):
    """
    Set seed for reproducibility.
    """
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set seed for reproducibility
seed_everything(42)

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    dtype = torch.cuda.FloatTensor
else:
    device = torch.device('cpu')
    dtype = torch.FloatTensor

print(f"Using {device}")

torch.set_default_dtype(torch.float64)

if device.type == 'cuda':
    print('GPU Name:', torch.cuda.get_device_name(0))
    print('Total GPU Memory:', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
# Out:
# Using cuda
# GPU Name: NVIDIA GeForce RTX 4090
# Total GPU Memory: 23.6 GB

# %% [markdown]
# # Modèle

# %% [markdown]
# ### Structure SSM (Single State Model pour variables latentes + VAE pour observations):
#
# - $z_t$ variables latentes forment une chaîne de Markov, transition $p(z_t \vert z_{t-1})$
# - $x_t$ observations, modèle $p_{\theta_x}(x_t \vert z_t)$
# - NB : pas de commande/input $u_t$ ici

# %% [markdown]
# ### Deep Kalman Filter :
#
# \begin{align}
# p_{\theta_z}(z_t \vert z_{t-1}) &= \mathcal{N}(z_t \vert \mu_{\theta_z}(z_{t-1}), \text{diag}(\sigma_{\theta_z}^{2}(z_{t-1}))) \\
# d_z(z_{t-1}) &= [ \mu_{\theta_z}(z_{t-1}), \sigma_{\theta_z}(z_{t-1}) ] \\
# p_{\theta_x}(x_t \vert z_{t}) &= \mathcal{N}(x_t \vert \mu_{\theta_x}(z_{t}), \text{diag}(\sigma_{\theta_x}^{2}(z_{t}))) \\
# d_x(z_{t}) &= [ \mu_{\theta_x}(z_{t}), \sigma_{\theta_x}(z_{t}) ] \\
# \end{align}
#
# où $d_x, d_z$ sont des réseaux.

# %% [markdown]
# ### Modèle inférence
#
# Le "true posterior" s'écrit :
# \begin{align}
# p_{\theta}(z_{1:T} \vert x_{1:T}) &= \prod_{t=1}^T p_{\theta} (z_t \vert z_{1:t-1}, x_{1:T} ) \\
# &= \prod_{t=1}^T p_{\theta} (z_t \vert z_{t-1}, x_{t:T} )
# \end{align}
#
# où la première écriture est l'application de la chain rule, et la deuxième est un résultat de D-séparation (latentes à dépendance Markovienne).
#
# On choisit comme approximation du posterior (=encodeur) une formulation calquée sur le vrai posterior :
#
# \begin{align}
# q_{\phi}(z_{1:T} \vert x_{1:T}) &= \prod_{t=1}^T q_{\phi} (z_{t} \vert z_{t-1}, x_{t:T})
# \end{align}
#
# On voit que l'inférence prend en compte les observations futures $x_{t:T}$ (comme le Kalman smoother par exemple)

# %% [markdown]
# # Implémentation de l'inférence

# %% [markdown]
# - **backward RNN** (dans les faits, un LSTM) pour encoder les $x_{t:T}$ par les hidden states $h_t$ :
#
# \begin{align}
# h_t = \text{LSTM}(h_{t+1}, x_t)
# \end{align}
#
# - **combiner** (réseau MLP) pour aggréger $h_t$ et $z_{t-1}
#
# \begin{align}
# g_t = \text{Combiner}(h_t, z_{t-1})
# \end{align}
#
# - **Encoder** (réseau MLP) pour inférer les paramètres du posterior:
#
# \begin{align}
# e_z(g_t) &= [ \mu_\phi(g_t), \sigma_\phi(g_t)] \\
# q_\phi(z_t \vert g_t) &= \mathcal{N}(z_t \vert \mu_{\phi}(g_t), \text{diag}(\sigma_\phi^2(g_t)))
# \end{align}
#
# NB : il existe d'autres formulations du posterior approximé $q_\phi$, qui peuvent faire intervenir un forward LSTM.

# %% [markdown]
# # Training

# %% [markdown]
# Le modèle s'entraîne en maximisant un ELBO, dont la formulation générique se simplifie dans le cas du DKF en :
#
# \begin{align}
# \mathcal{L}(\theta, \phi; X) &= \sum_{t=1}^T \mathbb{E}_{q_\phi(z_t \vert x_{1:T})} \log(p_{\theta_x}(x_t \vert z_t)) -
# \sum_{t=1}^T \mathbb{E}_{q_\phi(z_{t-1} \vert x_{1:T})} \text{D}_{\text{KL}} \left[ q_\phi(z_t \vert z_{t-1}, x_{t:T}) \vert\vert
# p_{\theta_z}(z_t \vert z_{t-1}) \right]
# \end{align}
#
# Les deux termes s'explicitent de la façon suivante (avec $D$ dimension de l'espace des observations) :
#
# \begin{align}
# p_{\theta_x}(x_t \vert z_t) &= \mathcal{N}(x_t \vert \mu_{\theta_x}(z_t), \text{diag}(\sigma_{\theta_x}^2(z_t))) \\
# \log{p_{\theta_x}(x_t \vert z_t)} &= -\frac{D}{2} \log{2\pi} - \frac{1}{2}\log{\vert \text{diag}(\sigma_{\theta_x}^2(z_t)) \vert} -
# \frac{1}{2} \left[ (x_t - \mu_{\theta_x}(z_t))^T (\text{diag}(\sigma_{\theta_x}^2(z_t)))^{-1} (x_t - \mu_{\theta_x}(z_t)) \right] \\
# &= - \frac{1}{2} \left( \sum_{i=1}^D \log{\sigma_{\theta_x}^2(z_t)}\vert_{i} + (x_t - \mu_{\theta_x}(z_t))^T \text{diag} \frac{1}{\sigma_{\theta_x}^2(z_t)} (x_t - \mu_{\theta_x}(z_t)) + D \log{2\pi} \right)
# \end{align}
#
# Et la KL entre les deux Gaussiennes:
#
# \begin{align}
# q_\phi(z_t \vert z_{t-1}, x_{t:T}) &= \mathcal{N}(z_t \vert \mu_{\phi}(g_t), \text{diag}(\sigma_\phi^2(g_t))) \\
# p_{\theta_z}(z_t \vert z_{t-1}) &= \mathcal{N}(z_t \vert \mu_{\theta_z}(z_{t-1}), \text{diag}(\sigma_{\theta_z}^{2}(z_{t-1}))) \\
# \end{align}
#
# a une close form (avec $Z$ dimension de l'espace latent):
#
# \begin{align}
# \text{D}_{\text{KL}}(q_\phi \vert\vert p_{\theta_z}) &= \frac{1}{2} \left[ \text{Tr}(\text{diag}(\sigma_{\theta_z}^{2})^{-1} \text{diag}(\sigma_\phi^2) ) + (\mu_{\theta_z} - \mu_\phi)^T (\text{diag}(\sigma_{\theta_z}^{2})^{-1}) (\mu_{\theta_z} - \mu_\phi) +
# \log{\frac{\vert \text{diag}(\sigma_{\theta_z}^{2})\vert}{\vert \text{diag}(\sigma_\phi^2) \vert} } \right] \\
# &= \frac{1}{2}\left[ \sum_{i=1}^Z \log{\sigma_{\theta_z}^{2}}\vert_i - \sum_{i=1}^Z \log{\sigma_{\phi}^{2}}\vert_i +
#  (\mu_{\theta_z} - \mu_\phi)^T \text{diag}(\frac{1}{\sigma_{\theta_z}^{2}}) (\mu_{\theta_z} - \mu_\phi) + \sum_{i=1}^Z \frac{\sigma_{\phi}^{2}\vert_i} {\sigma_{\theta_z}^{2}\vert_i} - Z
# \right]
# \end{align}

# %% [markdown]
# # Code

# %%
X_DIM = 1 # Dimension of the observation space
Z_DIM = 2 # Dimension of the latent space
H_DIM = 16 # Dimension of the hidden state of the LSTM network(s)
G_DIM = 2 # Dimension of the output of the combiner
INTERMEDIATE_LAYER_DIM = 16 # Dimension of the intermediate layers of the MLPs

# %% [markdown]
# ### Briques de base

# %%
#--- brick 1 : backward LSTM -----------------------------

class BackwardLSTM(nn.Module):
    """
    Backward LSTM module.
    Creates a unidirectional LSTM, with num_layers layers, hidden state
    of dimension hidden_size, and input of dimension input_size.
    The LSTM is used to process the input sequence in reverse order.
    """
    def __init__(self, input_size, hidden_size, num_layers=2):
        super(BackwardLSTM, self).__init__()
        
        self.input_size = input_size
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        self.lstm = nn.LSTM(
            input_size,   # dimension of the observation space
            hidden_size,  # dimension of the hidden state of the LSTM network
            num_layers=num_layers, # number of layers of the LSTM network
            batch_first=False, # using the default PyTorch LSTM implementation, expecting input shape (seq_len, batch, input_size)
            bidirectional=False # unidirectional LSTM to start with
            )

    def forward(self, x):
        """
        Forward pass of the backward LSTM module. The sequence x
        is reversed via a torch.flip operation, then passed through the LSTM.
        The output sequence is reversed again to get the final output.
        
        Args:
            x: input sequence
            shape (seq_len, batch, input_size)
        Returns:
            out: output sequence
            shape (seq_len, batch, hidden_size)
        """
        # Reverse the input sequence - axis 0 is the time axis here
        x_reversed = torch.flip(x, [0])
        # Pass through LSTM
        # using initial hidden state and cell state as zeros
        out, _ = self.lstm(x_reversed)
        # Reverse the output sequence
        out_reversed = torch.flip(out, [0])
        # return output shape (seq_len, batch, hidden_size)
        
        return out_reversed

# %%
#--- brick 2 : combiner -----------------------------
#
# this combines the latent variable at time t-1
# with the hidden state from the backward LSTM at time t,
# to compute a t
    # X_DIM = 1 # Dimension of the observation space
    # Z_DIM = 16 # Dimension of the latent space
    # H_DIM = 16 # Dimension of the hidden state of the LSTM network(s)
    # G_DIM = 8 # Dimension of the output of the combiner
    # INTERMEDIATE_LAYER_DIM = 16 # Dimension of the intermediate layers of the MLPsensor g at time t, that will be used
# to compute the parameters of the approximate posterior distribution
# of the latent variable
#

class CombinerMLP(nn.Module):
    """Combiner module. Takes the hidden state of the backward LSTM at time t
    and the (sampled) latent variable at time t-1, to compute a tensor g at time t,
    that will be used to compute the parameters of the approximate posterior
    distribution of the latent variable.
    """
    
    def __init__(self, 
                 latent_dim=Z_DIM, 
                 hidden_dim=H_DIM, 
                 output_dim=G_DIM,
                 layers_dim = None,  # list of layers dimensions, without the input dimnesion, without the output dimension
                 activation = 'tanh',
                 inter_dim = INTERMEDIATE_LAYER_DIM,
                 ):
        """Creates a combiner module, ie a MLP layer, to combine h_t (the output of the backward lstm at time t
        and (sampled) z_t-1, the latent variable at time t-1.
        The input_dimension is the sum of the latent dimension (dimension of z_t-1) and the hidden dimension
        (dimension of h_t).
        The output dimension is the dimension of the combiner output, which is a parameter.
        The list of intermediate layers is passed in the list layers_dim.
        The activation function is passed as a string, either 'tanh' or 'relu'. (default = 'tanh')
        
        Inputs:
            latent_dim : dimension of the latent space
            hidden_dim : dimension of the hidden state of the LSTM network
            output_dim : dimension of the combiner output
            layers_dim : list of layers dimensions, without the input dimension, without the output dimension
            activation : activation function (default = 'tanh')
            inter_dim : dimension of the intermediate layers (default = INTERMEDIATE_LAYER_DIM)
        """
        super(CombinerMLP, self).__init__()
        
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        if activation == 'tanh':
            self.activation_fn = nn.Tanh()
        elif activation == 'relu':
            self.activation_fn = nn.ReLU()
        else:
            raise ValueError(f"Activation function {activation} not supported. Use 'tanh' or 'relu'.")
        self.inter_dim = inter_dim
        self.layers_dim = layers_dim
        
        if self.layers_dim is None:
            self.layers_dim = [self.inter_dim] * 2
        else:
            self.layers_dim = layers_dim
            
        # explicitly define the MLP layers
        layers = []
        for i, dim in enumerate(self.layers_dim):
            if i==0:  #first layer, latent_dim + hidden_dim => layers_dim[0]
                layers.append(nn.Linear(latent_dim + hidden_dim, dim))
            else:  # all other layers
                layers.append(nn.Linear(self.layers_dim[i-1], dim))
            layers.append(self.activation_fn)
        # last layer : layers_dim[-1] => output_dim
        layers.append(nn.Linear(self.layers_dim[-1], output_dim))
            
        # build the MLP
        self.mlp = nn.Sequential(*layers)
            
        
    def forward(self, h, z):
        """
        Forward pass of the combiner module.
        The use of the combiner module is sequential, so there is no seq_len dimension.
        
        Args:
            h: hidden state of the backward LSTM at time t
            shape (batch, hidden_dim)
            z: latent variable at time t-1
            shape (batch, latent_dim)
        Returns:
            g: tensor g at time t
            shape (batch, output_dim)
        """
        
        # Concatenate the hidden state and the latent variable on their dimension
        x = torch.cat((h, z), dim=-1) # shape (batch, hidden_dim + latent_dim)
        
        # Pass through MLP
        g = self.mlp(x) # output shape (batch, output_dim)
        
        return g

# %%
#--- brick 3 : Encoder -----------------------------
#
# This computes the parameters of the approximate posterior distribution
# of the latent vatiable at time t.
# The approximate posterior distribution is a Gaussian distribution,
# we use a MLP to compute the mean and the log of the variance.
#

class EncoderMLP(nn.Module):
    """Encoder module. 
    Computes the parameters of the approximate posterior
    distribution of the latent variable at time t. 
    The approximate posterior distribution is a Gaussian distribution, we use a MLP to compute the mean
    and the log of the variance.
    The input variables are g_t (the output of the combiner module at time t) and
    z_t-1 (the -sampled- latent variable at time t-1).
    """
    
    def __init__(self, 
                 latent_dim=Z_DIM, # Dimension of the latent space
                 combiner_dim=G_DIM, # Dimension of the combiner output
                 inter_dim=INTERMEDIATE_LAYER_DIM, # Dimension of the intermediate layers
                 layers_dim = None, # Dimension of the MLP layers (without inout nor output)
                 activation = 'tanh', # Activation function
    ):
        """Creates the encoder module.
        This is a MLP, that takes as input the combiner output g_t (combining h_t and z_t-1).
        The input dimension is the combiner dimension.
        The output dimension is the 2 * dimension of the latent space (mean, and log variance).
        The list of intermediate layers is passed in the list layers_dim.
        The activation function is passed as a string, either 'tanh' or 'relu'. (default = 'tanh')
        
        Inputs:
            latent_dim : dimension of the latent space
            combiner_dim : dimension of the combiner output
            inter_dim : dimension of the intermediate layers (default = INTERMEDIATE_LAYER_DIM)
            layers_dim : list of layers dimensions, without the input dimension, without the output dimension
            activation : activation function (default = 'tanh')
        """
        super(EncoderMLP, self).__init__()
        
        self.latent_dim = latent_dim
        self.combiner_dim = combiner_dim
        if activation == 'tanh':
            self.activation_fn = nn.Tanh()
        elif activation == 'relu':
            self.activation_fn = nn.ReLU()
        else:
            raise ValueError(f"Activation function {activation} not supported. Use 'tanh' or 'relu'.")
        self.inter_dim = inter_dim
        
        if layers_dim is None:
            self.layers_dim = [self.inter_dim] * 2
        else:
            self.layers_dim = layers_dim
            
        # explicitly define the MLP layers
        layers = []
        for i, dim in enumerate(self.layers_dim):
            if i==0:
                layers.append(nn.Linear(combiner_dim, dim))
            else:
                layers.append(nn.Linear(self.layers_dim[i-1], dim))
            layers.append(self.activation_fn)
            
        # last layer is linear, no activation
        layers.append(nn.Linear(self.layers_dim[-1], 2 * latent_dim)) 
                    
        # build the MLP
        self.mlp = nn.Sequential(*layers)
        
    def forward(self, g):
        """
        Forward pass of the encoder module.
        Takes g_t (the output of the combiner module at time t) as input, returns the parameters of the
        approximate posterior distribution of the latent variable at time t.
        The encoder module is used sequentially, so there is no seq_len dimension.
        The output is a tuple (mu, logvar), where mu is the mean of the approximate posterior distribution
        and logvar is the log of the variance of the approximate posterior distribution.
        
        Args:
            g: tensor g at time t
            shape (batch, combiner_dim)
            
        Returns:
            mu: mean of the approximate posterior distribution
            shape (batch, latent_dim)
            logvar: log of the variance of the approximate posterior distribution
            shape (batch, latent_dim)
        """
        
        # Pass through MLP
        out = self.mlp(g)
        
        # Split the output into mean and log variance
        # each with shape (batch, latent_dim)
        mu, logvar = out[:, :self.latent_dim], out[:, self.latent_dim:]
        
        return mu, logvar

# %%
#--- brick 4 : Latent Space Transition -----------------------------       
#
# This computes the parameters of the transition distribution
# of the latent variable at time t. Ie the prior distribution, 
# before inference.
# The transition distribution is a Gaussian distribution,
# we use a MLP to compute the mean and the log of the variance.
#

class LatentSpaceTransitionMLP(nn.Module):
    """Latent space transition module. 
    Computes the parameters of the transition distribution of the latent variable at time t (ie "prior").
    The transition distribution is a Gaussian distribution, we use a MLP to compute the mean
    and the log of the variance.
    """
    
    def __init__(self, 
                 latent_dim=Z_DIM, # Dimension of the latent space
                 inter_dim=INTERMEDIATE_LAYER_DIM, # Dimension of the intermediate layers
                 layers_dim = None, # Dimension of the MLP layers
                 activation = 'tanh', # Activation function
    ):
        """Creates the latent space transition MLP.
        This is a MLP, that takes as input the -sampled- lagged latent variable z_t-1,
        and computes the parameters of the transition distribution p(z_t|z_{t-1}).
        The input dimension is the latent dimension.
        The output dimension is the 2 * dimension of the latent space (mean, and log variance).
        The list of intermediate layers is passed in the list layers_dim.
        The activation function is passed as a string, either 'tanh' or 'relu'. (default = 'tanh')
        Inputs:
            latent_dim : dimension of the latent space
            inter_dim : dimension of the intermediate layers (default = INTERMEDIATE_LAYER_DIM)
            layers_dim : list of layers dimensions, without the input dimension, without the output dimension
            activation : activation function (default = 'tanh')
        """
        super(LatentSpaceTransitionMLP, self).__init__()
        
        self.latent_dim = latent_dim
        if activation == 'tanh':
            self.activation_fn = nn.Tanh()
        elif activation == 'relu':
            self.activation_fn = nn.ReLU()
        else:
            raise ValueError(f"Activation function {activation} not supported. Use 'tanh' or 'relu'.")
        self.inter_dim = inter_dim
        
        if layers_dim is None:
            layers_dim = [self.inter_dim]
        self.layers_dim = layers_dim
            
        # explicitly define the MLP layers
        layers = []
        for i, dim in enumerate(self.layers_dim):
            if i==0:
                layers.append(nn.Linear(self.latent_dim, dim))
            else:
                layers.append(nn.Linear(self.layers_dim[i-1], dim))
            layers.append(self.activation_fn)
            
        # last layer is linear, no activation
        layers.append(nn.Linear(self.layers_dim[-1], 2 * self.latent_dim)) 
                    
        # build the MLP
        self.mlp = nn.Sequential(*layers)
               
    def forward(self, z):
        """
        Forward pass of the latent space transition module.
        This takes as input a whole set of lagged -sampled- latent variables z_t-1,
        and computes the parameters of the transition distribution p(z_t|z_{t-1}) for each time step t.
        
        Args:
            z: latent variables lagged(set of latent variables at time t-1)
            shape (seq_len, batch, latent_dim)
            
        Returns:
            mu: means of the transition distribution
            shape (seq_len, batch, latent_dim)
            logvar: log of the variances of the transition distribution
            shape (seq_len, batch, latent_dim)
        """
        
        # Pass through MLP
        out = self.mlp(z)
        
        # Split the output into mean and log variance
        # each with shape (batch, latent_dim)
        mu, logvar = out[:, :, :self.latent_dim], out[:, :, self.latent_dim:]
        
        return mu, logvar

# %%
#--- brick 5 : Decoder (ie Observation Model) -----------------------------
#
# This computes the parameters of the distribution of 
# the observed variable 'x', given the latent variable 'z'.
# The distribution is a Gaussian distribution,
# we use a MLP to compute the mean and the log of the variance.
#

class DecoderMLP(nn.Module):
    """Decoder module. Computes the parameters of the distribution of the
    observed variable 'x', given the latent variable 'z' sampled from the approximate
    posterior distribution.
    The distribution is a Gaussian distribution, we use a MLP to compute the mean and the log of
    the variance.   
    """
    
    def __init__(self, 
                 latent_dim=Z_DIM, # Dimension of the latent space
                 observation_dim=X_DIM, # Dimension of the observation space
                 inter_dim=INTERMEDIATE_LAYER_DIM, # Dimension of the intermediate layers
                 layers_dim = None, # Dimension of the MLP layers
                 activation = 'tanh', # Activation function
    ):
        """Creates the decoder module.
        This is a MLP, that takes as input a set of -sampled- latent variables z_t,
        and computes the parameters of the distribution of the observed variable 'x'.
        The input dimension is the latent dimension.
        The output dimension is the 2 * dimension of the observation space (mean, and log variance).
        The list of intermediate layers is passed in the list layers_dim.
        The activation function is passed as a string, either 'tanh' or 'relu'. (default = 'tanh')
        
        Inputs:
            latent_dim : dimension of the latent space
            observation_dim : dimension of the observation space
            inter_dim : dimension of the intermediate layers (default = INTERMEDIATE_LAYER_DIM)
            layers_dim : list of layers dimensions, without the input dimension, without the output dimension
            activation : activation function (default = 'tanh')
        """
        super(DecoderMLP, self).__init__()
        
        self.latent_dim = latent_dim
        self.observation_dim = observation_dim
        self.inter_dim = inter_dim
        
        if activation == 'tanh':
            self.activation_fn = nn.Tanh()
        elif activation == 'relu':
            self.activation_fn = nn.ReLU()
        else:
            raise ValueError(f"Activation function {activation} not supported. Use 'tanh' or 'relu'.")
        
        if layers_dim is None:
            layers_dim = [self.inter_dim] # one layer per default
        self.layers_dim = layers_dim
            
        # explicitly define the MLP layers
        layers = []
        for i, dim in enumerate(self.layers_dim):
            if i==0:
                layers.append(nn.Linear(self.latent_dim, dim))
            else:
                layers.append(nn.Linear(self.layers_dim[i-1], dim))
            layers.append(self.activation_fn)
            
        # last layer is linear, no activation
        layers.append(nn.Linear(self.layers_dim[-1], 2 * self.observation_dim)) 
                    
        # build the MLP
        self.mlp = nn.Sequential(*layers)
        
    def forward(self, z):
        """
        Forward pass of the decoder module.
        This takes as input the set of -sampled- latent variables z_t, and 
        computes the set of parameters of the distribution of the observed variable 'x'.
        The decoder module is used after the sequential loop, so there is a seq_len dimension.
        
        Args:
            z: latent variable at time t
            shape (seq_len, batch, latent_dim)
        Returns:
            mu: means of the distribution of the observed variable
            shape (seq_len, batch, observation_dim)
            logvar: log of the variances of the distribution of the observed variable
            shape (seq_len, batch, observation_dim)
        """
        # Pass through MLP
        out = self.mlp(z)
        
        # Split the output into mean and log variance
        # each with shape (batch, observation_dim)
        mu, logvar = out[:, :, :self.observation_dim], out[:, :, self.observation_dim:]
        
        return mu, logvar

# %%
# --- brick 6 : Sampler with reparameterization trick -----------------------------
#
# This samples from a normal distribution of given mean and log variance
# using the reparameterization trick.

class Sampler(nn.Module):
    """Sampler module. Samples from a normal distribution of given mean and
    log variance using the reparameterization trick.
    
    NB : to be replaced by batch of tf.distributions.Normal(mu, logvar) ?
    """
    
    def __init__(self):
        super(Sampler, self).__init__()
        
    def forward(self, mu, logvar):
        """
        Forward pass of the sampler module.
        
        Args:
            mu: mean of the distribution
            shape (batch, dim)
            logvar: log of the variance of the distribution
            shape (batch, dim)
            
        Returns:
            v: sampled variables
            shape (batch, dim)
        """
        
        # Sample from a normal distribution using the reparameterization trick
        std = torch.exp(0.5 * logvar)  # standard deviation
        eps = torch.randn_like(std)  # random noise
        v = mu + eps * std  # sampled variables
        
        return v

# %% [markdown]
# # Class DeepKalman Filter

# %%
class DeepKalmanFilter(nn.Module):
    """Deep Kalman Filter (DKF) module. Implements the DKF algorithm.
    
    Args:
        nn (_type_): _description_
        
    Returns:
        _type_: _description_
    """
    
    def __init__(self,
                 input_dim=X_DIM, # Dimension of the observation space
                 latent_dim=Z_DIM, # Dimension of the latent space
                 hidden_dim=H_DIM, # Dimension of the hidden state of the LSTM network
                 combiner_dim=G_DIM, # Dimension of the combiner output
                 inter_dim=INTERMEDIATE_LAYER_DIM, # Dimension of the intermediate layers
                 activation='tanh', # Activation function
                 num_layers=1, # Number of layers of the LSTM network
                 device='cpu' # Device to use (cpu or cuda)
                 ):
        super(DeepKalmanFilter, self).__init__()
        
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim
        self.combiner_dim = combiner_dim
        self.inter_dim = inter_dim
        self.device = device
        
        # define the modules
        
        self.backward_lstm = BackwardLSTM(
            input_size=self.input_dim,
            hidden_size=self.hidden_dim,
            num_layers=num_layers
        )
        
        self.combiner = CombinerMLP(
            latent_dim=self.latent_dim,
            hidden_dim=self.hidden_dim,
            output_dim=self.combiner_dim,
            activation=activation,
            layers_dim=None, # list of layers dimensions, without the input dimension, without the output dimension
            inter_dim=self.inter_dim
        )
        
        self.encoder = EncoderMLP(
            latent_dim=self.latent_dim,
            combiner_dim=self.combiner_dim,
            inter_dim=self.inter_dim,
            activation=activation,
            layers_dim=None, # list of layers dimensions, without the input dimension, without the output dimension
        )
        
        self.latent_space_transition = LatentSpaceTransitionMLP(
            latent_dim=self.latent_dim,
            inter_dim=self.inter_dim,
            activation=activation,
            layers_dim=None, # list of layers dimensions, without the input dimension, without the output dimension
        )
        
        self.decoder = DecoderMLP(
            latent_dim=self.latent_dim,
            observation_dim=self.input_dim,
            inter_dim=self.inter_dim,
            activation=activation,
            layers_dim=None, # list of layers dimensions, without the input dimension, without the output dimension
        )
        
        self.sampler = Sampler()
        
    def forward(self, x_t):
        # """Forward pass of the Deep Kalman Filter.
        # Runs one step inference :
        # 0- Initialization are run (sampled latent variable)
        # 1- The input sequence x_t (seq_len, batch, input_dimension) is passed through the backward LSTM 
        #    to get the hidden states h_t (seq_len, batch, hidden_dim).
        # 2- A sequential loop is run from time t=1 to t=T (seq_len):
        #     2.1- the sampled latent variable at previous time step z_t-1, and the hidden state h_t, are run
        #          through the combiner module to get the tensor g_t.
        #     2.2- the tensor g_t is passed through the encoder module to get the parameters of the approximate posterior 
        #          distribution mu_phi and logvar_phi of the latent variable z_t.
        #     2.3- the  latent variable z_t at time t is sampled from the approximate posterior distribution
        #          using the reparameterization trick. The sampled latent variable z_t is stored in the sequence of
        #          sampled latent variables z_t_s.
        # 3- The whole sequence of sampled latent variables z_t_s is passed through the decoder module
        #    to get the parameters of the distribution of the observed variables x_t.
        # 4- The whole sequence of sampled latent variables z_t_s, lagged by one time step, is passed through the
        #    transition module to get the parameters of the transition distribution of the latent variable z_t. 
        
        # Args:
        #     x_t: input sequence - shape (seq_len, batch, input_dim)
            
        # Intermediate variables:
        #     sampled_z_t : sequence of sampled latent variables - shape (seq_len, batch, latent_dim).
        #     NB : z_0 is set to 0.
        #     h_t : hidden state of the backward LSTM at time t - shape (seq_len, batch, hidden_dim)
            
        # Returns:
        #     mu_x_t: means of the distribution of the observed variables - shape (seq_len, batch, input_dim)
        #     logvar_x_t: log of the variances of the distribution of the observed variables - shape (seq_len, batch, input_dim)
        #     mu_phi_z_t: means of the approximate posterior distribution (q_\phi) of the latent variable - shape (seq_len, batch, latent_dim)
        #     logvar_phi_z_t: log of the variances of the approximate posterior distribution (q_\phi) of the latent variable - shape (seq_len, batch, latent_dim)
        #     mu_theta_z_t: means of the transition distribution (p_\theta_z) of the latent variable - shape (seq_len, batch, latent_dim)
        #     logvar_theta_z_t: log of the variances of the transition distribution (p_\theta_z) of the latent variable - shape (seq_len, batch, latent_dim)
        # """
        
        # we assume that the input sequence is of shape (seq_len, batch, input_dim) and check some
        seq_len, batch_size, input_dim = x_t.shape
        assert input_dim == self.input_dim, f"Input dimension {input_dim} does not match the expected dimension {self.input_dim}"
        
        # initializations of the tensors for the sequential loop
                # NB : in INRIA code : self.register_buffer
                # "If you have parameters in your model, which should be saved and restored in the state_dict, 
                # but not trained by the optimizer, you should register them as buffers.
                # Buffers won’t be returned in model.parameters(), 
                # so that the optimizer won’t have a change to update them.#
        sampled_z_t = torch.zeros(seq_len, batch_size, self.latent_dim).to(self.device)
        z0 = torch.zeros(batch_size, self.latent_dim).to(self.device)  # initial latent variable z_0
        mu_phi_z_t = torch.zeros(seq_len, batch_size, self.latent_dim).to(self.device)
        logvar_phi_z_t = torch.zeros(seq_len, batch_size, self.latent_dim).to(self.device)
        
        # step 1 : run the backward LSTM on the input sequence
        # outputs are the hidden states, shape (seq_len, batch, hidden_dim)
        h_t = self.backward_lstm(x_t)
        
        # step 2 : loop from t=1 to t=T (seq_len) to compute and sampled the latent variables z_t
        for t in range(seq_len):
            
            # step 2.1 : at time t, get the sampled latent variable z_t-1 and the hidden state h_t
            if t == 0:
                sampled_z_t_1 = z0
            else:
                sampled_z_t_1 = sampled_z_t[t-1]
            # combine them to compute g_t
            g_t = self.combiner(h_t[t], sampled_z_t_1) # shpae is (batch_size, combiner_dim)
            
            # step 2.2 : compute the parameters of the approximate posterior distribution
            mu_phi, logvar_phi = self.encoder(g_t) 
            mu_phi_z_t[t], logvar_phi_z_t[t] = mu_phi, logvar_phi
            
            # step 2.3 : sample z_t from the approximate posterior distribution and store it
            sampled_z_t[t] = self.sampler(mu_phi, logvar_phi)
            
        # step 3 : compute the parameters of the observation distribution
        mu_x_t, logvar_x_t = self.decoder(sampled_z_t)
        
        # step 4 : compute the parameters of the transition distribution
        # form the lagged sampled latent variable z_t : z_t[0:seq_len-1]
        lagged_sampled_z_t = torch.cat([z0.unsqueeze(0), sampled_z_t[:-1]])
        mu_theta_z_t, logvar_theta_z_t = self.latent_space_transition(lagged_sampled_z_t) 
                        
        # return the outputs
        return x_t, mu_x_t, logvar_x_t, mu_phi_z_t, logvar_phi_z_t, mu_theta_z_t, logvar_theta_z_t
    
    def __repr__(self):
        
        msg = f"DeepKalmanFilter(input_dim={self.input_dim}, latent_dim={self.latent_dim}, hidden_dim={self.hidden_dim}, combiner_dim={self.combiner_dim}, inter_dim={self.inter_dim})"
        msg += f"\n{self.backward_lstm}"
        msg += f"\n{self.combiner}"
        msg += f"\n{self.encoder}"
        msg += f"\n{self.latent_space_transition}"
        msg += f"\n{self.decoder}"
        msg += f"\n{self.sampler}"
        
        return msg
    
    def predict(self, x, num_steps):
        """
        Predicts future steps based on the input sequence.

        Args:
            x_t (torch.Tensor): Input tensor of shape (seq_len, batch_size, x_dim).
            num_steps (int): Number of future steps to predict.

        Returns:
            mu_predictions (torch.Tensor): Tensor of shape (num_steps, batch_size, x_dim)
            containing the means of the predicted observations at future steps.
            logvar_predictions (torch.Tensor): Tensor of shape (num_steps, batch_size, x_dim)
            containing the log variances of the predicted observations at future steps.
            
            mu_full_x (torch.Tensor): Tensor of shape (seq_len + num_steps, batch_size, x_dim)
            containing the reconstructed input sequence and the means of the predicted future steps.
            logvar_full_x (torch.Tensor): Tensor of shape (seq_len + num_steps, batch_size, x_dim)
            containing the log variances of the reconstructed input sequence and the predicted future steps.
        """
        
        with torch.no_grad():
            
            # get hyperparameters
            seq_len, batch_size, input_dim = x.shape
            assert input_dim == self.input_dim, f"Input dimension {input_dim} does not match the expected dimension {self.input_dim}"
            
            # run an inference forward pass to get the parameters of the observation distribution,
            # the approximate posterior distribution of the latent variable,
            # and the transition distribution of the latent variable            
            x_t, mu_x_t, logvar_x_t, mu_phi_z_t, logvar_phi_z_t, mu_theta_z_t, logvar_theta_z_t = self.forward(x)
            
            
            # use mu_x_t as the first known values of reconstructed x
            x_hat = mu_x_t
            
            # Then, start with the last inferred latent state
            z_pred = mu_phi_z_t[-1:, :, :]

            # Start to predict x at the end of the given sequence
            mu_predictions = torch.zeros(num_steps, batch_size, self.input_dim).to(self.device)
            logvar_predictions = torch.zeros(num_steps, batch_size, self.input_dim).to(self.device)
            
            for s in range(num_steps):
                # Get the parameters (mean and variance) of the transition
                # distribution p(z_t|z_{t-1})
                z_pred_mean, z_pred_logvar = self.latent_space_transition(z_pred)

                # Sample from p(z_t|z_{t-1}) distribution
                z_pred = self.sampler(z_pred_mean, z_pred_logvar)
                
                # get the parameters of the predicted observation distribution
                mu_x_pred, logvar_x_pred = self.decoder(z_pred)
                
                # store those parameters
                mu_predictions[s,:,:] = mu_x_pred
                logvar_predictions[s,:,:] = logvar_x_pred

        # Append predictions to the reconstructed x
        mu_full_x = torch.cat([x_hat, mu_predictions], dim=0)
        logvar_full_x = torch.cat([logvar_x_t, logvar_predictions], dim=0)
        
        return mu_predictions, logvar_predictions, mu_full_x, logvar_full_x

# %% [markdown]
# # Loss function

# %%
def loss_function(x_t, mu_x_t, logvar_x_t, mu_phi_z_t, logvar_phi_z_t, mu_theta_z_t, logvar_theta_z_t, beta=None):
    # """
    # Version 2.0 of the loss function for the Deep Kalman Filter.
    # All distributions parameters are assumed to have been computed from K samples of each z_t.
    # The K samples are used to compute the expectations within the loss function.

    # Args:
    #     x_t (tensor): the original input sequence - shape (seq_len, batch_size, x_dim)

    #     mu_x_t (tensor): the mean of the distribution of the observed variable - shape (seq_len, batch_size, x_dim, K)
    #     logvar_x_t (tensor): the log of the variance of the distribution of the observed variable - shape (seq_len, batch_size, x_dim, K)
    #     mu_phi_z_t (tensor): the mean of the approximate posterior distribution (q_\phi) of the latent variable - shape (seq_len, batch_size, z_dim, K)
    #     logvar_phi_z_t (tensor): the log of the variance of the approximate posterior distribution (q_\phi) of the latent variable - shape (seq_len, batch_size, z_dim, K)
    #     mu_theta_z_t (tensor): the mean of the transition distribution (p_\theta_z) of the latent variable - shape (seq_len, batch_size, z_dim, K)
    #     logvar_theta_z_t (tensor): the log of the variance of the transition distribution (p_\theta_z) of the latent variable - shape (seq_len, batch_size, z_dim, K)

    #     beta (float, optional): the weight of the KL divergence term in the loss function. Defaults to None.
        
    # Returns:
    #     rec_loss (tensor): the reconstruction loss - shape (1,)
    #     kl_loss (tensor): the KL divergence loss - shape (1,)
    #     total_loss (tensor): the total loss - shape (1,)
    # """
    
    seq_len, batch_size, x_dim = x_t.shape
    
    # choose beta
    if beta is None:
        beta = 1.0
        
    # check whether there is a K dimension or not, add K=1 if none given
    if mu_x_t.dim() == 3:
        K = 1
        mu_x_t = mu_x_t.unsqueeze(-1)
        logvar_x_t = logvar_x_t.unsqueeze(-1)
        mu_phi_z_t = mu_phi_z_t.unsqueeze(-1)
        logvar_phi_z_t = logvar_phi_z_t.unsqueeze(-1)
        mu_theta_z_t = mu_theta_z_t.unsqueeze(-1)
        logvar_theta_z_t = logvar_theta_z_t.unsqueeze(-1)
    else:
        K = mu_x_t.shape[-1]
        
    z_dim = mu_phi_z_t.shape[-2]
        
    # compute the expectation of the reconstruction loss with K samples
    
    x_t_extended = x_t.unsqueeze(-1)  # (seq_len, batch_size, x_dim, K)
    var_x = logvar_x_t.exp() # (seq_len, batch_size, x_dim, K)
    
    rec_loss = torch.div((x_t_extended - mu_x_t)**2, var_x)  # (seq_len, batch_size, x_dim, K) - x_t_extended is broadcasted along last axis
    rec_loss += logvar_x_t # (seq_len, batch_size, x_dim, K)
    
    rec_loss = torch.mean(rec_loss, dim=3)  # Mean over the K samples - (seq_len, batch_size, x_dim)
    rec_loss = torch.sum(rec_loss, dim=2)  # Sum over the x_dim - (seq_len, batch_size)
    rec_loss += x_dim * torch.log(2 * torch.tensor(torch.pi))  # (seq_len, batch_size) - pour normaliser
    rec_loss = torch.sum(rec_loss, dim=0)  # Sum over the sequence length - (batch_size)
    rec_loss = torch.mean(rec_loss)  # Mean over the batch - ()
    
    rec_loss = 1/2 * (rec_loss / seq_len)
    
    # compute the expectation of the KL divergence loss with K samples
    
    kl_loss = logvar_theta_z_t - logvar_phi_z_t  # (seq_len, batch_size, z_dim, K)
    kl_loss += torch.div(logvar_phi_z_t.exp(), logvar_theta_z_t.exp()) # (seq_len, batch_size, z_dim, K)
    kl_loss += torch.div((mu_theta_z_t - mu_phi_z_t).pow(2), logvar_theta_z_t.exp())
       
    kl_loss = torch.mean(kl_loss, dim=3)  # Mean over the K samples - (seq_len, batch_size, z_dim)
    kl_loss = torch.sum(kl_loss, dim=2)  # Sum over the z_dim - (seq_len, batch_size)
    kl_loss -= z_dim # shape (seq_len, batch_size), normalisation
    kl_loss = torch.sum(kl_loss, dim=0)  # Sum over the sequence length - (batch_size)
    kl_loss = torch.mean(kl_loss)  # Mean over the batch
    
    kl_loss = 1/2 * kl_loss / seq_len
    
    return rec_loss, kl_loss, rec_loss + beta * kl_loss

# %% [markdown]
# # Toy Case : Data Generation for Time Series Forecasting

# %%
n_steps = 50
n_ahead = 20
n_series = 10000

def generate_time_series(batch_size, n_steps, noise=0.05):
    """Utility function to generate time series data.

    Args:
        batch_size (int): number of time series to generate (btach size)
        n_steps (_type_): length of each time series
    """
    
    f1,f2,o1,o2 = np.random.rand(4, batch_size, 1)  # return 4 values for each time series
    time = np.linspace(0, 1, n_steps)  # time vector
    
    series = 0.8 * np.sin((time - o1) * (f1 * 40 + 10)) # first sine wave
    series += 0.2 * np.sin((time - o1) * (f1 * 20 + 20)) # second sine wave
    series += noise * (np.random.randn(batch_size, n_steps) - 0.5)  # add noise
    
    return series

# %%
s = generate_time_series(n_series, n_steps+n_ahead)

# %%
N = 3
fig, axs = plt.subplots(N, 1, figsize=(16, 3 * N))
for i in range(N):
    axs[i].plot(s[i], color='blue', marker="x", linewidth=1)
    axs[i].set_title(f"Time series {i+1}")
    axs[i].set_xlabel("Time")
    axs[i].set_ylabel("Value")
    axs[i].grid(True)
plt.tight_layout()
plt.show()

# %%
cutoff = int(0.8 * n_series)

X_train, y_train = s[:cutoff,:n_steps], s[:cutoff,n_steps:]
X_valid, y_valid = s[cutoff:,:n_steps], s[cutoff:,n_steps:]

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_valid shape: {X_valid.shape}")
print(f"y_valid shape: {y_valid.shape}")
# Out:
# X_train shape: (8000, 50)
# y_train shape: (8000, 20)
# X_valid shape: (2000, 50)
# y_valid shape: (2000, 20)

# %%
# form datasets, dataloaders, etc

BATCH_SIZE = 4096   # 8192 ok sur RTX3080 et 150 time steps

from torch.utils.data import Dataset, DataLoader

class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X).to(device)
        self.y = torch.tensor(y).to(device)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]
    
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_valid, y_valid)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# # Baseline : RNN

# %%
class RNNModelLookAhead(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim, n_ahead=n_ahead, num_layers=1, batch_first=True, device=device, dtype=dtype):
        """Constructor for RNN.

        Args:
            input_dim (_type_): dimensionality of the input
            hidden_dim (_type_): dimensionality of the hidden state
            n_ahead (_type_, optional): number of time steps to predict. Defaults to N_AHEAD.
            output_dim (_type_, optional): dimensionality of the output.
            num_layers (int, optional): number of recurrent layers. Defaults to 1.
            batch_first (bool, optional): whether batch dim is first or not. Defaults to True.
                1. batch_first=True: (batch, seq, feature_dimension)
                2. batch_first=False: (seq, batch, feature_dimension)
            bidirectional (bool, optional): if True, becomes a bidriectional RNN. Defaults to False.
                1. bidirectional=True: num_directions=2, (batch, seq, hidden_dim * 2)
                2. bidirectional=False: num_directions=1, (batch, seq, hidden_dim)
            device (_type_, optional): _description_. Defaults to device.
            dtype (_type_, optional): _description_. Defaults to dtype.
        """
        super(RNNModelLookAhead, self).__init__()
        
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.batch_first = batch_first
        self.bidirectional = False
        self.n_ahead = n_ahead
        
        self.rnn = nn.RNN(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=batch_first,
            bidirectional=self.bidirectional
        )
        self.fc = nn.Linear(hidden_dim, n_ahead*output_dim)
    
    def forward(self, x):
        # first, initialize the hidden state
        h0 = torch.zeros((self.num_layers, x.size(0), self.hidden_dim), requires_grad=True).to(device)
        # INPUT : x : (batch, sequence_length, input_feature_dimension)
        x, _ = self.rnn(x, h0) 
        # OUTPUT: 
        # - output : (batch, sequence_length, hidden_dimension * num_directions)
        # - h_n : (num_layers * num_directions, batch, hidden_dimension) (hidden state for last time step)
        x = self.fc(x[:, -1, :])  # take the last time step
        x = x.view(-1, self.n_ahead, self.output_dim)
        # OUTPUT: x : (batch, output_dimension)
        return x

# %%
rnn = RNNModelLookAhead(
    input_dim=1,
    output_dim=1,
    n_ahead=n_ahead,
    hidden_dim=128,
    num_layers=4,
    batch_first=True,
    device=device,
    dtype=dtype
).to(device)

print(rnn)
# Out:
# RNNModelLookAhead(
#   (rnn): RNN(1, 128, num_layers=4, batch_first=True)
#   (fc): Linear(in_features=128, out_features=20, bias=True)
# )

# %%
# Test dimensions

x = torch.randn(BATCH_SIZE, 50, 1).to(device)
y = rnn(x)
print(f"input shape: {x.shape}")
print(f"output shape: {y.shape}")
# Out:
# input shape: torch.Size([4096, 50, 1])
# output shape: torch.Size([4096, 20, 1])

# %%
def loss_rnn(y, y_hat):
    """
    Compute the loss for the RNN model.
    
    Args:
        y: target values - shape is (seq_len, batch_size, output_dim)
        y_hat: predicted values - shape is (seq_len, batch_size, output_dim)
    Returns:
        loss: MSE loss
    """
    
    seq_len = y.shape[0]
    batch_size = y.shape[1]
    output_dim = y.shape[2]
    
    # compute the loss
    loss = (y - y_hat)**2
    # print(loss.shape)
    loss = torch.sum(loss, dim=2)  # Sum over the output dimension
    loss = torch.sum(loss, dim=0)  # Sum over the sequence length
    loss = torch.sqrt(loss)  # Square root of the sum
    loss = torch.mean(loss)  # Mean over the batch
    loss = loss / seq_len
    
    return loss

criterion = nn.MSELoss()
# criterion = loss_rnn

# %%
lr = 1e-4
optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)
num_epochs = 200

# %%
train_losses = []
valid_losses = []

print(f"Start training RNN model for {num_epochs} epochs")

for i in range(num_epochs):
    # loop on training data
    rnn.train()
    optimizer.zero_grad()
    ### loop on training data
    epoch_loss = 0
    for input, target in train_loader:
        input = input.to(device).unsqueeze(-1)  # add a feature dimension
        # print(f"input has shape {input.shape}")
        target = target.to(device).view(-1, n_ahead, 1)
        # print(f"target has shape {target.shape}")
        output = rnn(input)
        # print(F"output has shape {output.shape}")
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    epoch_loss /= len(train_loader) 
    train_losses.append(epoch_loss)
    
    # test step
    rnn.eval()
    epoch_loss = 0
    with torch.no_grad():
        for input, target in test_loader:
            input = input.to(device).unsqueeze(-1)  # add a feature dimension
            target = target.to(device).view(-1, n_ahead, 1)
            output = rnn(input)
            loss = criterion(output, target)
            epoch_loss += loss.item()
    epoch_loss /= len(test_loader)
    valid_losses.append(epoch_loss)
    
    # report out
    if (i+1) % 10 == 0:
        print(f"epoch {i+1:>4}/{num_epochs}, training loss = {train_losses[-1]:.4e}, validation loss = {valid_losses[-1]:.4e}")
# Out:
# Start training RNN model for 200 epochs
# epoch   10/200, training loss = 3.7589e-01, validation loss = 3.7372e-01
# epoch   20/200, training loss = 3.4898e-01, validation loss = 3.4510e-01
# epoch   30/200, training loss = 3.1186e-01, validation loss = 3.2140e-01
# epoch   40/200, training loss = 3.0169e-01, validation loss = 3.0300e-01
# epoch   50/200, training loss = 2.8480e-01, validation loss = 2.8099e-01
# epoch   60/200, training loss = 2.6715e-01, validation loss = 2.7021e-01
# epoch   70/200, training loss = 2.5109e-01, validation loss = 2.5599e-01
# epoch   80/200, training loss = 2.4441e-01, validation loss = 2.3696e-01
# epoch   90/200, training loss = 2.2975e-01, validation loss = 2.3311e-01
# epoch  100/200, training loss = 2.0643e-01, validation loss = 1.9792e-01
# epoch  110/200, training loss = 1.7036e-01, validation loss = 1.7171e-01
# epoch  120/200, training loss = 1.4655e-01, validation loss = 1.5259e-01
# epoch  130/200, training loss = 1.4173e-01, validation loss = 1.3445e-01
# epoch  140/200, training loss = 1.2482e-01, validation loss = 1.2695e-01
# epoch  150/200, training loss = 1.1490e-01, validation loss = 1.0736e-01
# epoch  160/200, training loss = 1.1241e-01, validation loss = 1.0274e-01
# epoch  170/200, training loss = 1.0345e-01, validation loss = 1.0677e-01
# epoch  180/200, training loss = 8.9087e-02, validation loss = 9.8208e-02
# epoch  190/200, training loss = 8.6826e-02, validation loss = 8.2624e-02
# epoch  200/200, training loss = 8.8798e-02, validation loss = 8.7277e-02

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 3))
ax.plot(train_losses, label="train")
ax.plot(valid_losses, label="valid")
ax.legend()
ax.set_xlabel("Epoch")
ax.set_xticks(np.arange(0, num_epochs+1, 10))
ax.set_xticklabels(np.arange(0, num_epochs+1, 10))
ax.set_ylabel("Loss")
ax.set_title("Training and Validation Loss")
ax.grid()
plt.show()

# %%
y_pred = rnn(torch.tensor(X_valid).to(device).unsqueeze(-1))
y_target = torch.tensor(y_valid).to(device).unsqueeze(-1)

# print(f"y_target shape: {y_target.shape}")
# print(f"y_pred shape: {y_pred.shape}")

print(f"Loss finale = {criterion(y_pred, y_target):.4e}")

y_pred = y_pred.cpu().detach().numpy()
y_target = y_target.cpu().detach().numpy()

# print(f"\n{np.mean(np.sqrt((y_target - y_pred) ** 2)):.4f} RMSE")
# Out:
# Loss finale = 8.7277e-02

# %%
N = 5
fig, ax  = plt.subplots(N, 1, figsize=(14, 2 * N))
x_shift = X_valid.shape[-1]

for i in range(N):
    input = torch.tensor(X_valid[i], device=device).unsqueeze(0).unsqueeze(-1)
    # input = input.permute(1, 0, 2)  # permute to (seq_len, batch_size, input_dim)
    # print(f"input has shape {input.shape}")
    target = torch.tensor(y_valid[i], device=device).view(-1, n_ahead, 1)
    # target = target.permute(1, 0, 2)  # permute to (seq_len, batch_size, output_dim)
    # print(f"target has shape {target.shape}")
    output = rnn(input)
    output = output.cpu().detach().numpy()
    # print(f"output has shape {output.shape}")
    target = target.cpu().detach().numpy()
    
    ax[i].plot(input.squeeze().cpu().detach().numpy(), color='blue', marker="x", linewidth=1, label="input")
    ax[i].plot(np.arange(len(target.squeeze()))+x_shift, target.squeeze(), color='red', marker="o", linewidth=1, label="ground truth")
    ax[i].plot(np.arange(len(target.squeeze()))+x_shift, output.squeeze(), color='green', marker="*", linewidth=1, label="prediction")
    ax[i].set_title(f"Time series {i+1}")
    ax[i].set_xlabel("Time")
    ax[i].set_ylabel("Value")
    ax[i].legend()
    ax[i].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Training DKF - XP 1
#
# https://www.youtube.com/watch?v=rz76gYgxySo&list=WL&index=1&t=1618s&ab_channel=SimonLeglaive

# %% [markdown]
# <div>
# <img src="/home/benjamin.deporte/MVA/MVA_Stage/DKF_Training.png" width="1500"/>
# </div>

# %%
def train_step(model, optimizer, criterion, train_loader=train_loader, device=device, beta=None, K=None):
    ### training step
    model.train()
    optimizer.zero_grad()
    ### loop on training data
    rec_loss = 0
    kl_loss = 0
    epoch_loss = 0
    ### check on K
    if K is None:
        K=1
        
    x_dim = model.input_dim
    latent_dim = model.latent_dim
    
    for input, _ in train_loader:
        input = input.to(device).unsqueeze(-1)  # add a feature dimension
        input = input.permute(1, 0, 2)  # permute to (seq_len, batch_size, input_dim)

        
        mu_x_t = torch.zeros(input.shape[0], input.shape[1], x_dim, K).to(device)
        logvar_x_t = torch.zeros(input.shape[0], input.shape[1], x_dim, K).to(device)
        mu_phi_z_t = torch.zeros(input.shape[0], input.shape[1], latent_dim, K).to(device)
        logvar_phi_z_t = torch.zeros(input.shape[0], input.shape[1], latent_dim, K).to(device)
        mu_theta_z_t = torch.zeros(input.shape[0], input.shape[1], latent_dim, K).to(device)
        logvar_theta_z_t = torch.zeros(input.shape[0], input.shape[1], latent_dim, K).to(device)

        # get K samples of the parameters of each distribution
        for k in range(K):
            # get the parameters of the distributions
            _, mu_x_t[:, :, :, k], logvar_x_t[:, :, :, k], mu_phi_z_t[:, :, :, k], logvar_phi_z_t[:, :, :, k], mu_theta_z_t[:, :, :, k], logvar_theta_z_t[:, :, :, k] = model(input)
        
        rec_loss, kl_loss, total_loss = criterion(input, mu_x_t, logvar_x_t, mu_phi_z_t, logvar_phi_z_t, mu_theta_z_t, logvar_theta_z_t, beta=beta)
        
        total_loss.backward()
        optimizer.step()
              
        rec_loss += rec_loss.item()
        kl_loss += kl_loss.item()
        epoch_loss += total_loss.item()
        
    epoch_loss /= len(train_loader)
    rec_loss /= len(train_loader)
    kl_loss /= len(train_loader)
    
    return rec_loss, kl_loss, epoch_loss

# %%
# Test step : perform validation test for one epoch

def test_step(model, optimizer, loss_fn, test_loader=test_loader, device=device, beta=None):
    ### test step
    model.eval()
    
    with torch.no_grad():
        ### loop on test data
        rec_loss = 0
        kl_loss = 0
        epoch_loss = 0
        
        for input, _ in test_loader:
            input = input.to(device).unsqueeze(-1)  # add a feature dimension
            input = input.permute(1, 0, 2)  # permute to (seq_len, batch_size, input_dim)

            _, mu_x_s, logvar_x_s, mu_z_s, logvar_z_s, mu_z_transition_s, logvar_z_transition_s = model(input)
            
            rec_loss, kl_loss, total_loss = loss_fn(input, mu_x_s, logvar_x_s, mu_z_s, logvar_z_s, mu_z_transition_s, logvar_z_transition_s, beta=beta)
                
            rec_loss += rec_loss.item()
            kl_loss += kl_loss.item()
            epoch_loss += total_loss.item()
            
        epoch_loss /= len(train_loader)
        rec_loss /= len(train_loader)
        kl_loss /= len(train_loader)
    
    return rec_loss, kl_loss, epoch_loss

# %%
def train(model, optimizer, loss_fn, num_epochs=100, beta=None, beta_scheduler=None, display_frequency=10, K=None):
    
    rec_losses = []
    kl_losses = []
    epoch_losses = []

    val_rec_losses = []
    val_kl_losses = []
    val_epoch_losses = []
    
    if K is None:
        K = 1
        
    print(f"Starting training...")
    if device.type == 'cuda':
        print('GPU Name:', torch.cuda.get_device_name(0))
        print('Total GPU Memory:', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
    print(f"Number of epochs: {num_epochs}")
    print(f"Learning rate: {optimizer.param_groups[0]['lr']:.3e}")
    print(f"Batch size: {BATCH_SIZE}")
    print(f"Beta : {beta:.3e}")
    print(f"K = {K}")
    print(f"Training set size: {len(train_loader.dataset)}")
    print(f"Validation set size: {len(test_loader.dataset)}")
    print(f"Device: {device}")
    print(f"\n")

    for i in range(num_epochs):
        
        # use the beat scheduler if provided
        if beta_scheduler is not None:
            beta = beta_scheduler(i)
        
        # run the training step
        rec_loss, kl_loss, epoch_loss = train_step(model, optimizer, loss_fn, beta=beta, K=K)
        # log results
        rec_losses.append(rec_loss)
        kl_losses.append(kl_loss)
        epoch_losses.append(epoch_loss)
        
        # run test step
        val_rec_loss, val_kl_loss, val_epoch_loss = test_step(model, optimizer, loss_fn, beta=beta)
        # log results
        val_rec_losses.append(val_rec_loss)
        val_kl_losses.append(val_kl_loss)
        val_epoch_losses.append(val_epoch_loss)
        
        # Print the losses for this epoch
        if (i+1) % display_frequency == 0:
            print(f"Epoch {i+1:>5}/{num_epochs} with beta = {beta:.2e} - TRAINING : Rec Loss: {rec_loss:.4e}, KL Loss: {kl_loss:.4e}, Total Loss: {epoch_loss:.4e} - TEST : Rec Loss: {val_rec_loss:.4e}, KL Loss: {val_kl_loss:.4e}, Total Loss: {val_epoch_loss:.4e}")
            
    return rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses

# %%
xdim = 1
latent_dim = 2
h_dim = 16
combiner_dim = 2
num_layers_rnn = 2

# %%
dkf = DeepKalmanFilter(
    input_dim = xdim,
    latent_dim = latent_dim,
    hidden_dim = h_dim,
    combiner_dim = combiner_dim,
    num_layers = num_layers_rnn,
    device=device
).to(device)

print(dkf)
# Out:
# DeepKalmanFilter(input_dim=1, latent_dim=2, hidden_dim=16, combiner_dim=2, inter_dim=16)
# BackwardLSTM(
#   (lstm): LSTM(1, 16, num_layers=2)
# )
# CombinerMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=18, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# EncoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# LatentSpaceTransitionMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# DecoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Sampler()

# %%
optimizer = torch.optim.Adam(dkf.parameters(), lr=1e-3)
loss_fn = loss_function
beta = 1e-3

K = 3

# %%
num_epochs = 450
n_displays = 45
display_frequency = int(num_epochs / n_displays)

# %%
rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses = train(
    dkf, optimizer, loss_fn, num_epochs=num_epochs, beta=beta, display_frequency=display_frequency, K=K
)
# Out:
# Starting training...
# GPU Name: NVIDIA GeForce RTX 4090
# Total GPU Memory: 23.6 GB
# Number of epochs: 450
# Learning rate: 1.000e-03
# Batch size: 4096
# Beta : 1.000e-03
# K = 3
# Training set size: 8000
# Validation set size: 2000
# Device: cuda
#
#
# Epoch    10/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 1.1513e+00, KL Loss: 1.8751e-01, Total Loss: 1.1545e+00 - TEST : Rec Loss: 1.1480e+00, KL Loss: 1.9444e-01, Total Loss: 5.7412e-01
# Epoch    20/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 1.0430e+00, KL Loss: 4.5448e-01, Total Loss: 1.0461e+00 - TEST : Rec Loss: 1.0414e+00, KL Loss: 4.7078e-01, Total Loss: 5.2093e-01
# Epoch    30/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.7275e-01, KL Loss: 7.5433e-01, Total Loss: 9.7433e-01 - TEST : Rec Loss: 9.7499e-01, KL Loss: 7.6712e-01, Total Loss: 4.8788e-01
# Epoch    40/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5675e-01, KL Loss: 8.5838e-01, Total Loss: 9.5887e-01 - TEST : Rec Loss: 9.6274e-01, KL Loss: 8.5545e-01, Total Loss: 4.8180e-01
# Epoch    50/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5373e-01, KL Loss: 7.8532e-01, Total Loss: 9.5490e-01 - TEST : Rec Loss: 9.5886e-01, KL Loss: 7.8294e-01, Total Loss: 4.7982e-01
# Epoch    60/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5226e-01, KL Loss: 7.3601e-01, Total Loss: 9.5324e-01 - TEST : Rec Loss: 9.5720e-01, KL Loss: 7.3282e-01, Total Loss: 4.7897e-01
# Epoch    70/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5070e-01, KL Loss: 6.5041e-01, Total Loss: 9.5215e-01 - TEST : Rec Loss: 9.5632e-01, KL Loss: 6.4465e-01, Total Loss: 4.7848e-01
# Epoch    80/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4969e-01, KL Loss: 5.1880e-01, Total Loss: 9.5142e-01 - TEST : Rec Loss: 9.5601e-01, KL Loss: 5.1123e-01, Total Loss: 4.7826e-01
# Epoch    90/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5052e-01, KL Loss: 3.6628e-01, Total Loss: 9.5091e-01 - TEST : Rec Loss: 9.5572e-01, KL Loss: 3.5879e-01, Total Loss: 4.7804e-01
# Epoch   100/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5070e-01, KL Loss: 2.2762e-01, Total Loss: 9.5047e-01 - TEST : Rec Loss: 9.5514e-01, KL Loss: 2.2162e-01, Total Loss: 4.7768e-01
# Epoch   110/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5186e-01, KL Loss: 1.3598e-01, Total Loss: 9.5016e-01 - TEST : Rec Loss: 9.5499e-01, KL Loss: 1.3252e-01, Total Loss: 4.7756e-01
# Epoch   120/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4930e-01, KL Loss: 8.7887e-02, Total Loss: 9.4991e-01 - TEST : Rec Loss: 9.5484e-01, KL Loss: 8.6135e-02, Total Loss: 4.7746e-01
# Epoch   130/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5002e-01, KL Loss: 6.5305e-02, Total Loss: 9.4978e-01 - TEST : Rec Loss: 9.5480e-01, KL Loss: 6.4630e-02, Total Loss: 4.7743e-01
# Epoch   140/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4912e-01, KL Loss: 5.5940e-02, Total Loss: 9.4967e-01 - TEST : Rec Loss: 9.5454e-01, KL Loss: 5.5641e-02, Total Loss: 4.7730e-01
# Epoch   150/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4924e-01, KL Loss: 5.2245e-02, Total Loss: 9.4957e-01 - TEST : Rec Loss: 9.5454e-01, KL Loss: 5.2185e-02, Total Loss: 4.7730e-01
# Epoch   160/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4940e-01, KL Loss: 5.0332e-02, Total Loss: 9.4949e-01 - TEST : Rec Loss: 9.5438e-01, KL Loss: 5.0331e-02, Total Loss: 4.7722e-01
# Epoch   170/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4953e-01, KL Loss: 4.8866e-02, Total Loss: 9.4947e-01 - TEST : Rec Loss: 9.5442e-01, KL Loss: 4.8763e-02, Total Loss: 4.7724e-01
# Epoch   180/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4830e-01, KL Loss: 4.7492e-02, Total Loss: 9.4937e-01 - TEST : Rec Loss: 9.5429e-01, KL Loss: 4.7406e-02, Total Loss: 4.7717e-01
# Epoch   190/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4995e-01, KL Loss: 4.6282e-02, Total Loss: 9.4935e-01 - TEST : Rec Loss: 9.5428e-01, KL Loss: 4.6206e-02, Total Loss: 4.7716e-01
# Epoch   200/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4921e-01, KL Loss: 4.5089e-02, Total Loss: 9.4929e-01 - TEST : Rec Loss: 9.5419e-01, KL Loss: 4.5075e-02, Total Loss: 4.7712e-01
# Epoch   210/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5029e-01, KL Loss: 4.4084e-02, Total Loss: 9.4931e-01 - TEST : Rec Loss: 9.5423e-01, KL Loss: 4.3994e-02, Total Loss: 4.7714e-01
# Epoch   220/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4851e-01, KL Loss: 4.3102e-02, Total Loss: 9.4924e-01 - TEST : Rec Loss: 9.5426e-01, KL Loss: 4.3044e-02, Total Loss: 4.7715e-01
# Epoch   230/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5082e-01, KL Loss: 4.2173e-02, Total Loss: 9.4926e-01 - TEST : Rec Loss: 9.5420e-01, KL Loss: 4.2109e-02, Total Loss: 4.7712e-01
# Epoch   240/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4829e-01, KL Loss: 4.1321e-02, Total Loss: 9.4917e-01 - TEST : Rec Loss: 9.5420e-01, KL Loss: 4.1247e-02, Total Loss: 4.7712e-01
# Epoch   250/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4852e-01, KL Loss: 4.0485e-02, Total Loss: 9.4915e-01 - TEST : Rec Loss: 9.5414e-01, KL Loss: 4.0443e-02, Total Loss: 4.7709e-01
# Epoch   260/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5020e-01, KL Loss: 3.9732e-02, Total Loss: 9.4916e-01 - TEST : Rec Loss: 9.5421e-01, KL Loss: 3.9739e-02, Total Loss: 4.7713e-01
# Epoch   270/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4703e-01, KL Loss: 3.9045e-02, Total Loss: 9.4908e-01 - TEST : Rec Loss: 9.5406e-01, KL Loss: 3.9010e-02, Total Loss: 4.7705e-01
# Epoch   280/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4811e-01, KL Loss: 3.8401e-02, Total Loss: 9.4911e-01 - TEST : Rec Loss: 9.5411e-01, KL Loss: 3.8372e-02, Total Loss: 4.7707e-01
# Epoch   290/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4812e-01, KL Loss: 3.7785e-02, Total Loss: 9.4908e-01 - TEST : Rec Loss: 9.5410e-01, KL Loss: 3.7750e-02, Total Loss: 4.7707e-01
# Epoch   300/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5044e-01, KL Loss: 3.7202e-02, Total Loss: 9.4915e-01 - TEST : Rec Loss: 9.5409e-01, KL Loss: 3.7191e-02, Total Loss: 4.7706e-01
# Epoch   310/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4896e-01, KL Loss: 3.6633e-02, Total Loss: 9.4908e-01 - TEST : Rec Loss: 9.5406e-01, KL Loss: 3.6598e-02, Total Loss: 4.7705e-01
# Epoch   320/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4746e-01, KL Loss: 3.6090e-02, Total Loss: 9.4904e-01 - TEST : Rec Loss: 9.5409e-01, KL Loss: 3.6075e-02, Total Loss: 4.7706e-01
# Epoch   330/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4902e-01, KL Loss: 3.5580e-02, Total Loss: 9.4908e-01 - TEST : Rec Loss: 9.5405e-01, KL Loss: 3.5567e-02, Total Loss: 4.7704e-01
# Epoch   340/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4870e-01, KL Loss: 3.5066e-02, Total Loss: 9.4906e-01 - TEST : Rec Loss: 9.5407e-01, KL Loss: 3.5051e-02, Total Loss: 4.7705e-01
# Epoch   350/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4740e-01, KL Loss: 3.4565e-02, Total Loss: 9.4902e-01 - TEST : Rec Loss: 9.5405e-01, KL Loss: 3.4519e-02, Total Loss: 4.7704e-01
# Epoch   360/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4932e-01, KL Loss: 3.4104e-02, Total Loss: 9.4905e-01 - TEST : Rec Loss: 9.5401e-01, KL Loss: 3.4126e-02, Total Loss: 4.7702e-01
# Epoch   370/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.5037e-01, KL Loss: 3.3703e-02, Total Loss: 9.4906e-01 - TEST : Rec Loss: 9.5402e-01, KL Loss: 3.3715e-02, Total Loss: 4.7703e-01
# Epoch   380/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4881e-01, KL Loss: 3.3538e-02, Total Loss: 9.4900e-01 - TEST : Rec Loss: 9.5398e-01, KL Loss: 3.3605e-02, Total Loss: 4.7701e-01
# Epoch   390/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 9.4891e-01, KL Loss: 3.5653e-02, Total Loss: 9.4884e-01 - TEST : Rec Loss: 9.5377e-01, KL Loss: 3.6377e-02, Total Loss: 4.7690e-01
# Epoch   400/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 8.8929e-01, KL Loss: 2.5764e+00, Total Loss: 8.9741e-01 - TEST : Rec Loss: 8.7455e-01, KL Loss: 2.4230e+00, Total Loss: 4.3849e-01
# Epoch   410/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 4.5880e-01, KL Loss: 1.3983e+00, Total Loss: 4.6651e-01 - TEST : Rec Loss: 4.2046e-01, KL Loss: 1.4683e+00, Total Loss: 2.1096e-01
# Epoch   420/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -1.1186e-01, KL Loss: 2.1923e+00, Total Loss: -7.2456e-02 - TEST : Rec Loss: -1.2023e-01, KL Loss: 2.2149e+00, Total Loss: -5.9008e-02
# Epoch   430/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -4.0221e-01, KL Loss: 2.6687e+00, Total Loss: -2.6740e-01 - TEST : Rec Loss: -4.8749e-01, KL Loss: 2.6417e+00, Total Loss: -2.4242e-01
# Epoch   440/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -2.9276e-01, KL Loss: 3.1781e+00, Total Loss: -3.9365e-01 - TEST : Rec Loss: -2.7790e-01, KL Loss: 3.2189e+00, Total Loss: -1.3734e-01
# Epoch   450/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -5.4877e-01, KL Loss: 3.3363e+00, Total Loss: -5.0355e-01 - TEST : Rec Loss: -7.1667e-01, KL Loss: 3.3717e+00, Total Loss: -3.5665e-01

# %%
def plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses):
    
    # Plot the losses

    fig, axs = plt.subplots(1, 3, figsize=(16, 4))

    axs[0].plot(torch.tensor(rec_losses).cpu().detach(), label='Training', color='blue')
    axs[0].plot(torch.tensor(val_rec_losses).cpu().detach(), label='Test', color='green')
    axs[0].set_title('Reconstruction Loss')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].legend()
    axs[0].grid()

    axs[1].plot(torch.tensor(kl_losses).cpu().detach(), label='Training', color='blue')
    axs[1].plot(torch.tensor(val_kl_losses).cpu().detach(), label='Test', color='green')
    axs[1].set_title('KL Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    axs[1].grid()

    axs[2].plot(torch.tensor(epoch_losses).cpu().detach(), label='Training', color='blue')
    axs[2].plot(torch.tensor(val_epoch_losses).cpu().detach(), label='Test', color='green')
    axs[2].set_title('Total Loss')
    axs[2].set_xlabel('Epochs')
    axs[2].set_ylabel('Loss')
    axs[2].legend()
    axs[2].grid()

    plt.tight_layout()
    plt.show()

# %%
plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses)

# %% [markdown]
# # Predictions

# %%
def sample_predictions(N_SAMPLES=3, model=dkf):
    
    idx = np.random.randint(0, len(X_valid), N_SAMPLES)
    X_valid_subset = X_valid[idx]
    y_valid_subset = y_valid[idx]
    
    fig, axs = plt.subplots(N_SAMPLES, 1, figsize=(16, 3 * N_SAMPLES))
    for i in range(N_SAMPLES):
        input = torch.tensor(X_valid_subset[i], device=device).unsqueeze(1).unsqueeze(2)
        # print(f"input shape : {input.shape}")
        target = torch.tensor(y_valid_subset[i], device=device)
        target = target.cpu().detach().numpy()
        mu_predictions, logvar_predictions, mu_full_x, logvar_full_x = model.predict(input, n_ahead)
              
        # display data
        axs[i].plot(input.squeeze().cpu().detach().numpy(), color='blue', marker="x", linewidth=1, label="input")
        axs[i].plot(np.arange(len(target))+n_steps, target, color='red', marker="o", linewidth=1, label="ground truth")
        
        # display predictions and credible intervals
        all_times = np.arange(n_steps+n_ahead)
        mu_full_x = mu_full_x.squeeze().cpu().detach().numpy()
        logvar_full_x = logvar_full_x.squeeze().cpu().detach().numpy()
        std_full_x = np.exp(logvar_full_x / 2)
        
        axs[i].scatter(all_times, mu_full_x, color='green', marker="*", linewidth=1, label="reconstructed and predicted")
        axs[i].fill_between(all_times, mu_full_x-2*std_full_x, mu_full_x+2*std_full_x, color='orange', label='+/- 2 std', alpha=0.2)
        
        axs[i].set_title(f"Time series {idx[i]}")
        axs[i].set_xlabel("Time")
        axs[i].set_ylabel("Value")
        axs[i].legend()
        axs[i].grid(True)
        
    plt.tight_layout()
    plt.show()

# %%
sample_predictions(N_SAMPLES=5, model=dkf)

# %% [markdown]
# # XP 2
#
# $\beta = 1.0$

# %%
xdim = 1
latent_dim = 2
h_dim = 16
combiner_dim = 2
num_layers_rnn = 2

# %%
dkf = DeepKalmanFilter(
    input_dim = xdim,
    latent_dim = latent_dim,
    hidden_dim = h_dim,
    combiner_dim = combiner_dim,
    num_layers = num_layers_rnn,
    device=device
).to(device)

print(dkf)
# Out:
# DeepKalmanFilter(input_dim=1, latent_dim=2, hidden_dim=16, combiner_dim=2, inter_dim=16)
# BackwardLSTM(
#   (lstm): LSTM(1, 16, num_layers=2)
# )
# CombinerMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=18, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# EncoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# LatentSpaceTransitionMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# DecoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Sampler()

# %%
optimizer = torch.optim.Adam(dkf.parameters(), lr=1e-4)
loss_fn = loss_function
beta = 1.0

K = 3

# %%
num_epochs = 1000
n_displays = 50
display_frequency = int(num_epochs / n_displays)

# %%
rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses = train(
    dkf, optimizer, loss_fn, num_epochs=num_epochs, beta=beta, display_frequency=display_frequency, K=K
)
# Out:
# Starting training...
# GPU Name: NVIDIA GeForce RTX 4090
# Total GPU Memory: 23.6 GB
# Number of epochs: 1000
# Learning rate: 1.000e-04
# Batch size: 4096
# Beta : 1.000e+00
# K = 3
# Training set size: 8000
# Validation set size: 2000
# Device: cuda
#
#
# Epoch    20/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.1016e+00, KL Loss: 1.0085e-01, Total Loss: 1.2037e+00 - TEST : Rec Loss: 1.1037e+00, KL Loss: 9.9824e-02, Total Loss: 6.0177e-01
# Epoch    40/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0878e+00, KL Loss: 6.2655e-02, Total Loss: 1.1518e+00 - TEST : Rec Loss: 1.0909e+00, KL Loss: 6.1955e-02, Total Loss: 5.7642e-01
# Epoch    60/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0766e+00, KL Loss: 4.0243e-02, Total Loss: 1.1170e+00 - TEST : Rec Loss: 1.0791e+00, KL Loss: 3.9899e-02, Total Loss: 5.5948e-01
# Epoch    80/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0648e+00, KL Loss: 2.7271e-02, Total Loss: 1.0928e+00 - TEST : Rec Loss: 1.0682e+00, KL Loss: 2.7185e-02, Total Loss: 5.4769e-01
# Epoch   100/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0557e+00, KL Loss: 1.9608e-02, Total Loss: 1.0752e+00 - TEST : Rec Loss: 1.0588e+00, KL Loss: 1.9448e-02, Total Loss: 5.3911e-01
# Epoch   120/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0466e+00, KL Loss: 1.4937e-02, Total Loss: 1.0616e+00 - TEST : Rec Loss: 1.0497e+00, KL Loss: 1.4829e-02, Total Loss: 5.3225e-01
# Epoch   140/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0387e+00, KL Loss: 1.1839e-02, Total Loss: 1.0503e+00 - TEST : Rec Loss: 1.0408e+00, KL Loss: 1.1753e-02, Total Loss: 5.2629e-01
# Epoch   160/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0325e+00, KL Loss: 9.5706e-03, Total Loss: 1.0411e+00 - TEST : Rec Loss: 1.0342e+00, KL Loss: 9.4948e-03, Total Loss: 5.2184e-01
# Epoch   180/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0249e+00, KL Loss: 7.8025e-03, Total Loss: 1.0323e+00 - TEST : Rec Loss: 1.0276e+00, KL Loss: 7.7995e-03, Total Loss: 5.1771e-01
# Epoch   200/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0168e+00, KL Loss: 6.4186e-03, Total Loss: 1.0248e+00 - TEST : Rec Loss: 1.0217e+00, KL Loss: 6.3561e-03, Total Loss: 5.1401e-01
# Epoch   220/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0119e+00, KL Loss: 5.3202e-03, Total Loss: 1.0181e+00 - TEST : Rec Loss: 1.0156e+00, KL Loss: 5.2847e-03, Total Loss: 5.1043e-01
# Epoch   240/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0071e+00, KL Loss: 4.4426e-03, Total Loss: 1.0119e+00 - TEST : Rec Loss: 1.0108e+00, KL Loss: 4.4291e-03, Total Loss: 5.0759e-01
# Epoch   260/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0020e+00, KL Loss: 3.7663e-03, Total Loss: 1.0063e+00 - TEST : Rec Loss: 1.0062e+00, KL Loss: 3.7634e-03, Total Loss: 5.0496e-01
# Epoch   280/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.9856e-01, KL Loss: 3.2761e-03, Total Loss: 1.0012e+00 - TEST : Rec Loss: 1.0011e+00, KL Loss: 3.2527e-03, Total Loss: 5.0218e-01
# Epoch   300/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.9386e-01, KL Loss: 2.8883e-03, Total Loss: 9.9666e-01 - TEST : Rec Loss: 9.9727e-01, KL Loss: 2.8746e-03, Total Loss: 5.0007e-01
# Epoch   320/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.8865e-01, KL Loss: 2.6115e-03, Total Loss: 9.9242e-01 - TEST : Rec Loss: 9.9320e-01, KL Loss: 2.6134e-03, Total Loss: 4.9791e-01
# Epoch   340/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.8726e-01, KL Loss: 2.4081e-03, Total Loss: 9.8870e-01 - TEST : Rec Loss: 9.8967e-01, KL Loss: 2.3916e-03, Total Loss: 4.9603e-01
# Epoch   360/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.8346e-01, KL Loss: 2.2497e-03, Total Loss: 9.8521e-01 - TEST : Rec Loss: 9.8692e-01, KL Loss: 2.2283e-03, Total Loss: 4.9457e-01
# Epoch   380/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.8061e-01, KL Loss: 2.1411e-03, Total Loss: 9.8204e-01 - TEST : Rec Loss: 9.8363e-01, KL Loss: 2.1233e-03, Total Loss: 4.9288e-01
# Epoch   400/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.7708e-01, KL Loss: 2.0380e-03, Total Loss: 9.7898e-01 - TEST : Rec Loss: 9.8078e-01, KL Loss: 2.0213e-03, Total Loss: 4.9140e-01
# Epoch   420/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.7558e-01, KL Loss: 1.9644e-03, Total Loss: 9.7655e-01 - TEST : Rec Loss: 9.7882e-01, KL Loss: 1.9502e-03, Total Loss: 4.9039e-01
# Epoch   440/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.7049e-01, KL Loss: 1.9043e-03, Total Loss: 9.7390e-01 - TEST : Rec Loss: 9.7636e-01, KL Loss: 1.9015e-03, Total Loss: 4.8913e-01
# Epoch   460/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.7014e-01, KL Loss: 1.8513e-03, Total Loss: 9.7192e-01 - TEST : Rec Loss: 9.7409e-01, KL Loss: 1.8636e-03, Total Loss: 4.8797e-01
# Epoch   480/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6751e-01, KL Loss: 1.8158e-03, Total Loss: 9.6992e-01 - TEST : Rec Loss: 9.7219e-01, KL Loss: 1.8172e-03, Total Loss: 4.8700e-01
# Epoch   500/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6559e-01, KL Loss: 1.7817e-03, Total Loss: 9.6804e-01 - TEST : Rec Loss: 9.7085e-01, KL Loss: 1.7897e-03, Total Loss: 4.8632e-01
# Epoch   520/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6436e-01, KL Loss: 1.7440e-03, Total Loss: 9.6627e-01 - TEST : Rec Loss: 9.6877e-01, KL Loss: 1.7297e-03, Total Loss: 4.8525e-01
# Epoch   540/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6394e-01, KL Loss: 1.7140e-03, Total Loss: 9.6477e-01 - TEST : Rec Loss: 9.6760e-01, KL Loss: 1.7078e-03, Total Loss: 4.8465e-01
# Epoch   560/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6004e-01, KL Loss: 1.6930e-03, Total Loss: 9.6338e-01 - TEST : Rec Loss: 9.6587e-01, KL Loss: 1.6813e-03, Total Loss: 4.8378e-01
# Epoch   580/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6227e-01, KL Loss: 1.6719e-03, Total Loss: 9.6204e-01 - TEST : Rec Loss: 9.6510e-01, KL Loss: 1.6776e-03, Total Loss: 4.8339e-01
# Epoch   600/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5991e-01, KL Loss: 1.6414e-03, Total Loss: 9.6098e-01 - TEST : Rec Loss: 9.6394e-01, KL Loss: 1.6619e-03, Total Loss: 4.8280e-01
# Epoch   620/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5809e-01, KL Loss: 1.6258e-03, Total Loss: 9.5996e-01 - TEST : Rec Loss: 9.6289e-01, KL Loss: 1.6130e-03, Total Loss: 4.8225e-01
# Epoch   640/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5701e-01, KL Loss: 1.6104e-03, Total Loss: 9.5889e-01 - TEST : Rec Loss: 9.6177e-01, KL Loss: 1.5965e-03, Total Loss: 4.8169e-01
# Epoch   660/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5663e-01, KL Loss: 1.5859e-03, Total Loss: 9.5793e-01 - TEST : Rec Loss: 9.6101e-01, KL Loss: 1.6016e-03, Total Loss: 4.8131e-01
# Epoch   680/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5572e-01, KL Loss: 1.5708e-03, Total Loss: 9.5711e-01 - TEST : Rec Loss: 9.6035e-01, KL Loss: 1.5760e-03, Total Loss: 4.8096e-01
# Epoch   700/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5462e-01, KL Loss: 1.5631e-03, Total Loss: 9.5643e-01 - TEST : Rec Loss: 9.5944e-01, KL Loss: 1.5668e-03, Total Loss: 4.8050e-01
# Epoch   720/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5277e-01, KL Loss: 1.5452e-03, Total Loss: 9.5572e-01 - TEST : Rec Loss: 9.5914e-01, KL Loss: 1.5602e-03, Total Loss: 4.8035e-01
# Epoch   740/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5383e-01, KL Loss: 1.5406e-03, Total Loss: 9.5518e-01 - TEST : Rec Loss: 9.5800e-01, KL Loss: 1.5201e-03, Total Loss: 4.7976e-01
# Epoch   760/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5275e-01, KL Loss: 1.5383e-03, Total Loss: 9.5449e-01 - TEST : Rec Loss: 9.5764e-01, KL Loss: 1.5292e-03, Total Loss: 4.7958e-01
# Epoch   780/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5294e-01, KL Loss: 1.5305e-03, Total Loss: 9.5406e-01 - TEST : Rec Loss: 9.5752e-01, KL Loss: 1.5467e-03, Total Loss: 4.7953e-01
# Epoch   800/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5153e-01, KL Loss: 1.5190e-03, Total Loss: 9.5355e-01 - TEST : Rec Loss: 9.5683e-01, KL Loss: 1.5321e-03, Total Loss: 4.7918e-01
# Epoch   820/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5181e-01, KL Loss: 1.5131e-03, Total Loss: 9.5320e-01 - TEST : Rec Loss: 9.5655e-01, KL Loss: 1.5344e-03, Total Loss: 4.7904e-01
# Epoch   840/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5043e-01, KL Loss: 1.5079e-03, Total Loss: 9.5287e-01 - TEST : Rec Loss: 9.5612e-01, KL Loss: 1.5158e-03, Total Loss: 4.7882e-01
# Epoch   860/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4970e-01, KL Loss: 1.4957e-03, Total Loss: 9.5250e-01 - TEST : Rec Loss: 9.5584e-01, KL Loss: 1.4956e-03, Total Loss: 4.7867e-01
# Epoch   880/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5048e-01, KL Loss: 1.4725e-03, Total Loss: 9.5227e-01 - TEST : Rec Loss: 9.5550e-01, KL Loss: 1.4746e-03, Total Loss: 4.7849e-01
# Epoch   900/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5106e-01, KL Loss: 1.4691e-03, Total Loss: 9.5196e-01 - TEST : Rec Loss: 9.5530e-01, KL Loss: 1.4774e-03, Total Loss: 4.7839e-01
# Epoch   920/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5213e-01, KL Loss: 1.4507e-03, Total Loss: 9.5173e-01 - TEST : Rec Loss: 9.5520e-01, KL Loss: 1.4480e-03, Total Loss: 4.7833e-01
# Epoch   940/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5038e-01, KL Loss: 1.4386e-03, Total Loss: 9.5153e-01 - TEST : Rec Loss: 9.5489e-01, KL Loss: 1.4364e-03, Total Loss: 4.7816e-01
# Epoch   960/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5007e-01, KL Loss: 1.4214e-03, Total Loss: 9.5136e-01 - TEST : Rec Loss: 9.5492e-01, KL Loss: 1.4297e-03, Total Loss: 4.7818e-01
# Epoch   980/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5029e-01, KL Loss: 1.3943e-03, Total Loss: 9.5106e-01 - TEST : Rec Loss: 9.5455e-01, KL Loss: 1.3952e-03, Total Loss: 4.7797e-01
# Epoch  1000/1000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4922e-01, KL Loss: 1.3686e-03, Total Loss: 9.5092e-01 - TEST : Rec Loss: 9.5450e-01, KL Loss: 1.3692e-03, Total Loss: 4.7793e-01

# %%
plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses)

# %%
sample_predictions(N_SAMPLES=5, model=dkf)

# %% [markdown]
# # XP 3
#
# Réseau plus expressif, $\beta = 1.0$, K=10

# %%
xdim = 1
latent_dim = 8
h_dim = 32
combiner_dim = 4
num_layers_rnn = 4

# %%
dkf = DeepKalmanFilter(
    input_dim = xdim,
    latent_dim = latent_dim,
    hidden_dim = h_dim,
    combiner_dim = combiner_dim,
    num_layers = num_layers_rnn,
    device=device
).to(device)

print(dkf)
# Out:
# DeepKalmanFilter(input_dim=1, latent_dim=8, hidden_dim=32, combiner_dim=4, inter_dim=16)
# BackwardLSTM(
#   (lstm): LSTM(1, 32, num_layers=4)
# )
# CombinerMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=40, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# EncoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=4, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=16, bias=True)
#   )
# )
# LatentSpaceTransitionMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#   )
# )
# DecoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Sampler()

# %%
optimizer = torch.optim.Adam(dkf.parameters(), lr=1e-3)
loss_fn = loss_function
beta = 1.0

K = 10

# %%
num_epochs = 400
n_displays = 200
display_frequency = int(num_epochs / n_displays)

# %%
rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses = train(
    dkf, optimizer, loss_fn, num_epochs=num_epochs, beta=beta, display_frequency=display_frequency, K=K
)
# Out:
# Starting training...
# GPU Name: NVIDIA GeForce RTX 4090
# Total GPU Memory: 23.6 GB
# Number of epochs: 400
# Learning rate: 1.000e-03
# Batch size: 4096
# Beta : 1.000e+00
# K = 10
# Training set size: 8000
# Validation set size: 2000
# Device: cuda
#
#
# Epoch     2/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.1091e+00, KL Loss: 5.6926e-01, Total Loss: 1.6936e+00 - TEST : Rec Loss: 1.1077e+00, KL Loss: 5.4242e-01, Total Loss: 8.2508e-01
# Epoch     4/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0978e+00, KL Loss: 4.6931e-01, Total Loss: 1.5797e+00 - TEST : Rec Loss: 1.0966e+00, KL Loss: 4.4857e-01, Total Loss: 7.7257e-01
# Epoch     6/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0868e+00, KL Loss: 3.9217e-01, Total Loss: 1.4899e+00 - TEST : Rec Loss: 1.0874e+00, KL Loss: 3.7587e-01, Total Loss: 7.3164e-01
# Epoch     8/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0792e+00, KL Loss: 3.3084e-01, Total Loss: 1.4176e+00 - TEST : Rec Loss: 1.0793e+00, KL Loss: 3.1811e-01, Total Loss: 6.9870e-01
# Epoch    10/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0701e+00, KL Loss: 2.8020e-01, Total Loss: 1.3572e+00 - TEST : Rec Loss: 1.0707e+00, KL Loss: 2.6835e-01, Total Loss: 6.6952e-01
# Epoch    12/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0616e+00, KL Loss: 2.3779e-01, Total Loss: 1.3061e+00 - TEST : Rec Loss: 1.0628e+00, KL Loss: 2.2855e-01, Total Loss: 6.4568e-01
# Epoch    14/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0551e+00, KL Loss: 2.0308e-01, Total Loss: 1.2631e+00 - TEST : Rec Loss: 1.0556e+00, KL Loss: 1.9555e-01, Total Loss: 6.2558e-01
# Epoch    16/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0474e+00, KL Loss: 1.7411e-01, Total Loss: 1.2263e+00 - TEST : Rec Loss: 1.0491e+00, KL Loss: 1.6735e-01, Total Loss: 6.0823e-01
# Epoch    18/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0406e+00, KL Loss: 1.4934e-01, Total Loss: 1.1942e+00 - TEST : Rec Loss: 1.0426e+00, KL Loss: 1.4375e-01, Total Loss: 5.9316e-01
# Epoch    20/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0357e+00, KL Loss: 1.2816e-01, Total Loss: 1.1663e+00 - TEST : Rec Loss: 1.0361e+00, KL Loss: 1.2319e-01, Total Loss: 5.7964e-01
# Epoch    22/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0289e+00, KL Loss: 1.0987e-01, Total Loss: 1.1416e+00 - TEST : Rec Loss: 1.0302e+00, KL Loss: 1.0558e-01, Total Loss: 5.6789e-01
# Epoch    24/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0229e+00, KL Loss: 9.3980e-02, Total Loss: 1.1197e+00 - TEST : Rec Loss: 1.0247e+00, KL Loss: 8.9988e-02, Total Loss: 5.5733e-01
# Epoch    26/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0181e+00, KL Loss: 8.0483e-02, Total Loss: 1.1005e+00 - TEST : Rec Loss: 1.0191e+00, KL Loss: 7.7554e-02, Total Loss: 5.4833e-01
# Epoch    28/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0128e+00, KL Loss: 6.9011e-02, Total Loss: 1.0836e+00 - TEST : Rec Loss: 1.0144e+00, KL Loss: 6.6368e-02, Total Loss: 5.4037e-01
# Epoch    30/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0071e+00, KL Loss: 5.9361e-02, Total Loss: 1.0688e+00 - TEST : Rec Loss: 1.0095e+00, KL Loss: 5.7399e-02, Total Loss: 5.3346e-01
# Epoch    32/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0027e+00, KL Loss: 5.1327e-02, Total Loss: 1.0558e+00 - TEST : Rec Loss: 1.0049e+00, KL Loss: 4.9486e-02, Total Loss: 5.2718e-01
# Epoch    34/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.9761e-01, KL Loss: 4.4574e-02, Total Loss: 1.0443e+00 - TEST : Rec Loss: 1.0005e+00, KL Loss: 4.3002e-02, Total Loss: 5.2175e-01
# Epoch    36/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.9338e-01, KL Loss: 3.8958e-02, Total Loss: 1.0343e+00 - TEST : Rec Loss: 9.9616e-01, KL Loss: 3.7592e-02, Total Loss: 5.1688e-01
# Epoch    38/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.9003e-01, KL Loss: 3.4127e-02, Total Loss: 1.0254e+00 - TEST : Rec Loss: 9.9267e-01, KL Loss: 3.2987e-02, Total Loss: 5.1283e-01
# Epoch    40/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.8675e-01, KL Loss: 3.0181e-02, Total Loss: 1.0176e+00 - TEST : Rec Loss: 9.8889e-01, KL Loss: 2.9244e-02, Total Loss: 5.0907e-01
# Epoch    42/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.8258e-01, KL Loss: 2.6783e-02, Total Loss: 1.0106e+00 - TEST : Rec Loss: 9.8552e-01, KL Loss: 2.6019e-02, Total Loss: 5.0577e-01
# Epoch    44/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.7941e-01, KL Loss: 2.3948e-02, Total Loss: 1.0044e+00 - TEST : Rec Loss: 9.8226e-01, KL Loss: 2.3331e-02, Total Loss: 5.0280e-01
# Epoch    46/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.7620e-01, KL Loss: 2.1492e-02, Total Loss: 9.9886e-01 - TEST : Rec Loss: 9.7960e-01, KL Loss: 2.0951e-02, Total Loss: 5.0028e-01
# Epoch    48/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.7291e-01, KL Loss: 1.9412e-02, Total Loss: 9.9402e-01 - TEST : Rec Loss: 9.7698e-01, KL Loss: 1.8905e-02, Total Loss: 4.9794e-01
# Epoch    50/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.7020e-01, KL Loss: 1.7625e-02, Total Loss: 9.8960e-01 - TEST : Rec Loss: 9.7490e-01, KL Loss: 1.7181e-02, Total Loss: 4.9604e-01
# Epoch    52/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6915e-01, KL Loss: 1.6060e-02, Total Loss: 9.8575e-01 - TEST : Rec Loss: 9.7224e-01, KL Loss: 1.5682e-02, Total Loss: 4.9396e-01
# Epoch    54/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6676e-01, KL Loss: 1.4744e-02, Total Loss: 9.8219e-01 - TEST : Rec Loss: 9.7044e-01, KL Loss: 1.4469e-02, Total Loss: 4.9246e-01
# Epoch    56/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6502e-01, KL Loss: 1.3547e-02, Total Loss: 9.7903e-01 - TEST : Rec Loss: 9.6827e-01, KL Loss: 1.3277e-02, Total Loss: 4.9077e-01
# Epoch    58/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6355e-01, KL Loss: 1.2533e-02, Total Loss: 9.7619e-01 - TEST : Rec Loss: 9.6697e-01, KL Loss: 1.2314e-02, Total Loss: 4.8964e-01
# Epoch    60/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.6167e-01, KL Loss: 1.1658e-02, Total Loss: 9.7371e-01 - TEST : Rec Loss: 9.6557e-01, KL Loss: 1.1465e-02, Total Loss: 4.8852e-01
# Epoch    62/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5927e-01, KL Loss: 1.0854e-02, Total Loss: 9.7139e-01 - TEST : Rec Loss: 9.6414e-01, KL Loss: 1.0639e-02, Total Loss: 4.8739e-01
# Epoch    64/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5706e-01, KL Loss: 1.0185e-02, Total Loss: 9.6928e-01 - TEST : Rec Loss: 9.6272e-01, KL Loss: 9.9896e-03, Total Loss: 4.8636e-01
# Epoch    66/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5790e-01, KL Loss: 9.5507e-03, Total Loss: 9.6757e-01 - TEST : Rec Loss: 9.6190e-01, KL Loss: 9.4013e-03, Total Loss: 4.8565e-01
# Epoch    68/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5705e-01, KL Loss: 9.0097e-03, Total Loss: 9.6595e-01 - TEST : Rec Loss: 9.6097e-01, KL Loss: 8.9184e-03, Total Loss: 4.8494e-01
# Epoch    70/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5649e-01, KL Loss: 8.5427e-03, Total Loss: 9.6451e-01 - TEST : Rec Loss: 9.5963e-01, KL Loss: 8.3959e-03, Total Loss: 4.8401e-01
# Epoch    72/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5731e-01, KL Loss: 8.0858e-03, Total Loss: 9.6331e-01 - TEST : Rec Loss: 9.5904e-01, KL Loss: 7.9665e-03, Total Loss: 4.8350e-01
# Epoch    74/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5347e-01, KL Loss: 7.7264e-03, Total Loss: 9.6206e-01 - TEST : Rec Loss: 9.5879e-01, KL Loss: 7.6622e-03, Total Loss: 4.8322e-01
# Epoch    76/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5402e-01, KL Loss: 7.3440e-03, Total Loss: 9.6110e-01 - TEST : Rec Loss: 9.5829e-01, KL Loss: 7.2804e-03, Total Loss: 4.8279e-01
# Epoch    78/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5253e-01, KL Loss: 7.0289e-03, Total Loss: 9.6012e-01 - TEST : Rec Loss: 9.5755e-01, KL Loss: 6.9464e-03, Total Loss: 4.8225e-01
# Epoch    80/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5397e-01, KL Loss: 6.7391e-03, Total Loss: 9.5942e-01 - TEST : Rec Loss: 9.5713e-01, KL Loss: 6.6418e-03, Total Loss: 4.8188e-01
# Epoch    82/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5241e-01, KL Loss: 6.4795e-03, Total Loss: 9.5876e-01 - TEST : Rec Loss: 9.5641e-01, KL Loss: 6.4173e-03, Total Loss: 4.8142e-01
# Epoch    84/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5186e-01, KL Loss: 6.2522e-03, Total Loss: 9.5812e-01 - TEST : Rec Loss: 9.5651e-01, KL Loss: 6.1927e-03, Total Loss: 4.8135e-01
# Epoch    86/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5185e-01, KL Loss: 6.0099e-03, Total Loss: 9.5759e-01 - TEST : Rec Loss: 9.5636e-01, KL Loss: 5.9434e-03, Total Loss: 4.8115e-01
# Epoch    88/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5139e-01, KL Loss: 5.8048e-03, Total Loss: 9.5715e-01 - TEST : Rec Loss: 9.5594e-01, KL Loss: 5.7505e-03, Total Loss: 4.8085e-01
# Epoch    90/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4998e-01, KL Loss: 5.6391e-03, Total Loss: 9.5673e-01 - TEST : Rec Loss: 9.5589e-01, KL Loss: 5.5799e-03, Total Loss: 4.8074e-01
# Epoch    92/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4975e-01, KL Loss: 5.4740e-03, Total Loss: 9.5640e-01 - TEST : Rec Loss: 9.5576e-01, KL Loss: 5.4323e-03, Total Loss: 4.8059e-01
# Epoch    94/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5135e-01, KL Loss: 5.3045e-03, Total Loss: 9.5615e-01 - TEST : Rec Loss: 9.5554e-01, KL Loss: 5.2913e-03, Total Loss: 4.8041e-01
# Epoch    96/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4987e-01, KL Loss: 5.1457e-03, Total Loss: 9.5582e-01 - TEST : Rec Loss: 9.5554e-01, KL Loss: 5.0850e-03, Total Loss: 4.8031e-01
# Epoch    98/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4890e-01, KL Loss: 5.0201e-03, Total Loss: 9.5563e-01 - TEST : Rec Loss: 9.5524e-01, KL Loss: 4.9932e-03, Total Loss: 4.8012e-01
# Epoch   100/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4912e-01, KL Loss: 4.9109e-03, Total Loss: 9.5542e-01 - TEST : Rec Loss: 9.5527e-01, KL Loss: 4.8632e-03, Total Loss: 4.8006e-01
# Epoch   102/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5135e-01, KL Loss: 4.7760e-03, Total Loss: 9.5528e-01 - TEST : Rec Loss: 9.5567e-01, KL Loss: 4.7804e-03, Total Loss: 4.8023e-01
# Epoch   104/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5231e-01, KL Loss: 4.6446e-03, Total Loss: 9.5511e-01 - TEST : Rec Loss: 9.5519e-01, KL Loss: 4.6292e-03, Total Loss: 4.7991e-01
# Epoch   106/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5078e-01, KL Loss: 4.5520e-03, Total Loss: 9.5500e-01 - TEST : Rec Loss: 9.5543e-01, KL Loss: 4.5394e-03, Total Loss: 4.7998e-01
# Epoch   108/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5072e-01, KL Loss: 4.4821e-03, Total Loss: 9.5483e-01 - TEST : Rec Loss: 9.5536e-01, KL Loss: 4.4438e-03, Total Loss: 4.7990e-01
# Epoch   110/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4919e-01, KL Loss: 4.3682e-03, Total Loss: 9.5462e-01 - TEST : Rec Loss: 9.5523e-01, KL Loss: 4.3807e-03, Total Loss: 4.7980e-01
# Epoch   112/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4933e-01, KL Loss: 4.2533e-03, Total Loss: 9.5451e-01 - TEST : Rec Loss: 9.5513e-01, KL Loss: 4.2426e-03, Total Loss: 4.7968e-01
# Epoch   114/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5017e-01, KL Loss: 4.1858e-03, Total Loss: 9.5450e-01 - TEST : Rec Loss: 9.5539e-01, KL Loss: 4.1406e-03, Total Loss: 4.7976e-01
# Epoch   116/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5161e-01, KL Loss: 4.1389e-03, Total Loss: 9.5440e-01 - TEST : Rec Loss: 9.5520e-01, KL Loss: 4.0787e-03, Total Loss: 4.7964e-01
# Epoch   118/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5087e-01, KL Loss: 4.0390e-03, Total Loss: 9.5426e-01 - TEST : Rec Loss: 9.5541e-01, KL Loss: 4.0087e-03, Total Loss: 4.7971e-01
# Epoch   120/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4970e-01, KL Loss: 3.9329e-03, Total Loss: 9.5413e-01 - TEST : Rec Loss: 9.5516e-01, KL Loss: 3.9311e-03, Total Loss: 4.7955e-01
# Epoch   122/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4959e-01, KL Loss: 3.8907e-03, Total Loss: 9.5408e-01 - TEST : Rec Loss: 9.5497e-01, KL Loss: 3.8513e-03, Total Loss: 4.7941e-01
# Epoch   124/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4940e-01, KL Loss: 3.8497e-03, Total Loss: 9.5399e-01 - TEST : Rec Loss: 9.5520e-01, KL Loss: 3.8292e-03, Total Loss: 4.7951e-01
# Epoch   126/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4895e-01, KL Loss: 3.7477e-03, Total Loss: 9.5383e-01 - TEST : Rec Loss: 9.5508e-01, KL Loss: 3.7507e-03, Total Loss: 4.7941e-01
# Epoch   128/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4963e-01, KL Loss: 3.6752e-03, Total Loss: 9.5380e-01 - TEST : Rec Loss: 9.5488e-01, KL Loss: 3.6836e-03, Total Loss: 4.7928e-01
# Epoch   130/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4939e-01, KL Loss: 3.6510e-03, Total Loss: 9.5371e-01 - TEST : Rec Loss: 9.5520e-01, KL Loss: 3.5988e-03, Total Loss: 4.7940e-01
# Epoch   132/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4938e-01, KL Loss: 3.5959e-03, Total Loss: 9.5366e-01 - TEST : Rec Loss: 9.5493e-01, KL Loss: 3.6018e-03, Total Loss: 4.7926e-01
# Epoch   134/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4907e-01, KL Loss: 3.5039e-03, Total Loss: 9.5351e-01 - TEST : Rec Loss: 9.5529e-01, KL Loss: 3.5092e-03, Total Loss: 4.7940e-01
# Epoch   136/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5082e-01, KL Loss: 3.4677e-03, Total Loss: 9.5354e-01 - TEST : Rec Loss: 9.5527e-01, KL Loss: 3.4292e-03, Total Loss: 4.7935e-01
# Epoch   138/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4944e-01, KL Loss: 3.4489e-03, Total Loss: 9.5342e-01 - TEST : Rec Loss: 9.5498e-01, KL Loss: 3.4058e-03, Total Loss: 4.7919e-01
# Epoch   140/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5048e-01, KL Loss: 3.3717e-03, Total Loss: 9.5336e-01 - TEST : Rec Loss: 9.5490e-01, KL Loss: 3.3916e-03, Total Loss: 4.7915e-01
# Epoch   142/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4982e-01, KL Loss: 3.2986e-03, Total Loss: 9.5330e-01 - TEST : Rec Loss: 9.5498e-01, KL Loss: 3.3191e-03, Total Loss: 4.7915e-01
# Epoch   144/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5025e-01, KL Loss: 3.2780e-03, Total Loss: 9.5328e-01 - TEST : Rec Loss: 9.5504e-01, KL Loss: 3.2271e-03, Total Loss: 4.7913e-01
# Epoch   146/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4997e-01, KL Loss: 3.2448e-03, Total Loss: 9.5316e-01 - TEST : Rec Loss: 9.5485e-01, KL Loss: 3.2212e-03, Total Loss: 4.7904e-01
# Epoch   148/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5176e-01, KL Loss: 3.1618e-03, Total Loss: 9.5317e-01 - TEST : Rec Loss: 9.5499e-01, KL Loss: 3.1630e-03, Total Loss: 4.7908e-01
# Epoch   150/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5117e-01, KL Loss: 3.1330e-03, Total Loss: 9.5309e-01 - TEST : Rec Loss: 9.5485e-01, KL Loss: 3.1015e-03, Total Loss: 4.7898e-01
# Epoch   152/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5044e-01, KL Loss: 3.1170e-03, Total Loss: 9.5301e-01 - TEST : Rec Loss: 9.5487e-01, KL Loss: 3.1014e-03, Total Loss: 4.7899e-01
# Epoch   154/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5027e-01, KL Loss: 3.0590e-03, Total Loss: 9.5294e-01 - TEST : Rec Loss: 9.5504e-01, KL Loss: 3.0837e-03, Total Loss: 4.7906e-01
# Epoch   156/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4979e-01, KL Loss: 2.9897e-03, Total Loss: 9.5287e-01 - TEST : Rec Loss: 9.5474e-01, KL Loss: 3.0097e-03, Total Loss: 4.7887e-01
# Epoch   158/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4886e-01, KL Loss: 2.9894e-03, Total Loss: 9.5281e-01 - TEST : Rec Loss: 9.5486e-01, KL Loss: 2.9687e-03, Total Loss: 4.7892e-01
# Epoch   160/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4958e-01, KL Loss: 2.9554e-03, Total Loss: 9.5280e-01 - TEST : Rec Loss: 9.5490e-01, KL Loss: 2.9475e-03, Total Loss: 4.7892e-01
# Epoch   162/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5064e-01, KL Loss: 2.8908e-03, Total Loss: 9.5270e-01 - TEST : Rec Loss: 9.5484e-01, KL Loss: 2.9099e-03, Total Loss: 4.7888e-01
# Epoch   164/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5140e-01, KL Loss: 2.8628e-03, Total Loss: 9.5268e-01 - TEST : Rec Loss: 9.5499e-01, KL Loss: 2.8315e-03, Total Loss: 4.7891e-01
# Epoch   166/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4974e-01, KL Loss: 2.8523e-03, Total Loss: 9.5265e-01 - TEST : Rec Loss: 9.5496e-01, KL Loss: 2.8276e-03, Total Loss: 4.7890e-01
# Epoch   168/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5016e-01, KL Loss: 2.8046e-03, Total Loss: 9.5255e-01 - TEST : Rec Loss: 9.5481e-01, KL Loss: 2.8204e-03, Total Loss: 4.7882e-01
# Epoch   170/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5093e-01, KL Loss: 2.7591e-03, Total Loss: 9.5257e-01 - TEST : Rec Loss: 9.5484e-01, KL Loss: 2.7728e-03, Total Loss: 4.7880e-01
# Epoch   172/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4998e-01, KL Loss: 2.7404e-03, Total Loss: 9.5248e-01 - TEST : Rec Loss: 9.5476e-01, KL Loss: 2.7250e-03, Total Loss: 4.7874e-01
# Epoch   174/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4944e-01, KL Loss: 2.7241e-03, Total Loss: 9.5240e-01 - TEST : Rec Loss: 9.5460e-01, KL Loss: 2.7072e-03, Total Loss: 4.7865e-01
# Epoch   176/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4869e-01, KL Loss: 2.6675e-03, Total Loss: 9.5235e-01 - TEST : Rec Loss: 9.5475e-01, KL Loss: 2.6703e-03, Total Loss: 4.7871e-01
# Epoch   178/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4997e-01, KL Loss: 2.6449e-03, Total Loss: 9.5233e-01 - TEST : Rec Loss: 9.5473e-01, KL Loss: 2.6139e-03, Total Loss: 4.7867e-01
# Epoch   180/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4998e-01, KL Loss: 2.6359e-03, Total Loss: 9.5233e-01 - TEST : Rec Loss: 9.5470e-01, KL Loss: 2.6028e-03, Total Loss: 4.7865e-01
# Epoch   182/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4963e-01, KL Loss: 2.5959e-03, Total Loss: 9.5223e-01 - TEST : Rec Loss: 9.5465e-01, KL Loss: 2.5901e-03, Total Loss: 4.7862e-01
# Epoch   184/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4888e-01, KL Loss: 2.5589e-03, Total Loss: 9.5215e-01 - TEST : Rec Loss: 9.5462e-01, KL Loss: 2.5689e-03, Total Loss: 4.7859e-01
# Epoch   186/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4728e-01, KL Loss: 2.5577e-03, Total Loss: 9.5208e-01 - TEST : Rec Loss: 9.5466e-01, KL Loss: 2.5302e-03, Total Loss: 4.7859e-01
# Epoch   188/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4956e-01, KL Loss: 2.5432e-03, Total Loss: 9.5211e-01 - TEST : Rec Loss: 9.5446e-01, KL Loss: 2.5327e-03, Total Loss: 4.7850e-01
# Epoch   190/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4829e-01, KL Loss: 2.5110e-03, Total Loss: 9.5201e-01 - TEST : Rec Loss: 9.5467e-01, KL Loss: 2.4950e-03, Total Loss: 4.7858e-01
# Epoch   192/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4973e-01, KL Loss: 2.4818e-03, Total Loss: 9.5204e-01 - TEST : Rec Loss: 9.5465e-01, KL Loss: 2.4620e-03, Total Loss: 4.7856e-01
# Epoch   194/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5058e-01, KL Loss: 2.4867e-03, Total Loss: 9.5203e-01 - TEST : Rec Loss: 9.5444e-01, KL Loss: 2.4666e-03, Total Loss: 4.7845e-01
# Epoch   196/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4878e-01, KL Loss: 2.4448e-03, Total Loss: 9.5191e-01 - TEST : Rec Loss: 9.5459e-01, KL Loss: 2.4432e-03, Total Loss: 4.7852e-01
# Epoch   198/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5057e-01, KL Loss: 2.3998e-03, Total Loss: 9.5192e-01 - TEST : Rec Loss: 9.5472e-01, KL Loss: 2.3991e-03, Total Loss: 4.7856e-01
# Epoch   200/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5038e-01, KL Loss: 2.4102e-03, Total Loss: 9.5190e-01 - TEST : Rec Loss: 9.5447e-01, KL Loss: 2.4283e-03, Total Loss: 4.7845e-01
# Epoch   202/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4965e-01, KL Loss: 2.3764e-03, Total Loss: 9.5184e-01 - TEST : Rec Loss: 9.5462e-01, KL Loss: 2.3720e-03, Total Loss: 4.7850e-01
# Epoch   204/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5040e-01, KL Loss: 2.3458e-03, Total Loss: 9.5181e-01 - TEST : Rec Loss: 9.5475e-01, KL Loss: 2.3541e-03, Total Loss: 4.7855e-01
# Epoch   206/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5028e-01, KL Loss: 2.3561e-03, Total Loss: 9.5178e-01 - TEST : Rec Loss: 9.5431e-01, KL Loss: 2.3338e-03, Total Loss: 4.7832e-01
# Epoch   208/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4775e-01, KL Loss: 2.2983e-03, Total Loss: 9.5169e-01 - TEST : Rec Loss: 9.5446e-01, KL Loss: 2.3042e-03, Total Loss: 4.7838e-01
# Epoch   210/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4833e-01, KL Loss: 2.2619e-03, Total Loss: 9.5169e-01 - TEST : Rec Loss: 9.5429e-01, KL Loss: 2.2582e-03, Total Loss: 4.7827e-01
# Epoch   212/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4922e-01, KL Loss: 2.2597e-03, Total Loss: 9.5166e-01 - TEST : Rec Loss: 9.5450e-01, KL Loss: 2.2393e-03, Total Loss: 4.7837e-01
# Epoch   214/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4906e-01, KL Loss: 2.2312e-03, Total Loss: 9.5159e-01 - TEST : Rec Loss: 9.5437e-01, KL Loss: 2.2249e-03, Total Loss: 4.7830e-01
# Epoch   216/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4954e-01, KL Loss: 2.2041e-03, Total Loss: 9.5160e-01 - TEST : Rec Loss: 9.5445e-01, KL Loss: 2.2223e-03, Total Loss: 4.7834e-01
# Epoch   218/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5058e-01, KL Loss: 2.1842e-03, Total Loss: 9.5159e-01 - TEST : Rec Loss: 9.5443e-01, KL Loss: 2.1655e-03, Total Loss: 4.7830e-01
# Epoch   220/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4927e-01, KL Loss: 2.1716e-03, Total Loss: 9.5155e-01 - TEST : Rec Loss: 9.5438e-01, KL Loss: 2.1653e-03, Total Loss: 4.7827e-01
# Epoch   222/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5026e-01, KL Loss: 2.1551e-03, Total Loss: 9.5155e-01 - TEST : Rec Loss: 9.5441e-01, KL Loss: 2.1558e-03, Total Loss: 4.7828e-01
# Epoch   224/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4875e-01, KL Loss: 2.1144e-03, Total Loss: 9.5145e-01 - TEST : Rec Loss: 9.5445e-01, KL Loss: 2.1029e-03, Total Loss: 4.7828e-01
# Epoch   226/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5007e-01, KL Loss: 2.1037e-03, Total Loss: 9.5149e-01 - TEST : Rec Loss: 9.5443e-01, KL Loss: 2.0882e-03, Total Loss: 4.7826e-01
# Epoch   228/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4959e-01, KL Loss: 2.0915e-03, Total Loss: 9.5143e-01 - TEST : Rec Loss: 9.5443e-01, KL Loss: 2.0894e-03, Total Loss: 4.7826e-01
# Epoch   230/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4870e-01, KL Loss: 2.0268e-03, Total Loss: 9.5136e-01 - TEST : Rec Loss: 9.5432e-01, KL Loss: 2.0434e-03, Total Loss: 4.7818e-01
# Epoch   232/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4940e-01, KL Loss: 2.0153e-03, Total Loss: 9.5133e-01 - TEST : Rec Loss: 9.5442e-01, KL Loss: 1.9875e-03, Total Loss: 4.7821e-01
# Epoch   234/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4769e-01, KL Loss: 2.0179e-03, Total Loss: 9.5130e-01 - TEST : Rec Loss: 9.5426e-01, KL Loss: 2.0160e-03, Total Loss: 4.7814e-01
# Epoch   236/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4966e-01, KL Loss: 1.9737e-03, Total Loss: 9.5128e-01 - TEST : Rec Loss: 9.5427e-01, KL Loss: 1.9623e-03, Total Loss: 4.7811e-01
# Epoch   238/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4880e-01, KL Loss: 1.9594e-03, Total Loss: 9.5128e-01 - TEST : Rec Loss: 9.5432e-01, KL Loss: 1.9457e-03, Total Loss: 4.7813e-01
# Epoch   240/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4899e-01, KL Loss: 1.9644e-03, Total Loss: 9.5120e-01 - TEST : Rec Loss: 9.5427e-01, KL Loss: 1.9632e-03, Total Loss: 4.7811e-01
# Epoch   242/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5054e-01, KL Loss: 1.9193e-03, Total Loss: 9.5123e-01 - TEST : Rec Loss: 9.5436e-01, KL Loss: 1.9261e-03, Total Loss: 4.7814e-01
# Epoch   244/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4691e-01, KL Loss: 1.8986e-03, Total Loss: 9.5112e-01 - TEST : Rec Loss: 9.5422e-01, KL Loss: 1.8807e-03, Total Loss: 4.7805e-01
# Epoch   246/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4850e-01, KL Loss: 1.9025e-03, Total Loss: 9.5117e-01 - TEST : Rec Loss: 9.5421e-01, KL Loss: 1.8898e-03, Total Loss: 4.7805e-01
# Epoch   248/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4889e-01, KL Loss: 1.8649e-03, Total Loss: 9.5111e-01 - TEST : Rec Loss: 9.5422e-01, KL Loss: 1.8737e-03, Total Loss: 4.7805e-01
# Epoch   250/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5081e-01, KL Loss: 1.8521e-03, Total Loss: 9.5113e-01 - TEST : Rec Loss: 9.5436e-01, KL Loss: 1.8516e-03, Total Loss: 4.7811e-01
# Epoch   252/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4910e-01, KL Loss: 1.8594e-03, Total Loss: 9.5109e-01 - TEST : Rec Loss: 9.5432e-01, KL Loss: 1.8506e-03, Total Loss: 4.7808e-01
# Epoch   254/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4995e-01, KL Loss: 1.8281e-03, Total Loss: 9.5107e-01 - TEST : Rec Loss: 9.5420e-01, KL Loss: 1.8323e-03, Total Loss: 4.7802e-01
# Epoch   256/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4919e-01, KL Loss: 1.7997e-03, Total Loss: 9.5102e-01 - TEST : Rec Loss: 9.5428e-01, KL Loss: 1.7948e-03, Total Loss: 4.7804e-01
# Epoch   258/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4967e-01, KL Loss: 1.7970e-03, Total Loss: 9.5101e-01 - TEST : Rec Loss: 9.5421e-01, KL Loss: 1.7818e-03, Total Loss: 4.7800e-01
# Epoch   260/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4843e-01, KL Loss: 1.7713e-03, Total Loss: 9.5099e-01 - TEST : Rec Loss: 9.5408e-01, KL Loss: 1.7600e-03, Total Loss: 4.7792e-01
# Epoch   262/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4881e-01, KL Loss: 1.7447e-03, Total Loss: 9.5097e-01 - TEST : Rec Loss: 9.5422e-01, KL Loss: 1.7627e-03, Total Loss: 4.7799e-01
# Epoch   264/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4832e-01, KL Loss: 1.7315e-03, Total Loss: 9.5093e-01 - TEST : Rec Loss: 9.5416e-01, KL Loss: 1.7208e-03, Total Loss: 4.7794e-01
# Epoch   266/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5018e-01, KL Loss: 1.7146e-03, Total Loss: 9.5094e-01 - TEST : Rec Loss: 9.5425e-01, KL Loss: 1.7017e-03, Total Loss: 4.7798e-01
# Epoch   268/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4970e-01, KL Loss: 1.6988e-03, Total Loss: 9.5092e-01 - TEST : Rec Loss: 9.5421e-01, KL Loss: 1.6976e-03, Total Loss: 4.7795e-01
# Epoch   270/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4975e-01, KL Loss: 1.6875e-03, Total Loss: 9.5091e-01 - TEST : Rec Loss: 9.5421e-01, KL Loss: 1.6742e-03, Total Loss: 4.7794e-01
# Epoch   272/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4945e-01, KL Loss: 1.6660e-03, Total Loss: 9.5085e-01 - TEST : Rec Loss: 9.5415e-01, KL Loss: 1.6594e-03, Total Loss: 4.7790e-01
# Epoch   274/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4754e-01, KL Loss: 1.6501e-03, Total Loss: 9.5079e-01 - TEST : Rec Loss: 9.5418e-01, KL Loss: 1.6552e-03, Total Loss: 4.7792e-01
# Epoch   276/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5044e-01, KL Loss: 1.6202e-03, Total Loss: 9.5081e-01 - TEST : Rec Loss: 9.5416e-01, KL Loss: 1.6104e-03, Total Loss: 4.7789e-01
# Epoch   278/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5080e-01, KL Loss: 1.6092e-03, Total Loss: 9.5086e-01 - TEST : Rec Loss: 9.5412e-01, KL Loss: 1.5977e-03, Total Loss: 4.7786e-01
# Epoch   280/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4750e-01, KL Loss: 1.6181e-03, Total Loss: 9.5075e-01 - TEST : Rec Loss: 9.5428e-01, KL Loss: 1.6111e-03, Total Loss: 4.7795e-01
# Epoch   282/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5041e-01, KL Loss: 1.5748e-03, Total Loss: 9.5080e-01 - TEST : Rec Loss: 9.5409e-01, KL Loss: 1.5725e-03, Total Loss: 4.7783e-01
# Epoch   284/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5012e-01, KL Loss: 1.5572e-03, Total Loss: 9.5075e-01 - TEST : Rec Loss: 9.5404e-01, KL Loss: 1.5647e-03, Total Loss: 4.7780e-01
# Epoch   286/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4965e-01, KL Loss: 1.5628e-03, Total Loss: 9.5073e-01 - TEST : Rec Loss: 9.5417e-01, KL Loss: 1.5578e-03, Total Loss: 4.7786e-01
# Epoch   288/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4968e-01, KL Loss: 1.5342e-03, Total Loss: 9.5073e-01 - TEST : Rec Loss: 9.5407e-01, KL Loss: 1.5222e-03, Total Loss: 4.7780e-01
# Epoch   290/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4956e-01, KL Loss: 1.5124e-03, Total Loss: 9.5067e-01 - TEST : Rec Loss: 9.5430e-01, KL Loss: 1.5159e-03, Total Loss: 4.7791e-01
# Epoch   292/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4952e-01, KL Loss: 1.5016e-03, Total Loss: 9.5069e-01 - TEST : Rec Loss: 9.5420e-01, KL Loss: 1.4885e-03, Total Loss: 4.7785e-01
# Epoch   294/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4798e-01, KL Loss: 1.4850e-03, Total Loss: 9.5064e-01 - TEST : Rec Loss: 9.5405e-01, KL Loss: 1.4843e-03, Total Loss: 4.7777e-01
# Epoch   296/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5028e-01, KL Loss: 1.4672e-03, Total Loss: 9.5065e-01 - TEST : Rec Loss: 9.5431e-01, KL Loss: 1.4773e-03, Total Loss: 4.7789e-01
# Epoch   298/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4891e-01, KL Loss: 1.4674e-03, Total Loss: 9.5064e-01 - TEST : Rec Loss: 9.5419e-01, KL Loss: 1.4461e-03, Total Loss: 4.7782e-01
# Epoch   300/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4674e-01, KL Loss: 1.4674e-03, Total Loss: 9.5056e-01 - TEST : Rec Loss: 9.5414e-01, KL Loss: 1.4472e-03, Total Loss: 4.7780e-01
# Epoch   302/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5008e-01, KL Loss: 1.4414e-03, Total Loss: 9.5059e-01 - TEST : Rec Loss: 9.5414e-01, KL Loss: 1.4426e-03, Total Loss: 4.7779e-01
# Epoch   304/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4971e-01, KL Loss: 1.4163e-03, Total Loss: 9.5056e-01 - TEST : Rec Loss: 9.5416e-01, KL Loss: 1.4203e-03, Total Loss: 4.7779e-01
# Epoch   306/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4867e-01, KL Loss: 1.3990e-03, Total Loss: 9.5058e-01 - TEST : Rec Loss: 9.5430e-01, KL Loss: 1.3917e-03, Total Loss: 4.7785e-01
# Epoch   308/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5009e-01, KL Loss: 1.3972e-03, Total Loss: 9.5054e-01 - TEST : Rec Loss: 9.5411e-01, KL Loss: 1.3898e-03, Total Loss: 4.7775e-01
# Epoch   310/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4955e-01, KL Loss: 1.3936e-03, Total Loss: 9.5052e-01 - TEST : Rec Loss: 9.5423e-01, KL Loss: 1.3878e-03, Total Loss: 4.7781e-01
# Epoch   312/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4983e-01, KL Loss: 1.3737e-03, Total Loss: 9.5049e-01 - TEST : Rec Loss: 9.5424e-01, KL Loss: 1.3639e-03, Total Loss: 4.7780e-01
# Epoch   314/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4839e-01, KL Loss: 1.3678e-03, Total Loss: 9.5048e-01 - TEST : Rec Loss: 9.5422e-01, KL Loss: 1.3760e-03, Total Loss: 4.7780e-01
# Epoch   316/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4801e-01, KL Loss: 1.3400e-03, Total Loss: 9.5044e-01 - TEST : Rec Loss: 9.5407e-01, KL Loss: 1.3554e-03, Total Loss: 4.7771e-01
# Epoch   318/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4915e-01, KL Loss: 1.3336e-03, Total Loss: 9.5048e-01 - TEST : Rec Loss: 9.5413e-01, KL Loss: 1.3184e-03, Total Loss: 4.7772e-01
# Epoch   320/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4936e-01, KL Loss: 1.3608e-03, Total Loss: 9.5048e-01 - TEST : Rec Loss: 9.5409e-01, KL Loss: 1.3256e-03, Total Loss: 4.7771e-01
# Epoch   322/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4869e-01, KL Loss: 1.3378e-03, Total Loss: 9.5045e-01 - TEST : Rec Loss: 9.5390e-01, KL Loss: 1.3217e-03, Total Loss: 4.7761e-01
# Epoch   324/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4903e-01, KL Loss: 1.2967e-03, Total Loss: 9.5040e-01 - TEST : Rec Loss: 9.5409e-01, KL Loss: 1.3344e-03, Total Loss: 4.7771e-01
# Epoch   326/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4721e-01, KL Loss: 1.2639e-03, Total Loss: 9.5035e-01 - TEST : Rec Loss: 9.5413e-01, KL Loss: 1.2805e-03, Total Loss: 4.7771e-01
# Epoch   328/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4875e-01, KL Loss: 1.2881e-03, Total Loss: 9.5038e-01 - TEST : Rec Loss: 9.5412e-01, KL Loss: 1.2540e-03, Total Loss: 4.7769e-01
# Epoch   330/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5082e-01, KL Loss: 1.3177e-03, Total Loss: 9.5044e-01 - TEST : Rec Loss: 9.5427e-01, KL Loss: 1.2855e-03, Total Loss: 4.7778e-01
# Epoch   332/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4843e-01, KL Loss: 1.2842e-03, Total Loss: 9.5035e-01 - TEST : Rec Loss: 9.5423e-01, KL Loss: 1.2796e-03, Total Loss: 4.7776e-01
# Epoch   334/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4892e-01, KL Loss: 1.2524e-03, Total Loss: 9.5032e-01 - TEST : Rec Loss: 9.5430e-01, KL Loss: 1.2775e-03, Total Loss: 4.7779e-01
# Epoch   336/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4897e-01, KL Loss: 1.2279e-03, Total Loss: 9.5032e-01 - TEST : Rec Loss: 9.5408e-01, KL Loss: 1.2432e-03, Total Loss: 4.7766e-01
# Epoch   338/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5039e-01, KL Loss: 1.2330e-03, Total Loss: 9.5038e-01 - TEST : Rec Loss: 9.5406e-01, KL Loss: 1.2220e-03, Total Loss: 4.7764e-01
# Epoch   340/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4815e-01, KL Loss: 1.2716e-03, Total Loss: 9.5033e-01 - TEST : Rec Loss: 9.5421e-01, KL Loss: 1.2142e-03, Total Loss: 4.7771e-01
# Epoch   342/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4740e-01, KL Loss: 1.2644e-03, Total Loss: 9.5027e-01 - TEST : Rec Loss: 9.5412e-01, KL Loss: 1.2564e-03, Total Loss: 4.7769e-01
# Epoch   344/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4781e-01, KL Loss: 1.2054e-03, Total Loss: 9.5026e-01 - TEST : Rec Loss: 9.5426e-01, KL Loss: 1.2602e-03, Total Loss: 4.7776e-01
# Epoch   346/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4817e-01, KL Loss: 1.1703e-03, Total Loss: 9.5025e-01 - TEST : Rec Loss: 9.5416e-01, KL Loss: 1.1774e-03, Total Loss: 4.7767e-01
# Epoch   348/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4823e-01, KL Loss: 1.2245e-03, Total Loss: 9.5029e-01 - TEST : Rec Loss: 9.5410e-01, KL Loss: 1.1583e-03, Total Loss: 4.7763e-01
# Epoch   350/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4903e-01, KL Loss: 1.2824e-03, Total Loss: 9.5032e-01 - TEST : Rec Loss: 9.5409e-01, KL Loss: 1.2311e-03, Total Loss: 4.7766e-01
# Epoch   352/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4945e-01, KL Loss: 1.2003e-03, Total Loss: 9.5024e-01 - TEST : Rec Loss: 9.5408e-01, KL Loss: 1.2503e-03, Total Loss: 4.7766e-01
# Epoch   354/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4876e-01, KL Loss: 1.1204e-03, Total Loss: 9.5019e-01 - TEST : Rec Loss: 9.5419e-01, KL Loss: 1.1802e-03, Total Loss: 4.7769e-01
# Epoch   356/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4881e-01, KL Loss: 1.1737e-03, Total Loss: 9.5026e-01 - TEST : Rec Loss: 9.5406e-01, KL Loss: 1.1163e-03, Total Loss: 4.7759e-01
# Epoch   358/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4987e-01, KL Loss: 1.2452e-03, Total Loss: 9.5029e-01 - TEST : Rec Loss: 9.5425e-01, KL Loss: 1.1697e-03, Total Loss: 4.7771e-01
# Epoch   360/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4797e-01, KL Loss: 1.2017e-03, Total Loss: 9.5020e-01 - TEST : Rec Loss: 9.5405e-01, KL Loss: 1.2339e-03, Total Loss: 4.7764e-01
# Epoch   362/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4830e-01, KL Loss: 1.1037e-03, Total Loss: 9.5015e-01 - TEST : Rec Loss: 9.5401e-01, KL Loss: 1.1540e-03, Total Loss: 4.7758e-01
# Epoch   364/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4810e-01, KL Loss: 1.1266e-03, Total Loss: 9.5020e-01 - TEST : Rec Loss: 9.5401e-01, KL Loss: 1.0917e-03, Total Loss: 4.7755e-01
# Epoch   366/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5016e-01, KL Loss: 1.2060e-03, Total Loss: 9.5029e-01 - TEST : Rec Loss: 9.5403e-01, KL Loss: 1.1271e-03, Total Loss: 4.7758e-01
# Epoch   368/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4778e-01, KL Loss: 1.1792e-03, Total Loss: 9.5019e-01 - TEST : Rec Loss: 9.5400e-01, KL Loss: 1.1816e-03, Total Loss: 4.7759e-01
# Epoch   370/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4676e-01, KL Loss: 1.0976e-03, Total Loss: 9.5008e-01 - TEST : Rec Loss: 9.5408e-01, KL Loss: 1.1532e-03, Total Loss: 4.7762e-01
# Epoch   372/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4818e-01, KL Loss: 1.0887e-03, Total Loss: 9.5013e-01 - TEST : Rec Loss: 9.5416e-01, KL Loss: 1.0654e-03, Total Loss: 4.7761e-01
# Epoch   374/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5087e-01, KL Loss: 1.1600e-03, Total Loss: 9.5024e-01 - TEST : Rec Loss: 9.5405e-01, KL Loss: 1.0809e-03, Total Loss: 4.7756e-01
# Epoch   376/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4848e-01, KL Loss: 1.1622e-03, Total Loss: 9.5014e-01 - TEST : Rec Loss: 9.5402e-01, KL Loss: 1.1599e-03, Total Loss: 4.7759e-01
# Epoch   378/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4880e-01, KL Loss: 1.0440e-03, Total Loss: 9.5008e-01 - TEST : Rec Loss: 9.5413e-01, KL Loss: 1.1126e-03, Total Loss: 4.7762e-01
# Epoch   380/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4869e-01, KL Loss: 1.0548e-03, Total Loss: 9.5013e-01 - TEST : Rec Loss: 9.5408e-01, KL Loss: 1.0191e-03, Total Loss: 4.7755e-01
# Epoch   382/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4872e-01, KL Loss: 1.1737e-03, Total Loss: 9.5017e-01 - TEST : Rec Loss: 9.5403e-01, KL Loss: 1.0811e-03, Total Loss: 4.7755e-01
# Epoch   384/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4837e-01, KL Loss: 1.1149e-03, Total Loss: 9.5009e-01 - TEST : Rec Loss: 9.5403e-01, KL Loss: 1.1521e-03, Total Loss: 4.7759e-01
# Epoch   386/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4980e-01, KL Loss: 9.9608e-04, Total Loss: 9.5004e-01 - TEST : Rec Loss: 9.5406e-01, KL Loss: 1.0621e-03, Total Loss: 4.7756e-01
# Epoch   388/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4916e-01, KL Loss: 1.0660e-03, Total Loss: 9.5012e-01 - TEST : Rec Loss: 9.5396e-01, KL Loss: 9.7972e-04, Total Loss: 4.7747e-01
# Epoch   390/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4949e-01, KL Loss: 1.1443e-03, Total Loss: 9.5017e-01 - TEST : Rec Loss: 9.5414e-01, KL Loss: 1.0881e-03, Total Loss: 4.7762e-01
# Epoch   392/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5006e-01, KL Loss: 1.0314e-03, Total Loss: 9.5004e-01 - TEST : Rec Loss: 9.5396e-01, KL Loss: 1.1180e-03, Total Loss: 4.7754e-01
# Epoch   394/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4916e-01, KL Loss: 9.7309e-04, Total Loss: 9.5004e-01 - TEST : Rec Loss: 9.5396e-01, KL Loss: 9.6423e-04, Total Loss: 4.7746e-01
# Epoch   396/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.5019e-01, KL Loss: 1.0956e-03, Total Loss: 9.5015e-01 - TEST : Rec Loss: 9.5407e-01, KL Loss: 9.9017e-04, Total Loss: 4.7753e-01
# Epoch   398/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4799e-01, KL Loss: 1.0712e-03, Total Loss: 9.5002e-01 - TEST : Rec Loss: 9.5400e-01, KL Loss: 1.1024e-03, Total Loss: 4.7755e-01
# Epoch   400/400 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4873e-01, KL Loss: 9.2809e-04, Total Loss: 9.4997e-01 - TEST : Rec Loss: 9.5403e-01, KL Loss: 9.8953e-04, Total Loss: 4.7751e-01

# %%
plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses)

# %%
sample_predictions(N_SAMPLES=5, model=dkf)

# %% [markdown]
# # Commentaires à ce stade :
#
# ~~C1 - REVOIR LE TRAINING ! cf https://dynamicalvae.github.io/tuto_icassp2021/DVAE_tutorial.html (slide training DKF)~~
#
# Q1 - L'ELBO contient une expectation de KLs entre les vraies posterieures et les approximées. Une méthode est mentionnée p64 du papier de l'INRIA.
#
# #### Mon codage de la loss est-il correct ?
#
# Q2 - A priori plus de problème de stabilité ? Mais on constate un changement de régime pendant le training. Est-ce que cela correspond à un maximum d'expressivité du modèle ? Ou autre chose (ie $\sigma_{\theta_x} \longrightarrow 0$?)
#
# Q3 - Je calcule la prédiction en utilisant la moyenne de $p_{\theta_z}$ plutôt que celle de $q_\phi$ ... Mais ça se discute ?
#
# Q4 - Comment arbitrer entre la KL et la reconstruction ? Piste 1 : faire un scheduler sur $\beta$ ? (cf papiers plus bas)
#
# Q5 - Choix des différents paramètres ? Grid-search ? Early stopping + train till end of patience ? Autre ?
#
# Q6 - Influence de K ? (nombre de samples pour calculer les expectations dans la loss)
#
# Q7 - Architecture des réseaux : drop outs ? batch norms ? softplus pour sortir var plutôt qu'une linéaire pour sortir logvar ?
#
# Articles sur le sujet (biblio papier INRIA):
# - https://arxiv.org/pdf/1602.02282 (Ladder VAE)
# - https://arxiv.org/pdf/2007.03898 (NVAE: A Deep Hierarchical Variational Autoencoder)
#
# Tuto (slides extrêmement bien faites):
# - https://dynamicalvae.github.io/tuto_icassp2021/DVAE_tutorial.html

# %% [markdown]
# ## Piste 1 : Implementing a simple linear Beta scheduler

# %%
class BetaLinearScheduler():
    """Scheduler linéaire simple du beta, rapport entre la loss de reconstruction et la loss KL
    """
    
    def __init__(self, beta_start=0.0, beta_end=1.0, num_epochs=100):
        """Constructeur

        Args:
            beta_start (float, optional): coefficient beta au démarrage. Defaults to 0.0.
            beta_end (float, optional): coefficient beta en fin de schedule. Defaults to 1.0.
            num_epochs (int, optional): nombre d'epochs sur lequel se fait l'évolution du beta. Defaults to 100.
        """
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.num_epochs = num_epochs
        
    def __call__(self, epoch):
        """Calcul du beta à l'epoch donnée

        Args:
            epoch (int): epoch courante

        Returns:
            float: beta
        """
        
        return self.beta_start + (self.beta_end - self.beta_start) * (np.min([epoch, self.num_epochs]) / self.num_epochs)

# %%
# dkf = DeepKalmanFilter(
#     input_dim = xdim,
#     latent_dim = latent_dim,
#     hidden_dim = h_dim,
#     combiner_dim = combiner_dim,
#     num_layers = num_layers_rnn,
#     device=device
# ).to(device)

# print(dkf)

# %%
# optimizer = torch.optim.Adam(dkf.parameters(), lr=1e-3)
# loss_fn = loss_function

# num_epochs = 250
# n_displays = 20  # nombre d'affichages souhaités
# display_frequency = int(num_epochs / n_displays)

# beta_scheduler = BetaLinearScheduler(beta_start=0.0, beta_end=1.0, num_epochs=50)  # warm up beta

# %%
# rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses = train(
#     dkf, optimizer, loss_fn, num_epochs=num_epochs, beta_scheduler=beta_scheduler, display_frequency=display_frequency
# )

# %%
# plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses)

# %%
# sample_predictions(N_SAMPLES=5, model=dkf)
