# %% [markdown]
# VAEs dynamiques : https://arxiv.org/abs/2008.12595
#
# # Training Deep Kalman Filter

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# from tests.unit_tests import test_brick_1, test_brick_2, test_brick_3, test_brick_4, test_brick_5, test_brick_6
# from libs.dkf import DeepKalmanFilter, loss_function

# %%
def seed_everything(seed=42):
    """
    Set seed for reproducibility.
    """
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set seed for reproducibility
seed_everything(42)

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    dtype = torch.cuda.FloatTensor
else:
    device = torch.device('cpu')
    dtype = torch.FloatTensor

print(f"Using {device}")

torch.set_default_dtype(torch.float64)

if device.type == 'cuda':
    print('GPU Name:', torch.cuda.get_device_name(0))
    print('Total GPU Memory:', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
# Out:
# Using cuda
# GPU Name: NVIDIA GeForce RTX 4090
# Total GPU Memory: 23.6 GB

# %% [markdown]
# # Modèle

# %% [markdown]
# ### Structure SSM (Single State Model pour variables latentes + VAE pour observations):
#
# - $z_t$ variables latentes forment une chaîne de Markov, transition $p(z_t \vert z_{t-1})$
# - $x_t$ observations, modèle $p_{\theta_x}(x_t \vert z_t)$
# - NB : pas de commande/input $u_t$ ici

# %% [markdown]
# ### Deep Kalman Filter :
#
# \begin{align}
# p_{\theta_z}(z_t \vert z_{t-1}) &= \mathcal{N}(z_t \vert \mu_{\theta_z}(z_{t-1}), \text{diag}(\sigma_{\theta_z}^{2}(z_{t-1}))) \\
# d_z(z_{t-1}) &= [ \mu_{\theta_z}(z_{t-1}), \sigma_{\theta_z}(z_{t-1}) ] \\
# p_{\theta_x}(x_t \vert z_{t}) &= \mathcal{N}(x_t \vert \mu_{\theta_x}(z_{t}), \text{diag}(\sigma_{\theta_x}^{2}(z_{t}))) \\
# d_x(z_{t}) &= [ \mu_{\theta_x}(z_{t}), \sigma_{\theta_x}(z_{t}) ] \\
# \end{align}
#
# où $d_x, d_z$ sont des réseaux.

# %% [markdown]
# ### Modèle inférence
#
# Le "true posterior" s'écrit :
# \begin{align}
# p_{\theta}(z_{1:T} \vert x_{1:T}) &= \prod_{t=1}^T p_{\theta} (z_t \vert z_{1:t-1}, x_{1:T} ) \\
# &= \prod_{t=1}^T p_{\theta} (z_t \vert z_{t-1}, x_{t:T} )
# \end{align}
#
# où la première écriture est l'application de la chain rule, et la deuxième est un résultat de D-séparation (latentes à dépendance Markovienne).
#
# On choisit comme approximation du posterior (=encodeur) une formulation calquée sur le vrai posterior :
#
# \begin{align}
# q_{\phi}(z_{1:T} \vert x_{1:T}) &= \prod_{t=1}^T q_{\phi} (z_{t} \vert z_{t-1}, x_{t:T})
# \end{align}
#
# On voit que l'inférence prend en compte les observations futures $x_{t:T}$ (comme le Kalman smoother par exemple)

# %% [markdown]
# # Implémentation de l'inférence

# %% [markdown]
# - **backward RNN** (dans les faits, un LSTM) pour encoder les $x_{t:T}$ par les hidden states $h_t$ :
#
# \begin{align}
# h_t = \text{LSTM}(h_{t+1}, x_t)
# \end{align}
#
# - **combiner** (réseau MLP) pour aggréger $h_t$ et $z_{t-1}
#
# \begin{align}
# g_t = \text{Combiner}(h_t, z_{t-1})
# \end{align}
#
# - **Encoder** (réseau MLP) pour inférer les paramètres du posterior:
#
# \begin{align}
# e_z(g_t) &= [ \mu_\phi(g_t), \sigma_\phi(g_t)] \\
# q_\phi(z_t \vert g_t) &= \mathcal{N}(z_t \vert \mu_{\phi}(g_t), \text{diag}(\sigma_\phi^2(g_t)))
# \end{align}
#
# NB : il existe d'autres formulations du posterior approximé $q_\phi$, qui peuvent faire intervenir un forward LSTM.

# %% [markdown]
# # Training

# %% [markdown]
# Le modèle s'entraîne en maximisant un ELBO, dont la formulation générique se simplifie dans le cas du DKF en :
#
# \begin{align}
# \mathcal{L}(\theta, \phi; X) &= \sum_{t=1}^T \mathbb{E}_{q_\phi(z_t \vert x_{1:T})} \log(p_{\theta_x}(x_t \vert z_t)) -
# \sum_{t=1}^T \mathbb{E}_{q_\phi(z_{t-1} \vert x_{1:T})} \text{D}_{\text{KL}} \left[ q_\phi(z_t \vert z_{t-1}, x_{t:T}) \vert\vert
# p_{\theta_z}(z_t \vert z_{t-1}) \right]
# \end{align}
#
# Les deux termes s'explicitent de la façon suivante (avec $D$ dimension de l'espace des observations) :
#
# \begin{align}
# p_{\theta_x}(x_t \vert z_t) &= \mathcal{N}(x_t \vert \mu_{\theta_x}(z_t), \text{diag}(\sigma_{\theta_x}^2(z_t))) \\
# \log{p_{\theta_x}(x_t \vert z_t)} &= -\frac{D}{2} \log{2\pi} - \frac{1}{2}\log{\vert \text{diag}(\sigma_{\theta_x}^2(z_t)) \vert} -
# \frac{1}{2} \left[ (x_t - \mu_{\theta_x}(z_t))^T (\text{diag}(\sigma_{\theta_x}^2(z_t)))^{-1} (x_t - \mu_{\theta_x}(z_t)) \right] \\
# &= \frac{1}{2} \left( \sum_{i=1}^D \log{\sigma_{\theta_x}^2(z_t)}\vert_{i} + (x_t - \mu_{\theta_x}(z_t))^T \text{diag} \frac{1}{\sigma_{\theta_x}^2(z_t)} (x_t - \mu_{\theta_x}(z_t)) \right)
# \end{align}
#
# Et la KL entre les deux Gaussiennes:
#
# \begin{align}
# q_\phi(z_t \vert z_{t-1}, x_{t:T}) &= \mathcal{N}(z_t \vert \mu_{\phi}(g_t), \text{diag}(\sigma_\phi^2(g_t))) \\
# p_{\theta_z}(z_t \vert z_{t-1}) &= \mathcal{N}(z_t \vert \mu_{\theta_z}(z_{t-1}), \text{diag}(\sigma_{\theta_z}^{2}(z_{t-1}))) \\
# \end{align}
#
# a une close form (avec $Z$ dimension de l'espace latent):
#
# \begin{align}
# \text{D}_{\text{KL}}(q_\phi \vert\vert p_{\theta_z}) &= \frac{1}{2} \left[ \text{Tr}(\text{diag}(\sigma_{\theta_z}^{2})^{-1} \text{diag}(\sigma_\phi^2) ) + (\mu_{\theta_z} - \mu_\phi)^T (\text{diag}(\sigma_{\theta_z}^{2})^{-1}) (\mu_{\theta_z} - \mu_\phi) +
# \log{\frac{\vert \text{diag}(\sigma_{\theta_z}^{2})\vert}{\vert \text{diag}(\sigma_\phi^2) \vert} } \right] \\
# &= \frac{1}{2}\left[ \sum_{i=1}^Z \log{\sigma_{\theta_z}^{2}}\vert_i - \sum_{i=1}^Z \log{\sigma_{\phi}^{2}}\vert_i +
#  (\mu_{\theta_z} - \mu_\phi)^T \text{diag}(\frac{1}{\sigma_{\theta_z}^{2}}) (\mu_{\theta_z} - \mu_\phi) + \sum_{i=1}^Z \frac{\sigma_{\phi}^{2}\vert_i} {\sigma_{\theta_z}^{2}\vert_i} - Z
# \right]
# \end{align}

# %% [markdown]
# # Code

# %%
X_DIM = 1 # Dimension of the observation space
Z_DIM = 2 # Dimension of the latent space
H_DIM = 16 # Dimension of the hidden state of the LSTM network(s)
G_DIM = 2 # Dimension of the output of the combiner
INTERMEDIATE_LAYER_DIM = 16 # Dimension of the intermediate layers of the MLPs

# %% [markdown]
# ### Briques de base

# %%
#--- brick 1 : backward LSTM -----------------------------

class BackwardLSTM(nn.Module):
    """
    Backward LSTM module.
    Creates a unidirectional LSTM, with num_layers layers, hidden state
    of dimension hidden_size, and input of dimension input_size.
    The LSTM is used to process the input sequence in reverse order.
    """
    def __init__(self, input_size, hidden_size, num_layers=2):
        super(BackwardLSTM, self).__init__()
        
        self.input_size = input_size
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        self.lstm = nn.LSTM(
            input_size,   # dimension of the observation space
            hidden_size,  # dimension of the hidden state of the LSTM network
            num_layers=num_layers, # number of layers of the LSTM network
            batch_first=False, # using the default PyTorch LSTM implementation, expecting input shape (seq_len, batch, input_size)
            bidirectional=False # unidirectional LSTM to start with
            )

    def forward(self, x):
        """
        Forward pass of the backward LSTM module. The sequence x
        is reversed via a torch.flip operation, then passed through the LSTM.
        The output sequence is reversed again to get the final output.
        
        Args:
            x: input sequence
            shape (seq_len, batch, input_size)
        Returns:
            out: output sequence
            shape (seq_len, batch, hidden_size)
        """
        # Reverse the input sequence - axis 0 is the time axis here
        x_reversed = torch.flip(x, [0])
        # Pass through LSTM
        # using initial hidden state and cell state as zeros
        out, _ = self.lstm(x_reversed)
        # Reverse the output sequence
        out_reversed = torch.flip(out, [0])
        # return output shape (seq_len, batch, hidden_size)
        
        return out_reversed

# %%
#--- brick 2 : combiner -----------------------------
#
# this combines the latent variable at time t-1
# with the hidden state from the backward LSTM at time t,
# to compute a t
    # X_DIM = 1 # Dimension of the observation space
    # Z_DIM = 16 # Dimension of the latent space
    # H_DIM = 16 # Dimension of the hidden state of the LSTM network(s)
    # G_DIM = 8 # Dimension of the output of the combiner
    # INTERMEDIATE_LAYER_DIM = 16 # Dimension of the intermediate layers of the MLPsensor g at time t, that will be used
# to compute the parameters of the approximate posterior distribution
# of the latent variable
#

class CombinerMLP(nn.Module):
    """Combiner module. Takes the hidden state of the backward LSTM at time t
    and the (sampled) latent variable at time t-1, to compute a tensor g at time t,
    that will be used to compute the parameters of the approximate posterior
    distribution of the latent variable.
    """
    
    def __init__(self, 
                 latent_dim=Z_DIM, 
                 hidden_dim=H_DIM, 
                 output_dim=G_DIM,
                 layers_dim = None,  # list of layers dimensions, without the input dimnesion, without the output dimension
                 activation = 'tanh',
                 inter_dim = INTERMEDIATE_LAYER_DIM,
                 ):
        """Creates a combiner module, ie a MLP layer, to combine h_t (the output of the backward lstm at time t
        and (sampled) z_t-1, the latent variable at time t-1.
        The input_dimension is the sum of the latent dimension (dimension of z_t-1) and the hidden dimension
        (dimension of h_t).
        The output dimension is the dimension of the combiner output, which is a parameter.
        The list of intermediate layers is passed in the list layers_dim.
        The activation function is passed as a string, either 'tanh' or 'relu'. (default = 'tanh')
        
        Inputs:
            latent_dim : dimension of the latent space
            hidden_dim : dimension of the hidden state of the LSTM network
            output_dim : dimension of the combiner output
            layers_dim : list of layers dimensions, without the input dimension, without the output dimension
            activation : activation function (default = 'tanh')
            inter_dim : dimension of the intermediate layers (default = INTERMEDIATE_LAYER_DIM)
        """
        super(CombinerMLP, self).__init__()
        
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        if activation == 'tanh':
            self.activation_fn = nn.Tanh()
        elif activation == 'relu':
            self.activation_fn = nn.ReLU()
        else:
            raise ValueError(f"Activation function {activation} not supported. Use 'tanh' or 'relu'.")
        self.inter_dim = inter_dim
        self.layers_dim = layers_dim
        
        if self.layers_dim is None:
            self.layers_dim = [self.inter_dim] * 2
        else:
            self.layers_dim = layers_dim
            
        # explicitly define the MLP layers
        layers = []
        for i, dim in enumerate(self.layers_dim):
            if i==0:  #first layer, latent_dim + hidden_dim => layers_dim[0]
                layers.append(nn.Linear(latent_dim + hidden_dim, dim))
            else:  # all other layers
                layers.append(nn.Linear(self.layers_dim[i-1], dim))
            layers.append(self.activation_fn)
        # last layer : layers_dim[-1] => output_dim
        layers.append(nn.Linear(self.layers_dim[-1], output_dim))
            
        # build the MLP
        self.mlp = nn.Sequential(*layers)
            
        
    def forward(self, h, z):
        """
        Forward pass of the combiner module.
        The use of the combiner module is sequential, so there is no seq_len dimension.
        
        Args:
            h: hidden state of the backward LSTM at time t
            shape (batch, hidden_dim)
            z: latent variable at time t-1
            shape (batch, latent_dim)
        Returns:
            g: tensor g at time t
            shape (batch, output_dim)
        """
        
        # Concatenate the hidden state and the latent variable on their dimension
        x = torch.cat((h, z), dim=-1) # shape (batch, hidden_dim + latent_dim)
        
        # Pass through MLP
        g = self.mlp(x) # output shape (batch, output_dim)
        
        return g

# %%
#--- brick 3 : Encoder -----------------------------
#
# This computes the parameters of the approximate posterior distribution
# of the latent vatiable at time t.
# The approximate posterior distribution is a Gaussian distribution,
# we use a MLP to compute the mean and the log of the variance.
#

class EncoderMLP(nn.Module):
    """Encoder module. 
    Computes the parameters of the approximate posterior
    distribution of the latent variable at time t. 
    The approximate posterior distribution is a Gaussian distribution, we use a MLP to compute the mean
    and the log of the variance.
    The input variables are g_t (the output of the combiner module at time t) and
    z_t-1 (the -sampled- latent variable at time t-1).
    """
    
    def __init__(self, 
                 latent_dim=Z_DIM, # Dimension of the latent space
                 combiner_dim=G_DIM, # Dimension of the combiner output
                 inter_dim=INTERMEDIATE_LAYER_DIM, # Dimension of the intermediate layers
                 layers_dim = None, # Dimension of the MLP layers (without inout nor output)
                 activation = 'tanh', # Activation function
    ):
        """Creates the encoder module.
        This is a MLP, that takes as input the combiner output g_t (combining h_t and z_t-1).
        The input dimension is the combiner dimension.
        The output dimension is the 2 * dimension of the latent space (mean, and log variance).
        The list of intermediate layers is passed in the list layers_dim.
        The activation function is passed as a string, either 'tanh' or 'relu'. (default = 'tanh')
        
        Inputs:
            latent_dim : dimension of the latent space
            combiner_dim : dimension of the combiner output
            inter_dim : dimension of the intermediate layers (default = INTERMEDIATE_LAYER_DIM)
            layers_dim : list of layers dimensions, without the input dimension, without the output dimension
            activation : activation function (default = 'tanh')
        """
        super(EncoderMLP, self).__init__()
        
        self.latent_dim = latent_dim
        self.combiner_dim = combiner_dim
        if activation == 'tanh':
            self.activation_fn = nn.Tanh()
        elif activation == 'relu':
            self.activation_fn = nn.ReLU()
        else:
            raise ValueError(f"Activation function {activation} not supported. Use 'tanh' or 'relu'.")
        self.inter_dim = inter_dim
        
        if layers_dim is None:
            self.layers_dim = [self.inter_dim] * 2
        else:
            self.layers_dim = layers_dim
            
        # explicitly define the MLP layers
        layers = []
        for i, dim in enumerate(self.layers_dim):
            if i==0:
                layers.append(nn.Linear(combiner_dim, dim))
            else:
                layers.append(nn.Linear(self.layers_dim[i-1], dim))
            layers.append(self.activation_fn)
            
        # last layer is linear, no activation
        layers.append(nn.Linear(self.layers_dim[-1], 2 * latent_dim)) 
                    
        # build the MLP
        self.mlp = nn.Sequential(*layers)
        
    def forward(self, g):
        """
        Forward pass of the encoder module.
        Takes g_t (the output of the combiner module at time t) as input, returns the parameters of the
        approximate posterior distribution of the latent variable at time t.
        The encoder module is used sequentially, so there is no seq_len dimension.
        The output is a tuple (mu, logvar), where mu is the mean of the approximate posterior distribution
        and logvar is the log of the variance of the approximate posterior distribution.
        
        Args:
            g: tensor g at time t
            shape (batch, combiner_dim)
            
        Returns:
            mu: mean of the approximate posterior distribution
            shape (batch, latent_dim)
            logvar: log of the variance of the approximate posterior distribution
            shape (batch, latent_dim)
        """
        
        # Pass through MLP
        out = self.mlp(g)
        
        # Split the output into mean and log variance
        # each with shape (batch, latent_dim)
        mu, logvar = out[:, :self.latent_dim], out[:, self.latent_dim:]
        
        return mu, logvar

# %%
#--- brick 4 : Latent Space Transition -----------------------------       
#
# This computes the parameters of the transition distribution
# of the latent variable at time t. Ie the prior distribution, 
# before inference.
# The transition distribution is a Gaussian distribution,
# we use a MLP to compute the mean and the log of the variance.
#

class LatentSpaceTransitionMLP(nn.Module):
    """Latent space transition module. 
    Computes the parameters of the transition distribution of the latent variable at time t (ie "prior").
    The transition distribution is a Gaussian distribution, we use a MLP to compute the mean
    and the log of the variance.
    """
    
    def __init__(self, 
                 latent_dim=Z_DIM, # Dimension of the latent space
                 inter_dim=INTERMEDIATE_LAYER_DIM, # Dimension of the intermediate layers
                 layers_dim = None, # Dimension of the MLP layers
                 activation = 'tanh', # Activation function
    ):
        """Creates the latent space transition MLP.
        This is a MLP, that takes as input the -sampled- lagged latent variable z_t-1,
        and computes the parameters of the transition distribution p(z_t|z_{t-1}).
        The input dimension is the latent dimension.
        The output dimension is the 2 * dimension of the latent space (mean, and log variance).
        The list of intermediate layers is passed in the list layers_dim.
        The activation function is passed as a string, either 'tanh' or 'relu'. (default = 'tanh')
        Inputs:
            latent_dim : dimension of the latent space
            inter_dim : dimension of the intermediate layers (default = INTERMEDIATE_LAYER_DIM)
            layers_dim : list of layers dimensions, without the input dimension, without the output dimension
            activation : activation function (default = 'tanh')
        """
        super(LatentSpaceTransitionMLP, self).__init__()
        
        self.latent_dim = latent_dim
        if activation == 'tanh':
            self.activation_fn = nn.Tanh()
        elif activation == 'relu':
            self.activation_fn = nn.ReLU()
        else:
            raise ValueError(f"Activation function {activation} not supported. Use 'tanh' or 'relu'.")
        self.inter_dim = inter_dim
        
        if layers_dim is None:
            layers_dim = [self.inter_dim]
        self.layers_dim = layers_dim
            
        # explicitly define the MLP layers
        layers = []
        for i, dim in enumerate(self.layers_dim):
            if i==0:
                layers.append(nn.Linear(self.latent_dim, dim))
            else:
                layers.append(nn.Linear(self.layers_dim[i-1], dim))
            layers.append(self.activation_fn)
            
        # last layer is linear, no activation
        layers.append(nn.Linear(self.layers_dim[-1], 2 * self.latent_dim)) 
                    
        # build the MLP
        self.mlp = nn.Sequential(*layers)
               
    def forward(self, z):
        """
        Forward pass of the latent space transition module.
        This takes as input a whole set of lagged -sampled- latent variables z_t-1,
        and computes the parameters of the transition distribution p(z_t|z_{t-1}) for each time step t.
        
        Args:
            z: latent variables lagged(set of latent variables at time t-1)
            shape (seq_len, batch, latent_dim)
            
        Returns:
            mu: means of the transition distribution
            shape (seq_len, batch, latent_dim)
            logvar: log of the variances of the transition distribution
            shape (seq_len, batch, latent_dim)
        """
        
        # Pass through MLP
        out = self.mlp(z)
        
        # Split the output into mean and log variance
        # each with shape (batch, latent_dim)
        mu, logvar = out[:, :, :self.latent_dim], out[:, :, self.latent_dim:]
        
        return mu, logvar

# %%
#--- brick 5 : Decoder (ie Observation Model) -----------------------------
#
# This computes the parameters of the distribution of 
# the observed variable 'x', given the latent variable 'z'.
# The distribution is a Gaussian distribution,
# we use a MLP to compute the mean and the log of the variance.
#

class DecoderMLP(nn.Module):
    """Decoder module. Computes the parameters of the distribution of the
    observed variable 'x', given the latent variable 'z' sampled from the approximate
    posterior distribution.
    The distribution is a Gaussian distribution, we use a MLP to compute the mean and the log of
    the variance.   
    """
    
    def __init__(self, 
                 latent_dim=Z_DIM, # Dimension of the latent space
                 observation_dim=X_DIM, # Dimension of the observation space
                 inter_dim=INTERMEDIATE_LAYER_DIM, # Dimension of the intermediate layers
                 layers_dim = None, # Dimension of the MLP layers
                 activation = 'tanh', # Activation function
    ):
        """Creates the decoder module.
        This is a MLP, that takes as input a set of -sampled- latent variables z_t,
        and computes the parameters of the distribution of the observed variable 'x'.
        The input dimension is the latent dimension.
        The output dimension is the 2 * dimension of the observation space (mean, and log variance).
        The list of intermediate layers is passed in the list layers_dim.
        The activation function is passed as a string, either 'tanh' or 'relu'. (default = 'tanh')
        
        Inputs:
            latent_dim : dimension of the latent space
            observation_dim : dimension of the observation space
            inter_dim : dimension of the intermediate layers (default = INTERMEDIATE_LAYER_DIM)
            layers_dim : list of layers dimensions, without the input dimension, without the output dimension
            activation : activation function (default = 'tanh')
        """
        super(DecoderMLP, self).__init__()
        
        self.latent_dim = latent_dim
        self.observation_dim = observation_dim
        self.inter_dim = inter_dim
        
        if activation == 'tanh':
            self.activation_fn = nn.Tanh()
        elif activation == 'relu':
            self.activation_fn = nn.ReLU()
        else:
            raise ValueError(f"Activation function {activation} not supported. Use 'tanh' or 'relu'.")
        
        if layers_dim is None:
            layers_dim = [self.inter_dim] # one layer per default
        self.layers_dim = layers_dim
            
        # explicitly define the MLP layers
        layers = []
        for i, dim in enumerate(self.layers_dim):
            if i==0:
                layers.append(nn.Linear(self.latent_dim, dim))
            else:
                layers.append(nn.Linear(self.layers_dim[i-1], dim))
            layers.append(self.activation_fn)
            
        # last layer is linear, no activation
        layers.append(nn.Linear(self.layers_dim[-1], 2 * self.observation_dim)) 
                    
        # build the MLP
        self.mlp = nn.Sequential(*layers)
        
    def forward(self, z):
        """
        Forward pass of the decoder module.
        This takes as input the set of -sampled- latent variables z_t, and 
        computes the set of parameters of the distribution of the observed variable 'x'.
        The decoder module is used after the sequential loop, so there is a seq_len dimension.
        
        Args:
            z: latent variable at time t
            shape (seq_len, batch, latent_dim)
        Returns:
            mu: means of the distribution of the observed variable
            shape (seq_len, batch, observation_dim)
            logvar: log of the variances of the distribution of the observed variable
            shape (seq_len, batch, observation_dim)
        """
        # Pass through MLP
        out = self.mlp(z)
        
        # Split the output into mean and log variance
        # each with shape (batch, observation_dim)
        mu, logvar = out[:, :, :self.observation_dim], out[:, :, self.observation_dim:]
        
        return mu, logvar

# %%
# --- brick 6 : Sampler with reparameterization trick -----------------------------
#
# This samples from a normal distribution of given mean and log variance
# using the reparameterization trick.

class Sampler(nn.Module):
    """Sampler module. Samples from a normal distribution of given mean and
    log variance using the reparameterization trick.
    
    NB : to be replaced by batch of tf.distributions.Normal(mu, logvar) ?
    """
    
    def __init__(self):
        super(Sampler, self).__init__()
        
    def forward(self, mu, logvar):
        """
        Forward pass of the sampler module.
        
        Args:
            mu: mean of the distribution
            shape (batch, dim)
            logvar: log of the variance of the distribution
            shape (batch, dim)
            
        Returns:
            v: sampled variables
            shape (batch, dim)
        """
        
        # Sample from a normal distribution using the reparameterization trick
        std = torch.exp(0.5 * logvar)  # standard deviation
        eps = torch.randn_like(std)  # random noise
        v = mu + eps * std  # sampled variables
        
        return v

# %% [markdown]
# # Class DeepKalman Filter

# %%
class DeepKalmanFilter(nn.Module):
    """Deep Kalman Filter (DKF) module. Implements the DKF algorithm.
    
    Args:
        nn (_type_): _description_
        
    Returns:
        _type_: _description_
    """
    
    def __init__(self,
                 input_dim=X_DIM, # Dimension of the observation space
                 latent_dim=Z_DIM, # Dimension of the latent space
                 hidden_dim=H_DIM, # Dimension of the hidden state of the LSTM network
                 combiner_dim=G_DIM, # Dimension of the combiner output
                 inter_dim=INTERMEDIATE_LAYER_DIM, # Dimension of the intermediate layers
                 activation='tanh', # Activation function
                 num_layers=1, # Number of layers of the LSTM network
                 device='cpu' # Device to use (cpu or cuda)
                 ):
        super(DeepKalmanFilter, self).__init__()
        
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.hidden_dim = hidden_dim
        self.combiner_dim = combiner_dim
        self.inter_dim = inter_dim
        self.device = device
        
        # define the modules
        
        self.backward_lstm = BackwardLSTM(
            input_size=self.input_dim,
            hidden_size=self.hidden_dim,
            num_layers=num_layers
        )
        
        self.combiner = CombinerMLP(
            latent_dim=self.latent_dim,
            hidden_dim=self.hidden_dim,
            output_dim=self.combiner_dim,
            activation=activation,
            layers_dim=None, # list of layers dimensions, without the input dimension, without the output dimension
            inter_dim=self.inter_dim
        )
        
        self.encoder = EncoderMLP(
            latent_dim=self.latent_dim,
            combiner_dim=self.combiner_dim,
            inter_dim=self.inter_dim,
            activation=activation,
            layers_dim=None, # list of layers dimensions, without the input dimension, without the output dimension
        )
        
        self.latent_space_transition = LatentSpaceTransitionMLP(
            latent_dim=self.latent_dim,
            inter_dim=self.inter_dim,
            activation=activation,
            layers_dim=None, # list of layers dimensions, without the input dimension, without the output dimension
        )
        
        self.decoder = DecoderMLP(
            latent_dim=self.latent_dim,
            observation_dim=self.input_dim,
            inter_dim=self.inter_dim,
            activation=activation,
            layers_dim=None, # list of layers dimensions, without the input dimension, without the output dimension
        )
        
        self.sampler = Sampler()
        
    def forward(self, x_t):
        # """Forward pass of the Deep Kalman Filter.
        # Runs one step inference :
        # 0- Initialization are run (sampled latent variable)
        # 1- The input sequence x_t (seq_len, batch, input_dimension) is passed through the backward LSTM 
        #    to get the hidden states h_t (seq_len, batch, hidden_dim).
        # 2- A sequential loop is run from time t=1 to t=T (seq_len):
        #     2.1- the sampled latent variable at previous time step z_t-1, and the hidden state h_t, are run
        #          through the combiner module to get the tensor g_t.
        #     2.2- the tensor g_t is passed through the encoder module to get the parameters of the approximate posterior 
        #          distribution mu_phi and logvar_phi of the latent variable z_t.
        #     2.3- the  latent variable z_t at time t is sampled from the approximate posterior distribution
        #          using the reparameterization trick. The sampled latent variable z_t is stored in the sequence of
        #          sampled latent variables z_t_s.
        # 3- The whole sequence of sampled latent variables z_t_s is passed through the decoder module
        #    to get the parameters of the distribution of the observed variables x_t.
        # 4- The whole sequence of sampled latent variables z_t_s, lagged by one time step, is passed through the
        #    transition module to get the parameters of the transition distribution of the latent variable z_t. 
        
        # Args:
        #     x_t: input sequence - shape (seq_len, batch, input_dim)
            
        # Intermediate variables:
        #     sampled_z_t : sequence of sampled latent variables - shape (seq_len, batch, latent_dim).
        #     NB : z_0 is set to 0.
        #     h_t : hidden state of the backward LSTM at time t - shape (seq_len, batch, hidden_dim)
            
        # Returns:
        #     mu_x_t: means of the distribution of the observed variables - shape (seq_len, batch, input_dim)
        #     logvar_x_t: log of the variances of the distribution of the observed variables - shape (seq_len, batch, input_dim)
        #     mu_phi_z_t: means of the approximate posterior distribution (q_\phi) of the latent variable - shape (seq_len, batch, latent_dim)
        #     logvar_phi_z_t: log of the variances of the approximate posterior distribution (q_\phi) of the latent variable - shape (seq_len, batch, latent_dim)
        #     mu_theta_z_t: means of the transition distribution (p_\theta_z) of the latent variable - shape (seq_len, batch, latent_dim)
        #     logvar_theta_z_t: log of the variances of the transition distribution (p_\theta_z) of the latent variable - shape (seq_len, batch, latent_dim)
        # """
        
        # we assume that the input sequence is of shape (seq_len, batch, input_dim) and check some
        seq_len, batch_size, input_dim = x_t.shape
        assert input_dim == self.input_dim, f"Input dimension {input_dim} does not match the expected dimension {self.input_dim}"
        
        # initializations of the tensors for the sequential loop
                # NB : in INRIA code : self.register_buffer
                # "If you have parameters in your model, which should be saved and restored in the state_dict, 
                # but not trained by the optimizer, you should register them as buffers.
                # Buffers won’t be returned in model.parameters(), 
                # so that the optimizer won’t have a change to update them.#
        sampled_z_t = torch.zeros(seq_len, batch_size, self.latent_dim).to(self.device)
        z0 = torch.zeros(batch_size, self.latent_dim).to(self.device)  # initial latent variable z_0
        mu_phi_z_t = torch.zeros(seq_len, batch_size, self.latent_dim).to(self.device)
        logvar_phi_z_t = torch.zeros(seq_len, batch_size, self.latent_dim).to(self.device)
        
        # step 1 : run the backward LSTM on the input sequence
        # outputs are the hidden states, shape (seq_len, batch, hidden_dim)
        h_t = self.backward_lstm(x_t)
        
        # step 2 : loop from t=1 to t=T (seq_len) to compute and sampled the latent variables z_t
        for t in range(seq_len):
            
            # step 2.1 : at time t, get the sampled latent variable z_t-1 and the hidden state h_t
            if t == 0:
                sampled_z_t_1 = z0
            else:
                sampled_z_t_1 = sampled_z_t[t-1]
            # combine them to compute g_t
            g_t = self.combiner(h_t[t], sampled_z_t_1) # shpae is (batch_size, combiner_dim)
            
            # step 2.2 : compute the parameters of the approximate posterior distribution
            mu_phi, logvar_phi = self.encoder(g_t) 
            mu_phi_z_t[t], logvar_phi_z_t[t] = mu_phi, logvar_phi
            
            # step 2.3 : sample z_t from the approximate posterior distribution and store it
            sampled_z_t[t] = self.sampler(mu_phi, logvar_phi)
            
        # step 3 : compute the parameters of the observation distribution
        mu_x_t, logvar_x_t = self.decoder(sampled_z_t)
        
        # step 4 : compute the parameters of the transition distribution
        # form the lagged sampled latent variable z_t : z_t[0:seq_len-1]
        lagged_sampled_z_t = torch.cat([z0.unsqueeze(0), sampled_z_t[:-1]])
        mu_theta_z_t, logvar_theta_z_t = self.latent_space_transition(lagged_sampled_z_t) 
                        
        # return the outputs
        return x_t, mu_x_t, logvar_x_t, mu_phi_z_t, logvar_phi_z_t, mu_theta_z_t, logvar_theta_z_t
    
    def __repr__(self):
        
        msg = f"DeepKalmanFilter(input_dim={self.input_dim}, latent_dim={self.latent_dim}, hidden_dim={self.hidden_dim}, combiner_dim={self.combiner_dim}, inter_dim={self.inter_dim})"
        msg += f"\n{self.backward_lstm}"
        msg += f"\n{self.combiner}"
        msg += f"\n{self.encoder}"
        msg += f"\n{self.latent_space_transition}"
        msg += f"\n{self.decoder}"
        msg += f"\n{self.sampler}"
        
        return msg
    
    def predict(self, x, num_steps):
        """
        Predicts future steps based on the input sequence.

        Args:
            x_t (torch.Tensor): Input tensor of shape (seq_len, batch_size, x_dim).
            num_steps (int): Number of future steps to predict.

        Returns:
            mu_predictions (torch.Tensor): Tensor of shape (num_steps, batch_size, x_dim)
            containing the means of the predicted observations at future steps.
            logvar_predictions (torch.Tensor): Tensor of shape (num_steps, batch_size, x_dim)
            containing the log variances of the predicted observations at future steps.
            
            mu_full_x (torch.Tensor): Tensor of shape (seq_len + num_steps, batch_size, x_dim)
            containing the reconstructed input sequence and the means of the predicted future steps.
            logvar_full_x (torch.Tensor): Tensor of shape (seq_len + num_steps, batch_size, x_dim)
            containing the log variances of the reconstructed input sequence and the predicted future steps.
        """
        
        with torch.no_grad():
            
            # get hyperparameters
            seq_len, batch_size, input_dim = x.shape
            assert input_dim == self.input_dim, f"Input dimension {input_dim} does not match the expected dimension {self.input_dim}"
            
            # run an inference forward pass to get the parameters of the observation distribution,
            # the approximate posterior distribution of the latent variable,
            # and the transition distribution of the latent variable            
            x_t, mu_x_t, logvar_x_t, mu_phi_z_t, logvar_phi_z_t, mu_theta_z_t, logvar_theta_z_t = self.forward(x)
            
            
            # use mu_x_t as the first known values of reconstructed x
            x_hat = mu_x_t
            
            # Then, start with the last inferred latent state
            z_pred = mu_phi_z_t[-1:, :, :]

            # Start to predict x at the end of the given sequence
            mu_predictions = torch.zeros(num_steps, batch_size, self.input_dim).to(self.device)
            logvar_predictions = torch.zeros(num_steps, batch_size, self.input_dim).to(self.device)
            
            for s in range(num_steps):
                # Get the parameters (mean and variance) of the transition
                # distribution p(z_t|z_{t-1})
                z_pred_mean, z_pred_logvar = self.latent_space_transition(z_pred)

                # Sample from p(z_t|z_{t-1}) distribution
                z_pred = self.sampler(z_pred_mean, z_pred_logvar)
                
                # get the parameters of the predicted observation distribution
                mu_x_pred, logvar_x_pred = self.decoder(z_pred)
                
                # store those parameters
                mu_predictions[s,:,:] = mu_x_pred
                logvar_predictions[s,:,:] = logvar_x_pred

        # Append predictions to the reconstructed x
        mu_full_x = torch.cat([x_hat, mu_predictions], dim=0)
        logvar_full_x = torch.cat([logvar_x_t, logvar_predictions], dim=0)
        
        return mu_predictions, logvar_predictions, mu_full_x, logvar_full_x

# %% [markdown]
# # Loss function

# %%
def loss_function(x_t, mu_x_t, logvar_x_t, mu_phi_z_t, logvar_phi_z_t, mu_theta_z_t, logvar_theta_z_t, beta=None):
    # """
    # Version 2.0 of the loss function for the Deep Kalman Filter.
    # All distributions parameters are assumed to have been computed from K samples of each z_t.
    # The K samples are used to compute the expectations within the loss function.

    # Args:
    #     x_t (tensor): the original input sequence - shape (seq_len, batch_size, x_dim)

    #     mu_x_t (tensor): the mean of the distribution of the observed variable - shape (seq_len, batch_size, x_dim, K)
    #     logvar_x_t (tensor): the log of the variance of the distribution of the observed variable - shape (seq_len, batch_size, x_dim, K)
    #     mu_phi_z_t (tensor): the mean of the approximate posterior distribution (q_\phi) of the latent variable - shape (seq_len, batch_size, z_dim, K)
    #     logvar_phi_z_t (tensor): the log of the variance of the approximate posterior distribution (q_\phi) of the latent variable - shape (seq_len, batch_size, z_dim, K)
    #     mu_theta_z_t (tensor): the mean of the transition distribution (p_\theta_z) of the latent variable - shape (seq_len, batch_size, z_dim, K)
    #     logvar_theta_z_t (tensor): the log of the variance of the transition distribution (p_\theta_z) of the latent variable - shape (seq_len, batch_size, z_dim, K)

    #     beta (float, optional): the weight of the KL divergence term in the loss function. Defaults to None.
        
    # Returns:
    #     rec_loss (tensor): the reconstruction loss - shape (1,)
    #     kl_loss (tensor): the KL divergence loss - shape (1,)
    #     total_loss (tensor): the total loss - shape (1,)
    # """
    
    seq_len, batch_size, x_dim = x_t.shape
    
    # choose beta
    if beta is None:
        beta = 1.0
        
    # check whether there is a K dimension or not, add K=1 if none given
    if mu_x_t.dim() == 3:
        K = 1
        mu_x_t = mu_x_t.unsqueeze(-1)
        logvar_x_t = logvar_x_t.unsqueeze(-1)
        mu_phi_z_t = mu_phi_z_t.unsqueeze(-1)
        logvar_phi_z_t = logvar_phi_z_t.unsqueeze(-1)
        mu_theta_z_t = mu_theta_z_t.unsqueeze(-1)
        logvar_theta_z_t = logvar_theta_z_t.unsqueeze(-1)
    else:
        K = mu_x_t.shape[-1]
        
    z_dim = mu_phi_z_t.shape[-2]
        
    # compute the expectation of the reconstruction loss with K samples
    
    x_t_extended = x_t.unsqueeze(-1)  # (seq_len, batch_size, x_dim, K)
    var_x = logvar_x_t.exp() # (seq_len, batch_size, x_dim, K)
    
    rec_loss = torch.div((x_t_extended - mu_x_t)**2, var_x)  # (seq_len, batch_size, x_dim, K) - x_t_extended is broadcasted along last axis
    rec_loss += logvar_x_t # (seq_len, batch_size, x_dim, K)
    
    rec_loss = torch.mean(rec_loss, dim=3)  # Mean over the K samples - (seq_len, batch_size, x_dim)
    rec_loss = torch.sum(rec_loss, dim=2)  # Sum over the x_dim - (seq_len, batch_size)
    rec_loss = torch.sum(rec_loss, dim=0)  # Sum over the sequence length - (batch_size)
    rec_loss = torch.mean(rec_loss)  # Mean over the batch - ()
    
    rec_loss = 1/2 * (rec_loss / seq_len)
    
    # compute the expectation of the KL divergence loss with K samples
    
    kl_loss = logvar_theta_z_t - logvar_phi_z_t  # (seq_len, batch_size, z_dim, K)
    kl_loss += torch.div(logvar_phi_z_t.exp(), logvar_theta_z_t.exp()) # (seq_len, batch_size, z_dim, K)
    kl_loss += torch.div((mu_theta_z_t - mu_phi_z_t).pow(2), logvar_theta_z_t.exp())
       
    kl_loss = torch.mean(kl_loss, dim=3)  # Mean over the K samples - (seq_len, batch_size, z_dim)
    kl_loss = torch.sum(kl_loss, dim=2)  # Sum over the z_dim - (seq_len, batch_size)
    kl_loss -= z_dim # shape (seq_len, batch_size)  # Hum... où soustrait-on z_dim ?
    kl_loss = torch.sum(kl_loss, dim=0)  # Sum over the sequence length - (batch_size)
    kl_loss = torch.mean(kl_loss)  # Mean over the batch
    
    kl_loss = 1/2 * kl_loss / seq_len
    
    return rec_loss, kl_loss, rec_loss + beta * kl_loss

# %% [markdown]
# # Toy Case : Data Generation for Time Series Forecasting

# %%
n_steps = 50
n_ahead = 20
n_series = 10000

def generate_time_series(batch_size, n_steps, noise=0.05):
    """Utility function to generate time series data.

    Args:
        batch_size (int): number of time series to generate (btach size)
        n_steps (_type_): length of each time series
    """
    
    f1,f2,o1,o2 = np.random.rand(4, batch_size, 1)  # return 4 values for each time series
    time = np.linspace(0, 1, n_steps)  # time vector
    
    series = 0.8 * np.sin((time - o1) * (f1 * 40 + 10)) # first sine wave
    series += 0.2 * np.sin((time - o1) * (f1 * 20 + 20)) # second sine wave
    series += noise * (np.random.randn(batch_size, n_steps) - 0.5)  # add noise
    
    return series

# %%
s = generate_time_series(n_series, n_steps+n_ahead)

# %%
N = 3
fig, axs = plt.subplots(N, 1, figsize=(16, 3 * N))
for i in range(N):
    axs[i].plot(s[i], color='blue', marker="x", linewidth=1)
    axs[i].set_title(f"Time series {i+1}")
    axs[i].set_xlabel("Time")
    axs[i].set_ylabel("Value")
    axs[i].grid(True)
plt.tight_layout()
plt.show()

# %%
cutoff = int(0.8 * n_series)

X_train, y_train = s[:cutoff,:n_steps], s[:cutoff,n_steps:]
X_valid, y_valid = s[cutoff:,:n_steps], s[cutoff:,n_steps:]

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_valid shape: {X_valid.shape}")
print(f"y_valid shape: {y_valid.shape}")
# Out:
# X_train shape: (8000, 50)
# y_train shape: (8000, 20)
# X_valid shape: (2000, 50)
# y_valid shape: (2000, 20)

# %%
# form datasets, dataloaders, etc

BATCH_SIZE = 4096   # 8192 ok sur RTX3080 et 150 time steps

from torch.utils.data import Dataset, DataLoader

class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X).to(device)
        self.y = torch.tensor(y).to(device)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]
    
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_valid, y_valid)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# # Baseline : RNN

# %%
class RNNModelLookAhead(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim, n_ahead=n_ahead, num_layers=1, batch_first=True, device=device, dtype=dtype):
        """Constructor for RNN.

        Args:
            input_dim (_type_): dimensionality of the input
            hidden_dim (_type_): dimensionality of the hidden state
            n_ahead (_type_, optional): number of time steps to predict. Defaults to N_AHEAD.
            output_dim (_type_, optional): dimensionality of the output.
            num_layers (int, optional): number of recurrent layers. Defaults to 1.
            batch_first (bool, optional): whether batch dim is first or not. Defaults to True.
                1. batch_first=True: (batch, seq, feature_dimension)
                2. batch_first=False: (seq, batch, feature_dimension)
            bidirectional (bool, optional): if True, becomes a bidriectional RNN. Defaults to False.
                1. bidirectional=True: num_directions=2, (batch, seq, hidden_dim * 2)
                2. bidirectional=False: num_directions=1, (batch, seq, hidden_dim)
            device (_type_, optional): _description_. Defaults to device.
            dtype (_type_, optional): _description_. Defaults to dtype.
        """
        super(RNNModelLookAhead, self).__init__()
        
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.batch_first = batch_first
        self.bidirectional = False
        self.n_ahead = n_ahead
        
        self.rnn = nn.RNN(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=batch_first,
            bidirectional=self.bidirectional
        )
        self.fc = nn.Linear(hidden_dim, n_ahead*output_dim)
    
    def forward(self, x):
        # first, initialize the hidden state
        h0 = torch.zeros((self.num_layers, x.size(0), self.hidden_dim), requires_grad=True).to(device)
        # INPUT : x : (batch, sequence_length, input_feature_dimension)
        x, _ = self.rnn(x, h0) 
        # OUTPUT: 
        # - output : (batch, sequence_length, hidden_dimension * num_directions)
        # - h_n : (num_layers * num_directions, batch, hidden_dimension) (hidden state for last time step)
        x = self.fc(x[:, -1, :])  # take the last time step
        x = x.view(-1, self.n_ahead, self.output_dim)
        # OUTPUT: x : (batch, output_dimension)
        return x

# %%
rnn = RNNModelLookAhead(
    input_dim=1,
    output_dim=1,
    n_ahead=n_ahead,
    hidden_dim=128,
    num_layers=4,
    batch_first=True,
    device=device,
    dtype=dtype
).to(device)

print(rnn)
# Out:
# RNNModelLookAhead(
#   (rnn): RNN(1, 128, num_layers=4, batch_first=True)
#   (fc): Linear(in_features=128, out_features=20, bias=True)
# )

# %%
# Test dimensions

x = torch.randn(BATCH_SIZE, 50, 1).to(device)
y = rnn(x)
print(f"input shape: {x.shape}")
print(f"output shape: {y.shape}")
# Out:
# input shape: torch.Size([4096, 50, 1])
# output shape: torch.Size([4096, 20, 1])

# %%
def loss_rnn(y, y_hat):
    """
    Compute the loss for the RNN model.
    
    Args:
        y: target values - shape is (seq_len, batch_size, output_dim)
        y_hat: predicted values - shape is (seq_len, batch_size, output_dim)
    Returns:
        loss: MSE loss
    """
    
    seq_len = y.shape[0]
    batch_size = y.shape[1]
    output_dim = y.shape[2]
    
    # compute the loss
    loss = (y - y_hat)**2
    # print(loss.shape)
    loss = torch.sum(loss, dim=2)  # Sum over the output dimension
    loss = torch.sum(loss, dim=0)  # Sum over the sequence length
    loss = torch.sqrt(loss)  # Square root of the sum
    loss = torch.mean(loss)  # Mean over the batch
    loss = loss / seq_len
    
    return loss

criterion = nn.MSELoss()
# criterion = loss_rnn

# %%
lr = 1e-4
optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)
num_epochs = 200

# %%
train_losses = []
valid_losses = []

print(f"Start training RNN model for {num_epochs} epochs")

for i in range(num_epochs):
    # loop on training data
    rnn.train()
    optimizer.zero_grad()
    ### loop on training data
    epoch_loss = 0
    for input, target in train_loader:
        input = input.to(device).unsqueeze(-1)  # add a feature dimension
        # print(f"input has shape {input.shape}")
        target = target.to(device).view(-1, n_ahead, 1)
        # print(f"target has shape {target.shape}")
        output = rnn(input)
        # print(F"output has shape {output.shape}")
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    epoch_loss /= len(train_loader) 
    train_losses.append(epoch_loss)
    
    # test step
    rnn.eval()
    epoch_loss = 0
    with torch.no_grad():
        for input, target in test_loader:
            input = input.to(device).unsqueeze(-1)  # add a feature dimension
            target = target.to(device).view(-1, n_ahead, 1)
            output = rnn(input)
            loss = criterion(output, target)
            epoch_loss += loss.item()
    epoch_loss /= len(test_loader)
    valid_losses.append(epoch_loss)
    
    # report out
    if (i+1) % 10 == 0:
        print(f"epoch {i+1:>4}/{num_epochs}, training loss = {train_losses[-1]:.4e}, validation loss = {valid_losses[-1]:.4e}")
# Out:
# Start training RNN model for 200 epochs
# epoch   10/200, training loss = 3.7589e-01, validation loss = 3.7372e-01
# epoch   20/200, training loss = 3.4898e-01, validation loss = 3.4510e-01
# epoch   30/200, training loss = 3.1186e-01, validation loss = 3.2140e-01
# epoch   40/200, training loss = 3.0169e-01, validation loss = 3.0300e-01
# epoch   50/200, training loss = 2.8480e-01, validation loss = 2.8099e-01
# epoch   60/200, training loss = 2.6715e-01, validation loss = 2.7021e-01
# epoch   70/200, training loss = 2.5109e-01, validation loss = 2.5599e-01
# epoch   80/200, training loss = 2.4441e-01, validation loss = 2.3696e-01
# epoch   90/200, training loss = 2.2975e-01, validation loss = 2.3311e-01
# epoch  100/200, training loss = 2.0643e-01, validation loss = 1.9792e-01
# epoch  110/200, training loss = 1.7036e-01, validation loss = 1.7171e-01
# epoch  120/200, training loss = 1.4655e-01, validation loss = 1.5259e-01
# epoch  130/200, training loss = 1.4173e-01, validation loss = 1.3445e-01
# epoch  140/200, training loss = 1.2482e-01, validation loss = 1.2695e-01
# epoch  150/200, training loss = 1.1490e-01, validation loss = 1.0736e-01
# epoch  160/200, training loss = 1.1241e-01, validation loss = 1.0274e-01
# epoch  170/200, training loss = 1.0345e-01, validation loss = 1.0677e-01
# epoch  180/200, training loss = 8.9087e-02, validation loss = 9.8208e-02
# epoch  190/200, training loss = 8.6826e-02, validation loss = 8.2624e-02
# epoch  200/200, training loss = 8.8798e-02, validation loss = 8.7277e-02

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 3))
ax.plot(train_losses, label="train")
ax.plot(valid_losses, label="valid")
ax.legend()
ax.set_xlabel("Epoch")
ax.set_xticks(np.arange(0, num_epochs+1, 10))
ax.set_xticklabels(np.arange(0, num_epochs+1, 10))
ax.set_ylabel("Loss")
ax.set_title("Training and Validation Loss")
ax.grid()
plt.show()

# %%
y_pred = rnn(torch.tensor(X_valid).to(device).unsqueeze(-1))
y_target = torch.tensor(y_valid).to(device).unsqueeze(-1)

# print(f"y_target shape: {y_target.shape}")
# print(f"y_pred shape: {y_pred.shape}")

print(f"Loss finale = {criterion(y_pred, y_target):.4e}")

y_pred = y_pred.cpu().detach().numpy()
y_target = y_target.cpu().detach().numpy()

# print(f"\n{np.mean(np.sqrt((y_target - y_pred) ** 2)):.4f} RMSE")
# Out:
# Loss finale = 8.7277e-02

# %%
N = 5
fig, ax  = plt.subplots(N, 1, figsize=(14, 2 * N))
x_shift = X_valid.shape[-1]

for i in range(N):
    input = torch.tensor(X_valid[i], device=device).unsqueeze(0).unsqueeze(-1)
    # input = input.permute(1, 0, 2)  # permute to (seq_len, batch_size, input_dim)
    # print(f"input has shape {input.shape}")
    target = torch.tensor(y_valid[i], device=device).view(-1, n_ahead, 1)
    # target = target.permute(1, 0, 2)  # permute to (seq_len, batch_size, output_dim)
    # print(f"target has shape {target.shape}")
    output = rnn(input)
    output = output.cpu().detach().numpy()
    # print(f"output has shape {output.shape}")
    target = target.cpu().detach().numpy()
    
    ax[i].plot(input.squeeze().cpu().detach().numpy(), color='blue', marker="x", linewidth=1, label="input")
    ax[i].plot(np.arange(len(target.squeeze()))+x_shift, target.squeeze(), color='red', marker="o", linewidth=1, label="ground truth")
    ax[i].plot(np.arange(len(target.squeeze()))+x_shift, output.squeeze(), color='green', marker="*", linewidth=1, label="prediction")
    ax[i].set_title(f"Time series {i+1}")
    ax[i].set_xlabel("Time")
    ax[i].set_ylabel("Value")
    ax[i].legend()
    ax[i].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Training DKF - XP 1
#
# https://www.youtube.com/watch?v=rz76gYgxySo&list=WL&index=1&t=1618s&ab_channel=SimonLeglaive

# %% [markdown]
# <div>
# <img src="/home/benjamin.deporte/MVA/MVA_Stage/DKF_Training.png" width="1500"/>
# </div>

# %%
def train_step(model, optimizer, criterion, train_loader=train_loader, device=device, beta=None, K=None):
    ### training step
    model.train()
    optimizer.zero_grad()
    ### loop on training data
    rec_loss = 0
    kl_loss = 0
    epoch_loss = 0
    ### check on K
    if K is None:
        K=1
        
    x_dim = model.input_dim
    latent_dim = model.latent_dim
    
    for input, _ in train_loader:
        input = input.to(device).unsqueeze(-1)  # add a feature dimension
        input = input.permute(1, 0, 2)  # permute to (seq_len, batch_size, input_dim)

        
        mu_x_t = torch.zeros(input.shape[0], input.shape[1], x_dim, K).to(device)
        logvar_x_t = torch.zeros(input.shape[0], input.shape[1], x_dim, K).to(device)
        mu_phi_z_t = torch.zeros(input.shape[0], input.shape[1], latent_dim, K).to(device)
        logvar_phi_z_t = torch.zeros(input.shape[0], input.shape[1], latent_dim, K).to(device)
        mu_theta_z_t = torch.zeros(input.shape[0], input.shape[1], latent_dim, K).to(device)
        logvar_theta_z_t = torch.zeros(input.shape[0], input.shape[1], latent_dim, K).to(device)

        # get K samples of the parameters of each distribution
        for k in range(K):
            # get the parameters of the distributions
            _, mu_x_t[:, :, :, k], logvar_x_t[:, :, :, k], mu_phi_z_t[:, :, :, k], logvar_phi_z_t[:, :, :, k], mu_theta_z_t[:, :, :, k], logvar_theta_z_t[:, :, :, k] = model(input)
        
        rec_loss, kl_loss, total_loss = criterion(input, mu_x_t, logvar_x_t, mu_phi_z_t, logvar_phi_z_t, mu_theta_z_t, logvar_theta_z_t, beta=beta)
        
        total_loss.backward()
        optimizer.step()
              
        rec_loss += rec_loss.item()
        kl_loss += kl_loss.item()
        epoch_loss += total_loss.item()
        
    epoch_loss /= len(train_loader)
    rec_loss /= len(train_loader)
    kl_loss /= len(train_loader)
    
    return rec_loss, kl_loss, epoch_loss

# %%
# Test step : perform validation test for one epoch

def test_step(model, optimizer, loss_fn, test_loader=test_loader, device=device, beta=None):
    ### test step
    model.eval()
    
    with torch.no_grad():
        ### loop on test data
        rec_loss = 0
        kl_loss = 0
        epoch_loss = 0
        
        for input, _ in test_loader:
            input = input.to(device).unsqueeze(-1)  # add a feature dimension
            input = input.permute(1, 0, 2)  # permute to (seq_len, batch_size, input_dim)

            _, mu_x_s, logvar_x_s, mu_z_s, logvar_z_s, mu_z_transition_s, logvar_z_transition_s = model(input)
            
            rec_loss, kl_loss, total_loss = loss_fn(input, mu_x_s, logvar_x_s, mu_z_s, logvar_z_s, mu_z_transition_s, logvar_z_transition_s, beta=beta)
                
            rec_loss += rec_loss.item()
            kl_loss += kl_loss.item()
            epoch_loss += total_loss.item()
            
        epoch_loss /= len(train_loader)
        rec_loss /= len(train_loader)
        kl_loss /= len(train_loader)
    
    return rec_loss, kl_loss, epoch_loss

# %%
def train(model, optimizer, loss_fn, num_epochs=100, beta=None, beta_scheduler=None, display_frequency=10, K=None):
    
    rec_losses = []
    kl_losses = []
    epoch_losses = []

    val_rec_losses = []
    val_kl_losses = []
    val_epoch_losses = []
    
    if K is None:
        K = 1
        
    print(f"Starting training...")
    if device.type == 'cuda':
        print('GPU Name:', torch.cuda.get_device_name(0))
        print('Total GPU Memory:', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
    print(f"Number of epochs: {num_epochs}")
    print(f"Learning rate: {optimizer.param_groups[0]['lr']:.3e}")
    print(f"Batch size: {BATCH_SIZE}")
    print(f"Beta : {beta:.3e}")
    print(f"K = {K}")
    print(f"Training set size: {len(train_loader.dataset)}")
    print(f"Validation set size: {len(test_loader.dataset)}")
    print(f"Device: {device}")
    print(f"\n")

    for i in range(num_epochs):
        
        # use the beat scheduler if provided
        if beta_scheduler is not None:
            beta = beta_scheduler(i)
        
        # run the training step
        rec_loss, kl_loss, epoch_loss = train_step(model, optimizer, loss_fn, beta=beta, K=K)
        # log results
        rec_losses.append(rec_loss)
        kl_losses.append(kl_loss)
        epoch_losses.append(epoch_loss)
        
        # run test step
        val_rec_loss, val_kl_loss, val_epoch_loss = test_step(model, optimizer, loss_fn, beta=beta)
        # log results
        val_rec_losses.append(val_rec_loss)
        val_kl_losses.append(val_kl_loss)
        val_epoch_losses.append(val_epoch_loss)
        
        # Print the losses for this epoch
        if (i+1) % display_frequency == 0:
            print(f"Epoch {i+1:>5}/{num_epochs} with beta = {beta:.2e} - TRAINING : Rec Loss: {rec_loss:.4e}, KL Loss: {kl_loss:.4e}, Total Loss: {epoch_loss:.4e} - TEST : Rec Loss: {val_rec_loss:.4e}, KL Loss: {val_kl_loss:.4e}, Total Loss: {val_epoch_loss:.4e}")
            
    return rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses

# %%
xdim = 1
latent_dim = 2
h_dim = 16
combiner_dim = 2
num_layers_rnn = 2

# %%
dkf = DeepKalmanFilter(
    input_dim = xdim,
    latent_dim = latent_dim,
    hidden_dim = h_dim,
    combiner_dim = combiner_dim,
    num_layers = num_layers_rnn,
    device=device
).to(device)

print(dkf)
# Out:
# DeepKalmanFilter(input_dim=1, latent_dim=2, hidden_dim=16, combiner_dim=2, inter_dim=16)
# BackwardLSTM(
#   (lstm): LSTM(1, 16, num_layers=2)
# )
# CombinerMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=18, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# EncoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# LatentSpaceTransitionMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# DecoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Sampler()

# %%
optimizer = torch.optim.Adam(dkf.parameters(), lr=1e-3)
loss_fn = loss_function
beta = 1e-3

K = 3

# %%
num_epochs = 450
n_displays = 50
display_frequency = int(num_epochs / n_displays)

# %%
rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses = train(
    dkf, optimizer, loss_fn, num_epochs=num_epochs, beta=beta, display_frequency=display_frequency, K=K
)
# Out:
# Starting training...
# GPU Name: NVIDIA GeForce RTX 4090
# Total GPU Memory: 23.6 GB
# Number of epochs: 450
# Learning rate: 1.000e-03
# Batch size: 4096
# Beta : 1.000e-03
# K = 3
# Training set size: 8000
# Validation set size: 2000
# Device: cuda
#
#
# Epoch     9/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.4435e-01, KL Loss: 1.7692e-01, Total Loss: 2.4703e-01 - TEST : Rec Loss: 2.4063e-01, KL Loss: 1.8214e-01, Total Loss: 1.2040e-01
# Epoch    18/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 1.4504e-01, KL Loss: 3.8610e-01, Total Loss: 1.4781e-01 - TEST : Rec Loss: 1.4175e-01, KL Loss: 4.0232e-01, Total Loss: 7.1075e-02
# Epoch    27/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 6.6737e-02, KL Loss: 6.7172e-01, Total Loss: 7.0031e-02 - TEST : Rec Loss: 6.8502e-02, KL Loss: 6.8611e-01, Total Loss: 3.4594e-02
# Epoch    36/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 4.0242e-02, KL Loss: 8.5908e-01, Total Loss: 4.2538e-02 - TEST : Rec Loss: 4.6034e-02, KL Loss: 8.6197e-01, Total Loss: 2.3448e-02
# Epoch    45/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.7494e-02, KL Loss: 8.1860e-01, Total Loss: 3.7520e-02 - TEST : Rec Loss: 4.1738e-02, KL Loss: 8.1449e-01, Total Loss: 2.1276e-02
# Epoch    54/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.3444e-02, KL Loss: 7.6739e-01, Total Loss: 3.5082e-02 - TEST : Rec Loss: 3.9144e-02, KL Loss: 7.6500e-01, Total Loss: 1.9955e-02
# Epoch    63/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.3002e-02, KL Loss: 7.1560e-01, Total Loss: 3.3996e-02 - TEST : Rec Loss: 3.8492e-02, KL Loss: 7.1162e-01, Total Loss: 1.9602e-02
# Epoch    72/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.4156e-02, KL Loss: 6.2729e-01, Total Loss: 3.3131e-02 - TEST : Rec Loss: 3.7346e-02, KL Loss: 6.2103e-01, Total Loss: 1.8984e-02
# Epoch    81/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.2912e-02, KL Loss: 5.0396e-01, Total Loss: 3.2499e-02 - TEST : Rec Loss: 3.6865e-02, KL Loss: 4.9649e-01, Total Loss: 1.8681e-02
# Epoch    90/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.1583e-02, KL Loss: 3.6628e-01, Total Loss: 3.1975e-02 - TEST : Rec Loss: 3.6786e-02, KL Loss: 3.5879e-01, Total Loss: 1.8572e-02
# Epoch    99/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.1823e-02, KL Loss: 2.3994e-01, Total Loss: 3.1596e-02 - TEST : Rec Loss: 3.6208e-02, KL Loss: 2.3329e-01, Total Loss: 1.8220e-02
# Epoch   108/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.1985e-02, KL Loss: 1.5007e-01, Total Loss: 3.1301e-02 - TEST : Rec Loss: 3.6323e-02, KL Loss: 1.4625e-01, Total Loss: 1.8235e-02
# Epoch   117/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.0026e-02, KL Loss: 9.8979e-02, Total Loss: 3.1090e-02 - TEST : Rec Loss: 3.6027e-02, KL Loss: 9.6944e-02, Total Loss: 1.8062e-02
# Epoch   126/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9623e-02, KL Loss: 7.2234e-02, Total Loss: 3.0894e-02 - TEST : Rec Loss: 3.5873e-02, KL Loss: 7.1446e-02, Total Loss: 1.7972e-02
# Epoch   135/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.1111e-02, KL Loss: 5.9581e-02, Total Loss: 3.0777e-02 - TEST : Rec Loss: 3.5713e-02, KL Loss: 5.9156e-02, Total Loss: 1.7886e-02
# Epoch   144/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.0936e-02, KL Loss: 5.4109e-02, Total Loss: 3.0693e-02 - TEST : Rec Loss: 3.5731e-02, KL Loss: 5.3764e-02, Total Loss: 1.7892e-02
# Epoch   153/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.0202e-02, KL Loss: 5.1611e-02, Total Loss: 3.0602e-02 - TEST : Rec Loss: 3.5600e-02, KL Loss: 5.1381e-02, Total Loss: 1.7826e-02
# Epoch   162/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.8330e-02, KL Loss: 4.9994e-02, Total Loss: 3.0529e-02 - TEST : Rec Loss: 3.5504e-02, KL Loss: 4.9802e-02, Total Loss: 1.7777e-02
# Epoch   171/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.8978e-02, KL Loss: 4.8740e-02, Total Loss: 3.0452e-02 - TEST : Rec Loss: 3.5402e-02, KL Loss: 4.8646e-02, Total Loss: 1.7725e-02
# Epoch   180/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9366e-02, KL Loss: 4.7492e-02, Total Loss: 3.0431e-02 - TEST : Rec Loss: 3.5350e-02, KL Loss: 4.7406e-02, Total Loss: 1.7699e-02
# Epoch   189/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9400e-02, KL Loss: 4.6387e-02, Total Loss: 3.0370e-02 - TEST : Rec Loss: 3.5283e-02, KL Loss: 4.6295e-02, Total Loss: 1.7665e-02
# Epoch   198/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.1440e-02, KL Loss: 4.5343e-02, Total Loss: 3.0409e-02 - TEST : Rec Loss: 3.5274e-02, KL Loss: 4.5230e-02, Total Loss: 1.7660e-02
# Epoch   207/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.1795e-02, KL Loss: 4.4344e-02, Total Loss: 3.0385e-02 - TEST : Rec Loss: 3.5321e-02, KL Loss: 4.4296e-02, Total Loss: 1.7682e-02
# Epoch   216/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9392e-02, KL Loss: 4.3492e-02, Total Loss: 3.0322e-02 - TEST : Rec Loss: 3.5348e-02, KL Loss: 4.3426e-02, Total Loss: 1.7696e-02
# Epoch   225/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.7795e-02, KL Loss: 4.2632e-02, Total Loss: 3.0231e-02 - TEST : Rec Loss: 3.5279e-02, KL Loss: 4.2590e-02, Total Loss: 1.7661e-02
# Epoch   234/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9952e-02, KL Loss: 4.1816e-02, Total Loss: 3.0286e-02 - TEST : Rec Loss: 3.5270e-02, KL Loss: 4.1767e-02, Total Loss: 1.7656e-02
# Epoch   243/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.2015e-02, KL Loss: 4.1064e-02, Total Loss: 3.0297e-02 - TEST : Rec Loss: 3.5236e-02, KL Loss: 4.1031e-02, Total Loss: 1.7639e-02
# Epoch   252/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.2160e-02, KL Loss: 4.0349e-02, Total Loss: 3.0297e-02 - TEST : Rec Loss: 3.5210e-02, KL Loss: 4.0328e-02, Total Loss: 1.7625e-02
# Epoch   261/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9963e-02, KL Loss: 3.9668e-02, Total Loss: 3.0223e-02 - TEST : Rec Loss: 3.5192e-02, KL Loss: 3.9631e-02, Total Loss: 1.7616e-02
# Epoch   270/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.8094e-02, KL Loss: 3.9045e-02, Total Loss: 3.0138e-02 - TEST : Rec Loss: 3.5124e-02, KL Loss: 3.9010e-02, Total Loss: 1.7581e-02
# Epoch   279/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9718e-02, KL Loss: 3.8470e-02, Total Loss: 3.0167e-02 - TEST : Rec Loss: 3.5207e-02, KL Loss: 3.8444e-02, Total Loss: 1.7623e-02
# Epoch   288/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.0526e-02, KL Loss: 3.7896e-02, Total Loss: 3.0198e-02 - TEST : Rec Loss: 3.5158e-02, KL Loss: 3.7895e-02, Total Loss: 1.7598e-02
# Epoch   297/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.1072e-02, KL Loss: 3.7368e-02, Total Loss: 3.0209e-02 - TEST : Rec Loss: 3.5111e-02, KL Loss: 3.7320e-02, Total Loss: 1.7574e-02
# Epoch   306/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9865e-02, KL Loss: 3.6843e-02, Total Loss: 3.0150e-02 - TEST : Rec Loss: 3.5116e-02, KL Loss: 3.6837e-02, Total Loss: 1.7576e-02
# Epoch   315/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9205e-02, KL Loss: 3.6373e-02, Total Loss: 3.0135e-02 - TEST : Rec Loss: 3.5125e-02, KL Loss: 3.6330e-02, Total Loss: 1.7581e-02
# Epoch   324/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.8676e-02, KL Loss: 3.5882e-02, Total Loss: 3.0108e-02 - TEST : Rec Loss: 3.5109e-02, KL Loss: 3.5828e-02, Total Loss: 1.7573e-02
# Epoch   333/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9662e-02, KL Loss: 3.5415e-02, Total Loss: 3.0133e-02 - TEST : Rec Loss: 3.5149e-02, KL Loss: 3.5384e-02, Total Loss: 1.7592e-02
# Epoch   342/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.0578e-02, KL Loss: 3.4961e-02, Total Loss: 3.0133e-02 - TEST : Rec Loss: 3.5118e-02, KL Loss: 3.4928e-02, Total Loss: 1.7577e-02
# Epoch   351/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.0367e-02, KL Loss: 3.4525e-02, Total Loss: 3.0119e-02 - TEST : Rec Loss: 3.5121e-02, KL Loss: 3.4510e-02, Total Loss: 1.7578e-02
# Epoch   360/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.0380e-02, KL Loss: 3.4104e-02, Total Loss: 3.0113e-02 - TEST : Rec Loss: 3.5069e-02, KL Loss: 3.4126e-02, Total Loss: 1.7551e-02
# Epoch   369/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9460e-02, KL Loss: 3.3724e-02, Total Loss: 3.0081e-02 - TEST : Rec Loss: 3.5065e-02, KL Loss: 3.3779e-02, Total Loss: 1.7549e-02
# Epoch   378/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.9823e-02, KL Loss: 3.3539e-02, Total Loss: 3.0079e-02 - TEST : Rec Loss: 3.5071e-02, KL Loss: 3.3551e-02, Total Loss: 1.7552e-02
# Epoch   387/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 3.1742e-02, KL Loss: 3.4168e-02, Total Loss: 3.0045e-02 - TEST : Rec Loss: 3.4980e-02, KL Loss: 3.4421e-02, Total Loss: 1.7507e-02
# Epoch   396/450 with beta = 1.00e-03 - TRAINING : Rec Loss: 2.4563e-02, KL Loss: 1.8189e-01, Total Loss: 2.6977e-02 - TEST : Rec Loss: 2.9290e-02, KL Loss: 2.9220e-01, Total Loss: 1.4791e-02
# Epoch   405/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -2.3405e-01, KL Loss: 3.1996e+00, Total Loss: -2.2077e-01 - TEST : Rec Loss: -2.5027e-01, KL Loss: 3.0321e+00, Total Loss: -1.2362e-01
# Epoch   414/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -6.9188e-01, KL Loss: 1.9070e+00, Total Loss: -6.7169e-01 - TEST : Rec Loss: -7.4206e-01, KL Loss: 1.8511e+00, Total Loss: -3.7010e-01
# Epoch   423/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -1.0058e+00, KL Loss: 2.1203e+00, Total Loss: -1.0108e+00 - TEST : Rec Loss: -1.1971e+00, KL Loss: 2.2181e+00, Total Loss: -5.9745e-01
# Epoch   432/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -9.9662e-01, KL Loss: 2.6628e+00, Total Loss: -9.9900e-01 - TEST : Rec Loss: -1.2297e+00, KL Loss: 2.7415e+00, Total Loss: -6.1345e-01
# Epoch   441/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -1.3095e+00, KL Loss: 3.2296e+00, Total Loss: -1.2508e+00 - TEST : Rec Loss: -1.4952e+00, KL Loss: 3.2041e+00, Total Loss: -7.4599e-01
# Epoch   450/450 with beta = 1.00e-03 - TRAINING : Rec Loss: -1.4677e+00, KL Loss: 3.3363e+00, Total Loss: -1.4225e+00 - TEST : Rec Loss: -1.6356e+00, KL Loss: 3.3717e+00, Total Loss: -8.1612e-01

# %%
def plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses):
    
    # Plot the losses

    fig, axs = plt.subplots(1, 3, figsize=(16, 4))

    axs[0].plot(torch.tensor(rec_losses).cpu().detach(), label='Training', color='blue')
    axs[0].plot(torch.tensor(val_rec_losses).cpu().detach(), label='Test', color='green')
    axs[0].set_title('Reconstruction Loss')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].legend()
    axs[0].grid()

    axs[1].plot(torch.tensor(kl_losses).cpu().detach(), label='Training', color='blue')
    axs[1].plot(torch.tensor(val_kl_losses).cpu().detach(), label='Test', color='green')
    axs[1].set_title('KL Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    axs[1].grid()

    axs[2].plot(torch.tensor(epoch_losses).cpu().detach(), label='Training', color='blue')
    axs[2].plot(torch.tensor(val_epoch_losses).cpu().detach(), label='Test', color='green')
    axs[2].set_title('Total Loss')
    axs[2].set_xlabel('Epochs')
    axs[2].set_ylabel('Loss')
    axs[2].legend()
    axs[2].grid()

    plt.tight_layout()
    plt.show()

# %%
plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses)

# %% [markdown]
# # Predictions

# %%
def sample_predictions(N_SAMPLES=3, model=dkf):
    
    idx = np.random.randint(0, len(X_valid), N_SAMPLES)
    X_valid_subset = X_valid[idx]
    y_valid_subset = y_valid[idx]
    
    fig, axs = plt.subplots(N_SAMPLES, 1, figsize=(16, 3 * N_SAMPLES))
    for i in range(N_SAMPLES):
        input = torch.tensor(X_valid_subset[i], device=device).unsqueeze(1).unsqueeze(2)
        # print(f"input shape : {input.shape}")
        target = torch.tensor(y_valid_subset[i], device=device)
        target = target.cpu().detach().numpy()
        mu_predictions, logvar_predictions, mu_full_x, logvar_full_x = model.predict(input, n_ahead)
              
        # display data
        axs[i].plot(input.squeeze().cpu().detach().numpy(), color='blue', marker="x", linewidth=1, label="input")
        axs[i].plot(np.arange(len(target))+n_steps, target, color='red', marker="o", linewidth=1, label="ground truth")
        
        # display predictions and credible intervals
        all_times = np.arange(n_steps+n_ahead)
        mu_full_x = mu_full_x.squeeze().cpu().detach().numpy()
        logvar_full_x = logvar_full_x.squeeze().cpu().detach().numpy()
        std_full_x = np.exp(logvar_full_x / 2)
        
        axs[i].scatter(all_times, mu_full_x, color='green', marker="*", linewidth=1, label="reconstructed and predicted")
        axs[i].fill_between(all_times, mu_full_x-2*std_full_x, mu_full_x+2*std_full_x, color='orange', label='+/- 2 std', alpha=0.2)
        
        axs[i].set_title(f"Time series {idx[i]}")
        axs[i].set_xlabel("Time")
        axs[i].set_ylabel("Value")
        axs[i].legend()
        axs[i].grid(True)
        
    plt.tight_layout()
    plt.show()

# %%
sample_predictions(N_SAMPLES=5, model=dkf)

# %% [markdown]
# # XP 2
#
# $\beta = 1.0$, n_epochs = 2000

# %%
xdim = 1
latent_dim = 2
h_dim = 16
combiner_dim = 2
num_layers_rnn = 2

# %%
dkf = DeepKalmanFilter(
    input_dim = xdim,
    latent_dim = latent_dim,
    hidden_dim = h_dim,
    combiner_dim = combiner_dim,
    num_layers = num_layers_rnn,
    device=device
).to(device)

print(dkf)
# Out:
# DeepKalmanFilter(input_dim=1, latent_dim=2, hidden_dim=16, combiner_dim=2, inter_dim=16)
# BackwardLSTM(
#   (lstm): LSTM(1, 16, num_layers=2)
# )
# CombinerMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=18, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# EncoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# LatentSpaceTransitionMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# DecoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Sampler()

# %%
optimizer = torch.optim.Adam(dkf.parameters(), lr=1e-4)
loss_fn = loss_function
beta = 1.0

K = 3

# %%
num_epochs = 2000
n_displays = 50
display_frequency = int(num_epochs / n_displays)

# %%
rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses = train(
    dkf, optimizer, loss_fn, num_epochs=num_epochs, beta=beta, display_frequency=display_frequency, K=K
)
# Out:
# Starting training...
# GPU Name: NVIDIA GeForce RTX 4090
# Total GPU Memory: 23.6 GB
# Number of epochs: 2000
# Learning rate: 1.000e-04
# Batch size: 4096
# Beta : 1.000e+00
# K = 3
# Training set size: 8000
# Validation set size: 2000
# Device: cuda
#
#
# Epoch    40/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.3189e-01, KL Loss: 2.4630e-01, Total Loss: 3.7923e-01 - TEST : Rec Loss: 1.3408e-01, KL Loss: 2.4499e-01, Total Loss: 1.8954e-01
# Epoch    80/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.1457e-01, KL Loss: 1.4266e-01, Total Loss: 2.5688e-01 - TEST : Rec Loss: 1.1573e-01, KL Loss: 1.4206e-01, Total Loss: 1.2890e-01
# Epoch   120/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.7685e-02, KL Loss: 8.2363e-02, Total Loss: 1.8035e-01 - TEST : Rec Loss: 1.0061e-01, KL Loss: 8.2100e-02, Total Loss: 9.1353e-02
# Epoch   160/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 8.3794e-02, KL Loss: 4.7581e-02, Total Loss: 1.3158e-01 - TEST : Rec Loss: 8.6892e-02, KL Loss: 4.7038e-02, Total Loss: 6.6965e-02
# Epoch   200/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 7.3598e-02, KL Loss: 2.8844e-02, Total Loss: 1.0134e-01 - TEST : Rec Loss: 7.5569e-02, KL Loss: 2.8660e-02, Total Loss: 5.2115e-02
# Epoch   240/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 6.4450e-02, KL Loss: 1.9447e-02, Total Loss: 8.2740e-02 - TEST : Rec Loss: 6.6771e-02, KL Loss: 1.9374e-02, Total Loss: 4.3073e-02
# Epoch   280/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 5.5990e-02, KL Loss: 1.3957e-02, Total Loss: 6.9826e-02 - TEST : Rec Loss: 5.9971e-02, KL Loss: 1.3818e-02, Total Loss: 3.6894e-02
# Epoch   320/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 5.0195e-02, KL Loss: 1.0101e-02, Total Loss: 6.0475e-02 - TEST : Rec Loss: 5.3970e-02, KL Loss: 1.0092e-02, Total Loss: 3.2031e-02
# Epoch   360/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 4.5483e-02, KL Loss: 7.2962e-03, Total Loss: 5.3238e-02 - TEST : Rec Loss: 4.9778e-02, KL Loss: 7.2316e-03, Total Loss: 2.8505e-02
# Epoch   400/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 4.1120e-02, KL Loss: 5.3277e-03, Total Loss: 4.7837e-02 - TEST : Rec Loss: 4.6809e-02, KL Loss: 5.2847e-03, Total Loss: 2.6047e-02
# Epoch   440/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.8832e-02, KL Loss: 4.0487e-03, Total Loss: 4.3932e-02 - TEST : Rec Loss: 4.4555e-02, KL Loss: 4.0067e-03, Total Loss: 2.4281e-02
# Epoch   480/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.7049e-02, KL Loss: 3.3215e-03, Total Loss: 4.1316e-02 - TEST : Rec Loss: 4.2193e-02, KL Loss: 3.2861e-03, Total Loss: 2.2739e-02
# Epoch   520/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.6783e-02, KL Loss: 2.8917e-03, Total Loss: 3.9408e-02 - TEST : Rec Loss: 4.1243e-02, KL Loss: 2.8666e-03, Total Loss: 2.2055e-02
# Epoch   560/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.5271e-02, KL Loss: 2.6318e-03, Total Loss: 3.8008e-02 - TEST : Rec Loss: 3.9905e-02, KL Loss: 2.6254e-03, Total Loss: 2.1265e-02
# Epoch   600/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3091e-02, KL Loss: 2.4558e-03, Total Loss: 3.6790e-02 - TEST : Rec Loss: 3.9324e-02, KL Loss: 2.4764e-03, Total Loss: 2.0900e-02
# Epoch   640/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3212e-02, KL Loss: 2.3268e-03, Total Loss: 3.5971e-02 - TEST : Rec Loss: 3.8313e-02, KL Loss: 2.3043e-03, Total Loss: 2.0308e-02
# Epoch   680/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1560e-02, KL Loss: 2.2036e-03, Total Loss: 3.5291e-02 - TEST : Rec Loss: 3.7851e-02, KL Loss: 2.1952e-03, Total Loss: 2.0023e-02
# Epoch   720/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3564e-02, KL Loss: 2.0955e-03, Total Loss: 3.4783e-02 - TEST : Rec Loss: 3.7729e-02, KL Loss: 2.1119e-03, Total Loss: 1.9921e-02
# Epoch   760/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2117e-02, KL Loss: 2.0079e-03, Total Loss: 3.4395e-02 - TEST : Rec Loss: 3.6900e-02, KL Loss: 1.9843e-03, Total Loss: 1.9442e-02
# Epoch   800/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1962e-02, KL Loss: 1.9107e-03, Total Loss: 3.3981e-02 - TEST : Rec Loss: 3.6948e-02, KL Loss: 1.9244e-03, Total Loss: 1.9436e-02
# Epoch   840/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2508e-02, KL Loss: 1.8230e-03, Total Loss: 3.3698e-02 - TEST : Rec Loss: 3.6650e-02, KL Loss: 1.8222e-03, Total Loss: 1.9236e-02
# Epoch   880/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1524e-02, KL Loss: 1.7378e-03, Total Loss: 3.3362e-02 - TEST : Rec Loss: 3.6825e-02, KL Loss: 1.7300e-03, Total Loss: 1.9278e-02
# Epoch   920/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1604e-02, KL Loss: 1.6545e-03, Total Loss: 3.3196e-02 - TEST : Rec Loss: 3.6521e-02, KL Loss: 1.6418e-03, Total Loss: 1.9081e-02
# Epoch   960/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1702e-02, KL Loss: 1.5771e-03, Total Loss: 3.2964e-02 - TEST : Rec Loss: 3.6376e-02, KL Loss: 1.5779e-03, Total Loss: 1.8977e-02
# Epoch  1000/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1300e-02, KL Loss: 1.5035e-03, Total Loss: 3.2760e-02 - TEST : Rec Loss: 3.6325e-02, KL Loss: 1.4972e-03, Total Loss: 1.8911e-02
# Epoch  1040/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2891e-02, KL Loss: 1.4269e-03, Total Loss: 3.2699e-02 - TEST : Rec Loss: 3.6365e-02, KL Loss: 1.4222e-03, Total Loss: 1.8894e-02
# Epoch  1080/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9074e-02, KL Loss: 1.3633e-03, Total Loss: 3.2543e-02 - TEST : Rec Loss: 3.6077e-02, KL Loss: 1.3506e-03, Total Loss: 1.8714e-02
# Epoch  1120/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1289e-02, KL Loss: 1.2857e-03, Total Loss: 3.2420e-02 - TEST : Rec Loss: 3.6045e-02, KL Loss: 1.2919e-03, Total Loss: 1.8668e-02
# Epoch  1160/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0172e-02, KL Loss: 1.2283e-03, Total Loss: 3.2292e-02 - TEST : Rec Loss: 3.6099e-02, KL Loss: 1.2238e-03, Total Loss: 1.8661e-02
# Epoch  1200/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2073e-02, KL Loss: 1.1661e-03, Total Loss: 3.2191e-02 - TEST : Rec Loss: 3.6036e-02, KL Loss: 1.1525e-03, Total Loss: 1.8594e-02
# Epoch  1240/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1376e-02, KL Loss: 1.1051e-03, Total Loss: 3.2114e-02 - TEST : Rec Loss: 3.5858e-02, KL Loss: 1.0938e-03, Total Loss: 1.8476e-02
# Epoch  1280/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3285e-02, KL Loss: 1.0446e-03, Total Loss: 3.2057e-02 - TEST : Rec Loss: 3.5673e-02, KL Loss: 1.0489e-03, Total Loss: 1.8361e-02
# Epoch  1320/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0143e-02, KL Loss: 9.8599e-04, Total Loss: 3.1885e-02 - TEST : Rec Loss: 3.5861e-02, KL Loss: 9.8633e-04, Total Loss: 1.8424e-02
# Epoch  1360/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3038e-02, KL Loss: 9.3439e-04, Total Loss: 3.1820e-02 - TEST : Rec Loss: 3.5980e-02, KL Loss: 9.3415e-04, Total Loss: 1.8457e-02
# Epoch  1400/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0527e-02, KL Loss: 8.8242e-04, Total Loss: 3.1694e-02 - TEST : Rec Loss: 3.5731e-02, KL Loss: 8.7773e-04, Total Loss: 1.8305e-02
# Epoch  1440/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2076e-02, KL Loss: 8.3606e-04, Total Loss: 3.1661e-02 - TEST : Rec Loss: 3.5759e-02, KL Loss: 8.3888e-04, Total Loss: 1.8299e-02
# Epoch  1480/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0312e-02, KL Loss: 7.9042e-04, Total Loss: 3.1533e-02 - TEST : Rec Loss: 3.5871e-02, KL Loss: 7.8131e-04, Total Loss: 1.8326e-02
# Epoch  1520/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1320e-02, KL Loss: 7.4930e-04, Total Loss: 3.1475e-02 - TEST : Rec Loss: 3.5843e-02, KL Loss: 7.5245e-04, Total Loss: 1.8298e-02
# Epoch  1560/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2582e-02, KL Loss: 7.1036e-04, Total Loss: 3.1486e-02 - TEST : Rec Loss: 3.5798e-02, KL Loss: 7.0650e-04, Total Loss: 1.8252e-02
# Epoch  1600/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1934e-02, KL Loss: 6.7013e-04, Total Loss: 3.1418e-02 - TEST : Rec Loss: 3.5617e-02, KL Loss: 6.7137e-04, Total Loss: 1.8144e-02
# Epoch  1640/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0802e-02, KL Loss: 6.3443e-04, Total Loss: 3.1287e-02 - TEST : Rec Loss: 3.5761e-02, KL Loss: 6.3924e-04, Total Loss: 1.8200e-02
# Epoch  1680/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9569e-02, KL Loss: 6.0340e-04, Total Loss: 3.1220e-02 - TEST : Rec Loss: 3.5573e-02, KL Loss: 5.9719e-04, Total Loss: 1.8085e-02
# Epoch  1720/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0319e-02, KL Loss: 5.7025e-04, Total Loss: 3.1175e-02 - TEST : Rec Loss: 3.5741e-02, KL Loss: 5.7197e-04, Total Loss: 1.8157e-02
# Epoch  1760/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9333e-02, KL Loss: 5.4265e-04, Total Loss: 3.1116e-02 - TEST : Rec Loss: 3.5560e-02, KL Loss: 5.4084e-04, Total Loss: 1.8051e-02
# Epoch  1800/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0134e-02, KL Loss: 5.1346e-04, Total Loss: 3.1061e-02 - TEST : Rec Loss: 3.5512e-02, KL Loss: 5.0947e-04, Total Loss: 1.8011e-02
# Epoch  1840/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0654e-02, KL Loss: 4.8605e-04, Total Loss: 3.1080e-02 - TEST : Rec Loss: 3.5525e-02, KL Loss: 4.8214e-04, Total Loss: 1.8003e-02
# Epoch  1880/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0675e-02, KL Loss: 4.6510e-04, Total Loss: 3.0979e-02 - TEST : Rec Loss: 3.5633e-02, KL Loss: 4.6823e-04, Total Loss: 1.8050e-02
# Epoch  1920/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0992e-02, KL Loss: 4.3983e-04, Total Loss: 3.0965e-02 - TEST : Rec Loss: 3.5591e-02, KL Loss: 4.4190e-04, Total Loss: 1.8016e-02
# Epoch  1960/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0135e-02, KL Loss: 4.1802e-04, Total Loss: 3.0882e-02 - TEST : Rec Loss: 3.5416e-02, KL Loss: 4.2423e-04, Total Loss: 1.7920e-02
# Epoch  2000/2000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9602e-02, KL Loss: 3.9550e-04, Total Loss: 3.0840e-02 - TEST : Rec Loss: 3.5387e-02, KL Loss: 3.9070e-04, Total Loss: 1.7889e-02

# %%
plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses)

# %%
sample_predictions(N_SAMPLES=5, model=dkf)

# %% [markdown]
# # XP 3
#
# Réseau plus expressif, $\beta = 1.0$, 5000 epochs, K=10

# %%
xdim = 1
latent_dim = 8
h_dim = 32
combiner_dim = 4
num_layers_rnn = 4

# %%
dkf = DeepKalmanFilter(
    input_dim = xdim,
    latent_dim = latent_dim,
    hidden_dim = h_dim,
    combiner_dim = combiner_dim,
    num_layers = num_layers_rnn,
    device=device
).to(device)

print(dkf)
# Out:
# DeepKalmanFilter(input_dim=1, latent_dim=8, hidden_dim=32, combiner_dim=4, inter_dim=16)
# BackwardLSTM(
#   (lstm): LSTM(1, 32, num_layers=4)
# )
# CombinerMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=40, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=4, bias=True)
#   )
# )
# EncoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=4, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=16, out_features=16, bias=True)
#   )
# )
# LatentSpaceTransitionMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#   )
# )
# DecoderMLP(
#   (activation_fn): Tanh()
#   (mlp): Sequential(
#     (0): Linear(in_features=8, out_features=16, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Sampler()

# %%
optimizer = torch.optim.Adam(dkf.parameters(), lr=1e-4)
loss_fn = loss_function
beta = 1.0

K = 10

# %%
num_epochs = 5000
n_displays = 200
display_frequency = int(num_epochs / n_displays)

# %%
rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses = train(
    dkf, optimizer, loss_fn, num_epochs=num_epochs, beta=beta, display_frequency=display_frequency, K=K
)
# Out:
# Starting training...
# GPU Name: NVIDIA GeForce RTX 4090
# Total GPU Memory: 23.6 GB
# Number of epochs: 5000
# Learning rate: 1.000e-04
# Batch size: 4096
# Beta : 1.000e+00
# K = 10
# Training set size: 8000
# Validation set size: 2000
# Device: cuda
#
#
# Epoch    25/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.2969e-01, KL Loss: 4.2827e-01, Total Loss: 6.5839e-01 - TEST : Rec Loss: 2.3173e-01, KL Loss: 4.2632e-01, Total Loss: 3.2902e-01
# Epoch    50/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.0945e-01, KL Loss: 3.4999e-01, Total Loss: 5.6074e-01 - TEST : Rec Loss: 2.1360e-01, KL Loss: 3.4945e-01, Total Loss: 2.8152e-01
# Epoch    75/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.9429e-01, KL Loss: 2.8649e-01, Total Loss: 4.8084e-01 - TEST : Rec Loss: 1.9650e-01, KL Loss: 2.8605e-01, Total Loss: 2.4127e-01
# Epoch   100/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.7873e-01, KL Loss: 2.3558e-01, Total Loss: 4.1497e-01 - TEST : Rec Loss: 1.8250e-01, KL Loss: 2.3446e-01, Total Loss: 2.0848e-01
# Epoch   125/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.6450e-01, KL Loss: 1.9437e-01, Total Loss: 3.5960e-01 - TEST : Rec Loss: 1.6673e-01, KL Loss: 1.9328e-01, Total Loss: 1.8001e-01
# Epoch   150/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.5096e-01, KL Loss: 1.6005e-01, Total Loss: 3.1168e-01 - TEST : Rec Loss: 1.5348e-01, KL Loss: 1.5908e-01, Total Loss: 1.5628e-01
# Epoch   175/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.3881e-01, KL Loss: 1.3088e-01, Total Loss: 2.6948e-01 - TEST : Rec Loss: 1.4123e-01, KL Loss: 1.3048e-01, Total Loss: 1.3586e-01
# Epoch   200/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.2561e-01, KL Loss: 1.0682e-01, Total Loss: 2.3340e-01 - TEST : Rec Loss: 1.2916e-01, KL Loss: 1.0638e-01, Total Loss: 1.1777e-01
# Epoch   225/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.1464e-01, KL Loss: 8.7430e-02, Total Loss: 2.0244e-01 - TEST : Rec Loss: 1.1783e-01, KL Loss: 8.7159e-02, Total Loss: 1.0249e-01
# Epoch   250/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 1.0379e-01, KL Loss: 7.2134e-02, Total Loss: 1.7658e-01 - TEST : Rec Loss: 1.0710e-01, KL Loss: 7.1828e-02, Total Loss: 8.9462e-02
# Epoch   275/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 9.4261e-02, KL Loss: 5.9897e-02, Total Loss: 1.5459e-01 - TEST : Rec Loss: 9.8192e-02, KL Loss: 5.9563e-02, Total Loss: 7.8878e-02
# Epoch   300/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 8.5261e-02, KL Loss: 5.0085e-02, Total Loss: 1.3608e-01 - TEST : Rec Loss: 8.9070e-02, KL Loss: 4.9874e-02, Total Loss: 6.9472e-02
# Epoch   325/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 7.7031e-02, KL Loss: 4.2109e-02, Total Loss: 1.2036e-01 - TEST : Rec Loss: 8.1452e-02, KL Loss: 4.1925e-02, Total Loss: 6.1688e-02
# Epoch   350/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 7.1766e-02, KL Loss: 3.5559e-02, Total Loss: 1.0706e-01 - TEST : Rec Loss: 7.4829e-02, KL Loss: 3.5472e-02, Total Loss: 5.5151e-02
# Epoch   375/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 6.5332e-02, KL Loss: 3.0097e-02, Total Loss: 9.5659e-02 - TEST : Rec Loss: 6.9036e-02, KL Loss: 2.9998e-02, Total Loss: 4.9517e-02
# Epoch   400/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 6.0004e-02, KL Loss: 2.5595e-02, Total Loss: 8.5889e-02 - TEST : Rec Loss: 6.3168e-02, KL Loss: 2.5529e-02, Total Loss: 4.4349e-02
# Epoch   425/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 5.6189e-02, KL Loss: 2.1848e-02, Total Loss: 7.7602e-02 - TEST : Rec Loss: 5.9483e-02, KL Loss: 2.1775e-02, Total Loss: 4.0629e-02
# Epoch   450/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 5.0441e-02, KL Loss: 1.8814e-02, Total Loss: 7.0727e-02 - TEST : Rec Loss: 5.5267e-02, KL Loss: 1.8799e-02, Total Loss: 3.7033e-02
# Epoch   475/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 4.9218e-02, KL Loss: 1.6356e-02, Total Loss: 6.5028e-02 - TEST : Rec Loss: 5.2692e-02, KL Loss: 1.6339e-02, Total Loss: 3.4515e-02
# Epoch   500/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 4.5939e-02, KL Loss: 1.4366e-02, Total Loss: 6.0329e-02 - TEST : Rec Loss: 4.9909e-02, KL Loss: 1.4373e-02, Total Loss: 3.2141e-02
# Epoch   525/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 4.4188e-02, KL Loss: 1.2734e-02, Total Loss: 5.6277e-02 - TEST : Rec Loss: 4.7586e-02, KL Loss: 1.2744e-02, Total Loss: 3.0165e-02
# Epoch   550/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 4.0375e-02, KL Loss: 1.1404e-02, Total Loss: 5.2879e-02 - TEST : Rec Loss: 4.5991e-02, KL Loss: 1.1404e-02, Total Loss: 2.8698e-02
# Epoch   575/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.9465e-02, KL Loss: 1.0288e-02, Total Loss: 5.0092e-02 - TEST : Rec Loss: 4.4028e-02, KL Loss: 1.0311e-02, Total Loss: 2.7169e-02
# Epoch   600/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.7951e-02, KL Loss: 9.3526e-03, Total Loss: 4.7789e-02 - TEST : Rec Loss: 4.2846e-02, KL Loss: 9.3563e-03, Total Loss: 2.6101e-02
# Epoch   625/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.7295e-02, KL Loss: 8.5604e-03, Total Loss: 4.5793e-02 - TEST : Rec Loss: 4.1498e-02, KL Loss: 8.5192e-03, Total Loss: 2.5008e-02
# Epoch   650/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.5028e-02, KL Loss: 7.8731e-03, Total Loss: 4.4054e-02 - TEST : Rec Loss: 4.0865e-02, KL Loss: 7.9092e-03, Total Loss: 2.4387e-02
# Epoch   675/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.4708e-02, KL Loss: 7.2882e-03, Total Loss: 4.2623e-02 - TEST : Rec Loss: 3.9998e-02, KL Loss: 7.2589e-03, Total Loss: 2.3628e-02
# Epoch   700/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.4769e-02, KL Loss: 6.7829e-03, Total Loss: 4.1440e-02 - TEST : Rec Loss: 3.9223e-02, KL Loss: 6.7701e-03, Total Loss: 2.2997e-02
# Epoch   725/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3639e-02, KL Loss: 6.3314e-03, Total Loss: 4.0399e-02 - TEST : Rec Loss: 3.8860e-02, KL Loss: 6.3073e-03, Total Loss: 2.2584e-02
# Epoch   750/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3765e-02, KL Loss: 5.9458e-03, Total Loss: 3.9503e-02 - TEST : Rec Loss: 3.8371e-02, KL Loss: 5.9227e-03, Total Loss: 2.2147e-02
# Epoch   775/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.4369e-02, KL Loss: 5.6090e-03, Total Loss: 3.8752e-02 - TEST : Rec Loss: 3.8235e-02, KL Loss: 5.6084e-03, Total Loss: 2.1922e-02
# Epoch   800/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.4293e-02, KL Loss: 5.3157e-03, Total Loss: 3.8191e-02 - TEST : Rec Loss: 3.7357e-02, KL Loss: 5.3341e-03, Total Loss: 2.1346e-02
# Epoch   825/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2871e-02, KL Loss: 5.0402e-03, Total Loss: 3.7575e-02 - TEST : Rec Loss: 3.6839e-02, KL Loss: 5.0503e-03, Total Loss: 2.0945e-02
# Epoch   850/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3082e-02, KL Loss: 4.8095e-03, Total Loss: 3.7082e-02 - TEST : Rec Loss: 3.7163e-02, KL Loss: 4.7731e-03, Total Loss: 2.0968e-02
# Epoch   875/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2824e-02, KL Loss: 4.5892e-03, Total Loss: 3.6717e-02 - TEST : Rec Loss: 3.6952e-02, KL Loss: 4.5682e-03, Total Loss: 2.0760e-02
# Epoch   900/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1760e-02, KL Loss: 4.3904e-03, Total Loss: 3.6331e-02 - TEST : Rec Loss: 3.6695e-02, KL Loss: 4.4239e-03, Total Loss: 2.0560e-02
# Epoch   925/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0949e-02, KL Loss: 4.2053e-03, Total Loss: 3.5999e-02 - TEST : Rec Loss: 3.6669e-02, KL Loss: 4.1973e-03, Total Loss: 2.0433e-02
# Epoch   950/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2481e-02, KL Loss: 4.0504e-03, Total Loss: 3.5777e-02 - TEST : Rec Loss: 3.6687e-02, KL Loss: 4.0551e-03, Total Loss: 2.0371e-02
# Epoch   975/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1655e-02, KL Loss: 3.8979e-03, Total Loss: 3.5566e-02 - TEST : Rec Loss: 3.6403e-02, KL Loss: 3.8749e-03, Total Loss: 2.0139e-02
# Epoch  1000/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3653e-02, KL Loss: 3.7548e-03, Total Loss: 3.5385e-02 - TEST : Rec Loss: 3.6479e-02, KL Loss: 3.7433e-03, Total Loss: 2.0111e-02
# Epoch  1025/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.3320e-02, KL Loss: 3.6191e-03, Total Loss: 3.5135e-02 - TEST : Rec Loss: 3.6554e-02, KL Loss: 3.6132e-03, Total Loss: 2.0084e-02
# Epoch  1050/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0281e-02, KL Loss: 3.4934e-03, Total Loss: 3.4901e-02 - TEST : Rec Loss: 3.6357e-02, KL Loss: 3.4695e-03, Total Loss: 1.9913e-02
# Epoch  1075/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2649e-02, KL Loss: 3.3718e-03, Total Loss: 3.4838e-02 - TEST : Rec Loss: 3.6141e-02, KL Loss: 3.3867e-03, Total Loss: 1.9764e-02
# Epoch  1100/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0578e-02, KL Loss: 3.2678e-03, Total Loss: 3.4625e-02 - TEST : Rec Loss: 3.6435e-02, KL Loss: 3.2566e-03, Total Loss: 1.9846e-02
# Epoch  1125/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0592e-02, KL Loss: 3.1601e-03, Total Loss: 3.4463e-02 - TEST : Rec Loss: 3.6267e-02, KL Loss: 3.1417e-03, Total Loss: 1.9704e-02
# Epoch  1150/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1452e-02, KL Loss: 3.0656e-03, Total Loss: 3.4379e-02 - TEST : Rec Loss: 3.6199e-02, KL Loss: 3.0358e-03, Total Loss: 1.9618e-02
# Epoch  1175/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1872e-02, KL Loss: 2.9578e-03, Total Loss: 3.4223e-02 - TEST : Rec Loss: 3.6296e-02, KL Loss: 2.9393e-03, Total Loss: 1.9617e-02
# Epoch  1200/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1433e-02, KL Loss: 2.8713e-03, Total Loss: 3.4066e-02 - TEST : Rec Loss: 3.6112e-02, KL Loss: 2.8668e-03, Total Loss: 1.9489e-02
# Epoch  1225/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1440e-02, KL Loss: 2.7869e-03, Total Loss: 3.3987e-02 - TEST : Rec Loss: 3.5956e-02, KL Loss: 2.8078e-03, Total Loss: 1.9382e-02
# Epoch  1250/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1623e-02, KL Loss: 2.7068e-03, Total Loss: 3.3871e-02 - TEST : Rec Loss: 3.6196e-02, KL Loss: 2.7070e-03, Total Loss: 1.9452e-02
# Epoch  1275/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1519e-02, KL Loss: 2.6213e-03, Total Loss: 3.3734e-02 - TEST : Rec Loss: 3.6152e-02, KL Loss: 2.6306e-03, Total Loss: 1.9391e-02
# Epoch  1300/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9656e-02, KL Loss: 2.5445e-03, Total Loss: 3.3596e-02 - TEST : Rec Loss: 3.6004e-02, KL Loss: 2.5386e-03, Total Loss: 1.9272e-02
# Epoch  1325/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1874e-02, KL Loss: 2.4713e-03, Total Loss: 3.3573e-02 - TEST : Rec Loss: 3.5890e-02, KL Loss: 2.4485e-03, Total Loss: 1.9169e-02
# Epoch  1350/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1939e-02, KL Loss: 2.3960e-03, Total Loss: 3.3471e-02 - TEST : Rec Loss: 3.6103e-02, KL Loss: 2.3991e-03, Total Loss: 1.9251e-02
# Epoch  1375/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1923e-02, KL Loss: 2.3257e-03, Total Loss: 3.3377e-02 - TEST : Rec Loss: 3.6016e-02, KL Loss: 2.3190e-03, Total Loss: 1.9168e-02
# Epoch  1400/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0972e-02, KL Loss: 2.2639e-03, Total Loss: 3.3254e-02 - TEST : Rec Loss: 3.5813e-02, KL Loss: 2.2719e-03, Total Loss: 1.9043e-02
# Epoch  1425/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2932e-02, KL Loss: 2.1930e-03, Total Loss: 3.3206e-02 - TEST : Rec Loss: 3.5806e-02, KL Loss: 2.1793e-03, Total Loss: 1.8993e-02
# Epoch  1450/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0500e-02, KL Loss: 2.1311e-03, Total Loss: 3.3049e-02 - TEST : Rec Loss: 3.6095e-02, KL Loss: 2.1367e-03, Total Loss: 1.9116e-02
# Epoch  1475/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9780e-02, KL Loss: 2.0693e-03, Total Loss: 3.2933e-02 - TEST : Rec Loss: 3.5917e-02, KL Loss: 2.0813e-03, Total Loss: 1.8999e-02
# Epoch  1500/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1853e-02, KL Loss: 2.0157e-03, Total Loss: 3.2915e-02 - TEST : Rec Loss: 3.5939e-02, KL Loss: 1.9931e-03, Total Loss: 1.8966e-02
# Epoch  1525/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0704e-02, KL Loss: 1.9608e-03, Total Loss: 3.2819e-02 - TEST : Rec Loss: 3.5910e-02, KL Loss: 1.9674e-03, Total Loss: 1.8939e-02
# Epoch  1550/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1425e-02, KL Loss: 1.9062e-03, Total Loss: 3.2740e-02 - TEST : Rec Loss: 3.5772e-02, KL Loss: 1.9093e-03, Total Loss: 1.8841e-02
# Epoch  1575/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1661e-02, KL Loss: 1.8530e-03, Total Loss: 3.2694e-02 - TEST : Rec Loss: 3.5919e-02, KL Loss: 1.8422e-03, Total Loss: 1.8880e-02
# Epoch  1600/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9560e-02, KL Loss: 1.7989e-03, Total Loss: 3.2580e-02 - TEST : Rec Loss: 3.5873e-02, KL Loss: 1.8061e-03, Total Loss: 1.8839e-02
# Epoch  1625/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1154e-02, KL Loss: 1.7509e-03, Total Loss: 3.2522e-02 - TEST : Rec Loss: 3.5955e-02, KL Loss: 1.7416e-03, Total Loss: 1.8848e-02
# Epoch  1650/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1229e-02, KL Loss: 1.6961e-03, Total Loss: 3.2478e-02 - TEST : Rec Loss: 3.5841e-02, KL Loss: 1.7066e-03, Total Loss: 1.8774e-02
# Epoch  1675/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1625e-02, KL Loss: 1.6518e-03, Total Loss: 3.2390e-02 - TEST : Rec Loss: 3.5747e-02, KL Loss: 1.6410e-03, Total Loss: 1.8694e-02
# Epoch  1700/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0097e-02, KL Loss: 1.6034e-03, Total Loss: 3.2302e-02 - TEST : Rec Loss: 3.5753e-02, KL Loss: 1.6088e-03, Total Loss: 1.8681e-02
# Epoch  1725/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9396e-02, KL Loss: 1.5590e-03, Total Loss: 3.2234e-02 - TEST : Rec Loss: 3.5717e-02, KL Loss: 1.5553e-03, Total Loss: 1.8636e-02
# Epoch  1750/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0244e-02, KL Loss: 1.5144e-03, Total Loss: 3.2174e-02 - TEST : Rec Loss: 3.5845e-02, KL Loss: 1.5157e-03, Total Loss: 1.8680e-02
# Epoch  1775/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0498e-02, KL Loss: 1.4715e-03, Total Loss: 3.2135e-02 - TEST : Rec Loss: 3.5630e-02, KL Loss: 1.4720e-03, Total Loss: 1.8551e-02
# Epoch  1800/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1671e-02, KL Loss: 1.4300e-03, Total Loss: 3.2090e-02 - TEST : Rec Loss: 3.5663e-02, KL Loss: 1.4190e-03, Total Loss: 1.8541e-02
# Epoch  1825/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0302e-02, KL Loss: 1.3883e-03, Total Loss: 3.1993e-02 - TEST : Rec Loss: 3.5509e-02, KL Loss: 1.3865e-03, Total Loss: 1.8448e-02
# Epoch  1850/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9615e-02, KL Loss: 1.3498e-03, Total Loss: 3.1941e-02 - TEST : Rec Loss: 3.5510e-02, KL Loss: 1.3499e-03, Total Loss: 1.8430e-02
# Epoch  1875/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1725e-02, KL Loss: 1.3120e-03, Total Loss: 3.1921e-02 - TEST : Rec Loss: 3.5692e-02, KL Loss: 1.3138e-03, Total Loss: 1.8503e-02
# Epoch  1900/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1638e-02, KL Loss: 1.2751e-03, Total Loss: 3.1862e-02 - TEST : Rec Loss: 3.5711e-02, KL Loss: 1.2694e-03, Total Loss: 1.8490e-02
# Epoch  1925/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1019e-02, KL Loss: 1.2396e-03, Total Loss: 3.1801e-02 - TEST : Rec Loss: 3.5597e-02, KL Loss: 1.2374e-03, Total Loss: 1.8417e-02
# Epoch  1950/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0546e-02, KL Loss: 1.2023e-03, Total Loss: 3.1706e-02 - TEST : Rec Loss: 3.5618e-02, KL Loss: 1.2047e-03, Total Loss: 1.8411e-02
# Epoch  1975/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9268e-02, KL Loss: 1.1726e-03, Total Loss: 3.1661e-02 - TEST : Rec Loss: 3.5671e-02, KL Loss: 1.1631e-03, Total Loss: 1.8417e-02
# Epoch  2000/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1207e-02, KL Loss: 1.1413e-03, Total Loss: 3.1670e-02 - TEST : Rec Loss: 3.5673e-02, KL Loss: 1.1363e-03, Total Loss: 1.8405e-02
# Epoch  2025/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0473e-02, KL Loss: 1.1092e-03, Total Loss: 3.1601e-02 - TEST : Rec Loss: 3.5457e-02, KL Loss: 1.1085e-03, Total Loss: 1.8283e-02
# Epoch  2050/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1379e-02, KL Loss: 1.0752e-03, Total Loss: 3.1549e-02 - TEST : Rec Loss: 3.5381e-02, KL Loss: 1.0789e-03, Total Loss: 1.8230e-02
# Epoch  2075/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0873e-02, KL Loss: 1.0453e-03, Total Loss: 3.1479e-02 - TEST : Rec Loss: 3.5436e-02, KL Loss: 1.0402e-03, Total Loss: 1.8238e-02
# Epoch  2100/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0295e-02, KL Loss: 1.0126e-03, Total Loss: 3.1450e-02 - TEST : Rec Loss: 3.5484e-02, KL Loss: 1.0152e-03, Total Loss: 1.8250e-02
# Epoch  2125/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1641e-02, KL Loss: 9.8352e-04, Total Loss: 3.1444e-02 - TEST : Rec Loss: 3.5432e-02, KL Loss: 9.8202e-04, Total Loss: 1.8207e-02
# Epoch  2150/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1576e-02, KL Loss: 9.5731e-04, Total Loss: 3.1402e-02 - TEST : Rec Loss: 3.5509e-02, KL Loss: 9.5099e-04, Total Loss: 1.8230e-02
# Epoch  2175/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1357e-02, KL Loss: 9.2985e-04, Total Loss: 3.1368e-02 - TEST : Rec Loss: 3.5490e-02, KL Loss: 9.2173e-04, Total Loss: 1.8206e-02
# Epoch  2200/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1811e-02, KL Loss: 9.0175e-04, Total Loss: 3.1330e-02 - TEST : Rec Loss: 3.5528e-02, KL Loss: 8.9970e-04, Total Loss: 1.8214e-02
# Epoch  2225/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9698e-02, KL Loss: 8.7594e-04, Total Loss: 3.1248e-02 - TEST : Rec Loss: 3.5314e-02, KL Loss: 8.7236e-04, Total Loss: 1.8093e-02
# Epoch  2250/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9305e-02, KL Loss: 8.4905e-04, Total Loss: 3.1187e-02 - TEST : Rec Loss: 3.5319e-02, KL Loss: 8.5369e-04, Total Loss: 1.8087e-02
# Epoch  2275/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.8448e-02, KL Loss: 8.2248e-04, Total Loss: 3.1142e-02 - TEST : Rec Loss: 3.5523e-02, KL Loss: 8.1783e-04, Total Loss: 1.8170e-02
# Epoch  2300/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9849e-02, KL Loss: 7.9866e-04, Total Loss: 3.1116e-02 - TEST : Rec Loss: 3.5442e-02, KL Loss: 7.9824e-04, Total Loss: 1.8120e-02
# Epoch  2325/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0384e-02, KL Loss: 7.7469e-04, Total Loss: 3.1117e-02 - TEST : Rec Loss: 3.5265e-02, KL Loss: 7.7609e-04, Total Loss: 1.8021e-02
# Epoch  2350/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9138e-02, KL Loss: 7.5217e-04, Total Loss: 3.1054e-02 - TEST : Rec Loss: 3.5299e-02, KL Loss: 7.5468e-04, Total Loss: 1.8027e-02
# Epoch  2375/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.8995e-02, KL Loss: 7.3048e-04, Total Loss: 3.1020e-02 - TEST : Rec Loss: 3.5338e-02, KL Loss: 7.3031e-04, Total Loss: 1.8034e-02
# Epoch  2400/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1430e-02, KL Loss: 7.0957e-04, Total Loss: 3.1053e-02 - TEST : Rec Loss: 3.5329e-02, KL Loss: 7.1618e-04, Total Loss: 1.8022e-02
# Epoch  2425/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0198e-02, KL Loss: 6.9155e-04, Total Loss: 3.0974e-02 - TEST : Rec Loss: 3.5276e-02, KL Loss: 6.8819e-04, Total Loss: 1.7982e-02
# Epoch  2450/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2333e-02, KL Loss: 6.7072e-04, Total Loss: 3.1007e-02 - TEST : Rec Loss: 3.5317e-02, KL Loss: 6.7715e-04, Total Loss: 1.7997e-02
# Epoch  2475/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2362e-02, KL Loss: 6.5325e-04, Total Loss: 3.0976e-02 - TEST : Rec Loss: 3.5375e-02, KL Loss: 6.4864e-04, Total Loss: 1.8012e-02
# Epoch  2500/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0542e-02, KL Loss: 6.3432e-04, Total Loss: 3.0923e-02 - TEST : Rec Loss: 3.5208e-02, KL Loss: 6.2875e-04, Total Loss: 1.7919e-02
# Epoch  2525/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9201e-02, KL Loss: 6.1729e-04, Total Loss: 3.0860e-02 - TEST : Rec Loss: 3.5247e-02, KL Loss: 6.1550e-04, Total Loss: 1.7931e-02
# Epoch  2550/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9926e-02, KL Loss: 5.9723e-04, Total Loss: 3.0841e-02 - TEST : Rec Loss: 3.5314e-02, KL Loss: 5.9299e-04, Total Loss: 1.7954e-02
# Epoch  2575/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.8781e-02, KL Loss: 5.7847e-04, Total Loss: 3.0779e-02 - TEST : Rec Loss: 3.5235e-02, KL Loss: 5.7968e-04, Total Loss: 1.7907e-02
# Epoch  2600/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1581e-02, KL Loss: 5.6083e-04, Total Loss: 3.0823e-02 - TEST : Rec Loss: 3.5267e-02, KL Loss: 5.5605e-04, Total Loss: 1.7911e-02
# Epoch  2625/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0333e-02, KL Loss: 5.4469e-04, Total Loss: 3.0754e-02 - TEST : Rec Loss: 3.5279e-02, KL Loss: 5.3956e-04, Total Loss: 1.7909e-02
# Epoch  2650/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0287e-02, KL Loss: 5.2670e-04, Total Loss: 3.0757e-02 - TEST : Rec Loss: 3.5318e-02, KL Loss: 5.2176e-04, Total Loss: 1.7920e-02
# Epoch  2675/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9431e-02, KL Loss: 5.1167e-04, Total Loss: 3.0726e-02 - TEST : Rec Loss: 3.5279e-02, KL Loss: 5.0881e-04, Total Loss: 1.7894e-02
# Epoch  2700/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9614e-02, KL Loss: 4.9524e-04, Total Loss: 3.0688e-02 - TEST : Rec Loss: 3.5247e-02, KL Loss: 4.8807e-04, Total Loss: 1.7867e-02
# Epoch  2725/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0604e-02, KL Loss: 4.8007e-04, Total Loss: 3.0685e-02 - TEST : Rec Loss: 3.5212e-02, KL Loss: 4.7750e-04, Total Loss: 1.7845e-02
# Epoch  2750/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1150e-02, KL Loss: 4.6361e-04, Total Loss: 3.0668e-02 - TEST : Rec Loss: 3.5170e-02, KL Loss: 4.6519e-04, Total Loss: 1.7818e-02
# Epoch  2775/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1036e-02, KL Loss: 4.4875e-04, Total Loss: 3.0660e-02 - TEST : Rec Loss: 3.5247e-02, KL Loss: 4.4857e-04, Total Loss: 1.7848e-02
# Epoch  2800/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.8951e-02, KL Loss: 4.3400e-04, Total Loss: 3.0589e-02 - TEST : Rec Loss: 3.5178e-02, KL Loss: 4.3259e-04, Total Loss: 1.7805e-02
# Epoch  2825/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9842e-02, KL Loss: 4.2090e-04, Total Loss: 3.0595e-02 - TEST : Rec Loss: 3.5142e-02, KL Loss: 4.2217e-04, Total Loss: 1.7782e-02
# Epoch  2850/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9095e-02, KL Loss: 4.0819e-04, Total Loss: 3.0546e-02 - TEST : Rec Loss: 3.5190e-02, KL Loss: 4.1196e-04, Total Loss: 1.7801e-02
# Epoch  2875/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9657e-02, KL Loss: 3.9640e-04, Total Loss: 3.0561e-02 - TEST : Rec Loss: 3.5261e-02, KL Loss: 3.9988e-04, Total Loss: 1.7831e-02
# Epoch  2900/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0622e-02, KL Loss: 3.8599e-04, Total Loss: 3.0554e-02 - TEST : Rec Loss: 3.5269e-02, KL Loss: 3.9091e-04, Total Loss: 1.7830e-02
# Epoch  2925/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0978e-02, KL Loss: 3.7415e-04, Total Loss: 3.0539e-02 - TEST : Rec Loss: 3.5196e-02, KL Loss: 3.7850e-04, Total Loss: 1.7787e-02
# Epoch  2950/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0718e-02, KL Loss: 3.6383e-04, Total Loss: 3.0523e-02 - TEST : Rec Loss: 3.5131e-02, KL Loss: 3.6747e-04, Total Loss: 1.7749e-02
# Epoch  2975/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0075e-02, KL Loss: 3.5309e-04, Total Loss: 3.0498e-02 - TEST : Rec Loss: 3.5247e-02, KL Loss: 3.5536e-04, Total Loss: 1.7801e-02
# Epoch  3000/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0822e-02, KL Loss: 3.4253e-04, Total Loss: 3.0488e-02 - TEST : Rec Loss: 3.5188e-02, KL Loss: 3.4251e-04, Total Loss: 1.7765e-02
# Epoch  3025/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9796e-02, KL Loss: 3.3258e-04, Total Loss: 3.0458e-02 - TEST : Rec Loss: 3.5113e-02, KL Loss: 3.3374e-04, Total Loss: 1.7724e-02
# Epoch  3050/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1913e-02, KL Loss: 3.2439e-04, Total Loss: 3.0506e-02 - TEST : Rec Loss: 3.5175e-02, KL Loss: 3.2126e-04, Total Loss: 1.7748e-02
# Epoch  3075/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0134e-02, KL Loss: 3.1436e-04, Total Loss: 3.0435e-02 - TEST : Rec Loss: 3.5206e-02, KL Loss: 3.1430e-04, Total Loss: 1.7760e-02
# Epoch  3100/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0110e-02, KL Loss: 3.0478e-04, Total Loss: 3.0418e-02 - TEST : Rec Loss: 3.5176e-02, KL Loss: 3.0281e-04, Total Loss: 1.7740e-02
# Epoch  3125/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9076e-02, KL Loss: 2.9533e-04, Total Loss: 3.0376e-02 - TEST : Rec Loss: 3.5134e-02, KL Loss: 2.9260e-04, Total Loss: 1.7714e-02
# Epoch  3150/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9966e-02, KL Loss: 2.8657e-04, Total Loss: 3.0390e-02 - TEST : Rec Loss: 3.5128e-02, KL Loss: 2.8229e-04, Total Loss: 1.7705e-02
# Epoch  3175/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0349e-02, KL Loss: 2.7723e-04, Total Loss: 3.0384e-02 - TEST : Rec Loss: 3.5087e-02, KL Loss: 2.7476e-04, Total Loss: 1.7681e-02
# Epoch  3200/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0406e-02, KL Loss: 2.6787e-04, Total Loss: 3.0377e-02 - TEST : Rec Loss: 3.5139e-02, KL Loss: 2.6229e-04, Total Loss: 1.7700e-02
# Epoch  3225/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.8578e-02, KL Loss: 2.5791e-04, Total Loss: 3.0321e-02 - TEST : Rec Loss: 3.5114e-02, KL Loss: 2.5252e-04, Total Loss: 1.7683e-02
# Epoch  3250/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.8998e-02, KL Loss: 2.4848e-04, Total Loss: 3.0328e-02 - TEST : Rec Loss: 3.5030e-02, KL Loss: 2.4643e-04, Total Loss: 1.7638e-02
# Epoch  3275/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.8771e-02, KL Loss: 2.3950e-04, Total Loss: 3.0304e-02 - TEST : Rec Loss: 3.5134e-02, KL Loss: 2.3754e-04, Total Loss: 1.7686e-02
# Epoch  3300/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0681e-02, KL Loss: 2.3125e-04, Total Loss: 3.0340e-02 - TEST : Rec Loss: 3.5006e-02, KL Loss: 2.3116e-04, Total Loss: 1.7619e-02
# Epoch  3325/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0387e-02, KL Loss: 2.2382e-04, Total Loss: 3.0317e-02 - TEST : Rec Loss: 3.5124e-02, KL Loss: 2.2298e-04, Total Loss: 1.7674e-02
# Epoch  3350/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1753e-02, KL Loss: 2.1671e-04, Total Loss: 3.0341e-02 - TEST : Rec Loss: 3.5157e-02, KL Loss: 2.1629e-04, Total Loss: 1.7687e-02
# Epoch  3375/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9057e-02, KL Loss: 2.0948e-04, Total Loss: 3.0274e-02 - TEST : Rec Loss: 3.5096e-02, KL Loss: 2.0875e-04, Total Loss: 1.7652e-02
# Epoch  3400/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9127e-02, KL Loss: 2.0275e-04, Total Loss: 3.0266e-02 - TEST : Rec Loss: 3.5130e-02, KL Loss: 2.0371e-04, Total Loss: 1.7667e-02
# Epoch  3425/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1291e-02, KL Loss: 1.9668e-04, Total Loss: 3.0292e-02 - TEST : Rec Loss: 3.5071e-02, KL Loss: 1.9959e-04, Total Loss: 1.7635e-02
# Epoch  3450/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9528e-02, KL Loss: 1.9016e-04, Total Loss: 3.0254e-02 - TEST : Rec Loss: 3.5178e-02, KL Loss: 1.9311e-04, Total Loss: 1.7686e-02
# Epoch  3475/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0039e-02, KL Loss: 1.8516e-04, Total Loss: 3.0265e-02 - TEST : Rec Loss: 3.5109e-02, KL Loss: 1.8881e-04, Total Loss: 1.7649e-02
# Epoch  3500/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0196e-02, KL Loss: 1.7980e-04, Total Loss: 3.0253e-02 - TEST : Rec Loss: 3.5062e-02, KL Loss: 1.8278e-04, Total Loss: 1.7622e-02
# Epoch  3525/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0157e-02, KL Loss: 1.7559e-04, Total Loss: 3.0240e-02 - TEST : Rec Loss: 3.5054e-02, KL Loss: 1.7974e-04, Total Loss: 1.7617e-02
# Epoch  3550/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0165e-02, KL Loss: 1.7182e-04, Total Loss: 3.0231e-02 - TEST : Rec Loss: 3.5112e-02, KL Loss: 1.7558e-04, Total Loss: 1.7644e-02
# Epoch  3575/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9091e-02, KL Loss: 1.6777e-04, Total Loss: 3.0200e-02 - TEST : Rec Loss: 3.5089e-02, KL Loss: 1.6960e-04, Total Loss: 1.7629e-02
# Epoch  3600/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9321e-02, KL Loss: 1.6455e-04, Total Loss: 3.0201e-02 - TEST : Rec Loss: 3.5064e-02, KL Loss: 1.6396e-04, Total Loss: 1.7614e-02
# Epoch  3625/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1051e-02, KL Loss: 1.6059e-04, Total Loss: 3.0246e-02 - TEST : Rec Loss: 3.5036e-02, KL Loss: 1.5955e-04, Total Loss: 1.7598e-02
# Epoch  3650/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0488e-02, KL Loss: 1.5640e-04, Total Loss: 3.0218e-02 - TEST : Rec Loss: 3.5043e-02, KL Loss: 1.5238e-04, Total Loss: 1.7597e-02
# Epoch  3675/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0142e-02, KL Loss: 1.5152e-04, Total Loss: 3.0203e-02 - TEST : Rec Loss: 3.5082e-02, KL Loss: 1.4670e-04, Total Loss: 1.7614e-02
# Epoch  3700/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0185e-02, KL Loss: 1.4679e-04, Total Loss: 3.0203e-02 - TEST : Rec Loss: 3.5047e-02, KL Loss: 1.4177e-04, Total Loss: 1.7594e-02
# Epoch  3725/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0451e-02, KL Loss: 1.4168e-04, Total Loss: 3.0200e-02 - TEST : Rec Loss: 3.5075e-02, KL Loss: 1.3557e-04, Total Loss: 1.7605e-02
# Epoch  3750/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0072e-02, KL Loss: 1.3655e-04, Total Loss: 3.0190e-02 - TEST : Rec Loss: 3.5059e-02, KL Loss: 1.3130e-04, Total Loss: 1.7595e-02
# Epoch  3775/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9302e-02, KL Loss: 1.3184e-04, Total Loss: 3.0162e-02 - TEST : Rec Loss: 3.5054e-02, KL Loss: 1.2736e-04, Total Loss: 1.7591e-02
# Epoch  3800/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1328e-02, KL Loss: 1.2663e-04, Total Loss: 3.0205e-02 - TEST : Rec Loss: 3.5051e-02, KL Loss: 1.2311e-04, Total Loss: 1.7587e-02
# Epoch  3825/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1001e-02, KL Loss: 1.2244e-04, Total Loss: 3.0192e-02 - TEST : Rec Loss: 3.5094e-02, KL Loss: 1.1970e-04, Total Loss: 1.7607e-02
# Epoch  3850/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.8752e-02, KL Loss: 1.1762e-04, Total Loss: 3.0133e-02 - TEST : Rec Loss: 3.5061e-02, KL Loss: 1.1473e-04, Total Loss: 1.7588e-02
# Epoch  3875/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9629e-02, KL Loss: 1.1320e-04, Total Loss: 3.0142e-02 - TEST : Rec Loss: 3.5060e-02, KL Loss: 1.1090e-04, Total Loss: 1.7585e-02
# Epoch  3900/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.7704e-02, KL Loss: 1.0912e-04, Total Loss: 3.0096e-02 - TEST : Rec Loss: 3.5052e-02, KL Loss: 1.0845e-04, Total Loss: 1.7580e-02
# Epoch  3925/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9464e-02, KL Loss: 1.0512e-04, Total Loss: 3.0137e-02 - TEST : Rec Loss: 3.5078e-02, KL Loss: 1.0527e-04, Total Loss: 1.7591e-02
# Epoch  3950/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1309e-02, KL Loss: 1.0149e-04, Total Loss: 3.0168e-02 - TEST : Rec Loss: 3.5065e-02, KL Loss: 1.0271e-04, Total Loss: 1.7584e-02
# Epoch  3975/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1304e-02, KL Loss: 9.8096e-05, Total Loss: 3.0162e-02 - TEST : Rec Loss: 3.5058e-02, KL Loss: 1.0051e-04, Total Loss: 1.7579e-02
# Epoch  4000/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0870e-02, KL Loss: 9.5181e-05, Total Loss: 3.0153e-02 - TEST : Rec Loss: 3.5074e-02, KL Loss: 9.8859e-05, Total Loss: 1.7586e-02
# Epoch  4025/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9495e-02, KL Loss: 9.2956e-05, Total Loss: 3.0113e-02 - TEST : Rec Loss: 3.5035e-02, KL Loss: 9.6851e-05, Total Loss: 1.7566e-02
# Epoch  4050/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.7937e-02, KL Loss: 9.1464e-05, Total Loss: 3.0072e-02 - TEST : Rec Loss: 3.5092e-02, KL Loss: 9.5729e-05, Total Loss: 1.7594e-02
# Epoch  4075/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0318e-02, KL Loss: 9.0357e-05, Total Loss: 3.0128e-02 - TEST : Rec Loss: 3.5059e-02, KL Loss: 9.3778e-05, Total Loss: 1.7577e-02
# Epoch  4100/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0477e-02, KL Loss: 8.8941e-05, Total Loss: 3.0124e-02 - TEST : Rec Loss: 3.5079e-02, KL Loss: 9.2195e-05, Total Loss: 1.7586e-02
# Epoch  4125/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0892e-02, KL Loss: 8.7494e-05, Total Loss: 3.0136e-02 - TEST : Rec Loss: 3.5051e-02, KL Loss: 8.9108e-05, Total Loss: 1.7570e-02
# Epoch  4150/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0515e-02, KL Loss: 8.5651e-05, Total Loss: 3.0124e-02 - TEST : Rec Loss: 3.5023e-02, KL Loss: 8.5942e-05, Total Loss: 1.7555e-02
# Epoch  4175/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1261e-02, KL Loss: 8.3770e-05, Total Loss: 3.0133e-02 - TEST : Rec Loss: 3.5076e-02, KL Loss: 8.3148e-05, Total Loss: 1.7580e-02
# Epoch  4200/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0270e-02, KL Loss: 8.1850e-05, Total Loss: 3.0114e-02 - TEST : Rec Loss: 3.5058e-02, KL Loss: 8.0352e-05, Total Loss: 1.7569e-02
# Epoch  4225/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0129e-02, KL Loss: 7.9870e-05, Total Loss: 3.0103e-02 - TEST : Rec Loss: 3.5051e-02, KL Loss: 7.7420e-05, Total Loss: 1.7564e-02
# Epoch  4250/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9842e-02, KL Loss: 7.7873e-05, Total Loss: 3.0096e-02 - TEST : Rec Loss: 3.5027e-02, KL Loss: 7.5109e-05, Total Loss: 1.7551e-02
# Epoch  4275/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0045e-02, KL Loss: 7.5870e-05, Total Loss: 3.0099e-02 - TEST : Rec Loss: 3.5041e-02, KL Loss: 7.1963e-05, Total Loss: 1.7557e-02
# Epoch  4300/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.2614e-02, KL Loss: 7.3729e-05, Total Loss: 3.0158e-02 - TEST : Rec Loss: 3.5035e-02, KL Loss: 6.9009e-05, Total Loss: 1.7552e-02
# Epoch  4325/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0427e-02, KL Loss: 7.1304e-05, Total Loss: 3.0100e-02 - TEST : Rec Loss: 3.5046e-02, KL Loss: 6.6468e-05, Total Loss: 1.7556e-02
# Epoch  4350/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9789e-02, KL Loss: 6.8866e-05, Total Loss: 3.0086e-02 - TEST : Rec Loss: 3.5026e-02, KL Loss: 6.4528e-05, Total Loss: 1.7545e-02
# Epoch  4375/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9702e-02, KL Loss: 6.5937e-05, Total Loss: 3.0077e-02 - TEST : Rec Loss: 3.5027e-02, KL Loss: 6.1170e-05, Total Loss: 1.7544e-02
# Epoch  4400/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9711e-02, KL Loss: 6.3283e-05, Total Loss: 3.0075e-02 - TEST : Rec Loss: 3.5026e-02, KL Loss: 5.7949e-05, Total Loss: 1.7542e-02
# Epoch  4425/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0554e-02, KL Loss: 6.0667e-05, Total Loss: 3.0094e-02 - TEST : Rec Loss: 3.5020e-02, KL Loss: 5.6842e-05, Total Loss: 1.7538e-02
# Epoch  4450/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.8761e-02, KL Loss: 5.8049e-05, Total Loss: 3.0050e-02 - TEST : Rec Loss: 3.5059e-02, KL Loss: 5.4957e-05, Total Loss: 1.7557e-02
# Epoch  4475/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0747e-02, KL Loss: 5.5387e-05, Total Loss: 3.0093e-02 - TEST : Rec Loss: 3.5067e-02, KL Loss: 5.3264e-05, Total Loss: 1.7560e-02
# Epoch  4500/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0176e-02, KL Loss: 5.3017e-05, Total Loss: 3.0074e-02 - TEST : Rec Loss: 3.5066e-02, KL Loss: 5.1988e-05, Total Loss: 1.7559e-02
# Epoch  4525/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9913e-02, KL Loss: 5.0819e-05, Total Loss: 3.0066e-02 - TEST : Rec Loss: 3.5066e-02, KL Loss: 5.0814e-05, Total Loss: 1.7559e-02
# Epoch  4550/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9826e-02, KL Loss: 4.9187e-05, Total Loss: 3.0063e-02 - TEST : Rec Loss: 3.5032e-02, KL Loss: 5.0760e-05, Total Loss: 1.7541e-02
# Epoch  4575/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0570e-02, KL Loss: 4.7500e-05, Total Loss: 3.0073e-02 - TEST : Rec Loss: 3.5055e-02, KL Loss: 4.9424e-05, Total Loss: 1.7552e-02
# Epoch  4600/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0419e-02, KL Loss: 4.6161e-05, Total Loss: 3.0072e-02 - TEST : Rec Loss: 3.5033e-02, KL Loss: 4.9305e-05, Total Loss: 1.7541e-02
# Epoch  4625/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9667e-02, KL Loss: 4.5224e-05, Total Loss: 3.0056e-02 - TEST : Rec Loss: 3.5051e-02, KL Loss: 4.8937e-05, Total Loss: 1.7550e-02
# Epoch  4650/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9533e-02, KL Loss: 4.4297e-05, Total Loss: 3.0047e-02 - TEST : Rec Loss: 3.5038e-02, KL Loss: 4.8035e-05, Total Loss: 1.7543e-02
# Epoch  4675/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0283e-02, KL Loss: 4.3954e-05, Total Loss: 3.0064e-02 - TEST : Rec Loss: 3.5036e-02, KL Loss: 4.8046e-05, Total Loss: 1.7542e-02
# Epoch  4700/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9910e-02, KL Loss: 4.3328e-05, Total Loss: 3.0052e-02 - TEST : Rec Loss: 3.5027e-02, KL Loss: 4.7660e-05, Total Loss: 1.7537e-02
# Epoch  4725/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9325e-02, KL Loss: 4.2940e-05, Total Loss: 3.0036e-02 - TEST : Rec Loss: 3.5073e-02, KL Loss: 4.6537e-05, Total Loss: 1.7560e-02
# Epoch  4750/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1382e-02, KL Loss: 4.2674e-05, Total Loss: 3.0086e-02 - TEST : Rec Loss: 3.5056e-02, KL Loss: 4.5608e-05, Total Loss: 1.7551e-02
# Epoch  4775/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9480e-02, KL Loss: 4.2245e-05, Total Loss: 3.0039e-02 - TEST : Rec Loss: 3.5029e-02, KL Loss: 4.4510e-05, Total Loss: 1.7537e-02
# Epoch  4800/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0621e-02, KL Loss: 4.1920e-05, Total Loss: 3.0064e-02 - TEST : Rec Loss: 3.5046e-02, KL Loss: 4.3505e-05, Total Loss: 1.7545e-02
# Epoch  4825/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9832e-02, KL Loss: 4.1590e-05, Total Loss: 3.0046e-02 - TEST : Rec Loss: 3.5059e-02, KL Loss: 4.2083e-05, Total Loss: 1.7550e-02
# Epoch  4850/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9470e-02, KL Loss: 4.1339e-05, Total Loss: 3.0039e-02 - TEST : Rec Loss: 3.5051e-02, KL Loss: 4.0877e-05, Total Loss: 1.7546e-02
# Epoch  4875/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9143e-02, KL Loss: 4.0779e-05, Total Loss: 3.0027e-02 - TEST : Rec Loss: 3.5033e-02, KL Loss: 3.9620e-05, Total Loss: 1.7536e-02
# Epoch  4900/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0945e-02, KL Loss: 3.9959e-05, Total Loss: 3.0072e-02 - TEST : Rec Loss: 3.5039e-02, KL Loss: 3.7735e-05, Total Loss: 1.7538e-02
# Epoch  4925/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.1320e-02, KL Loss: 3.8995e-05, Total Loss: 3.0079e-02 - TEST : Rec Loss: 3.5050e-02, KL Loss: 3.5904e-05, Total Loss: 1.7543e-02
# Epoch  4950/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0165e-02, KL Loss: 3.7811e-05, Total Loss: 3.0049e-02 - TEST : Rec Loss: 3.5043e-02, KL Loss: 3.3931e-05, Total Loss: 1.7538e-02
# Epoch  4975/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 2.9547e-02, KL Loss: 3.6800e-05, Total Loss: 3.0038e-02 - TEST : Rec Loss: 3.5052e-02, KL Loss: 3.2175e-05, Total Loss: 1.7542e-02
# Epoch  5000/5000 with beta = 1.00e+00 - TRAINING : Rec Loss: 3.0701e-02, KL Loss: 3.4606e-05, Total Loss: 3.0060e-02 - TEST : Rec Loss: 3.5047e-02, KL Loss: 3.0673e-05, Total Loss: 1.7539e-02

# %%
plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses)

# %%
sample_predictions(N_SAMPLES=5, model=dkf)

# %% [markdown]
# # Commentaires à ce stade :
#
# ~~C1 - REVOIR LE TRAINING ! cf https://dynamicalvae.github.io/tuto_icassp2021/DVAE_tutorial.html (slide training DKF)~~
#
# Q1 - L'ELBO contient une expectation de KLs entre les vraies posterieures et les approximées. Une méthode est mentionnée p64 du papier de l'INRIA.
#
# #### Mon codage de la loss est-il correct ?
#
# Q2 - A priori plus de problème de stabilité ? Mais on constate un changement de régime pendant le training. Est-ce que cela correspond à un maximum d'expressivité du modèle ? Ou autre chose (ie $\sigma_{\theta_x} \longrightarrow 0$?)
#
# Q3 - Je calcule la prédiction en utilisant la moyenne de $p_{\theta_z}$ plutôt que celle de $q_\phi$ ... Mais ça se discute ?
#
# Q4 - Comment arbitrer entre la KL et la reconstruction ? Piste 1 : faire un scheduler sur $\beta$ ? (cf papiers plus bas)
#
# Q5 - Choix des différents paramètres ? Grid-search ? Early stopping + train till end of patience ? Autre ?
#
# Q6 - Influence de K ? (nombre de samples pour calculer les expectations dans la loss)
#
# Q7 - Architecture des réseaux : drop outs ? batch norms ? softplus pour sortir var plutôt qu'une linéaire pour sortir logvar ?
#
# Articles sur le sujet (biblio papier INRIA):
# - https://arxiv.org/pdf/1602.02282 (Ladder VAE)
# - https://arxiv.org/pdf/2007.03898 (NVAE: A Deep Hierarchical Variational Autoencoder)
#
# Tuto (slides extrêmement bien faites):
# - https://dynamicalvae.github.io/tuto_icassp2021/DVAE_tutorial.html

# %% [markdown]
# ## Piste 1 : Implementing a simple linear Beta scheduler

# %%
class BetaLinearScheduler():
    """Scheduler linéaire simple du beta, rapport entre la loss de reconstruction et la loss KL
    """
    
    def __init__(self, beta_start=0.0, beta_end=1.0, num_epochs=100):
        """Constructeur

        Args:
            beta_start (float, optional): coefficient beta au démarrage. Defaults to 0.0.
            beta_end (float, optional): coefficient beta en fin de schedule. Defaults to 1.0.
            num_epochs (int, optional): nombre d'epochs sur lequel se fait l'évolution du beta. Defaults to 100.
        """
        self.beta_start = beta_start
        self.beta_end = beta_end
        self.num_epochs = num_epochs
        
    def __call__(self, epoch):
        """Calcul du beta à l'epoch donnée

        Args:
            epoch (int): epoch courante

        Returns:
            float: beta
        """
        
        return self.beta_start + (self.beta_end - self.beta_start) * (np.min([epoch, self.num_epochs]) / self.num_epochs)

# %%
# dkf = DeepKalmanFilter(
#     input_dim = xdim,
#     latent_dim = latent_dim,
#     hidden_dim = h_dim,
#     combiner_dim = combiner_dim,
#     num_layers = num_layers_rnn,
#     device=device
# ).to(device)

# print(dkf)

# %%
# optimizer = torch.optim.Adam(dkf.parameters(), lr=1e-3)
# loss_fn = loss_function

# num_epochs = 250
# n_displays = 20  # nombre d'affichages souhaités
# display_frequency = int(num_epochs / n_displays)

# beta_scheduler = BetaLinearScheduler(beta_start=0.0, beta_end=1.0, num_epochs=50)  # warm up beta

# %%
# rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses = train(
#     dkf, optimizer, loss_fn, num_epochs=num_epochs, beta_scheduler=beta_scheduler, display_frequency=display_frequency
# )

# %%
# plot_losses(rec_losses, kl_losses, epoch_losses, val_rec_losses, val_kl_losses, val_epoch_losses)

# %%
# sample_predictions(N_SAMPLES=5, model=dkf)
