# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# This is a notebook to describe the step by step logic of training a GP-VAE
# </div>
#
# VAEs dynamiques : https://arxiv.org/abs/2008.12595
#
# Papiers GP-VAE :
# - Deep Probabilistic Time Series Imputation https://arxiv.org/abs/1907.04155
# - Gaussian Process Prior Variational Autoencoders : https://arxiv.org/abs/1810.11738
# - Bayesian Gaussian Process Latent Variable Model : https://proceedings.mlr.press/v9/titsias10a/titsias10a.pdf
# - Markovian Gaussian Process Variational Autoencoders : https://arxiv.org/abs/2207.05543

# %% [markdown]
# Imports and set up

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import sys
import os

# Add the parent directory to sys.path to find the libs module
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
    
# print(f"Added {parent_dir} to Python path")
# print(f"Current working directory: {os.getcwd()}")
# print(f"Python path: {sys.path}")

# %%
# Set seed for reproducibility

def seed_everything(seed=42):
    """
    Set seed for reproducibility.
    """
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
    
seed_everything(42)

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    dtype = torch.cuda.FloatTensor
else:
    device = torch.device('cpu')
    dtype = torch.FloatTensor

print(f"Using {device}")

torch.set_default_dtype(torch.float64)

if device.type == 'cuda':
    print('GPU Name:', torch.cuda.get_device_name(0))
    print('Total GPU Memory:', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
# Out:
# Using cuda
# GPU Name: NVIDIA GeForce RTX 4090
# Total GPU Memory: 23.6 GB

# %% [markdown]
# ### Synthetic data
#
# We assume here a batch of $B$ time series, each composed of $N$ points $x \in \mathbb{R}^{D_x}$.
#
# We will use a set of $D_z$ Gaussian Processes to encode the latent representation.

# %%
# Dimensions
Dx = 4
Dz = 2

# parameters
N = 100
B = 1

# %%
# Synthetic data
x = torch.randn((B,N,Dx)).to(device)
t = torch.linspace(0, 1, N).to(device).unsqueeze(0).repeat(B, 1)

# report
print(f"batch size: {B}")
print(f"time series length: {N}")
print(f"Dx: {Dx}, Dz: {Dz}")
print(f"x shape: {x.shape}")
print(f"t shape: {t.shape}")
# Out:
# batch size: 1
# time series length: 100
# Dx: 4, Dz: 2
# x shape: torch.Size([1, 100, 4])
# t shape: torch.Size([1, 100])

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# Generative model
# </div>

# %%
# Utility function to create a Multi-Layer Perceptron (MLP)

def make_mlp(
    input_dim, 
    output_dim, 
    n_layers=3, 
    inter_dim=128, 
    activation=nn.ReLU):
    """Create a Multi-Layer Perceptron (MLP) with specified parameters.
    
    Args:
        input_dim (int): Dimension of the input layer.
        output_dim (int): Dimension of the output layer.
        n_layers (int, optional): Number of layers in the MLP. Defaults to 3.
            - first layer is input_dim x inter_dim
            - last layer is inter_dim x output_dim
            - all other layers are inter_dim x inter_dim
        inter_dim (int, optional): Number of neurons in the hidden layers. Defaults to 128.
        activation (nn.Module, optional): Activation function to use. Defaults to nn.ReLU.
            the last layer does not have an activation function.
        
    Returns:
        nn.Sequential: A sequential model representing the MLP.
    """
    
    layers = []
    for i in range(n_layers):
        if i == 0:
            layers.append(nn.Linear(input_dim, inter_dim))
        elif i == n_layers - 1:
            layers.append(nn.Linear(inter_dim, output_dim))
        else:
            layers.append(nn.Linear(inter_dim, inter_dim))
        
        if i < n_layers - 1:
            layers.append(activation())
    
    return nn.Sequential(*layers)

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 20px; color: black; font-weight: bold;">
# Encoder
# </div>
#
# For a given time serie, the approximate posterior $q_{\phi}$ is a set of $D_z$ independent -but not identical- multivariate Gaussians of dimension $N$.
#
# This encodes a temporal dependency over each dimension of the latent variables, but no dependency between dimensions.
#
# $q_{\phi}$ is a tf.distribution.MultivariateNormal object with batch_shape = $(B, D_z)$ and event_shape = ($N$)
#
# \begin{align}
# q_{\phi}(z_{1:N} \vert x_{1:N}) &= \mathcal{N}(\mu_{\phi}(z_{1:N} \vert x_{1:N}), \Sigma_{\phi}(z_{1:N} \vert x_{1:N}))
# \end{align}

# %% [markdown]
# ### Encoder mean
#
# We output the mean $\mu_{\phi}(z_{1:N} \vert x_{1:N})$ of $q_{\phi}$ with a simple MLP.
#
# The neural net takes an input tensor $(B, N, D_x)$ and outputs a tensor $(B, D_z, N)$ - note the permutation between $D_z$ and $N$.

# %%
class EncoderMean(nn.Module):
    """ Neural Net to compute the mean of the Gaussian Encoder distribution.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(EncoderMean, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0 !"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
                
        self.mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,  # output is a vector of length sequence_length * z_dimension
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=self.activation
        )
        
    
    def forward(self, input):
        """
        Forward pass of the EncoderMean.
        Args:
            x (torch.Tensor): Input tensor (..., N, x_dimension) (possibly N=1, ie a single point)
        Returns:
            z (torch.Tensor): Output tensor (..., z_dimension, N)
        """
        
        assert input.size(-1) == self.x_dimension, f"Wrong x_dim in EncoderMean. Input tensor must have shape (..., {self.x_dimension})"
        assert input.dim() >= 2, "Input tensor must have at least 2 dimensions (sequence_length -possibly 1- and x_dimension)"
        
        output = self.mlp(input)  # (..., N, Dz)
        output = torch.transpose(output,-1, -2)  # (..., Dz, N)
            
        return output  # (..., Dz, N) : batch of Dz independent but not identical Gaussians of dimension N. (can have N=1).
    
    def __repr__(self):
        return (f"{self.__class__.__name__}, "
                f"x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}")

# %%
encoder_mean = EncoderMean(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=32,
    activation=nn.ReLU,
).to(device)

print(f"Encoder mean function: {encoder_mean}")

mu_phi = encoder_mean(x)

# report
print(f"Encoder input shape : (B,N,Dx) = {x.shape}")
print(f"Encoder mean output mu_phi shape : (B,Dz,N) = {mu_phi.shape}")
# Out:
# Encoder mean function: EncoderMean, x_dimension=4, z_dimension=2, n_layers=2, inter_dim=32, activation=ReLU
# Encoder input shape : (B,N,Dx) = torch.Size([1, 100, 4])
# Encoder mean output mu_phi shape : (B,Dz,N) = torch.Size([1, 2, 100])

# %% [markdown]
# ### Parametrizing the Gaussian Encoder with either precision matrix or covariance matrix
#
# We have the choice of parametrizing $q_{\phi}$ with covariance matrices, precision matrices, of Cholesky-lower triangular matrices.
#
# Precision matrices are formed following Deep Probabilistic Time Series Imputation https://arxiv.org/abs/1907.04155 :
#
# First, a bi-band upper triangular matrix $B$ is formed as the sum of a diagonal matrix $D$ (with $D_{ii} > 0$) and a upper-band matrix $U = U_{ij}$ with $U_{ij} = u_{ij}$ if $j \in [i, i+1]$.
#
# Then the precision matrix is assembled by $\Lambda = B^TB$ (this ensures positive definitiveness)
#
# We output a batch of precision matrices of shape $(B, Dz, N, N)$

# %%
# Encoder Precision

class EncoderPrecision(nn.Module):
    """Reprise de l'implémentation du papier GPVAE avec
    matrice de précision triangulaire supérieure à deux bandes
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 2,
                 inter_dim = 32,
                 activation = nn.ReLU,
                 epsilon = 1e-3
                 ):
        
        super(EncoderPrecision, self).__init__()
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        self.epsilon = float(epsilon) 
        
        self.diagonal_mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
        self.off_diagonal_mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
    def forward(self, x):
        """
        x : (B, N, Dx)
        return : (B, Dz, Dz)
        """
        N = x.size(-2)
        
        # Compute the diagonal part
        D = self.diagonal_mlp(x) # (B, N, Dz)
        D = torch.transpose(D, -1, -2)  # (B, Dz, N)
        D = torch.exp(D) # ensure > 0
        D = torch.diag_embed(D) # (B, Dz, N, N)
        
        # compute the upper band
        U = self.off_diagonal_mlp(x) # (B, N, Dz)
        U = torch.transpose(U, -1, -2)  # (B, Dz, N)
        U = torch.diag_embed(U[...,:-1], offset=1)  # (B, Dz, N, N)
        
        # Combine diagonal and upper band
        B = D + U # (B, Dz, N, N)

        precision_matrix = torch.transpose(B, -1, -2) @ B  # (B, N, Dz, Dz)        
        # Add epsilon to the diagonal to ensure PSD numerical stability
        epsilon_matrix = self.epsilon * torch.eye(N, device=device) # (N, N)
        precision_matrix = precision_matrix + epsilon_matrix # (B, Dz, N, N) with epsilon broacasted
        
        return D, B, precision_matrix  # (B, Dz, N, N)
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(x_dimension={self.x_dimension}, "
                f"z_dimension={self.z_dimension}, n_layers={self.n_layers}, "
                f"inter_dim={self.inter_dim}, activation={self.activation.__name__}, "
                f"epsilon={self.epsilon})")

# %%
encoder_precision = EncoderPrecision(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=32,
    activation=nn.ReLU,
).to(device)

D, B, precision_matrix_q_phi = encoder_precision(x)

print(f"EncoderPrecision: {encoder_precision}")
print()
print(f"batch size = {x.size(0)}")
print(f"longueur de la séquence = {x.size(1)}")
print(f"Dimension de l'entrée x = {x.size(-1)}")
print(f"Dimension de l'espace latent z = {Dz}")
print()
print(f"Input x shape: {x.shape}")  # (B, N, Dx)
print(f"Batch matrices diagonales D, shape (B,Dz,N,N): {D.shape}")  # (B, Dz, N, N)
print(f"Batch matrices bi-bandes B, shape (B,Dz,N,N): {B.shape}")  # (B, Dz, N, N)
print(f"Batch matrices precision, shape (B,Dz,N,N): {precision_matrix_q_phi.shape}")  # (B, Dz, N, N)
# Out:
# EncoderPrecision: EncoderPrecision(x_dimension=4, z_dimension=2, n_layers=2, inter_dim=32, activation=ReLU, epsilon=0.001)
#
# batch size = 1
# longueur de la séquence = 100
# Dimension de l'entrée x = 4
# Dimension de l'espace latent z = 2
#
# Input x shape: torch.Size([1, 100, 4])
# Batch matrices diagonales D, shape (B,Dz,N,N): torch.Size([1, 2, 100, 100])
# Batch matrices bi-bandes B, shape (B,Dz,N,N): torch.Size([1, 2, 100, 100])
# Batch matrices precision, shape (B,Dz,N,N): torch.Size([1, 2, 100, 100])

# %% [markdown]
# Covariance matrices are formed by using the Cholesky decomposition, $C = LL^T$, with $L$ lower traingular with stricly positive entries on the diagonal.

# %%
# Encoder Covariance

class EncoderCovariance(nn.Module):
    """ Neural Net to compute the covariance of the Gaussian Encoder distribution.
    Uses a MLP to compute the lower triangular matrix of the Cholesky decomposition of the covariance matrix.
    L is triangular inferior, with diagonal elements strictly positive.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 epsilon = 1e-3,  # small positive constant to ensure positive definiteness of the kernel matrix
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(EncoderCovariance, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0 !"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        self.epsilon = float(epsilon)  # small positive constant to ensure positive definiteness of the kernel matrix
        
        # this network to get the diagonal elements of the covariance matrix
        self.diagonal_mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
        # this network to get Dz elements that will be the lower triangular part (without the diagonal) of the covariance matrix                
        self.full_matrix_mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
    
    def forward(self, x):
        """
        Forward pass of the EncoderCovariance.
        Args:
            x (torch.Tensor): Input tensor (..., N, x_dimension) 
                - N can be 1 (ie a single point) or the sequence length. Must be specified.

        Returns:
            L (torch.Tensor): Lower triangular matrix of shape (..., z_dimension, N, N) 
                L can be used as scale_tril in tf.distributions.MultivariateNormal
            C (torch.Tensor): Covariance matrix of shape (..., z_dimension, N, N) 
                C can be used as covariance_matrix in tf.distributions.MultivariateNormal. but this creates lots of numerical instabilities.
            C is computed as L @ L^T, where L is the lower triangular matrix. (Cholesky decomposition)
        """
        
        # basic check of shape of input x
        assert x.size(-1) == self.x_dimension, f"Wrong x_dim in EncoderCovariance. Input tensor must have shape (batch_size, {self.sequence_length}, {self.x_dimension}) or ({self.sequence_length}, {self.x_dimension})"
        assert x.dim() >= 2, "Input tensor must have at least 2 dimensions (sequence_length -possibly 1- and x_dimension)"
        
        # input is a tensor of shape (..., N, Dx)
        N = x.size(-2)  # sequence length
        
        # Compute the diagonal elements of the covariance matrix
        D = self.diagonal_mlp(x)  # out : (..., N, Dz)
        D = torch.transpose(D, -1, -2)  # out : (..., Dz, N)
        D = torch.exp(D) # out : (..., Dz, N). Ensure entries > 0.
        D = torch.diag_embed(D) # shape (..., Dz, N, N)
        
        # Get the elements outside the diagonal
        M = self.full_matrix_mlp(x) # shape (..., N, Dz)
        M = torch.transpose(M, -1, -2)  # shape (..., Dz, N)
        M1 = M.unsqueeze(-1)  # shape (..., Dz, N, 1)
        M2 = M.unsqueeze(-2)  # shape (..., Dz, 1, N)
        M = torch.matmul(M1, M2)  # shape (..., Dz, N, N)
        M = torch.tril(M, diagonal=-1)  # Keep only the lower triangular part of the matrix (excluding the diagonal) (..., Dz, N, N))
        
        # Assemble the lower triangular matrix L
        L = D + M # (..., Dz, N, N)
        
        # Assemble the covariance matrix C
        C = L @ L.transpose(-1, -2)  # C = L @ L^T # (..., Dz, N, N)
        C = C + self.epsilon * torch.eye(N, device=x.device) # Add a small value to the diagonal for numerical stability (use broadcasting)
            
        return L, C # (..., Dz, N, N) Covariance matrix C
    
    def __repr__(self):
        return (f"{self.__class__.__name__} : "
                f"(x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}, "
                f"epsilon (to ensure PSD)={self.epsilon:.3e})")

# %%
encoder_covariance = EncoderCovariance(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=32,
    activation=nn.ReLU,
).to(device)

L_q_phi, covariance_matrix_q_phi = encoder_covariance(x)

print(f"Encoder Covariance: {encoder_covariance}")
print()

print(f"batch size = {x.size(0)}")
print(f"longueur de la séquence = {x.size(1)}")
print(f"Dimension de l'entrée x = {x.size(-1)}")
print(f"Dimension de l'espace latent z = {Dz}")
print()

print(f"Input x shape (B,N,Dx): {x.shape}")  # (B, N, Dx)
print(f"Batch matrices triangulaires inférieures L, shape (B,Dz,N,N): {L_q_phi.shape}")  # (B, Dz, N, N)
print(f"Batch matrices covariance, shape (B,Dz,N,N): {covariance_matrix_q_phi.shape}")  # (B, Dz, N, N)
# Out:
# Encoder Covariance: EncoderCovariance : (x_dimension=4, z_dimension=2, n_layers=2, inter_dim=32, activation=ReLU, epsilon (to ensure PSD)=1.000e-03)
#
# batch size = 1
# longueur de la séquence = 100
# Dimension de l'entrée x = 4
# Dimension de l'espace latent z = 2
#
# Input x shape (B,N,Dx): torch.Size([1, 100, 4])
# Batch matrices triangulaires inférieures L, shape (B,Dz,N,N): torch.Size([1, 2, 100, 100])
# Batch matrices covariance, shape (B,Dz,N,N): torch.Size([1, 2, 100, 100])

# %% [markdown]
# We can form the approximate posterior (encoder) with either parametrization.

# %%
#------- CHOIX 1 : PRECISION MATRIX -------
q_phi_p = torch.distributions.MultivariateNormal(
    loc=mu_phi,  # (Dz, N)
    precision_matrix=precision_matrix_q_phi,  # (Dz, N, N)
)

# ------- CHOIX 2 : COVARIANCE MATRIX -------
q_phi_c = torch.distributions.MultivariateNormal(
    loc=mu_phi,  # (Dz, N)
    scale_tril=L_q_phi,  # (Dz, N, N)
)

# ----- Summary de l'encoder q_phi -----
print(f"q_phi with precision matrix : {q_phi_p}")
print(f"\tq_phi batch shape: {q_phi_p.batch_shape}")
print(f"\tq_phi event shape: {q_phi_p.event_shape}")

print()
print(f"q_phi with Cholesky matrix : {q_phi_c}")
print(f"\tq_phi batch shape: {q_phi_c.batch_shape}")
print(f"\tq_phi event shape: {q_phi_c.event_shape}")
# Out:
# q_phi with precision matrix : MultivariateNormal(loc: torch.Size([1, 2, 100]), precision_matrix: torch.Size([1, 2, 100, 100]))
# 	q_phi batch shape: torch.Size([1, 2])
# 	q_phi event shape: torch.Size([100])
#
# q_phi with Cholesky matrix : MultivariateNormal(loc: torch.Size([1, 2, 100]), scale_tril: torch.Size([1, 2, 100, 100]))
# 	q_phi batch shape: torch.Size([1, 2])
# 	q_phi event shape: torch.Size([100])

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 20px; color: black; font-weight: bold;">
# Decoder
# </div>
#
# By D-separation, we know that the decoder factorizes :
#
# \begin{align}
# p_{\theta_x}(x_{1:N} \vert z_{1:N}) &= \prod_{i=1}^{N} p_{\theta_x}(x_i \vert z_i)
# \end{align}
#
# When the decoder is chosen to be Gaussian, each $p_{\theta_x}(x_i \vert z_i)$ is a Gaussian distribution of dimension $D_x$ with a covariance matrix that can be any PSD matrix (as there are correlations between dimensions of $x$) :
#
# \begin{align}
# p_{\theta_x} (x_{i} \vert z_{i}) &= \mathcal{N}(\mu_{\theta_x}(x_{i} \vert z_{i}), (\Sigma_{\theta_x}(x_{i} \vert z_{i})))
# \end{align}
#
# We learn $\mu_{\theta_x}$ and $\Sigma_{\theta_x}$ with two MLPs.

# %%
class DecoderMean(nn.Module):
    """ Neural Net to compute the mean of the Gaussian Decoder distribution.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(DecoderMean, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        
        self.mlp = make_mlp(
            input_dim=z_dimension,
            output_dim=x_dimension,
            n_layers=n_layers,
            inter_dim=inter_dim,
            activation=activation
        )
    
    def forward(self, z):
        """
        Forward pass of the DecoderMean.
        Args:
            z (torch.Tensor): Input tensor of shape (..., z_dimension)
        Returns:
            torch.Tensor: mu_x : Output tensor of shape (..., x_dimension)
        """
              
        # mini check
        assert z.size(-1) == self.z_dimension, f"Incorrect latent dim. Input tensor z must have shape (..., {self.z_dimension})"
            
        return self.mlp(z)  # (..., Dx)
    
    def __repr__(self):
        return (f"{self.__class__.__name__} "
                f"x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}")

# %%
decoder_mean = DecoderMean(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=16,
    activation=nn.ReLU,
).to(device)

print(decoder_mean)

z = q_phi_c.sample()  # (B, Dz, N)
print()
print(f"z shape when sampled : {z.shape}")  # (B, Dz, N)
print(f"Note that we need to permute the last two dimensions of z to match the decoder_mean input shape (B, N, Dz)")

z = z.permute(0, 2, 1)  # (B, N, Dz) to match the decoder input shape
print(f"z shape after permutation for decoding : {z.shape}")  # (B, N, Dz)
decoder_mean_output = decoder_mean(z)  # (B, N, Dx)
# decoder_mean_output = decoder_mean_output.transpose(-1,-2)  # (B, Dx, N) to match the output shape

print()
print(f"decoder_mean_output shape (B,N,Dx): {decoder_mean_output.shape}")  # (B, Dx, N)
# Out:
# DecoderMean x_dimension=4, z_dimension=2, n_layers=2, inter_dim=16, activation=ReLU
#
# z shape when sampled : torch.Size([1, 2, 100])
# Note that we need to permute the last two dimensions of z to match the decoder_mean input shape (B, N, Dz)
# z shape after permutation for decoding : torch.Size([1, 100, 2])
#
# decoder_mean_output shape (B,N,Dx): torch.Size([1, 100, 4])

# %% [markdown]
# We get the decoder covariance matrix $D_x \times D_x$ as we did for the encoder covariance matrix (ie via bi-bande-based precision matrix or Cholesky-based covariance matrix)

# %%
# Decoder Covariance

class DecoderCovariance(nn.Module):
    """ Neural Net to compute the covariance of the Gaussian Decoder distribution.
    Uses a MLP to compute the lower triangular matrix of the Cholesky decomposition of the covariance matrix.
    L is triangular inferior, with diagonal elements strictly positive.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 epsilon = 1e-3,  # small positive constant to ensure positive definiteness of the kernel matrix
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(DecoderCovariance, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0 !"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        self.epsilon = float(epsilon)  # small positive constant to ensure positive definiteness of the kernel matrix
        
        # this network to get the diagonal elements of the covariance matrix
        self.diagonal_mlp = make_mlp(
            input_dim=self.z_dimension,
            output_dim=self.x_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
        # this network to get Dz elements that will be the lower triangular part (without the diagonal) of the covariance matrix                
        self.full_matrix_mlp = make_mlp(
            input_dim=self.z_dimension,
            output_dim=self.x_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
    
    def forward(self, z):
        """
        Forward pass of the EncoderCovariance.
        Args:
            z (torch.Tensor): Input tensor (..., N, z_dimension) 
                - N can be 1 (ie a single point) or the sequence length. Must be specified.

        Returns:
            L (torch.Tensor): Lower triangular matrix of shape (..., N, x_dimension, x_dimension) 
                L can be used as scale_tril in tf.distributions.MultivariateNormal
            C (torch.Tensor): Covariance matrix of shape (..., N, x_dimension, x_dimension) 
                C can be used as covariance_matrix in tf.distributions.MultivariateNormal. but this creates lots of numerical instabilities.
            C is computed as L @ L^T, where L is the lower triangular matrix. (Cholesky decomposition)
        """
        
        # basic check of shape of input x
        assert z.size(-1) == self.z_dimension, f"Wrong z_dim in DecoderCovariance. Input tensor must have shape (batch_size, {self.sequence_length}, {self.z_dimension}) or ({self.sequence_length}, {self.z_dimension})"
        assert z.dim() >= 2, "Input tensor must have at least 2 dimensions (sequence_length -possibly 1- and x_dimension)"
        
        # input is a tensor of shape (..., N, Dx)
        N = z.size(-2)  # sequence length
        
        # Compute the diagonal elements of the covariance matrix
        D = self.diagonal_mlp(z)  # out : (..., N,Dx)
        D = torch.exp(D) # out : (..., N,Dx). Ensure entries > 0.
        D = torch.diag_embed(D) # shape (...,N,Dx,Dx)
        
        # Get the elements outside the diagonal
        M = self.full_matrix_mlp(z) # shape (..., N,Dx)
        M1 = M.unsqueeze(-1)  # shape (...,N,Dx,1)
        M2 = M.unsqueeze(-2)  # shape (...,N,1,Dx)
        M = torch.matmul(M1, M2)  # shape (..., N,Dx,DX)
        # Keep only the lower triangular part of the matrix (excluding the diagonal)
        M = torch.tril(M, diagonal=-1)  # (...,N,Dx,Dx)
        
        # Assemble the lower triangular matrix L
        L = D + M # (...,N,Dx,Dx)
        
        # Assemble the covariance matrix C
        C = L @ L.transpose(-1, -2)  # C = L @ L^T # (...,N,Dx,Dx)
        C = C + self.epsilon * torch.eye(self.x_dimension, device=x.device) # Add a small value to the diagonal for numerical stability (use broadcasting)
        
        return L, C # (..., Dz, N, N) Covariance matrix C
    
    def __repr__(self):
        return (f"{self.__class__.__name__} : "
                f"(x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}, "
                f"epsilon (to ensure PSD)={self.epsilon:.3e})")

# %%
# Decoder Covariance

class DecoderCovarianceDiagonal(nn.Module):
    """ Neural Net to compute a Diagonal covariance of the Gaussian Decoder distribution.
    Uses a MLP to compute the lower triangular matrix of the Cholesky decomposition of the covariance matrix. 
    But does not use it :-)
    L is triangular inferior, with diagonal elements strictly positive.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 epsilon = 1e-3,  # small positive constant to ensure positive definiteness of the kernel matrix
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(DecoderCovarianceDiagonal, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0 !"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        self.epsilon = float(epsilon)  # small positive constant to ensure positive definiteness of the kernel matrix
        
        # this network to get the diagonal elements of the covariance matrix
        self.diagonal_mlp = make_mlp(
            input_dim=self.z_dimension,
            output_dim=self.x_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
        # this network to get Dz elements that will be the lower triangular part (without the diagonal) of the covariance matrix                
        self.full_matrix_mlp = make_mlp(
            input_dim=self.z_dimension,
            output_dim=self.x_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
    
    def forward(self, z):
        """
        Forward pass of the EncoderCovariance.
        Args:
            z (torch.Tensor): Input tensor (..., N, z_dimension) 
                - N can be 1 (ie a single point) or the sequence length. Must be specified.

        Returns:
            L (torch.Tensor): Diagonal covariance matrix of shape (..., N, x_dimension, x_dimension) 
                L can be used as scale_tril in tf.distributions.MultivariateNormal
            C (torch.Tensor): Covariance matrix of shape (..., N, x_dimension, x_dimension) 
                C can be used as covariance_matrix in tf.distributions.MultivariateNormal. but this creates lots of numerical instabilities.
            C is computed as L @ L^T, where L is the lower triangular matrix. (Cholesky decomposition)
        """
        
        # basic check of shape of input x
        assert z.size(-1) == self.z_dimension, f"Wrong z_dim in DecoderCovariance. Input tensor must have shape (batch_size, {self.sequence_length}, {self.z_dimension}) or ({self.sequence_length}, {self.z_dimension})"
        assert z.dim() >= 2, "Input tensor must have at least 2 dimensions (sequence_length -possibly 1- and x_dimension)"
        
        # input is a tensor of shape (..., N, Dx)
        N = z.size(-2)  # sequence length
        
        # Compute the diagonal elements of the covariance matrix
        D = self.diagonal_mlp(z)  # out : (..., N,Dx)
        D = torch.exp(D) # out : (..., N,Dx). Ensure entries > 0.
        D = torch.diag_embed(D) # shape (...,N,Dx,Dx)
        
        # Get the elements outside the diagonal
        M = self.full_matrix_mlp(z) # shape (..., N,Dx)
        M1 = M.unsqueeze(-1)  # shape (...,N,Dx,1)
        M2 = M.unsqueeze(-2)  # shape (...,N,1,Dx)
        M = torch.matmul(M1, M2)  # shape (..., N,Dx,DX)
        # Keep only the lower triangular part of the matrix (excluding the diagonal)
        M = torch.tril(M, diagonal=-1)  # (...,N,Dx,Dx)
        
        # Assemble the lower triangular matrix L
        # L = D + M # (...,N,Dx,Dx)
        L = D  # keep only the diagonal part
        
        # Assemble the covariance matrix C
        C = L @ L.transpose(-1, -2)  # C = L @ L^T # (...,N,Dx,Dx)
        C = C + self.epsilon * torch.eye(self.x_dimension, device=x.device) # Add a small value to the diagonal for numerical stability (use broadcasting)
        
        return L, C # (..., Dz, N, N) Covariance matrix C
    
    def __repr__(self):
        return (f"{self.__class__.__name__} : "
                f"(x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}, "
                f"epsilon (to ensure PSD)={self.epsilon:.3e})")

# %%
# decoder_covariance = DecoderCovariance(
#     x_dimension=Dx,
#     z_dimension=Dz,
#     n_layers=2,
#     inter_dim=32,
#     activation=nn.ReLU,
# ).to(device)

decoder_covariance = DecoderCovarianceDiagonal(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=32,
    activation=nn.ReLU,
).to(device)

print(decoder_covariance)

z = q_phi_c.sample()  # (B, Dz, N)

print()
print(f"z shape when sampled (B,Dz,N): {z.shape}")  # (B, Dz, N)
z = z.permute(0, 2, 1)  # (B, N, Dz) to match the decoder input shape
print(f"Note that we need to permute the last two dimensions of z to match the decoder_mean input shape (B, N, Dz)")
print(f"z shape after permutation for decoding (B,N,Dz): {z.shape}")  # (B, N, Dz)

L, decoder_covar_output = decoder_covariance(z)  # (B,N,Dx,Dx)

print()
print(f"decoder_covar_output shape (B,N,Dx,Dx): {decoder_covar_output.shape}")  # (B,N,Dx,Dx)
# Out:
# DecoderCovarianceDiagonal : (x_dimension=4, z_dimension=2, n_layers=2, inter_dim=32, activation=ReLU, epsilon (to ensure PSD)=1.000e-03)
#
# z shape when sampled (B,Dz,N): torch.Size([1, 2, 100])
# Note that we need to permute the last two dimensions of z to match the decoder_mean input shape (B, N, Dz)
# z shape after permutation for decoding (B,N,Dz): torch.Size([1, 100, 2])
#
# decoder_covar_output shape (B,N,Dx,Dx): torch.Size([1, 100, 4, 4])

# %% [markdown]
# We form the decoder with a multivariate normal distribution

# %%
mu_x = decoder_mean_output  # (B,N,Dx)
print(f"mu_x shape (B,N,Dx): {mu_x.shape}")

covar_x = decoder_covar_output  # (B,N,Dx,Dx)
print(f"covar_x shape (B,N,Dx,Dx): {covar_x.shape}")

p_theta_x = torch.distributions.MultivariateNormal(
    loc=mu_x,
    covariance_matrix=covar_x
)

print(f"p_theta_x: {p_theta_x}")
print(f"\tp_theta_x batch shape (B,Dx): {p_theta_x.batch_shape}") # (B,Dx)
print(f"\tp_theta_x event shape (N): {p_theta_x.event_shape}") # (N,)
# Out:
# mu_x shape (B,N,Dx): torch.Size([1, 100, 4])
# covar_x shape (B,N,Dx,Dx): torch.Size([1, 100, 4, 4])
# p_theta_x: MultivariateNormal(loc: torch.Size([1, 100, 4]), covariance_matrix: torch.Size([1, 100, 4, 4]))
# 	p_theta_x batch shape (B,Dx): torch.Size([1, 100])
# 	p_theta_x event shape (N): torch.Size([4])

# %% [markdown]
# We will actually instantiate several ($K$) distributions $p_{\theta_x}$ by sampling $K$ times $z_{1:N}$, so we can average the reconstruction loss.

# %%
K = 30  # Number of samples to average the reconstruction loss
z_sampled = q_phi_c.sample((K,))  # (K,B,Dz,N)

print(f"z shape when sampled K={K} times (K,B,Dz,N): {z_sampled.shape}")  # (K, B, Dz, N)
z_sampled_p = z_sampled.transpose(-1, -2)
print(f"Permuting the last two dimensions of z to match the decoder covariance input shape (K,B,N,Dz)")
print(f"z shape after permutation for decoding mean (K,B,N,Dz) : {z_sampled_p.shape}")  # (K, B, N, Dz)

mu_x = decoder_mean(z_sampled_p)  # (K,B,N,Dx)
print()
print(f"mu_x shape (K,B,N,Dx): {mu_x.shape}")

L_x, covar_x = decoder_covariance(z_sampled_p)  # (K,B,N,Dx,Dx)
print(f"covar_x shape (K,B,N,Dx,Dx): {covar_x.shape}")

p_theta_x = torch.distributions.MultivariateNormal(
    loc=mu_x,
    covariance_matrix=covar_x
)

print()
print(f"p_theta_x: {p_theta_x}")
print(f"\tp_theta_x batch shape (K,B,N): {p_theta_x.batch_shape}")  # (K, B, N)
print(f"\tp_theta_x event shape (Dx): {p_theta_x.event_shape}")  # (Dx,)
# Out:
# z shape when sampled K=30 times (K,B,Dz,N): torch.Size([30, 1, 2, 100])
# Permuting the last two dimensions of z to match the decoder covariance input shape (K,B,N,Dz)
# z shape after permutation for decoding mean (K,B,N,Dz) : torch.Size([30, 1, 100, 2])
#
# mu_x shape (K,B,N,Dx): torch.Size([30, 1, 100, 4])
# covar_x shape (K,B,N,Dx,Dx): torch.Size([30, 1, 100, 4, 4])
#
# p_theta_x: MultivariateNormal(loc: torch.Size([30, 1, 100, 4]), covariance_matrix: torch.Size([30, 1, 100, 4, 4]))
# 	p_theta_x batch shape (K,B,N): torch.Size([30, 1, 100])
# 	p_theta_x event shape (Dx): torch.Size([4])

# %%
print(f"One covariance matrix for one x_t: ")
print(f"{covar_x[0,0,0]}")  # (Dx, Dx)
# Out:
# One covariance matrix for one x_t:
# tensor([[2.0730, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.3397, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.1494, 0.0000],
#         [0.0000, 0.0000, 0.0000, 1.2788]], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 20px; color: black; font-weight: bold;">
# Gaussian Process priors
# </div>
#
# Each dimension $l$ of the latent variables (with $1 \leq l \leq D_z$) has a Gaussian Process prior over times:
#
# \begin{align}
# z_l \sim \mathcal{GP}(m_l(.), k_l(.,.))
# \end{align}
#
# The mean functions $m_l$ are usually constant null.
#
# The kernel functions $k_l(.,.)$ are a priori different along the dimensions. They encode the prior knowledge (if any) regarding the time series. They can either be fixed, or have learnable parameters.

# %% [markdown]
# Gaussian Kernel class with learnable parameters

# %%
class GaussianKernel(nn.Module):  
    """Gaussian kernel for one univariate Gaussian Process.
    The lengthscale and variance parameters are learnable (nn.Parameter).
    """
    
    # we need to add a small positive constant to ensure positive definiteness of the kernel matrix
    # 1e-3 is ok for time series up to 10,000 time points.
    # 1e-4 is ok for time series up to 2,880 time points. (ie 2 days @ 1 minute resolution).
    # 1e-4 is ok for time series up to 1,000 time points.
    # 1e-6 is ok for time series up to 100 time points.
    # the value can be decreased for shorter time series.
    # but it should not be too small, otherwise the Cholesky decomposition will fail.
    
    def __init__(self, lengthscale=1.0, sigma=1.0, epsilon=1e-3):
        super(GaussianKernel, self).__init__()
        
        # learnable parameters for the Gaussian kernel
        self.lengthscale = nn.Parameter(torch.tensor(lengthscale))  # learnable lengthscale parameter       
        self.sigma = nn.Parameter(torch.tensor(sigma))  # learnable variance parameter
        
        self.epsilon = torch.tensor(epsilon)  # tolerance to ensure positive definiteness of the kernel matrix
    
    def forward(self, t1, t2):
        """Compute the Gaussian kernel between two sets of time points.
        
        Args:
            t1 (torch.Tensor): First set of time points (..., N) - N is typically the sequence length.
            t2 (torch.Tensor): Second set of time points (..., M)
        
        Returns:
            torch.Tensor: Kernel matrix of shape (..., N, M)
        """
        
        assert t1.dim() == t2.dim(), "GaussianKernel object : Input tensors must have the same number of dimensions"
        
        # Compute the Gaussian kernel matrix
        if t1.dim() == 1:
            t1_b = t1.unsqueeze(-1)  # (N, 1)
            t2_b = t2.unsqueeze(0)   # (1, M)
            kernel = torch.exp(-0.5 * ((t1_b - t2_b) / self.lengthscale)**2)  # (N, M)
        else:
            t1_b = t1.unsqueeze(-1) # (...,N, 1)
            t2_b = t2.unsqueeze(-2) # (...,1, M)
            kernel = torch.exp(-0.5 * ((t1_b - t2_b) / self.lengthscale)**2)  # (..., N, M)
        
        gaussian_kernel_matrix = self.sigma**2 * kernel  # (..., N, M)

        if torch.equal(t1, t2):
            # If t1 and t2 are the same, the kernel matrix should be symmetric and positive definite
            # so we compute and return the Cholesky decomposition of the kernel matrix
            # to be used in forming the MultivariateNormal distribution, adding
            # a small value to the diagonal for numerical stability
            gaussian_kernel_matrix = gaussian_kernel_matrix + self.epsilon * torch.eye(t1.size(-1), device=t1.device, dtype=t1.dtype)

            try:
                L = torch.linalg.cholesky(gaussian_kernel_matrix)  # Cholesky decomposition to ensure positive definiteness
                return gaussian_kernel_matrix, L  # Return the kernel matrix and its Cholesky factor L
            
            except RuntimeError:
                # If the Cholesky decomposition fails, it means the matrix is not positive definite
                # We can return None or raise an error, depending on how we want to handle this case
                # print("Warning: Cholesky decomposition failed.")
                # print(f"Kernel : {gaussian_kernel_matrix}")
                # return gaussian_kernel_matrix, None  # Return the kernel matrix and None for L
                raise NameError("Cholesky decomposition of a supposedly PSD kernel matrix failed. Tolerance alpha is likely too low.") 
            
        else:
            # If t1 and t2 are different, do not try to compute the Cholesky decomposition
            return gaussian_kernel_matrix, None
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(lengthscale={self.lengthscale.item():.3e}, "
                f"variance (sigma**2)={self.sigma.item()**2:.3e}, "
                f"sigma={self.sigma.item():.3e}, "
                f"epsilon={self.epsilon.item():.3e})")

# %%
class GaussianKernelFixed(nn.Module):  
    """Gaussian kernel for one univariate Gaussian Process.
    The lengthscale and variance parameters are NOT learnable.
    """
    
    # we need to add a small positive constant to ensure positive definiteness of the kernel matrix
    # 1e-3 is ok for time series up to 10,000 time points.
    # 1e-4 is ok for time series up to 2,880 time points. (ie 2 days @ 1 minute resolution).
    # 1e-4 is ok for time series up to 1,000 time points.
    # 1e-6 is ok for time series up to 100 time points.
    # the value can be decreased for shorter time series.
    # but it should not be too small, otherwise the Cholesky decomposition will fail.
    
    def __init__(self, lengthscale=1.0, sigma=1.0, epsilon=1e-3):
        super(GaussianKernelFixed, self).__init__()
        
        # learnable parameters for the Gaussian kernel
        self.lengthscale = torch.tensor(lengthscale)  # learnable lengthscale parameter       
        self.sigma = torch.tensor(sigma)  # learnable variance parameter
        
        self.epsilon = torch.tensor(epsilon)  # tolerance to ensure positive definiteness of the kernel matrix
    
    def forward(self, t1, t2):
        """Compute the Gaussian kernel between two sets of time points.
        
        Args:
            t1 (torch.Tensor): First set of time points (..., N) - N is typically the sequence length.
            t2 (torch.Tensor): Second set of time points (..., M)
        
        Returns:
            torch.Tensor: Kernel matrix of shape (..., N, M)
        """
        
        assert t1.dim() == t2.dim(), "GaussianKernel object : Input tensors must have the same number of dimensions"
        
        # Compute the Gaussian kernel matrix
        if t1.dim() == 1:
            t1_b = t1.unsqueeze(-1)  # (N, 1)
            t2_b = t2.unsqueeze(0)   # (1, M)
            kernel = torch.exp(-0.5 * ((t1_b - t2_b) / self.lengthscale)**2)  # (N, M)
        else:
            t1_b = t1.unsqueeze(-1) # (...,N, 1)
            t2_b = t2.unsqueeze(-2) # (...,1, M)
            kernel = torch.exp(-0.5 * ((t1_b - t2_b) / self.lengthscale)**2)  # (..., N, M)
        
        gaussian_kernel_matrix = self.sigma**2 * kernel  # (..., N, M)

        if torch.equal(t1, t2):
            # If t1 and t2 are the same, the kernel matrix should be symmetric and positive definite
            # so we compute and return the Cholesky decomposition of the kernel matrix
            # to be used in forming the MultivariateNormal distribution, adding
            # a small value to the diagonal for numerical stability
            gaussian_kernel_matrix = gaussian_kernel_matrix + self.epsilon * torch.eye(t1.size(-1), device=t1.device, dtype=t1.dtype)

            try:
                L = torch.linalg.cholesky(gaussian_kernel_matrix)  # Cholesky decomposition to ensure positive definiteness
                return gaussian_kernel_matrix, L  # Return the kernel matrix and its Cholesky factor L
            
            except RuntimeError:
                # If the Cholesky decomposition fails, it means the matrix is not positive definite
                # We can return None or raise an error, depending on how we want to handle this case
                # print("Warning: Cholesky decomposition failed.")
                # print(f"Kernel : {gaussian_kernel_matrix}")
                # return gaussian_kernel_matrix, None  # Return the kernel matrix and None for L
                raise NameError("Cholesky decomposition of a supposedly PSD kernel matrix failed. Tolerance alpha is likely too low.") 
            
        else:
            # If t1 and t2 are different, do not try to compute the Cholesky decomposition
            return gaussian_kernel_matrix, None
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(lengthscale={self.lengthscale.item():.3e}, "
                f"variance (sigma**2)={self.sigma.item()**2:.3e}, "
                f"sigma={self.sigma.item():.3e}, "
                f"epsilon={self.epsilon.item():.3e})")

# %% [markdown]
# Matern Kernel class with learnable parameters

# %%
class MaternKernel(nn.Module):
    """Matern kernel for one univariate Gaussian Process.
    Takes nu = 0.5, 1.5, 2.5 in the constructor.
    The lengthscale, variance and alpha parameters are learnable (nn.Parameter).
    """
    
    def __init__(self, nu, lengthscale=1.0, sigma=1.0, epsilon=1e-3):
        super(MaternKernel, self).__init__()
        
        # check
        if nu not in [0.5, 1.5, 2.5]:
            raise ValueError("MaternKernel: nu must be one of [0.5, 1.5, 2.5]")
        self.nu = nu  # Matern parameter nu
        
        # learnable parameters for the RQ kernel
        self.lengthscale = nn.Parameter(torch.tensor(lengthscale))  # learnable alpha parameter (shape parameter)
        self.sigma = nn.Parameter(torch.tensor(sigma))  # learnable variance = sigma**2 parameter

        self.epsilon = epsilon  # small value to ensure positive definiteness of the kernel matrix
    
    def forward(self, t1, t2):
        """Compute the Matern kernel between two sets of time points.
        
        Args:
            t1 (torch.Tensor): First set of time points (..., N) - N is typically the sequence length.
            t2 (torch.Tensor): Second set of time points (..., M)
        
        Returns:
            torch.Tensor: Kernel matrix of shape (..., N, M)
        """
        
        assert t1.dim() == t2.dim(), "Matern Kernel object : Input tensors must have the same number of dimensions"
        
        if t1.dim() == 1:
            t1_b = t1.unsqueeze(-1)  # (N, 1)
            t2_b = t2.unsqueeze(0)   # (1, M)
        else:
            t1_b = t1.unsqueeze(-1) # (..., N, 1)
            t2_b = t2.unsqueeze(-2) # (..., 1, M)
        
        d = torch.abs(t1_b - t2_b)  # (..., N, M)
        
        if self.nu == 0.5:
            # Matern kernel with nu = 0.5
            matern_kernel = self.sigma**2 * torch.exp(-d / self.lengthscale)
        elif self.nu == 1.5:
            # Matern kernel with nu = 1.5
            matern_kernel = self.sigma**2 * (1 + (d * torch.sqrt(torch.tensor(3))) / self.lengthscale) * torch.exp(-d * torch.sqrt(torch.tensor(3)) / self.lengthscale)
        elif self.nu == 2.5:
            # Matern kernel with nu = 2.5
            matern_kernel = self.sigma**2 * (1 + ((d * torch.sqrt(torch.tensor(5))) / self.lengthscale) + (5 * d**2 / (3 * self.lengthscale**2))) * torch.exp(-d * torch.sqrt(torch.tensor(5)) / self.lengthscale)
        else:
            raise ValueError("MaternKernel: nu must be one of [0.5, 1.5, 2.5]")

        if torch.equal(t1, t2):
            # If t1 and t2 are the same, the kernel matrix should be symmetric and positive definite
            # so we compute and return the Cholesky decomposition of the kernel matrix
            # to be used in forming the MultivariateNormal distribution, adding
            # a small value to the diagonal for numerical stability
            matern_kernel += self.epsilon * torch.eye(t1.size(-1), device=t1.device, dtype=t1.dtype)
            try:
                L = torch.linalg.cholesky(matern_kernel)  # Cholesky decomposition to ensure positive definiteness
                return matern_kernel, L  # Return the kernel matrix and its Cholesky factor L
            except RuntimeError:
                # If the Cholesky decomposition fails, it means the matrix is not positive definite
                # We can return None or raise an error, depending on how we want to handle this case
                # print("Warning: Cholesky decomposition failed.")
                # print(f"Kernel : {gaussian_kernel_matrix}")
                # return gaussian_kernel_matrix, None  # Return the kernel matrix and None for L
                raise NameError("Cholesky decomposition of a supposedly PSD kernel matrix failed in Matern Kernel. Tolerance epsilon is likely too low.") 
        else:
            # If t1 and t2 are different, do not try to compute the Cholesky decomposition
            return matern_kernel, None
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(nu={self.nu}, "
                f"lengthscale={self.lengthscale.item():.3e}, "
                f"sigma={self.sigma.item():.3e}, "
                f"variance (sigma**2)={self.sigma.item()**2:.3e}, "
                f"epsilon={self.epsilon:.3e})")

# %%
class MaternKernelFixed(nn.Module):
    """Matern kernel for one univariate Gaussian Process.
    Takes nu = 0.5, 1.5, 2.5 in the constructor.
    The lengthscale, variance and alpha parameters are NOT learnable.
    """
    
    def __init__(self, nu, lengthscale=1.0, sigma=1.0, epsilon=1e-3):
        super(MaternKernelFixed, self).__init__()
        
        # check
        if nu not in [0.5, 1.5, 2.5]:
            raise ValueError("MaternKernel: nu must be one of [0.5, 1.5, 2.5]")
        self.nu = nu  # Matern parameter nu
        
        # learnable parameters for the RQ kernel
        self.lengthscale = torch.tensor(lengthscale)  # NOT learnable alpha parameter (shape parameter)
        self.sigma = torch.tensor(sigma)  # NOT learnable variance = sigma**2 parameter

        self.epsilon = epsilon  # small value to ensure positive definiteness of the kernel matrix
    
    def forward(self, t1, t2):
        """Compute the Matern kernel between two sets of time points.
        
        Args:
            t1 (torch.Tensor): First set of time points (..., N) - N is typically the sequence length.
            t2 (torch.Tensor): Second set of time points (..., M)
        
        Returns:
            torch.Tensor: Kernel matrix of shape (..., N, M)
        """
        
        assert t1.dim() == t2.dim(), "Matern Kernel object : Input tensors must have the same number of dimensions"
        
        if t1.dim() == 1:
            t1_b = t1.unsqueeze(-1)  # (N, 1)
            t2_b = t2.unsqueeze(0)   # (1, M)
        else:
            t1_b = t1.unsqueeze(-1) # (..., N, 1)
            t2_b = t2.unsqueeze(-2) # (..., 1, M)
        
        d = torch.abs(t1_b - t2_b)  # (..., N, M)
        
        if self.nu == 0.5:
            # Matern kernel with nu = 0.5
            matern_kernel = self.sigma**2 * torch.exp(-d / self.lengthscale)
        elif self.nu == 1.5:
            # Matern kernel with nu = 1.5
            matern_kernel = self.sigma**2 * (1 + (d * torch.sqrt(torch.tensor(3))) / self.lengthscale) * torch.exp(-d * torch.sqrt(torch.tensor(3)) / self.lengthscale)
        elif self.nu == 2.5:
            # Matern kernel with nu = 2.5
            matern_kernel = self.sigma**2 * (1 + ((d * torch.sqrt(torch.tensor(5))) / self.lengthscale) + (5 * d**2 / (3 * self.lengthscale**2))) * torch.exp(-d * torch.sqrt(torch.tensor(5)) / self.lengthscale)
        else:
            raise ValueError("MaternKernel: nu must be one of [0.5, 1.5, 2.5]")

        if torch.equal(t1, t2):
            # If t1 and t2 are the same, the kernel matrix should be symmetric and positive definite
            # so we compute and return the Cholesky decomposition of the kernel matrix
            # to be used in forming the MultivariateNormal distribution, adding
            # a small value to the diagonal for numerical stability
            matern_kernel += self.epsilon * torch.eye(t1.size(-1), device=t1.device, dtype=t1.dtype)
            try:
                L = torch.linalg.cholesky(matern_kernel)  # Cholesky decomposition to ensure positive definiteness
                return matern_kernel, L  # Return the kernel matrix and its Cholesky factor L
            except RuntimeError:
                # If the Cholesky decomposition fails, it means the matrix is not positive definite
                # We can return None or raise an error, depending on how we want to handle this case
                # print("Warning: Cholesky decomposition failed.")
                # print(f"Kernel : {gaussian_kernel_matrix}")
                # return gaussian_kernel_matrix, None  # Return the kernel matrix and None for L
                raise NameError("Cholesky decomposition of a supposedly PSD kernel matrix failed in Matern Kernel. Tolerance epsilon is likely too low.") 
        else:
            # If t1 and t2 are different, do not try to compute the Cholesky decomposition
            return matern_kernel, None
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(nu={self.nu}, "
                f"lengthscale={self.lengthscale.item():.3e}, "
                f"sigma={self.sigma.item():.3e}, "
                f"variance (sigma**2)={self.sigma.item()**2:.3e}, "
                f"epsilon={self.epsilon:.3e})")

# %% [markdown]
# Null mean function class

# %%
class GPNullMean(nn.Module):
    """ Neural Net to compute the mean of one univariate Gaussian Process
    This is a null mean function, i.e. it returns a tensor of zeros...
    """
    
    def __init__(self):
        super(GPNullMean, self).__init__()
    
    def forward(self, t):
        """Forward pass of the GPNullMean.
        Just returns a tensor of zeros of shape identical to the input.
        
        Inputs:
            t (torch.Tensor): Input tensor of shape (..., N) - N is typically the sequence length.
        Returns:
            torch.Tensor: Output tensor of ZEROS of shape (..., N)
        """
        
        return torch.zeros_like(t, dtype=t.dtype, device=t.device)  # (..., N)
    
    def __repr__(self):
        return f"{self.__class__.__name__}"

# %% [markdown]
# Constant mean function class

# %%
class GPConstantMean(nn.Module):
    """ Neural Net to compute the mean of one univariate Gaussian Process
    This is a constant mean function, with a learnable parameter.
    """
    
    def __init__(self, constant_init=0.0):
        super(GPConstantMean, self).__init__()
        
        self.constant_value = nn.Parameter(torch.tensor(constant_init))  # learnable constant value
    
    def forward(self, t):
        """Forward pass of the GPNullMean.
        Just returns a tensor of zeros of shape identical to the input.
        
        Inputs:
            t (torch.Tensor): Input tensor of shape (..., N) - N is typically the sequence length.
        Returns:
            torch.Tensor: Output tensor of ZEROS of shape (..., N)
        """
        
        return self.constant_value * torch.ones_like(t, dtype=t.dtype, device=t.device)  # (..., N)
    
    def __repr__(self):
        return f"{self.__class__.__name__}, constant_value={self.constant_value.item():.3e})"

# %% [markdown]
# We assemble the $D_z$ Gaussian Process priors, for example with kernels with different lengthscales. (cf TF implementation of the GPVAE paper)

# %%
def compute_gp_priors_kernel(t, Dz, starting_lengthscale=0.1, verbose=False):
    """Compute the GP prior kernel matrices
    """
    
    # form the list of kernels and mean functions for the GP priors
    kernels_list = []
    mean_functions_list = []

    for i in range(Dz):
        # kernel = GaussianKernelFixed(lengthscale=starting_lengthscale / 2**i, sigma=1.0, epsilon=1e-12)  # diminishing lengthscale
        kernel = GaussianKernelFixed(lengthscale=starting_lengthscale, sigma=1.0, epsilon=1e-12)  # same fixed lengthscale for all GK
        # kernel = GaussianKernel(lengthscale=starting_lengthscale, sigma=1.0, epsilon=1e-12)  # same fixed lengthscale for all GK
        # kernel = MaternKernel(nu=0.5, lengthscale=starting_lengthscale / 2**i, sigma=1.0, epsilon=1e-3)
        # kernel = MaternKernel(nu=1.5, lengthscale=starting_lengthscale / 2**i, sigma=1.0, epsilon=1e-3)
        # kernel = MaternKernel(nu=2.5, lengthscale=starting_lengthscale / 2**i, sigma=1.0, epsilon=1e-3)
        kernels_list.append(kernel)
        # mean_function = GPConstantMean()
        mean_function = GPNullMean()
        mean_functions_list.append(mean_function)
        
    # compute the kernel matrices for each kernel
    kernel_matrices = []
    L_matrices = []
    means = []

    for i in range(Dz):
        mu_z_i = mean_functions_list[i](t)  # (B, N)
        kernel_matrix_i, L_i = kernels_list[i](t, t)
        kernel_matrices.append(kernel_matrix_i)  # (B, N, N)
        L_matrices.append(L_i)  # (B, N, N) or None
        means.append(mu_z_i)  # (B, N)
        
        if verbose:
            print()
            print(f"Computing Gaussian Process prior for z component {i+1} / {Dz}...")
            print(f"Kernel {i} is : {kernels_list[i]}")
            print(f"Mean function {i} is : {mean_functions_list[i]}")
            print(f"mu_z {i} shape (B,N): {mu_z_i.shape}")  # (B, N)
            print(f"Kernel matrix {i} shape (B,N,N): {kernel_matrix_i.shape}")  # (B, N, N)
        
    kernel_matrix = torch.stack(kernel_matrices, dim=0)  # (Dz, B, N, N)
    kernel_matrix = kernel_matrix.transpose(0, 1) # (B, Dz, N, N)
    L_matrix = torch.stack(L_matrices, dim=0) if L_matrices[0] is not None else None  # (Dz, B, N, N) or None
    L_matrix = L_matrix.transpose(0, 1) if L_matrix is not None else None  # (B, Dz, N, N)
    mean = torch.stack(means, dim=0)  # (Dz, B, N)
    mean = mean.transpose(0, 1)  # (B, Dz, N)
    
    if verbose:
        print()
        print(f"Full Kernel matrix shape after stack and transpose (B,Dz,N,N): {kernel_matrix.shape}")  # (Dz, B, N, N)
        print(f"Full L matrix shape after stack and transpose (B,Dz,N,N): {L_matrix.shape if L_matrix is not None else 'None'}")  # (B, Dz, N, N) or None
        print(f"Mean shape after stack and transpose (B,Dz,N): {mean.shape}")  # (B, Dz, N)
    
    return kernel_matrix, L_matrix, mean, kernels_list, mean_functions_list

# %%
kernel_matrix, L_matrix, mean, kernels_list, mean_functions_list = compute_gp_priors_kernel(t, Dz, verbose=True)
# Out:
# Computing Gaussian Process prior for z component 1 / 2...
# Kernel 0 is : GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 0 is : GPNullMean
# mu_z 0 shape (B,N): torch.Size([1, 100])
# Kernel matrix 0 shape (B,N,N): torch.Size([1, 100, 100])
#
# Computing Gaussian Process prior for z component 2 / 2...
# Kernel 1 is : GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 1 is : GPNullMean
# mu_z 1 shape (B,N): torch.Size([1, 100])
# Kernel matrix 1 shape (B,N,N): torch.Size([1, 100, 100])
#
# Full Kernel matrix shape after stack and transpose (B,Dz,N,N): torch.Size([1, 2, 100, 100])
# Full L matrix shape after stack and transpose (B,Dz,N,N): torch.Size([1, 2, 100, 100])
# Mean shape after stack and transpose (B,Dz,N): torch.Size([1, 2, 100])

# %% [markdown]
# And instantiate $p_{\theta_z}$

# %%
p_theta_z = torch.distributions.MultivariateNormal(
    loc=mean,  # (B, Dz, N)
    scale_tril=L_matrix,  # (B, Dz, N, N)
)

print(f"p_theta_z: {p_theta_z}")
print(f"\tp_theta_z batch shape (B,Dz): {p_theta_z.batch_shape}")  # (B, Dz)
print(f"\tp_theta_z event shape (N): {p_theta_z.event_shape}")  # (N)
# Out:
# p_theta_z: MultivariateNormal(loc: torch.Size([1, 2, 100]), scale_tril: torch.Size([1, 2, 100, 100]))
# 	p_theta_z batch shape (B,Dz): torch.Size([1, 2])
# 	p_theta_z event shape (N): torch.Size([100])

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 20px; color: black; font-weight: bold;">
# Computing the loss
# </div>
#
# The loss is
#
# \begin{align}
# \mathcal{L}(\theta_x, \theta_z, \phi, x_{1:N}) &= \sum_{i=1}^N \mathbb{E}_{z_i \sim q_{\phi}(z_i \vert x_{1:N})} \log{p_{\theta_x}(x_i \vert z_i)} - \sum_{l=1}^{D_z} \mathbb{KL} ( q_{\phi}(z_l \vert x_{1:N}) \vert\vert p_{\theta_z}(z_{l,1:N}))
# \end{align}
#
# Where the expectation $\mathbb{E}_{z_i \sim q_{\phi}(z_i \vert x_{1:N})}$ is approximated by averaging $K$ $p_{\theta_x}$ samples, and the $\mathbb{KL}$'s are computed analytically for two Gaussians.
#
# Remember that $p_{\theta_x}$ is a tf.distributions.MVN object of batch_shape $(K,B,N)$ and event_shape $D_x$. We adapt the original data $x$ of shape $(B,N,Dx)$ accordingly.

# %%
x_rec = torch.unsqueeze(x, 0).repeat(K,1,1,1)  # (K,B,N,Dx)
print(f"x_rec shape (K,B,N,Dx): {x_rec.shape}")  # (K, B, N, Dx)
# Out:
# x_rec shape (K,B,N,Dx): torch.Size([30, 1, 100, 4])

# %%
reconstruction_loss = -p_theta_x.log_prob(x_rec)  # (K,B,N)
print(f"Reconstruction loss tensor shape (K,B,N): {reconstruction_loss.shape}")

rec_loss = reconstruction_loss.sum(-1)  # Sum over the length N
# rec_loss = rec_loss.mean()  # Average over the batch size B and the K samples
rec_loss = rec_loss.sum()  # Sum over the batch size B and the K samples

kl = torch.distributions.kl_divergence(q_phi_c, p_theta_z)  # (B, Dz)
print(f"KL divergence tensor shape (B,Dz): {kl.shape}")  # (B, Dz)

kl_loss = kl.sum(-1)  # Sum over the dimensions Dz
# kl_loss = kl_loss.mean()  # Average over the batch size B
kl_loss = kl_loss.sum()  # Sum over the batch size B

print()
print(f"Summing the reconstruction loss over N and averaging over B and K")
print(f"Summing the KL divergence over Dz and averaging over B")
print(f"KL = {kl_loss.item():.4e}")
print(f"reconstruction = {rec_loss.item():.4e}")
print(f"total loss = {(kl_loss + rec_loss).item():.4e}")
# Out:
# Reconstruction loss tensor shape (K,B,N): torch.Size([30, 1, 100])
# KL divergence tensor shape (B,Dz): torch.Size([1, 2])
#
# Summing the reconstruction loss over N and averaging over B and K
# Summing the KL divergence over Dz and averaging over B
# KL = 1.2314e+14
# reconstruction = 1.8086e+04
# total loss = 1.2314e+14

# %% [markdown]
# Then we can backpropagate

# %%
loss = kl_loss + rec_loss  # Total loss
loss.backward()  # Backpropagation
print(f"Loss backpropagated. Gradients computed.")
# Out:
# Loss backpropagated. Gradients computed.

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# Data
# </div>
#
# We will create $Dx$ time series over $N$ points

# %%
# Dimensions
Dx = 4
Dz = 2

# parameters
N = 100
B = 1

# %%
t = torch.linspace(0, 1, N).to(device)
xs = [ t * torch.sin(2 * torch.pi * t * (4*(i+1))) for i in range(Dx) ] # (Dx,N)
x = torch.stack(xs, dim=-1)  # (N, Dx)
x = torch.unsqueeze(x,0)
x = x.repeat(B, 1, 1)  # (B, N, Dx)

t = t.unsqueeze(0).repeat(B, 1)  # (B, N)

print(f"t shape: {t.shape}")  # (B, N)
print(f"Input shape: {x.shape}")  # (B, N, Dx)

if Dx > 1:
    fig, axs = plt.subplots(Dx, 1, figsize=(10, 2 * Dx))
    for i in range(Dx):
        axs[i].plot(t[0].cpu().numpy(), x[0, :, i].cpu().numpy(), label=f"x_{i+1}")
        axs[i].set_title(f"Input x_{i+1}")
        axs[i].legend()
        axs[i].grid()
else:
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(t[0].cpu().numpy(), x[0, :, 0].cpu().numpy(), label="x_1")
    ax.set_title("Input x_1")
    ax.legend()
    ax.grid()
# Out:
# t shape: torch.Size([1, 100])
# Input shape: torch.Size([1, 100, 4])

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# Training
# </div>

# %% [markdown]
# Torch Encode and Decoder components

# %%
encoder_mean = EncoderMean(        
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=4,
    inter_dim=32,
    activation=nn.Tanh,
).to(device)

print(encoder_mean)

encoder_precision = EncoderPrecision(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=4,
    inter_dim=32,
    activation=nn.Tanh, 
    epsilon=1e-6
).to(device)

print(encoder_precision)

encoder_covariance = EncoderCovariance(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=8,
    inter_dim=64,
    activation=nn.Tanh,
    epsilon=1e-6
).to(device)

print(encoder_covariance)

decoder_mean = DecoderMean(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=8,
    inter_dim=64,
    activation=nn.Tanh,
).to(device)

print(decoder_mean)

# decoder_covariance = DecoderCovariance(
#     x_dimension=Dx,
#     z_dimension=Dz,
#     n_layers=8,
#     inter_dim=64,
#     activation=nn.Tanh,
#     epsilon=1e-6,
# ).to(device)

decoder_covariance = DecoderCovarianceDiagonal(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=8,
    inter_dim=64,
    activation=nn.Tanh,
    epsilon=1e-6,
).to(device)

print(decoder_covariance)
# Out:
# EncoderMean, x_dimension=4, z_dimension=2, n_layers=4, inter_dim=32, activation=Tanh
# EncoderPrecision(x_dimension=4, z_dimension=2, n_layers=4, inter_dim=32, activation=Tanh, epsilon=1e-06)
# EncoderCovariance : (x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh, epsilon (to ensure PSD)=1.000e-06)
# DecoderMean x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh
# DecoderCovarianceDiagonal : (x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh, epsilon (to ensure PSD)=1.000e-06)

# %% [markdown]
# Gaussian Process priors

# %%
kernel_matrix, L_matrix, mean, kernels_list, mean_functions_list = compute_gp_priors_kernel(t, Dz, verbose=True)
# Out:
# Computing Gaussian Process prior for z component 1 / 2...
# Kernel 0 is : GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 0 is : GPNullMean
# mu_z 0 shape (B,N): torch.Size([1, 100])
# Kernel matrix 0 shape (B,N,N): torch.Size([1, 100, 100])
#
# Computing Gaussian Process prior for z component 2 / 2...
# Kernel 1 is : GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 1 is : GPNullMean
# mu_z 1 shape (B,N): torch.Size([1, 100])
# Kernel matrix 1 shape (B,N,N): torch.Size([1, 100, 100])
#
# Full Kernel matrix shape after stack and transpose (B,Dz,N,N): torch.Size([1, 2, 100, 100])
# Full L matrix shape after stack and transpose (B,Dz,N,N): torch.Size([1, 2, 100, 100])
# Mean shape after stack and transpose (B,Dz,N): torch.Size([1, 2, 100])

# %%
def compute_p_theta_z(t, kernels_list, mean_functions_list, verbose=False):
    """ Compute the Gaussian Process prior p_theta_z for each kernel and mean function.
    This function is used at each training step as the parameters of the kernels and mean functions are updated.
    """
    
    kernel_matrices = []
    L_matrices = []
    means = []

    for i in range(Dz):
        
        mu_z_i = mean_functions_list[i](t)  # (B, N)
        kernel_matrix_i, L_i = kernels_list[i](t, t)

        kernel_matrices.append(kernel_matrix_i)  # (B, N, N)
        L_matrices.append(L_i)  # (B, N, N) or None
        means.append(mu_z_i)  # (B, N)
        
        if verbose:
            print()
            print(f"Computing Gaussian Process prior for z component {i+1} / {Dz}...")
            print(f"Kernel {i} is : {kernels_list[i]}")
            print(f"Mean function {i} is : {mean_functions_list[i]}")
            print(f"mu_z {i} shape (B,N): {mu_z_i.shape}")  # (B, N)
            print(f"Kernel matrix {i} shape (B,N,N): {kernel_matrix_i.shape}")  # (B, N, N)
        
    kernel_matrix = torch.stack(kernel_matrices, dim=0)  # (Dz, B, N, N)
    kernel_matrix = kernel_matrix.transpose(0, 1) # (B, Dz, N, N)
    L_matrix = torch.stack(L_matrices, dim=0) if L_matrices[0] is not None else None  # (Dz, B, N, N) or None
    L_matrix = L_matrix.transpose(0, 1) if L_matrix is not None else None  # (B, Dz, N, N)
    mean = torch.stack(means, dim=0)  # (Dz, B, N)
    mean = mean.transpose(0, 1)  # (B, Dz, N)
    
    if verbose:
        print()
        print(f"Kernel matrix shape after stack and transpose: {kernel_matrix.shape}")  # (Dz, B, N, N)
        print(f"L matrix shape after stack transpose: {L_matrix.shape if L_matrix is not None else 'None'}")  # (B, Dz, N, N) or None
        print(f"Mean shape after transpose: {mean.shape}")  # (B, Dz, N)

    p_theta_z = torch.distributions.MultivariateNormal(
        loc=mean,  # (B, Dz, N)
        scale_tril=L_matrix,  # (B, Dz, N, N)
    )
    if verbose:
        print()
        print(f"p_theta_z: {p_theta_z}")
        print(f"\tp_theta_z batch shape: {p_theta_z.batch_shape}")  # (B, Dz)
        print(f"\tp_theta_z event shape: {p_theta_z.event_shape}")  # (N)

    return p_theta_z, kernel_matrix, L_matrix, mean

# %% [markdown]
# Training setup

# %%
kernel_parameters = [ param for kernel in kernels_list for param in kernel.parameters() ]
mean_functions_parameters = [ param for mean_function in mean_functions_list for param in mean_function.parameters() ]

optimizer = torch.optim.Adam(
    list(encoder_mean.parameters()) + list(encoder_precision.parameters()) + list(encoder_covariance.parameters()) +
    list(decoder_mean.parameters()) + list(decoder_covariance.parameters()) +
    kernel_parameters +
    mean_functions_parameters,
    lr = 1e-3
)

# %%
losses = []
kls = []
reconstruction_losses = []

# dictionnary to store the parameters of the prior Gaussian Processes
mean_parameters_values = {}  # to store mean parameters if any
for i in range(Dz):
    mean_parameters_values[f"mean_function_{i}"] = {}
    mean_function = mean_functions_list[i]
    for name, param in mean_function.named_parameters():
        mean_parameters_values[f"mean_function_{i}"][name] = []
    
kernels_parameters_values = {}  # to store kernel parameters if any
for i in range(Dz):
    kernels_parameters_values[f"kernel_{i}"] = {}
    kernel = kernels_list[i]
    for name, param in kernel.named_parameters():
        kernels_parameters_values[f"kernel_{i}"][name] = []

# %%
if len(kernel_parameters) == 0 and len(mean_functions_parameters) == 0:
    learnable_kernel = False
    print("Prior kernels are fixed (no learnable parameters).")
else:
    learnable_kernel = True
    if len(kernel_parameters) > 0:
        print("Prior kernels are learnable (has learnable parameters).")
        print(kernels_parameters_values)
    if len(mean_functions_parameters) > 0:
        print("Prior mean functions are learnable (has learnable parameters).")
        print(mean_parameters_values)
# Out:
# Prior kernels are fixed (no learnable parameters).

# %%
# initialize prior Gaussian Processes
# can be done once before the training loop if there are no learnable parameters

p_theta_z, kernel_matrix, L_matrix, mean = compute_p_theta_z(t, kernels_list, mean_functions_list, verbose=True)
# Out:
# Computing Gaussian Process prior for z component 1 / 2...
# Kernel 0 is : GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 0 is : GPNullMean
# mu_z 0 shape (B,N): torch.Size([1, 100])
# Kernel matrix 0 shape (B,N,N): torch.Size([1, 100, 100])
#
# Computing Gaussian Process prior for z component 2 / 2...
# Kernel 1 is : GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 1 is : GPNullMean
# mu_z 1 shape (B,N): torch.Size([1, 100])
# Kernel matrix 1 shape (B,N,N): torch.Size([1, 100, 100])
#
# Kernel matrix shape after stack and transpose: torch.Size([1, 2, 100, 100])
# L matrix shape after stack transpose: torch.Size([1, 2, 100, 100])
# Mean shape after transpose: torch.Size([1, 2, 100])
#
# p_theta_z: MultivariateNormal(loc: torch.Size([1, 2, 100]), scale_tril: torch.Size([1, 2, 100, 100]))
# 	p_theta_z batch shape: torch.Size([1, 2])
# 	p_theta_z event shape: torch.Size([100])

# %%
N_EPOCHS = int(50000)
K = 5

N = t.size(-1)  # number of time points
epsilon = 1e-12
tolerance = epsilon * torch.eye(N).to(device)

x_rec = torch.unsqueeze(x,0).repeat(K,1,1,1)

print(f"x_rec shape (K,B,N,Dx) for reconstruction loss computation : {x_rec.shape}")  # (K, B, N, Dx)
# Out:
# x_rec shape (K,B,N,Dx) for reconstruction loss computation : torch.Size([5, 1, 100, 4])

# %%
# Early stopping class to prevent overfitting

class EarlyStoppingCallback:
    def __init__(self, patience=1, min_delta=0):
        # how many epochs do we accept with validation loss non decreasing
        self.patience = patience
        # tolerance for non decrease
        self.min_delta = min_delta
        # how many epochs without validation loss decrease
        self.counter = 0
        # minimum validation loss to beat
        self.min_validation_loss = float('inf')
        self.status = False

    def early_stop(self, validation_loss):
        # is the last validation loss better than the current minimum ?
        # status = True means stop training
        if validation_loss < self.min_validation_loss:
            # yes : update minimum value and reset counter
            self.min_validation_loss = validation_loss
            self.counter = 0
            self.status = False
            # no : are we within tolerance ?
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            # no : increase counter (losing patience)
            self.counter += 1
            # have we lost patience ?
            if self.counter >= self.patience:
                # yes
                self.status = True
            else:
                # no
                self.status = False

        return self.status, self.counter
    
early_stopping = EarlyStoppingCallback(patience=1000, min_delta=1e+2)

# %%
# Training parameters
print(f"Training for {N_EPOCHS} epochs")
print(f"Dx = {Dx}, Dz = {Dz}, N = {N}, B = {B}, K = {K}")
print(f"Optimizer: {optimizer}")
print(f"Encoder mean: {encoder_mean}")
print(f"Encoder covariance: {encoder_covariance}")
print(f"Decoder mean: {decoder_mean}")
print(f"Decoder covariance: {decoder_covariance}")
print(f"Learnable kernel: {learnable_kernel}")
for i,k in enumerate(kernels_list):
    print(f"Kernel {i+1}: {k}")
for i,m in enumerate(mean_functions_list):
    print(f"Mean function {i+1}: {m}")
print(f"Early stopping: patience = {early_stopping.patience}, min_delta = {early_stopping.min_delta}")
# Out:
# Training for 50000 epochs
# Dx = 4, Dz = 2, N = 100, B = 1, K = 5
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# Encoder mean: EncoderMean, x_dimension=4, z_dimension=2, n_layers=4, inter_dim=32, activation=Tanh
# Encoder covariance: EncoderCovariance : (x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh, epsilon (to ensure PSD)=1.000e-06)
# Decoder mean: DecoderMean x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh
# Decoder covariance: DecoderCovarianceDiagonal : (x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh, epsilon (to ensure PSD)=1.000e-06)
# Learnable kernel: False
# Kernel 1: GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Kernel 2: GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 1: GPNullMean
# Mean function 2: GPNullMean
# Early stopping: patience = 1000, min_delta = 100.0

# %%
# Training parameters
print(f"Training for {N_EPOCHS} epochs")
print(f"Dx = {Dx}, Dz = {Dz}, N = {N}, B = {B}, K = {K}")
print(f"Optimizer: {optimizer}")
print(f"Encoder mean: {encoder_mean}")
print(f"Encoder covariance: {encoder_covariance}")
print(f"Decoder mean: {decoder_mean}")
print(f"Decoder covariance: {decoder_covariance}")
print(f"Learnable kernel: {learnable_kernel}")
for i,k in enumerate(kernels_list):
    print(f"Kernel {i+1}: {k}")
for i,m in enumerate(mean_functions_list):
    print(f"Mean function {i+1}: {m}")
print(f"Early stopping: patience = {early_stopping.patience}, min_delta = {early_stopping.min_delta}")

for epoch in range(N_EPOCHS):
       
    # PRIOR pass --------------------------------------------------------------
    # if the kernel is learnable, we need to recompute the prior mean and kernel at each epoch
    if learnable_kernel:
        p_theta_z, kernel_matrix, L_matrix, mean = compute_p_theta_z(t, kernels_list, mean_functions_list, verbose=False)

    # ENCODER pass ------------------------------------------------------------
    # encode mean
    mu_phi = encoder_mean(x)  # (B, Dz, N)
    # encode precision or covariance
    # --- choice 1 : with precision matrix
    # _, _, precision_phi = encoder_precision(x)  # (B, Dz, N, N)
    # precision_phi = precision_phi  # (B, Dz, N, N)
    # q_phi = torch.distributions.MultivariateNormal(
    #     loc=mu_phi,  # (B, Dz, N)
    #     precision_matrix=precision_phi,  # (B, Dz, N, N)
    # )
    # -- choice 2 : with covariance matrix
    L_phi, covariance_phi = encoder_covariance(x)  # (B, Dz, N, N)
    covariance_phi = covariance_phi.squeeze(0)  # (B, Dz, N, N)
    # L_phi = L_phi.squeeze(0)  # (Dz, N, N)

    q_phi = torch.distributions.MultivariateNormal(
        loc=mu_phi,  # (B, Dz, N)
        scale_tril=L_phi,  # (B, Dz, N, N)
    )

    # DECODER pass ------------------------------------------------------------    
    # sample z
    z_sampled = q_phi.rsample((K,)) # (K, B, Dz, N)
    z_sampled_p = z_sampled.transpose(-1, -2)  # (K, B, N, Dz)
    
    # decode
    mu_x = decoder_mean(z_sampled_p)  # (K,B,N,Dx)
    L_x, covar_x = decoder_covariance(z_sampled_p) # + tolerance # (K,B,N,Dx,Dx)

    p_theta_x = torch.distributions.MultivariateNormal(
        loc=mu_x,
        scale_tril=L_x
    ) # batch_shape=(K,B,Dx), event_shape=(N,)
    # print(f"p_theta_x: {p_theta_x}")
    # print(f"\tp_theta_x batch shape: {p_theta_x.batch_shape}")  # (K,B,N)
    # print(f"\tp_theta_x event shape: {p_theta_x.event_shape}")  # (Dx,)
       
    # LOSS computation --------------------------------------------------------
    # compute loss
    kl = torch.distributions.kl_divergence(q_phi, p_theta_z).sum(-1).mean()  # (B,Dz,N) => scalar
    reconstruction_loss = p_theta_x.log_prob(x_rec).sum(-1).mean() # (K,B,N) => scalar
    # kl = torch.distributions.kl_divergence(q_phi, p_theta_z).sum(-1).sum()  # (B,Dz,N) => scalar
    # reconstruction_loss = p_theta_x.log_prob(x_rec).sum(-1).sum() # (K,B,N) => scalar
    # reconstruction_loss = p_theta_x.log_prob(x_rec).mean()
    loss = -reconstruction_loss + kl
        
    # optimization step
    optimizer.zero_grad()
    loss.backward()  
    optimizer.step()
    
    # log losses
    losses.append(loss.item())
    kls.append(kl.mean().item())
    reconstruction_losses.append(-reconstruction_loss.mean().item())
    
    # record parameters
    for i in range(Dz):
        # record mean function parameters
        mean_function = mean_functions_list[i]
        for name, param in mean_function.named_parameters():
            mean_parameters_values[f"mean_function_{i}"][name].append(param.item())
        # record kernel parameters
        kernel = kernels_list[i]
        for name, param in kernel.named_parameters():
            kernels_parameters_values[f"kernel_{i}"][name].append(param.item())
            
    # Early stopping check
    if early_stopping:
        stop, counter = early_stopping.early_stop(loss)
        if stop:
            msg = f'Early stopping at epoch {epoch+1} with counter {counter}'
        else:
            msg = f'Early stopping counter {counter} / {early_stopping.patience}'
        
    # print progress
    if (epoch + 1) % 10 == 0 or epoch == 0:
        print(f"Epoch [{epoch + 1:>6}/{N_EPOCHS:>6}], Loss: {loss.item():.4e}, "
              f"KL: {kl.mean().item():.4e}, "
              f"Reconstruction Loss (avg over {K} sample(s)): {-reconstruction_loss.mean().item():.4e}, "
              f"{msg}")
        
    if stop:
        break
# Out:
# Training for 50000 epochs
# Dx = 4, Dz = 2, N = 100, B = 1, K = 5
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# Encoder mean: EncoderMean, x_dimension=4, z_dimension=2, n_layers=4, inter_dim=32, activation=Tanh
# Encoder covariance: EncoderCovariance : (x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh, epsilon (to ensure PSD)=1.000e-06)
# Decoder mean: DecoderMean x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh
# Decoder covariance: DecoderCovarianceDiagonal : (x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh, epsilon (to ensure PSD)=1.000e-06)
# Learnable kernel: False
# Kernel 1: GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Kernel 2: GaussianKernelFixed(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 1: GPNullMean
# Mean function 2: GPNullMean
# Early stopping: patience = 1000, min_delta = 100.0
# Epoch [     1/ 50000], Loss: 6.9753e+13, KL: 6.9753e+13, Reconstruction Loss (avg over 5 sample(s)): 4.0650e+02, Early stopping counter 0 / 1000
# Epoch [    10/ 50000], Loss: 1.3225e+13, KL: 1.3225e+13, Reconstruction Loss (avg over 5 sample(s)): 2.7881e+02, Early stopping counter 0 / 1000
# Epoch [    20/ 50000], Loss: 1.6842e+12, KL: 1.6842e+12, Reconstruction Loss (avg over 5 sample(s)): 2.2962e+02, Early stopping counter 0 / 1000
# Epoch [    30/ 50000], Loss: 4.4974e+11, KL: 4.4974e+11, Reconstruction Loss (avg over 5 sample(s)): 2.1608e+02, Early stopping counter 0 / 1000
# Epoch [    40/ 50000], Loss: 2.3009e+11, KL: 2.3009e+11, Reconstruction Loss (avg over 5 sample(s)): 2.0513e+02, Early stopping counter 0 / 1000
# Epoch [    50/ 50000], Loss: 1.5905e+11, KL: 1.5905e+11, Reconstruction Loss (avg over 5 sample(s)): 2.0536e+02, Early stopping counter 0 / 1000
# Epoch [    60/ 50000], Loss: 1.3018e+11, KL: 1.3018e+11, Reconstruction Loss (avg over 5 sample(s)): 2.0677e+02, Early stopping counter 0 / 1000
# Epoch [    70/ 50000], Loss: 1.1405e+11, KL: 1.1405e+11, Reconstruction Loss (avg over 5 sample(s)): 2.0366e+02, Early stopping counter 0 / 1000
# Epoch [    80/ 50000], Loss: 1.0227e+11, KL: 1.0227e+11, Reconstruction Loss (avg over 5 sample(s)): 2.0125e+02, Early stopping counter 0 / 1000
# Epoch [    90/ 50000], Loss: 9.2612e+10, KL: 9.2612e+10, Reconstruction Loss (avg over 5 sample(s)): 2.0386e+02, Early stopping counter 0 / 1000
# Epoch [   100/ 50000], Loss: 8.4374e+10, KL: 8.4374e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9816e+02, Early stopping counter 0 / 1000
# Epoch [   110/ 50000], Loss: 7.7196e+10, KL: 7.7196e+10, Reconstruction Loss (avg over 5 sample(s)): 2.0321e+02, Early stopping counter 0 / 1000
# Epoch [   120/ 50000], Loss: 7.0856e+10, KL: 7.0856e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9973e+02, Early stopping counter 0 / 1000
# Epoch [   130/ 50000], Loss: 6.5214e+10, KL: 6.5214e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9665e+02, Early stopping counter 0 / 1000
# Epoch [   140/ 50000], Loss: 6.0171e+10, KL: 6.0171e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9946e+02, Early stopping counter 0 / 1000
# Epoch [   150/ 50000], Loss: 5.5651e+10, KL: 5.5651e+10, Reconstruction Loss (avg over 5 sample(s)): 2.0217e+02, Early stopping counter 0 / 1000
# Epoch [   160/ 50000], Loss: 5.1593e+10, KL: 5.1593e+10, Reconstruction Loss (avg over 5 sample(s)): 2.0509e+02, Early stopping counter 0 / 1000
# Epoch [   170/ 50000], Loss: 4.7941e+10, KL: 4.7941e+10, Reconstruction Loss (avg over 5 sample(s)): 1.7995e+02, Early stopping counter 0 / 1000
# Epoch [   180/ 50000], Loss: 4.4649e+10, KL: 4.4649e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9674e+02, Early stopping counter 0 / 1000
# Epoch [   190/ 50000], Loss: 4.1674e+10, KL: 4.1674e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9934e+02, Early stopping counter 0 / 1000
# Epoch [   200/ 50000], Loss: 3.8981e+10, KL: 3.8981e+10, Reconstruction Loss (avg over 5 sample(s)): 2.0088e+02, Early stopping counter 0 / 1000
# Epoch [   210/ 50000], Loss: 3.6539e+10, KL: 3.6539e+10, Reconstruction Loss (avg over 5 sample(s)): 1.8673e+02, Early stopping counter 0 / 1000
# Epoch [   220/ 50000], Loss: 3.4318e+10, KL: 3.4318e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9507e+02, Early stopping counter 0 / 1000
# Epoch [   230/ 50000], Loss: 3.2294e+10, KL: 3.2294e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9697e+02, Early stopping counter 0 / 1000
# Epoch [   240/ 50000], Loss: 3.0446e+10, KL: 3.0446e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9867e+02, Early stopping counter 0 / 1000
# Epoch [   250/ 50000], Loss: 2.8755e+10, KL: 2.8755e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9544e+02, Early stopping counter 0 / 1000
# Epoch [   260/ 50000], Loss: 2.7204e+10, KL: 2.7204e+10, Reconstruction Loss (avg over 5 sample(s)): 1.8873e+02, Early stopping counter 0 / 1000
# Epoch [   270/ 50000], Loss: 2.5778e+10, KL: 2.5778e+10, Reconstruction Loss (avg over 5 sample(s)): 1.8456e+02, Early stopping counter 0 / 1000
# Epoch [   280/ 50000], Loss: 2.4465e+10, KL: 2.4465e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9041e+02, Early stopping counter 0 / 1000
# Epoch [   290/ 50000], Loss: 2.3253e+10, KL: 2.3253e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9487e+02, Early stopping counter 0 / 1000
# Epoch [   300/ 50000], Loss: 2.2132e+10, KL: 2.2132e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9879e+02, Early stopping counter 0 / 1000
# Epoch [   310/ 50000], Loss: 2.1093e+10, KL: 2.1093e+10, Reconstruction Loss (avg over 5 sample(s)): 1.8025e+02, Early stopping counter 0 / 1000
# Epoch [   320/ 50000], Loss: 2.0129e+10, KL: 2.0129e+10, Reconstruction Loss (avg over 5 sample(s)): 2.0143e+02, Early stopping counter 0 / 1000
# Epoch [   330/ 50000], Loss: 1.9232e+10, KL: 1.9232e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9014e+02, Early stopping counter 0 / 1000
# Epoch [   340/ 50000], Loss: 1.8397e+10, KL: 1.8397e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9410e+02, Early stopping counter 0 / 1000
# Epoch [   350/ 50000], Loss: 1.7617e+10, KL: 1.7617e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9051e+02, Early stopping counter 0 / 1000
# Epoch [   360/ 50000], Loss: 1.6889e+10, KL: 1.6889e+10, Reconstruction Loss (avg over 5 sample(s)): 2.0685e+02, Early stopping counter 0 / 1000
# Epoch [   370/ 50000], Loss: 1.6206e+10, KL: 1.6206e+10, Reconstruction Loss (avg over 5 sample(s)): 2.1690e+02, Early stopping counter 0 / 1000
# Epoch [   380/ 50000], Loss: 1.5567e+10, KL: 1.5567e+10, Reconstruction Loss (avg over 5 sample(s)): 1.8341e+02, Early stopping counter 0 / 1000
# Epoch [   390/ 50000], Loss: 1.4966e+10, KL: 1.4966e+10, Reconstruction Loss (avg over 5 sample(s)): 1.8728e+02, Early stopping counter 0 / 1000
# Epoch [   400/ 50000], Loss: 1.4401e+10, KL: 1.4401e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9003e+02, Early stopping counter 0 / 1000
# Epoch [   410/ 50000], Loss: 1.3870e+10, KL: 1.3870e+10, Reconstruction Loss (avg over 5 sample(s)): 1.6989e+02, Early stopping counter 0 / 1000
# Epoch [   420/ 50000], Loss: 1.3369e+10, KL: 1.3369e+10, Reconstruction Loss (avg over 5 sample(s)): 2.1101e+02, Early stopping counter 0 / 1000
# Epoch [   430/ 50000], Loss: 1.2895e+10, KL: 1.2895e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9525e+02, Early stopping counter 0 / 1000
# Epoch [   440/ 50000], Loss: 1.2448e+10, KL: 1.2448e+10, Reconstruction Loss (avg over 5 sample(s)): 1.7204e+02, Early stopping counter 0 / 1000
# Epoch [   450/ 50000], Loss: 1.2025e+10, KL: 1.2025e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9902e+02, Early stopping counter 0 / 1000
# Epoch [   460/ 50000], Loss: 1.1625e+10, KL: 1.1625e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9877e+02, Early stopping counter 0 / 1000
# Epoch [   470/ 50000], Loss: 1.1245e+10, KL: 1.1245e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9182e+02, Early stopping counter 0 / 1000
# Epoch [   480/ 50000], Loss: 1.0884e+10, KL: 1.0884e+10, Reconstruction Loss (avg over 5 sample(s)): 2.2553e+02, Early stopping counter 0 / 1000
# Epoch [   490/ 50000], Loss: 1.0542e+10, KL: 1.0542e+10, Reconstruction Loss (avg over 5 sample(s)): 1.9973e+02, Early stopping counter 0 / 1000
# Epoch [   500/ 50000], Loss: 1.0216e+10, KL: 1.0216e+10, Reconstruction Loss (avg over 5 sample(s)): 1.7279e+02, Early stopping counter 0 / 1000
# Epoch [   510/ 50000], Loss: 9.9058e+09, KL: 9.9058e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8308e+02, Early stopping counter 0 / 1000
# Epoch [   520/ 50000], Loss: 9.6104e+09, KL: 9.6104e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1244e+02, Early stopping counter 0 / 1000
# Epoch [   530/ 50000], Loss: 9.3286e+09, KL: 9.3286e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7407e+02, Early stopping counter 0 / 1000
# Epoch [   540/ 50000], Loss: 9.0597e+09, KL: 9.0597e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8822e+02, Early stopping counter 0 / 1000
# Epoch [   550/ 50000], Loss: 8.8029e+09, KL: 8.8029e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8367e+02, Early stopping counter 0 / 1000
# Epoch [   560/ 50000], Loss: 8.5574e+09, KL: 8.5574e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1002e+02, Early stopping counter 0 / 1000
# Epoch [   570/ 50000], Loss: 8.3225e+09, KL: 8.3225e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7363e+02, Early stopping counter 0 / 1000
# Epoch [   580/ 50000], Loss: 8.0976e+09, KL: 8.0976e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7418e+02, Early stopping counter 0 / 1000
# Epoch [   590/ 50000], Loss: 7.8822e+09, KL: 7.8822e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8386e+02, Early stopping counter 0 / 1000
# Epoch [   600/ 50000], Loss: 7.6757e+09, KL: 7.6757e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1725e+02, Early stopping counter 0 / 1000
# Epoch [   610/ 50000], Loss: 7.4776e+09, KL: 7.4776e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8854e+02, Early stopping counter 0 / 1000
# Epoch [   620/ 50000], Loss: 7.2874e+09, KL: 7.2874e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8940e+02, Early stopping counter 0 / 1000
# Epoch [   630/ 50000], Loss: 7.1047e+09, KL: 7.1047e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9943e+02, Early stopping counter 0 / 1000
# Epoch [   640/ 50000], Loss: 6.9292e+09, KL: 6.9292e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7969e+02, Early stopping counter 0 / 1000
# Epoch [   650/ 50000], Loss: 6.7603e+09, KL: 6.7603e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8068e+02, Early stopping counter 0 / 1000
# Epoch [   660/ 50000], Loss: 6.5978e+09, KL: 6.5978e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9663e+02, Early stopping counter 0 / 1000
# Epoch [   670/ 50000], Loss: 6.4414e+09, KL: 6.4414e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7992e+02, Early stopping counter 0 / 1000
# Epoch [   680/ 50000], Loss: 6.2907e+09, KL: 6.2907e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7451e+02, Early stopping counter 0 / 1000
# Epoch [   690/ 50000], Loss: 6.1454e+09, KL: 6.1454e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1037e+02, Early stopping counter 0 / 1000
# Epoch [   700/ 50000], Loss: 6.0054e+09, KL: 6.0054e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7935e+02, Early stopping counter 0 / 1000
# Epoch [   710/ 50000], Loss: 5.8702e+09, KL: 5.8702e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9613e+02, Early stopping counter 0 / 1000
# Epoch [   720/ 50000], Loss: 5.7398e+09, KL: 5.7398e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8934e+02, Early stopping counter 0 / 1000
# Epoch [   730/ 50000], Loss: 5.6138e+09, KL: 5.6138e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9145e+02, Early stopping counter 0 / 1000
# Epoch [   740/ 50000], Loss: 5.4921e+09, KL: 5.4921e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9804e+02, Early stopping counter 0 / 1000
# Epoch [   750/ 50000], Loss: 5.3744e+09, KL: 5.3744e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7945e+02, Early stopping counter 0 / 1000
# Epoch [   760/ 50000], Loss: 5.2607e+09, KL: 5.2607e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8782e+02, Early stopping counter 0 / 1000
# Epoch [   770/ 50000], Loss: 5.1506e+09, KL: 5.1506e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9223e+02, Early stopping counter 0 / 1000
# Epoch [   780/ 50000], Loss: 5.0441e+09, KL: 5.0441e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7636e+02, Early stopping counter 0 / 1000
# Epoch [   790/ 50000], Loss: 4.9409e+09, KL: 4.9409e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7305e+02, Early stopping counter 0 / 1000
# Epoch [   800/ 50000], Loss: 4.8410e+09, KL: 4.8410e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8873e+02, Early stopping counter 0 / 1000
# Epoch [   810/ 50000], Loss: 4.7442e+09, KL: 4.7442e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9835e+02, Early stopping counter 0 / 1000
# Epoch [   820/ 50000], Loss: 4.6504e+09, KL: 4.6504e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7336e+02, Early stopping counter 0 / 1000
# Epoch [   830/ 50000], Loss: 4.5594e+09, KL: 4.5594e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9263e+02, Early stopping counter 0 / 1000
# Epoch [   840/ 50000], Loss: 4.4711e+09, KL: 4.4711e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7032e+02, Early stopping counter 0 / 1000
# Epoch [   850/ 50000], Loss: 4.3854e+09, KL: 4.3854e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1624e+02, Early stopping counter 0 / 1000
# Epoch [   860/ 50000], Loss: 4.3023e+09, KL: 4.3023e+09, Reconstruction Loss (avg over 5 sample(s)): 2.0473e+02, Early stopping counter 0 / 1000
# Epoch [   870/ 50000], Loss: 4.2215e+09, KL: 4.2215e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7202e+02, Early stopping counter 0 / 1000
# Epoch [   880/ 50000], Loss: 4.1431e+09, KL: 4.1431e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9383e+02, Early stopping counter 0 / 1000
# Epoch [   890/ 50000], Loss: 4.0669e+09, KL: 4.0669e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8201e+02, Early stopping counter 0 / 1000
# Epoch [   900/ 50000], Loss: 3.9928e+09, KL: 3.9928e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8114e+02, Early stopping counter 0 / 1000
# Epoch [   910/ 50000], Loss: 3.9208e+09, KL: 3.9208e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8257e+02, Early stopping counter 0 / 1000
# Epoch [   920/ 50000], Loss: 3.8508e+09, KL: 3.8508e+09, Reconstruction Loss (avg over 5 sample(s)): 2.0995e+02, Early stopping counter 0 / 1000
# Epoch [   930/ 50000], Loss: 3.7826e+09, KL: 3.7826e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7747e+02, Early stopping counter 0 / 1000
# Epoch [   940/ 50000], Loss: 3.7163e+09, KL: 3.7163e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8802e+02, Early stopping counter 0 / 1000
# Epoch [   950/ 50000], Loss: 3.6518e+09, KL: 3.6518e+09, Reconstruction Loss (avg over 5 sample(s)): 2.0252e+02, Early stopping counter 0 / 1000
# Epoch [   960/ 50000], Loss: 3.5889e+09, KL: 3.5889e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7438e+02, Early stopping counter 0 / 1000
# Epoch [   970/ 50000], Loss: 3.5277e+09, KL: 3.5277e+09, Reconstruction Loss (avg over 5 sample(s)): 2.0462e+02, Early stopping counter 0 / 1000
# Epoch [   980/ 50000], Loss: 3.4681e+09, KL: 3.4681e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7065e+02, Early stopping counter 0 / 1000
# Epoch [   990/ 50000], Loss: 3.4100e+09, KL: 3.4100e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7252e+02, Early stopping counter 0 / 1000
# Epoch [  1000/ 50000], Loss: 3.3534e+09, KL: 3.3534e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8255e+02, Early stopping counter 0 / 1000
# Epoch [  1010/ 50000], Loss: 3.2982e+09, KL: 3.2982e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8405e+02, Early stopping counter 0 / 1000
# Epoch [  1020/ 50000], Loss: 3.2443e+09, KL: 3.2443e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9164e+02, Early stopping counter 0 / 1000
# Epoch [  1030/ 50000], Loss: 3.1918e+09, KL: 3.1918e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9143e+02, Early stopping counter 0 / 1000
# Epoch [  1040/ 50000], Loss: 3.1406e+09, KL: 3.1406e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8765e+02, Early stopping counter 0 / 1000
# Epoch [  1050/ 50000], Loss: 3.0906e+09, KL: 3.0906e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7781e+02, Early stopping counter 0 / 1000
# Epoch [  1060/ 50000], Loss: 3.0418e+09, KL: 3.0418e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9876e+02, Early stopping counter 0 / 1000
# Epoch [  1070/ 50000], Loss: 2.9942e+09, KL: 2.9942e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7530e+02, Early stopping counter 0 / 1000
# Epoch [  1080/ 50000], Loss: 2.9476e+09, KL: 2.9476e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7185e+02, Early stopping counter 0 / 1000
# Epoch [  1090/ 50000], Loss: 2.9022e+09, KL: 2.9022e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7334e+02, Early stopping counter 0 / 1000
# Epoch [  1100/ 50000], Loss: 2.8578e+09, KL: 2.8578e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7414e+02, Early stopping counter 0 / 1000
# Epoch [  1110/ 50000], Loss: 2.8145e+09, KL: 2.8145e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1581e+02, Early stopping counter 0 / 1000
# Epoch [  1120/ 50000], Loss: 2.7721e+09, KL: 2.7721e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8749e+02, Early stopping counter 0 / 1000
# Epoch [  1130/ 50000], Loss: 2.7307e+09, KL: 2.7307e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8616e+02, Early stopping counter 0 / 1000
# Epoch [  1140/ 50000], Loss: 2.6902e+09, KL: 2.6902e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9448e+02, Early stopping counter 0 / 1000
# Epoch [  1150/ 50000], Loss: 2.6506e+09, KL: 2.6506e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8646e+02, Early stopping counter 0 / 1000
# Epoch [  1160/ 50000], Loss: 2.6118e+09, KL: 2.6118e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8199e+02, Early stopping counter 0 / 1000
# Epoch [  1170/ 50000], Loss: 2.5739e+09, KL: 2.5739e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8702e+02, Early stopping counter 0 / 1000
# Epoch [  1180/ 50000], Loss: 2.5369e+09, KL: 2.5369e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8488e+02, Early stopping counter 0 / 1000
# Epoch [  1190/ 50000], Loss: 2.5006e+09, KL: 2.5006e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8432e+02, Early stopping counter 0 / 1000
# Epoch [  1200/ 50000], Loss: 2.4651e+09, KL: 2.4651e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6266e+02, Early stopping counter 0 / 1000
# Epoch [  1210/ 50000], Loss: 2.4303e+09, KL: 2.4303e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6156e+02, Early stopping counter 0 / 1000
# Epoch [  1220/ 50000], Loss: 2.3963e+09, KL: 2.3963e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6723e+02, Early stopping counter 0 / 1000
# Epoch [  1230/ 50000], Loss: 2.3630e+09, KL: 2.3630e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6260e+02, Early stopping counter 0 / 1000
# Epoch [  1240/ 50000], Loss: 2.3303e+09, KL: 2.3303e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8673e+02, Early stopping counter 0 / 1000
# Epoch [  1250/ 50000], Loss: 2.2984e+09, KL: 2.2984e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6816e+02, Early stopping counter 0 / 1000
# Epoch [  1260/ 50000], Loss: 2.2670e+09, KL: 2.2670e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7691e+02, Early stopping counter 0 / 1000
# Epoch [  1270/ 50000], Loss: 2.2364e+09, KL: 2.2364e+09, Reconstruction Loss (avg over 5 sample(s)): 2.0122e+02, Early stopping counter 0 / 1000
# Epoch [  1280/ 50000], Loss: 2.2063e+09, KL: 2.2063e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9656e+02, Early stopping counter 0 / 1000
# Epoch [  1290/ 50000], Loss: 2.1768e+09, KL: 2.1768e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8178e+02, Early stopping counter 0 / 1000
# Epoch [  1300/ 50000], Loss: 2.1479e+09, KL: 2.1479e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6387e+02, Early stopping counter 0 / 1000
# Epoch [  1310/ 50000], Loss: 2.1196e+09, KL: 2.1196e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8137e+02, Early stopping counter 0 / 1000
# Epoch [  1320/ 50000], Loss: 2.0918e+09, KL: 2.0918e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7857e+02, Early stopping counter 0 / 1000
# Epoch [  1330/ 50000], Loss: 2.0645e+09, KL: 2.0645e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7981e+02, Early stopping counter 0 / 1000
# Epoch [  1340/ 50000], Loss: 2.0378e+09, KL: 2.0378e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1329e+02, Early stopping counter 0 / 1000
# Epoch [  1350/ 50000], Loss: 2.0116e+09, KL: 2.0116e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9193e+02, Early stopping counter 0 / 1000
# Epoch [  1360/ 50000], Loss: 1.9859e+09, KL: 1.9859e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7392e+02, Early stopping counter 0 / 1000
# Epoch [  1370/ 50000], Loss: 1.9606e+09, KL: 1.9606e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9339e+02, Early stopping counter 0 / 1000
# Epoch [  1380/ 50000], Loss: 1.9358e+09, KL: 1.9358e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7769e+02, Early stopping counter 0 / 1000
# Epoch [  1390/ 50000], Loss: 1.9115e+09, KL: 1.9115e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9783e+02, Early stopping counter 0 / 1000
# Epoch [  1400/ 50000], Loss: 1.8877e+09, KL: 1.8877e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6936e+02, Early stopping counter 0 / 1000
# Epoch [  1410/ 50000], Loss: 1.8642e+09, KL: 1.8642e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7996e+02, Early stopping counter 0 / 1000
# Epoch [  1420/ 50000], Loss: 1.8412e+09, KL: 1.8412e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6836e+02, Early stopping counter 0 / 1000
# Epoch [  1430/ 50000], Loss: 1.8186e+09, KL: 1.8186e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1486e+02, Early stopping counter 0 / 1000
# Epoch [  1440/ 50000], Loss: 1.7964e+09, KL: 1.7964e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9379e+02, Early stopping counter 0 / 1000
# Epoch [  1450/ 50000], Loss: 1.7746e+09, KL: 1.7746e+09, Reconstruction Loss (avg over 5 sample(s)): 2.0519e+02, Early stopping counter 0 / 1000
# Epoch [  1460/ 50000], Loss: 1.7532e+09, KL: 1.7532e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8666e+02, Early stopping counter 0 / 1000
# Epoch [  1470/ 50000], Loss: 1.7322e+09, KL: 1.7322e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8777e+02, Early stopping counter 0 / 1000
# Epoch [  1480/ 50000], Loss: 1.7115e+09, KL: 1.7115e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9999e+02, Early stopping counter 0 / 1000
# Epoch [  1490/ 50000], Loss: 1.6912e+09, KL: 1.6912e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6909e+02, Early stopping counter 0 / 1000
# Epoch [  1500/ 50000], Loss: 1.6712e+09, KL: 1.6712e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9243e+02, Early stopping counter 0 / 1000
# Epoch [  1510/ 50000], Loss: 1.6516e+09, KL: 1.6516e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8409e+02, Early stopping counter 0 / 1000
# Epoch [  1520/ 50000], Loss: 1.6323e+09, KL: 1.6323e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1495e+02, Early stopping counter 0 / 1000
# Epoch [  1530/ 50000], Loss: 1.6133e+09, KL: 1.6133e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7342e+02, Early stopping counter 0 / 1000
# Epoch [  1540/ 50000], Loss: 1.5947e+09, KL: 1.5947e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7381e+02, Early stopping counter 0 / 1000
# Epoch [  1550/ 50000], Loss: 1.5764e+09, KL: 1.5764e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9308e+02, Early stopping counter 0 / 1000
# Epoch [  1560/ 50000], Loss: 1.5583e+09, KL: 1.5583e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7582e+02, Early stopping counter 0 / 1000
# Epoch [  1570/ 50000], Loss: 1.5406e+09, KL: 1.5406e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7626e+02, Early stopping counter 0 / 1000
# Epoch [  1580/ 50000], Loss: 1.5231e+09, KL: 1.5231e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7932e+02, Early stopping counter 0 / 1000
# Epoch [  1590/ 50000], Loss: 1.5060e+09, KL: 1.5060e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7982e+02, Early stopping counter 0 / 1000
# Epoch [  1600/ 50000], Loss: 1.4891e+09, KL: 1.4891e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7569e+02, Early stopping counter 0 / 1000
# Epoch [  1610/ 50000], Loss: 1.4725e+09, KL: 1.4725e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1333e+02, Early stopping counter 0 / 1000
# Epoch [  1620/ 50000], Loss: 1.4561e+09, KL: 1.4561e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7725e+02, Early stopping counter 0 / 1000
# Epoch [  1630/ 50000], Loss: 1.4400e+09, KL: 1.4400e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8296e+02, Early stopping counter 0 / 1000
# Epoch [  1640/ 50000], Loss: 1.4242e+09, KL: 1.4242e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9074e+02, Early stopping counter 0 / 1000
# Epoch [  1650/ 50000], Loss: 1.4086e+09, KL: 1.4086e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8139e+02, Early stopping counter 0 / 1000
# Epoch [  1660/ 50000], Loss: 1.3933e+09, KL: 1.3933e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8648e+02, Early stopping counter 0 / 1000
# Epoch [  1670/ 50000], Loss: 1.3782e+09, KL: 1.3782e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8939e+02, Early stopping counter 0 / 1000
# Epoch [  1680/ 50000], Loss: 1.3633e+09, KL: 1.3633e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1453e+02, Early stopping counter 0 / 1000
# Epoch [  1690/ 50000], Loss: 1.3487e+09, KL: 1.3487e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9142e+02, Early stopping counter 0 / 1000
# Epoch [  1700/ 50000], Loss: 1.3342e+09, KL: 1.3342e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8187e+02, Early stopping counter 0 / 1000
# Epoch [  1710/ 50000], Loss: 1.3200e+09, KL: 1.3200e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7965e+02, Early stopping counter 0 / 1000
# Epoch [  1720/ 50000], Loss: 1.3061e+09, KL: 1.3061e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6515e+02, Early stopping counter 0 / 1000
# Epoch [  1730/ 50000], Loss: 1.2923e+09, KL: 1.2923e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9967e+02, Early stopping counter 0 / 1000
# Epoch [  1740/ 50000], Loss: 1.2787e+09, KL: 1.2787e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7615e+02, Early stopping counter 0 / 1000
# Epoch [  1750/ 50000], Loss: 1.2653e+09, KL: 1.2653e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9123e+02, Early stopping counter 0 / 1000
# Epoch [  1760/ 50000], Loss: 1.2522e+09, KL: 1.2522e+09, Reconstruction Loss (avg over 5 sample(s)): 2.2289e+02, Early stopping counter 0 / 1000
# Epoch [  1770/ 50000], Loss: 1.2392e+09, KL: 1.2392e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7635e+02, Early stopping counter 0 / 1000
# Epoch [  1780/ 50000], Loss: 1.2264e+09, KL: 1.2264e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8976e+02, Early stopping counter 0 / 1000
# Epoch [  1790/ 50000], Loss: 1.2138e+09, KL: 1.2138e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7253e+02, Early stopping counter 0 / 1000
# Epoch [  1800/ 50000], Loss: 1.2014e+09, KL: 1.2014e+09, Reconstruction Loss (avg over 5 sample(s)): 2.2933e+02, Early stopping counter 0 / 1000
# Epoch [  1810/ 50000], Loss: 1.1892e+09, KL: 1.1892e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8378e+02, Early stopping counter 0 / 1000
# Epoch [  1820/ 50000], Loss: 1.1771e+09, KL: 1.1771e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7897e+02, Early stopping counter 0 / 1000
# Epoch [  1830/ 50000], Loss: 1.1652e+09, KL: 1.1652e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9134e+02, Early stopping counter 0 / 1000
# Epoch [  1840/ 50000], Loss: 1.1535e+09, KL: 1.1535e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8780e+02, Early stopping counter 0 / 1000
# Epoch [  1850/ 50000], Loss: 1.1419e+09, KL: 1.1419e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9861e+02, Early stopping counter 0 / 1000
# Epoch [  1860/ 50000], Loss: 1.1305e+09, KL: 1.1305e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8592e+02, Early stopping counter 0 / 1000
# Epoch [  1870/ 50000], Loss: 1.1193e+09, KL: 1.1193e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7175e+02, Early stopping counter 0 / 1000
# Epoch [  1880/ 50000], Loss: 1.1082e+09, KL: 1.1082e+09, Reconstruction Loss (avg over 5 sample(s)): 2.0481e+02, Early stopping counter 0 / 1000
# Epoch [  1890/ 50000], Loss: 1.0973e+09, KL: 1.0973e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8228e+02, Early stopping counter 0 / 1000
# Epoch [  1900/ 50000], Loss: 1.0865e+09, KL: 1.0865e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8090e+02, Early stopping counter 0 / 1000
# Epoch [  1910/ 50000], Loss: 1.0759e+09, KL: 1.0759e+09, Reconstruction Loss (avg over 5 sample(s)): 1.9613e+02, Early stopping counter 0 / 1000
# Epoch [  1920/ 50000], Loss: 1.0654e+09, KL: 1.0654e+09, Reconstruction Loss (avg over 5 sample(s)): 2.1635e+02, Early stopping counter 0 / 1000
# Epoch [  1930/ 50000], Loss: 1.0551e+09, KL: 1.0551e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6728e+02, Early stopping counter 0 / 1000
# Epoch [  1940/ 50000], Loss: 1.0449e+09, KL: 1.0449e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8526e+02, Early stopping counter 0 / 1000
# Epoch [  1950/ 50000], Loss: 1.0348e+09, KL: 1.0348e+09, Reconstruction Loss (avg over 5 sample(s)): 1.6500e+02, Early stopping counter 0 / 1000
# Epoch [  1960/ 50000], Loss: 1.0249e+09, KL: 1.0249e+09, Reconstruction Loss (avg over 5 sample(s)): 2.0540e+02, Early stopping counter 0 / 1000
# Epoch [  1970/ 50000], Loss: 1.0151e+09, KL: 1.0151e+09, Reconstruction Loss (avg over 5 sample(s)): 1.7821e+02, Early stopping counter 0 / 1000
# Epoch [  1980/ 50000], Loss: 1.0054e+09, KL: 1.0054e+09, Reconstruction Loss (avg over 5 sample(s)): 1.8796e+02, Early stopping counter 0 / 1000
# Epoch [  1990/ 50000], Loss: 9.9589e+08, KL: 9.9589e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9081e+02, Early stopping counter 0 / 1000
# Epoch [  2000/ 50000], Loss: 9.8648e+08, KL: 9.8648e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6028e+02, Early stopping counter 0 / 1000
# Epoch [  2010/ 50000], Loss: 9.7719e+08, KL: 9.7719e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6602e+02, Early stopping counter 0 / 1000
# Epoch [  2020/ 50000], Loss: 9.6802e+08, KL: 9.6802e+08, Reconstruction Loss (avg over 5 sample(s)): 2.0698e+02, Early stopping counter 0 / 1000
# Epoch [  2030/ 50000], Loss: 9.5897e+08, KL: 9.5897e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7914e+02, Early stopping counter 0 / 1000
# Epoch [  2040/ 50000], Loss: 9.5003e+08, KL: 9.5003e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8979e+02, Early stopping counter 0 / 1000
# Epoch [  2050/ 50000], Loss: 9.4121e+08, KL: 9.4121e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8501e+02, Early stopping counter 0 / 1000
# Epoch [  2060/ 50000], Loss: 9.3251e+08, KL: 9.3251e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7629e+02, Early stopping counter 0 / 1000
# Epoch [  2070/ 50000], Loss: 9.2391e+08, KL: 9.2391e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7248e+02, Early stopping counter 0 / 1000
# Epoch [  2080/ 50000], Loss: 9.1543e+08, KL: 9.1543e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6744e+02, Early stopping counter 0 / 1000
# Epoch [  2090/ 50000], Loss: 9.0705e+08, KL: 9.0705e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7220e+02, Early stopping counter 0 / 1000
# Epoch [  2100/ 50000], Loss: 8.9877e+08, KL: 8.9877e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8860e+02, Early stopping counter 0 / 1000
# Epoch [  2110/ 50000], Loss: 8.9060e+08, KL: 8.9060e+08, Reconstruction Loss (avg over 5 sample(s)): 1.5886e+02, Early stopping counter 0 / 1000
# Epoch [  2120/ 50000], Loss: 8.8253e+08, KL: 8.8253e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8671e+02, Early stopping counter 0 / 1000
# Epoch [  2130/ 50000], Loss: 8.7456e+08, KL: 8.7456e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6698e+02, Early stopping counter 0 / 1000
# Epoch [  2140/ 50000], Loss: 8.6669e+08, KL: 8.6669e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8586e+02, Early stopping counter 0 / 1000
# Epoch [  2150/ 50000], Loss: 8.5892e+08, KL: 8.5892e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9402e+02, Early stopping counter 0 / 1000
# Epoch [  2160/ 50000], Loss: 8.5124e+08, KL: 8.5124e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8963e+02, Early stopping counter 0 / 1000
# Epoch [  2170/ 50000], Loss: 8.4366e+08, KL: 8.4366e+08, Reconstruction Loss (avg over 5 sample(s)): 1.5323e+02, Early stopping counter 0 / 1000
# Epoch [  2180/ 50000], Loss: 8.3616e+08, KL: 8.3616e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8387e+02, Early stopping counter 0 / 1000
# Epoch [  2190/ 50000], Loss: 8.2876e+08, KL: 8.2876e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7119e+02, Early stopping counter 0 / 1000
# Epoch [  2200/ 50000], Loss: 8.2145e+08, KL: 8.2145e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9028e+02, Early stopping counter 0 / 1000
# Epoch [  2210/ 50000], Loss: 8.1422e+08, KL: 8.1422e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9100e+02, Early stopping counter 0 / 1000
# Epoch [  2220/ 50000], Loss: 8.0709e+08, KL: 8.0709e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9723e+02, Early stopping counter 0 / 1000
# Epoch [  2230/ 50000], Loss: 8.0003e+08, KL: 8.0003e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9065e+02, Early stopping counter 0 / 1000
# Epoch [  2240/ 50000], Loss: 7.9306e+08, KL: 7.9306e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7677e+02, Early stopping counter 0 / 1000
# Epoch [  2250/ 50000], Loss: 7.8617e+08, KL: 7.8617e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8582e+02, Early stopping counter 0 / 1000
# Epoch [  2260/ 50000], Loss: 7.7936e+08, KL: 7.7936e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9565e+02, Early stopping counter 0 / 1000
# Epoch [  2270/ 50000], Loss: 7.7264e+08, KL: 7.7264e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7421e+02, Early stopping counter 0 / 1000
# Epoch [  2280/ 50000], Loss: 7.6599e+08, KL: 7.6599e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6450e+02, Early stopping counter 0 / 1000
# Epoch [  2290/ 50000], Loss: 7.5942e+08, KL: 7.5942e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7878e+02, Early stopping counter 0 / 1000
# Epoch [  2300/ 50000], Loss: 7.5292e+08, KL: 7.5292e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8505e+02, Early stopping counter 0 / 1000
# Epoch [  2310/ 50000], Loss: 7.4650e+08, KL: 7.4650e+08, Reconstruction Loss (avg over 5 sample(s)): 1.5635e+02, Early stopping counter 0 / 1000
# Epoch [  2320/ 50000], Loss: 7.4015e+08, KL: 7.4015e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8525e+02, Early stopping counter 0 / 1000
# Epoch [  2330/ 50000], Loss: 7.3388e+08, KL: 7.3388e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9447e+02, Early stopping counter 0 / 1000
# Epoch [  2340/ 50000], Loss: 7.2767e+08, KL: 7.2767e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8686e+02, Early stopping counter 0 / 1000
# Epoch [  2350/ 50000], Loss: 7.2154e+08, KL: 7.2154e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8875e+02, Early stopping counter 0 / 1000
# Epoch [  2360/ 50000], Loss: 7.1547e+08, KL: 7.1547e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9055e+02, Early stopping counter 0 / 1000
# Epoch [  2370/ 50000], Loss: 7.0948e+08, KL: 7.0948e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8685e+02, Early stopping counter 0 / 1000
# Epoch [  2380/ 50000], Loss: 7.0355e+08, KL: 7.0355e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9745e+02, Early stopping counter 0 / 1000
# Epoch [  2390/ 50000], Loss: 6.9769e+08, KL: 6.9769e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7626e+02, Early stopping counter 0 / 1000
# Epoch [  2400/ 50000], Loss: 6.9189e+08, KL: 6.9189e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7850e+02, Early stopping counter 0 / 1000
# Epoch [  2410/ 50000], Loss: 6.8616e+08, KL: 6.8616e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8608e+02, Early stopping counter 0 / 1000
# Epoch [  2420/ 50000], Loss: 6.8049e+08, KL: 6.8049e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6868e+02, Early stopping counter 0 / 1000
# Epoch [  2430/ 50000], Loss: 6.7488e+08, KL: 6.7488e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6837e+02, Early stopping counter 0 / 1000
# Epoch [  2440/ 50000], Loss: 6.6934e+08, KL: 6.6934e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8497e+02, Early stopping counter 0 / 1000
# Epoch [  2450/ 50000], Loss: 6.6385e+08, KL: 6.6385e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9358e+02, Early stopping counter 0 / 1000
# Epoch [  2460/ 50000], Loss: 6.5843e+08, KL: 6.5843e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8284e+02, Early stopping counter 0 / 1000
# Epoch [  2470/ 50000], Loss: 6.5306e+08, KL: 6.5306e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8776e+02, Early stopping counter 0 / 1000
# Epoch [  2480/ 50000], Loss: 6.4775e+08, KL: 6.4775e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7829e+02, Early stopping counter 0 / 1000
# Epoch [  2490/ 50000], Loss: 6.4250e+08, KL: 6.4250e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6714e+02, Early stopping counter 0 / 1000
# Epoch [  2500/ 50000], Loss: 6.3731e+08, KL: 6.3731e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6960e+02, Early stopping counter 0 / 1000
# Epoch [  2510/ 50000], Loss: 6.3217e+08, KL: 6.3217e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8495e+02, Early stopping counter 0 / 1000
# Epoch [  2520/ 50000], Loss: 6.2709e+08, KL: 6.2709e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9392e+02, Early stopping counter 0 / 1000
# Epoch [  2530/ 50000], Loss: 6.2206e+08, KL: 6.2206e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6818e+02, Early stopping counter 0 / 1000
# Epoch [  2540/ 50000], Loss: 6.1708e+08, KL: 6.1708e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8288e+02, Early stopping counter 0 / 1000
# Epoch [  2550/ 50000], Loss: 6.1215e+08, KL: 6.1215e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6646e+02, Early stopping counter 0 / 1000
# Epoch [  2560/ 50000], Loss: 6.0728e+08, KL: 6.0728e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8055e+02, Early stopping counter 0 / 1000
# Epoch [  2570/ 50000], Loss: 6.0246e+08, KL: 6.0246e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9140e+02, Early stopping counter 0 / 1000
# Epoch [  2580/ 50000], Loss: 5.9769e+08, KL: 5.9769e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6884e+02, Early stopping counter 0 / 1000
# Epoch [  2590/ 50000], Loss: 5.9297e+08, KL: 5.9297e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8058e+02, Early stopping counter 0 / 1000
# Epoch [  2600/ 50000], Loss: 5.8829e+08, KL: 5.8829e+08, Reconstruction Loss (avg over 5 sample(s)): 2.0597e+02, Early stopping counter 0 / 1000
# Epoch [  2610/ 50000], Loss: 5.8367e+08, KL: 5.8367e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9252e+02, Early stopping counter 0 / 1000
# Epoch [  2620/ 50000], Loss: 5.7909e+08, KL: 5.7909e+08, Reconstruction Loss (avg over 5 sample(s)): 2.3080e+02, Early stopping counter 0 / 1000
# Epoch [  2630/ 50000], Loss: 5.7456e+08, KL: 5.7456e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8509e+02, Early stopping counter 0 / 1000
# Epoch [  2640/ 50000], Loss: 5.7008e+08, KL: 5.7008e+08, Reconstruction Loss (avg over 5 sample(s)): 2.1814e+02, Early stopping counter 0 / 1000
# Epoch [  2650/ 50000], Loss: 5.6564e+08, KL: 5.6564e+08, Reconstruction Loss (avg over 5 sample(s)): 2.0754e+02, Early stopping counter 0 / 1000
# Epoch [  2660/ 50000], Loss: 5.6125e+08, KL: 5.6125e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9287e+02, Early stopping counter 0 / 1000
# Epoch [  2670/ 50000], Loss: 5.5690e+08, KL: 5.5690e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8911e+02, Early stopping counter 0 / 1000
# Epoch [  2680/ 50000], Loss: 5.5260e+08, KL: 5.5260e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8093e+02, Early stopping counter 0 / 1000
# Epoch [  2690/ 50000], Loss: 5.4834e+08, KL: 5.4834e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9036e+02, Early stopping counter 0 / 1000
# Epoch [  2700/ 50000], Loss: 5.4412e+08, KL: 5.4412e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6504e+02, Early stopping counter 0 / 1000
# Epoch [  2710/ 50000], Loss: 5.3994e+08, KL: 5.3994e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7858e+02, Early stopping counter 0 / 1000
# Epoch [  2720/ 50000], Loss: 5.3581e+08, KL: 5.3581e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9073e+02, Early stopping counter 0 / 1000
# Epoch [  2730/ 50000], Loss: 5.3172e+08, KL: 5.3172e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8857e+02, Early stopping counter 0 / 1000
# Epoch [  2740/ 50000], Loss: 5.2766e+08, KL: 5.2766e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6148e+02, Early stopping counter 0 / 1000
# Epoch [  2750/ 50000], Loss: 5.2365e+08, KL: 5.2365e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9087e+02, Early stopping counter 0 / 1000
# Epoch [  2760/ 50000], Loss: 5.1968e+08, KL: 5.1968e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7977e+02, Early stopping counter 0 / 1000
# Epoch [  2770/ 50000], Loss: 5.1574e+08, KL: 5.1574e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6608e+02, Early stopping counter 0 / 1000
# Epoch [  2780/ 50000], Loss: 5.1185e+08, KL: 5.1185e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9133e+02, Early stopping counter 0 / 1000
# Epoch [  2790/ 50000], Loss: 5.0799e+08, KL: 5.0799e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8711e+02, Early stopping counter 0 / 1000
# Epoch [  2800/ 50000], Loss: 5.0417e+08, KL: 5.0417e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8261e+02, Early stopping counter 0 / 1000
# Epoch [  2810/ 50000], Loss: 5.0039e+08, KL: 5.0039e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6722e+02, Early stopping counter 0 / 1000
# Epoch [  2820/ 50000], Loss: 4.9664e+08, KL: 4.9664e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7365e+02, Early stopping counter 0 / 1000
# Epoch [  2830/ 50000], Loss: 4.9293e+08, KL: 4.9293e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8556e+02, Early stopping counter 0 / 1000
# Epoch [  2840/ 50000], Loss: 4.8926e+08, KL: 4.8926e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7174e+02, Early stopping counter 0 / 1000
# Epoch [  2850/ 50000], Loss: 4.8562e+08, KL: 4.8562e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8018e+02, Early stopping counter 0 / 1000
# Epoch [  2860/ 50000], Loss: 4.8201e+08, KL: 4.8201e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7686e+02, Early stopping counter 0 / 1000
# Epoch [  2870/ 50000], Loss: 4.7844e+08, KL: 4.7844e+08, Reconstruction Loss (avg over 5 sample(s)): 2.0052e+02, Early stopping counter 0 / 1000
# Epoch [  2880/ 50000], Loss: 4.7491e+08, KL: 4.7491e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8119e+02, Early stopping counter 0 / 1000
# Epoch [  2890/ 50000], Loss: 4.7140e+08, KL: 4.7140e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8612e+02, Early stopping counter 0 / 1000
# Epoch [  2900/ 50000], Loss: 4.6793e+08, KL: 4.6793e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9254e+02, Early stopping counter 0 / 1000
# Epoch [  2910/ 50000], Loss: 4.6450e+08, KL: 4.6450e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6736e+02, Early stopping counter 0 / 1000
# Epoch [  2920/ 50000], Loss: 4.6109e+08, KL: 4.6109e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7676e+02, Early stopping counter 0 / 1000
# Epoch [  2930/ 50000], Loss: 4.5772e+08, KL: 4.5772e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9274e+02, Early stopping counter 0 / 1000
# Epoch [  2940/ 50000], Loss: 4.5438e+08, KL: 4.5438e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9753e+02, Early stopping counter 0 / 1000
# Epoch [  2950/ 50000], Loss: 4.5107e+08, KL: 4.5107e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8199e+02, Early stopping counter 0 / 1000
# Epoch [  2960/ 50000], Loss: 4.4779e+08, KL: 4.4779e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8865e+02, Early stopping counter 0 / 1000
# Epoch [  2970/ 50000], Loss: 4.4454e+08, KL: 4.4454e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7156e+02, Early stopping counter 0 / 1000
# Epoch [  2980/ 50000], Loss: 4.4132e+08, KL: 4.4132e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8170e+02, Early stopping counter 0 / 1000
# Epoch [  2990/ 50000], Loss: 4.3813e+08, KL: 4.3813e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6800e+02, Early stopping counter 0 / 1000
# Epoch [  3000/ 50000], Loss: 4.3497e+08, KL: 4.3497e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7990e+02, Early stopping counter 0 / 1000
# Epoch [  3010/ 50000], Loss: 4.3184e+08, KL: 4.3184e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8211e+02, Early stopping counter 0 / 1000
# Epoch [  3020/ 50000], Loss: 4.2873e+08, KL: 4.2873e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8576e+02, Early stopping counter 0 / 1000
# Epoch [  3030/ 50000], Loss: 4.2566e+08, KL: 4.2566e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7794e+02, Early stopping counter 0 / 1000
# Epoch [  3040/ 50000], Loss: 4.2261e+08, KL: 4.2261e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6897e+02, Early stopping counter 0 / 1000
# Epoch [  3050/ 50000], Loss: 4.1959e+08, KL: 4.1959e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7653e+02, Early stopping counter 0 / 1000
# Epoch [  3060/ 50000], Loss: 4.1660e+08, KL: 4.1660e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8978e+02, Early stopping counter 0 / 1000
# Epoch [  3070/ 50000], Loss: 4.1363e+08, KL: 4.1363e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9586e+02, Early stopping counter 0 / 1000
# Epoch [  3080/ 50000], Loss: 4.1070e+08, KL: 4.1070e+08, Reconstruction Loss (avg over 5 sample(s)): 2.0109e+02, Early stopping counter 0 / 1000
# Epoch [  3090/ 50000], Loss: 4.0778e+08, KL: 4.0778e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6921e+02, Early stopping counter 0 / 1000
# Epoch [  3100/ 50000], Loss: 4.0490e+08, KL: 4.0490e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9764e+02, Early stopping counter 0 / 1000
# Epoch [  3110/ 50000], Loss: 4.0204e+08, KL: 4.0204e+08, Reconstruction Loss (avg over 5 sample(s)): 1.8012e+02, Early stopping counter 0 / 1000
# Epoch [  3120/ 50000], Loss: 3.9920e+08, KL: 3.9920e+08, Reconstruction Loss (avg over 5 sample(s)): 1.7589e+02, Early stopping counter 0 / 1000
# Epoch [  3130/ 50000], Loss: 3.9639e+08, KL: 3.9639e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9742e+02, Early stopping counter 0 / 1000
# Epoch [  3140/ 50000], Loss: 3.9361e+08, KL: 3.9361e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9283e+02, Early stopping counter 0 / 1000
# Epoch [  3150/ 50000], Loss: 3.9085e+08, KL: 3.9084e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6844e+02, Early stopping counter 0 / 1000
# Epoch [  3160/ 50000], Loss: 3.8811e+08, KL: 3.8811e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6889e+02, Early stopping counter 0 / 1000
# Epoch [  3170/ 50000], Loss: 3.8540e+08, KL: 3.8540e+08, Reconstruction Loss (avg over 5 sample(s)): 1.9522e+02, Early stopping counter 0 / 1000
# Epoch [  3180/ 50000], Loss: 3.8271e+08, KL: 3.8271e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6472e+02, Early stopping counter 0 / 1000
# Epoch [  3190/ 50000], Loss: 3.8004e+08, KL: 3.8004e+08, Reconstruction Loss (avg over 5 sample(s)): 1.5584e+02, Early stopping counter 0 / 1000
# Epoch [  3200/ 50000], Loss: 3.7740e+08, KL: 3.7740e+08, Reconstruction Loss (avg over 5 sample(s)): 1.6204e+02, Early stopping counter 0 / 1000
# Epoch [  3210/ 50000], Loss: 3.7478e+08, KL: 3.7478e+08, Reconstruction Loss (avg over 5 sample(s)): 2.0530e+02, Early stopping counter 0 / 1000
# ...
# Epoch [ 24470/ 50000], Loss: 6.3253e+03, KL: 6.5953e+03, Reconstruction Loss (avg over 5 sample(s)): -2.6999e+02, Early stopping counter 0 / 1000
# Epoch [ 24480/ 50000], Loss: 6.7050e+03, KL: 6.8371e+03, Reconstruction Loss (avg over 5 sample(s)): -1.3215e+02, Early stopping counter 7 / 1000
# Epoch [ 24490/ 50000], Loss: 6.5025e+03, KL: 6.5520e+03, Reconstruction Loss (avg over 5 sample(s)): -4.9437e+01, Early stopping counter 17 / 1000
# Epoch [ 24500/ 50000], Loss: 6.4836e+03, KL: 6.7148e+03, Reconstruction Loss (avg over 5 sample(s)): -2.3114e+02, Early stopping counter 4 / 1000
# Epoch [ 24510/ 50000], Loss: 6.1198e+03, KL: 6.2851e+03, Reconstruction Loss (avg over 5 sample(s)): -1.6532e+02, Early stopping counter 0 / 1000
# Epoch [ 24520/ 50000], Loss: 6.1855e+03, KL: 6.3348e+03, Reconstruction Loss (avg over 5 sample(s)): -1.4927e+02, Early stopping counter 10 / 1000
# Epoch [ 24530/ 50000], Loss: 6.3844e+03, KL: 6.5475e+03, Reconstruction Loss (avg over 5 sample(s)): -1.6305e+02, Early stopping counter 20 / 1000
# Epoch [ 24540/ 50000], Loss: 6.0224e+03, KL: 6.2224e+03, Reconstruction Loss (avg over 5 sample(s)): -1.9995e+02, Early stopping counter 0 / 1000
# Epoch [ 24550/ 50000], Loss: 7.6961e+03, KL: 8.0025e+03, Reconstruction Loss (avg over 5 sample(s)): -3.0635e+02, Early stopping counter 7 / 1000
# Epoch [ 24560/ 50000], Loss: 1.5808e+05, KL: 1.5740e+05, Reconstruction Loss (avg over 5 sample(s)): 6.7328e+02, Early stopping counter 17 / 1000
# Epoch [ 24570/ 50000], Loss: 2.3403e+08, KL: 2.3403e+08, Reconstruction Loss (avg over 5 sample(s)): 7.4361e+02, Early stopping counter 27 / 1000
# Epoch [ 24580/ 50000], Loss: 1.5380e+08, KL: 1.5380e+08, Reconstruction Loss (avg over 5 sample(s)): 3.6193e+02, Early stopping counter 37 / 1000
# Epoch [ 24590/ 50000], Loss: 5.3548e+07, KL: 5.3548e+07, Reconstruction Loss (avg over 5 sample(s)): 2.7605e+02, Early stopping counter 47 / 1000
# Epoch [ 24600/ 50000], Loss: 1.2183e+07, KL: 1.2183e+07, Reconstruction Loss (avg over 5 sample(s)): 2.2060e+02, Early stopping counter 57 / 1000
# Epoch [ 24610/ 50000], Loss: 1.5722e+06, KL: 1.5720e+06, Reconstruction Loss (avg over 5 sample(s)): 1.9606e+02, Early stopping counter 67 / 1000
# Epoch [ 24620/ 50000], Loss: 1.3769e+06, KL: 1.3767e+06, Reconstruction Loss (avg over 5 sample(s)): 1.8567e+02, Early stopping counter 77 / 1000
# Epoch [ 24630/ 50000], Loss: 2.7014e+05, KL: 2.6997e+05, Reconstruction Loss (avg over 5 sample(s)): 1.7182e+02, Early stopping counter 87 / 1000
# Epoch [ 24640/ 50000], Loss: 1.9871e+05, KL: 1.9855e+05, Reconstruction Loss (avg over 5 sample(s)): 1.5396e+02, Early stopping counter 97 / 1000
# Epoch [ 24650/ 50000], Loss: 1.7941e+05, KL: 1.7927e+05, Reconstruction Loss (avg over 5 sample(s)): 1.3379e+02, Early stopping counter 107 / 1000
# Epoch [ 24660/ 50000], Loss: 1.6059e+05, KL: 1.6048e+05, Reconstruction Loss (avg over 5 sample(s)): 1.1170e+02, Early stopping counter 117 / 1000
# Epoch [ 24670/ 50000], Loss: 1.4440e+05, KL: 1.4433e+05, Reconstruction Loss (avg over 5 sample(s)): 6.9293e+01, Early stopping counter 127 / 1000
# Epoch [ 24680/ 50000], Loss: 1.3233e+05, KL: 1.3181e+05, Reconstruction Loss (avg over 5 sample(s)): 5.1965e+02, Early stopping counter 137 / 1000
# Epoch [ 24690/ 50000], Loss: 1.2198e+05, KL: 1.2186e+05, Reconstruction Loss (avg over 5 sample(s)): 1.1598e+02, Early stopping counter 147 / 1000
# Epoch [ 24700/ 50000], Loss: 1.1394e+05, KL: 1.1385e+05, Reconstruction Loss (avg over 5 sample(s)): 9.1789e+01, Early stopping counter 157 / 1000
# Epoch [ 24710/ 50000], Loss: 1.0722e+05, KL: 1.0715e+05, Reconstruction Loss (avg over 5 sample(s)): 6.5900e+01, Early stopping counter 167 / 1000
# Epoch [ 24720/ 50000], Loss: 1.0147e+05, KL: 1.0142e+05, Reconstruction Loss (avg over 5 sample(s)): 4.4006e+01, Early stopping counter 177 / 1000
# Epoch [ 24730/ 50000], Loss: 9.6503e+04, KL: 9.6449e+04, Reconstruction Loss (avg over 5 sample(s)): 5.4224e+01, Early stopping counter 187 / 1000
# Epoch [ 24740/ 50000], Loss: 9.2786e+04, KL: 9.2643e+04, Reconstruction Loss (avg over 5 sample(s)): 1.4261e+02, Early stopping counter 197 / 1000
# Epoch [ 24750/ 50000], Loss: 8.8307e+04, KL: 8.8205e+04, Reconstruction Loss (avg over 5 sample(s)): 1.0177e+02, Early stopping counter 207 / 1000
# Epoch [ 24760/ 50000], Loss: 8.4479e+04, KL: 8.4404e+04, Reconstruction Loss (avg over 5 sample(s)): 7.4646e+01, Early stopping counter 217 / 1000
# Epoch [ 24770/ 50000], Loss: 8.1126e+04, KL: 8.1080e+04, Reconstruction Loss (avg over 5 sample(s)): 4.6578e+01, Early stopping counter 227 / 1000
# Epoch [ 24780/ 50000], Loss: 7.8026e+04, KL: 7.8015e+04, Reconstruction Loss (avg over 5 sample(s)): 1.0732e+01, Early stopping counter 237 / 1000
# Epoch [ 24790/ 50000], Loss: 7.5169e+04, KL: 7.5193e+04, Reconstruction Loss (avg over 5 sample(s)): -2.4280e+01, Early stopping counter 247 / 1000
# Epoch [ 24800/ 50000], Loss: 7.2585e+04, KL: 7.2606e+04, Reconstruction Loss (avg over 5 sample(s)): -2.0904e+01, Early stopping counter 257 / 1000
# Epoch [ 24810/ 50000], Loss: 7.0428e+04, KL: 7.0412e+04, Reconstruction Loss (avg over 5 sample(s)): 1.6895e+01, Early stopping counter 267 / 1000
# Epoch [ 24820/ 50000], Loss: 6.8019e+04, KL: 6.8040e+04, Reconstruction Loss (avg over 5 sample(s)): -2.0675e+01, Early stopping counter 277 / 1000
# Epoch [ 24830/ 50000], Loss: 6.5758e+04, KL: 6.5796e+04, Reconstruction Loss (avg over 5 sample(s)): -3.8049e+01, Early stopping counter 287 / 1000
# Epoch [ 24840/ 50000], Loss: 6.3743e+04, KL: 6.3811e+04, Reconstruction Loss (avg over 5 sample(s)): -6.8685e+01, Early stopping counter 297 / 1000
# Epoch [ 24850/ 50000], Loss: 6.1820e+04, KL: 6.1931e+04, Reconstruction Loss (avg over 5 sample(s)): -1.1120e+02, Early stopping counter 307 / 1000
# Epoch [ 24860/ 50000], Loss: 6.0175e+04, KL: 6.0211e+04, Reconstruction Loss (avg over 5 sample(s)): -3.6005e+01, Early stopping counter 317 / 1000
# Epoch [ 24870/ 50000], Loss: 5.8646e+04, KL: 5.8716e+04, Reconstruction Loss (avg over 5 sample(s)): -6.9267e+01, Early stopping counter 327 / 1000
# Epoch [ 24880/ 50000], Loss: 5.7003e+04, KL: 5.7080e+04, Reconstruction Loss (avg over 5 sample(s)): -7.6876e+01, Early stopping counter 337 / 1000
# Epoch [ 24890/ 50000], Loss: 5.5425e+04, KL: 5.5452e+04, Reconstruction Loss (avg over 5 sample(s)): -2.7086e+01, Early stopping counter 347 / 1000
# Epoch [ 24900/ 50000], Loss: 5.3991e+04, KL: 5.4116e+04, Reconstruction Loss (avg over 5 sample(s)): -1.2497e+02, Early stopping counter 357 / 1000
# Epoch [ 24910/ 50000], Loss: 5.2490e+04, KL: 5.2656e+04, Reconstruction Loss (avg over 5 sample(s)): -1.6529e+02, Early stopping counter 367 / 1000
# Epoch [ 24920/ 50000], Loss: 5.3112e+04, KL: 5.2991e+04, Reconstruction Loss (avg over 5 sample(s)): 1.2163e+02, Early stopping counter 377 / 1000
# Epoch [ 24930/ 50000], Loss: 5.0116e+04, KL: 5.0182e+04, Reconstruction Loss (avg over 5 sample(s)): -6.6101e+01, Early stopping counter 387 / 1000
# Epoch [ 24940/ 50000], Loss: 4.9041e+04, KL: 4.9099e+04, Reconstruction Loss (avg over 5 sample(s)): -5.8237e+01, Early stopping counter 397 / 1000
# Epoch [ 24950/ 50000], Loss: 4.7925e+04, KL: 4.8014e+04, Reconstruction Loss (avg over 5 sample(s)): -8.8718e+01, Early stopping counter 407 / 1000
# Epoch [ 24960/ 50000], Loss: 4.7307e+04, KL: 4.7420e+04, Reconstruction Loss (avg over 5 sample(s)): -1.1279e+02, Early stopping counter 417 / 1000
# Epoch [ 24970/ 50000], Loss: 4.5764e+04, KL: 4.5884e+04, Reconstruction Loss (avg over 5 sample(s)): -1.1986e+02, Early stopping counter 427 / 1000
# Epoch [ 24980/ 50000], Loss: 4.4737e+04, KL: 4.4860e+04, Reconstruction Loss (avg over 5 sample(s)): -1.2310e+02, Early stopping counter 437 / 1000
# Epoch [ 24990/ 50000], Loss: 4.4094e+04, KL: 4.4183e+04, Reconstruction Loss (avg over 5 sample(s)): -8.9460e+01, Early stopping counter 447 / 1000
# Epoch [ 25000/ 50000], Loss: 4.2757e+04, KL: 4.2910e+04, Reconstruction Loss (avg over 5 sample(s)): -1.5279e+02, Early stopping counter 457 / 1000
# Epoch [ 25010/ 50000], Loss: 4.1881e+04, KL: 4.2042e+04, Reconstruction Loss (avg over 5 sample(s)): -1.6042e+02, Early stopping counter 467 / 1000
# Epoch [ 25020/ 50000], Loss: 4.1260e+04, KL: 4.1265e+04, Reconstruction Loss (avg over 5 sample(s)): -4.9529e+00, Early stopping counter 477 / 1000
# Epoch [ 25030/ 50000], Loss: 4.0508e+04, KL: 4.0553e+04, Reconstruction Loss (avg over 5 sample(s)): -4.4862e+01, Early stopping counter 487 / 1000
# Epoch [ 25040/ 50000], Loss: 3.9393e+04, KL: 3.9583e+04, Reconstruction Loss (avg over 5 sample(s)): -1.9006e+02, Early stopping counter 497 / 1000
# Epoch [ 25050/ 50000], Loss: 4.0508e+04, KL: 3.9770e+04, Reconstruction Loss (avg over 5 sample(s)): 7.3762e+02, Early stopping counter 507 / 1000
# Epoch [ 25060/ 50000], Loss: 3.8042e+04, KL: 3.8157e+04, Reconstruction Loss (avg over 5 sample(s)): -1.1489e+02, Early stopping counter 517 / 1000
# Epoch [ 25070/ 50000], Loss: 3.7277e+04, KL: 3.7401e+04, Reconstruction Loss (avg over 5 sample(s)): -1.2439e+02, Early stopping counter 527 / 1000
# Epoch [ 25080/ 50000], Loss: 3.6478e+04, KL: 3.6668e+04, Reconstruction Loss (avg over 5 sample(s)): -1.8956e+02, Early stopping counter 537 / 1000
# Epoch [ 25090/ 50000], Loss: 3.6087e+04, KL: 3.6075e+04, Reconstruction Loss (avg over 5 sample(s)): 1.1833e+01, Early stopping counter 547 / 1000
# Epoch [ 25100/ 50000], Loss: 3.5549e+04, KL: 3.5700e+04, Reconstruction Loss (avg over 5 sample(s)): -1.5089e+02, Early stopping counter 557 / 1000
# Epoch [ 25110/ 50000], Loss: 3.5661e+04, KL: 3.5824e+04, Reconstruction Loss (avg over 5 sample(s)): -1.6354e+02, Early stopping counter 567 / 1000
# Epoch [ 25120/ 50000], Loss: 3.4032e+04, KL: 3.4224e+04, Reconstruction Loss (avg over 5 sample(s)): -1.9176e+02, Early stopping counter 577 / 1000
# Epoch [ 25130/ 50000], Loss: 3.4440e+04, KL: 3.4294e+04, Reconstruction Loss (avg over 5 sample(s)): 1.4587e+02, Early stopping counter 587 / 1000
# Epoch [ 25140/ 50000], Loss: 3.2953e+04, KL: 3.3029e+04, Reconstruction Loss (avg over 5 sample(s)): -7.6685e+01, Early stopping counter 597 / 1000
# Epoch [ 25150/ 50000], Loss: 3.2255e+04, KL: 3.2433e+04, Reconstruction Loss (avg over 5 sample(s)): -1.7875e+02, Early stopping counter 607 / 1000
# Epoch [ 25160/ 50000], Loss: 3.2347e+04, KL: 3.2096e+04, Reconstruction Loss (avg over 5 sample(s)): 2.5068e+02, Early stopping counter 617 / 1000
# Epoch [ 25170/ 50000], Loss: 3.1203e+04, KL: 3.1391e+04, Reconstruction Loss (avg over 5 sample(s)): -1.8797e+02, Early stopping counter 627 / 1000
# Epoch [ 25180/ 50000], Loss: 3.0712e+04, KL: 3.0877e+04, Reconstruction Loss (avg over 5 sample(s)): -1.6441e+02, Early stopping counter 637 / 1000
# Epoch [ 25190/ 50000], Loss: 3.1318e+04, KL: 3.1122e+04, Reconstruction Loss (avg over 5 sample(s)): 1.9583e+02, Early stopping counter 647 / 1000
# Epoch [ 25200/ 50000], Loss: 2.9854e+04, KL: 3.0002e+04, Reconstruction Loss (avg over 5 sample(s)): -1.4742e+02, Early stopping counter 657 / 1000
# Epoch [ 25210/ 50000], Loss: 2.9210e+04, KL: 2.9416e+04, Reconstruction Loss (avg over 5 sample(s)): -2.0606e+02, Early stopping counter 667 / 1000
# Epoch [ 25220/ 50000], Loss: 2.9469e+04, KL: 2.9448e+04, Reconstruction Loss (avg over 5 sample(s)): 2.0859e+01, Early stopping counter 677 / 1000
# Epoch [ 25230/ 50000], Loss: 2.8624e+04, KL: 2.8762e+04, Reconstruction Loss (avg over 5 sample(s)): -1.3801e+02, Early stopping counter 687 / 1000
# Epoch [ 25240/ 50000], Loss: 2.9933e+04, KL: 3.0137e+04, Reconstruction Loss (avg over 5 sample(s)): -2.0435e+02, Early stopping counter 697 / 1000
# Epoch [ 25250/ 50000], Loss: 2.8857e+04, KL: 2.8673e+04, Reconstruction Loss (avg over 5 sample(s)): 1.8437e+02, Early stopping counter 707 / 1000
# Epoch [ 25260/ 50000], Loss: 2.7258e+04, KL: 2.7350e+04, Reconstruction Loss (avg over 5 sample(s)): -9.1931e+01, Early stopping counter 717 / 1000
# Epoch [ 25270/ 50000], Loss: 2.6760e+04, KL: 2.6925e+04, Reconstruction Loss (avg over 5 sample(s)): -1.6487e+02, Early stopping counter 727 / 1000
# Epoch [ 25280/ 50000], Loss: 2.6328e+04, KL: 2.6467e+04, Reconstruction Loss (avg over 5 sample(s)): -1.3910e+02, Early stopping counter 737 / 1000
# Epoch [ 25290/ 50000], Loss: 2.6142e+04, KL: 2.6253e+04, Reconstruction Loss (avg over 5 sample(s)): -1.1068e+02, Early stopping counter 747 / 1000
# Epoch [ 25300/ 50000], Loss: 2.5622e+04, KL: 2.5809e+04, Reconstruction Loss (avg over 5 sample(s)): -1.8702e+02, Early stopping counter 757 / 1000
# Epoch [ 25310/ 50000], Loss: 2.5147e+04, KL: 2.5342e+04, Reconstruction Loss (avg over 5 sample(s)): -1.9575e+02, Early stopping counter 767 / 1000
# Epoch [ 25320/ 50000], Loss: 2.6049e+04, KL: 2.5444e+04, Reconstruction Loss (avg over 5 sample(s)): 6.0495e+02, Early stopping counter 777 / 1000
# Epoch [ 25330/ 50000], Loss: 2.5854e+04, KL: 2.5937e+04, Reconstruction Loss (avg over 5 sample(s)): -8.3136e+01, Early stopping counter 787 / 1000
# Epoch [ 25340/ 50000], Loss: 2.4498e+04, KL: 2.4589e+04, Reconstruction Loss (avg over 5 sample(s)): -9.0561e+01, Early stopping counter 797 / 1000
# Epoch [ 25350/ 50000], Loss: 2.3858e+04, KL: 2.4018e+04, Reconstruction Loss (avg over 5 sample(s)): -1.6036e+02, Early stopping counter 807 / 1000
# Epoch [ 25360/ 50000], Loss: 2.3530e+04, KL: 2.3688e+04, Reconstruction Loss (avg over 5 sample(s)): -1.5820e+02, Early stopping counter 817 / 1000
# Epoch [ 25370/ 50000], Loss: 2.3123e+04, KL: 2.3320e+04, Reconstruction Loss (avg over 5 sample(s)): -1.9660e+02, Early stopping counter 827 / 1000
# Epoch [ 25380/ 50000], Loss: 2.2952e+04, KL: 2.3100e+04, Reconstruction Loss (avg over 5 sample(s)): -1.4782e+02, Early stopping counter 837 / 1000
# Epoch [ 25390/ 50000], Loss: 2.3542e+04, KL: 2.2897e+04, Reconstruction Loss (avg over 5 sample(s)): 6.4539e+02, Early stopping counter 847 / 1000
# Epoch [ 25400/ 50000], Loss: 2.2448e+04, KL: 2.2566e+04, Reconstruction Loss (avg over 5 sample(s)): -1.1786e+02, Early stopping counter 857 / 1000
# Epoch [ 25410/ 50000], Loss: 2.2057e+04, KL: 2.2198e+04, Reconstruction Loss (avg over 5 sample(s)): -1.4050e+02, Early stopping counter 867 / 1000
# Epoch [ 25420/ 50000], Loss: 2.1657e+04, KL: 2.1845e+04, Reconstruction Loss (avg over 5 sample(s)): -1.8850e+02, Early stopping counter 877 / 1000
# Epoch [ 25430/ 50000], Loss: 2.1719e+04, KL: 2.1853e+04, Reconstruction Loss (avg over 5 sample(s)): -1.3397e+02, Early stopping counter 887 / 1000
# Epoch [ 25440/ 50000], Loss: 2.1219e+04, KL: 2.1396e+04, Reconstruction Loss (avg over 5 sample(s)): -1.7732e+02, Early stopping counter 897 / 1000
# Epoch [ 25450/ 50000], Loss: 2.0814e+04, KL: 2.1039e+04, Reconstruction Loss (avg over 5 sample(s)): -2.2478e+02, Early stopping counter 907 / 1000
# Epoch [ 25460/ 50000], Loss: 2.0876e+04, KL: 2.0901e+04, Reconstruction Loss (avg over 5 sample(s)): -2.4356e+01, Early stopping counter 917 / 1000
# Epoch [ 25470/ 50000], Loss: 2.0568e+04, KL: 2.0686e+04, Reconstruction Loss (avg over 5 sample(s)): -1.1757e+02, Early stopping counter 927 / 1000
# Epoch [ 25480/ 50000], Loss: 2.1816e+04, KL: 2.1004e+04, Reconstruction Loss (avg over 5 sample(s)): 8.1182e+02, Early stopping counter 937 / 1000
# Epoch [ 25490/ 50000], Loss: 2.0577e+04, KL: 2.0658e+04, Reconstruction Loss (avg over 5 sample(s)): -8.0777e+01, Early stopping counter 947 / 1000
# Epoch [ 25500/ 50000], Loss: 1.9696e+04, KL: 1.9818e+04, Reconstruction Loss (avg over 5 sample(s)): -1.2141e+02, Early stopping counter 957 / 1000
# Epoch [ 25510/ 50000], Loss: 1.9415e+04, KL: 1.9573e+04, Reconstruction Loss (avg over 5 sample(s)): -1.5779e+02, Early stopping counter 967 / 1000
# Epoch [ 25520/ 50000], Loss: 1.9155e+04, KL: 1.9321e+04, Reconstruction Loss (avg over 5 sample(s)): -1.6617e+02, Early stopping counter 977 / 1000
# Epoch [ 25530/ 50000], Loss: 1.9584e+04, KL: 1.9773e+04, Reconstruction Loss (avg over 5 sample(s)): -1.8887e+02, Early stopping counter 987 / 1000
# Epoch [ 25540/ 50000], Loss: 1.8938e+04, KL: 1.9145e+04, Reconstruction Loss (avg over 5 sample(s)): -2.0719e+02, Early stopping counter 997 / 1000

# %%
def report_out_losses(losses, kls, reconstruction_losses):
    """ Report the losses and KL divergence.
    """
    
    print(f"Total Loss final: {losses[-1]:.4e}")
    print(f"KL Divergence final: {kls[-1]:.4e}")
    print(f"Reconstruction Loss (avg over {K} sample(s)) final: {reconstruction_losses[-1]:.4e}")

    fig, ax = plt.subplots(1,3, figsize=(18, 4))

    ax[0].plot(losses, label='Loss', color='blue')
    ax[0].set_title('Loss over epochs')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].set_yscale('log')
    ax[0].grid(True)
    ax[0].legend()

    ax[1].plot(kls, label='KL Divergence', color='orange')
    ax[1].set_title('KL Divergence over epochs')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('KL Divergence')
    ax[1].set_yscale('log')
    ax[1].grid(True)
    ax[1].legend()

    ax[2].plot(reconstruction_losses, label='Reconstruction Loss', color='green')
    ax[2].set_title(f'Reconstruction Loss over epochs (avg with {K} sample(s))')
    ax[2].set_xlabel('Epochs')      
    ax[2].set_ylabel('Reconstruction Loss')
    ax[2].set_yscale('log')
    ax[2].grid(True)
    ax[2].legend()

    plt.tight_layout()
    plt.show()
    
report_out_losses(losses, kls, reconstruction_losses)
# Out:
# Total Loss final: 1.9274e+04
# KL Divergence final: 1.9109e+04
# Reconstruction Loss (avg over 5 sample(s)) final: 1.6461e+02

# %%
def report_out_parameters(mean_parameters_values, kernels_parameters_values, Dz=Dz):
    """ Report the parameters of the prior Gaussian Processes.
    """
    
    print("Final Mean function parameters:")
    for i in range(Dz):
        print(f"Mean function {i}:")
        for name, values in mean_parameters_values[f"mean_function_{i}"].items():
            print(f"\t{name}: {values[-1]:.4e}")
            
    for i in range(Dz):
        mean_f = mean_functions_list[i]
        for name, param in mean_f.named_parameters():
            values = mean_parameters_values[f"mean_function_{i}"][name]
            fig, ax = plt.subplots(figsize=(6, 3))
            ax.plot(values, label=f"{name} (Mean function {i})")
            ax.set_title(f"Mean function {i} - {name} over epochs")
            ax.set_xlabel('Epochs')
            ax.set_ylabel(name)
            ax.grid(True)
            ax.legend()
            plt.show()
    
    print("\nFinal Kernel parameters:")
    for i in range(Dz):
        print(f"Kernel {i}:")
        for name, values in kernels_parameters_values[f"kernel_{i}"].items():
            print(f"\t{name}: {values[-1]:.4e}")
            
    for i in range(Dz):
        kernel = kernels_list[i]
        for name, param in kernel.named_parameters():
            values = kernels_parameters_values[f"kernel_{i}"][name]
            fig, ax = plt.subplots(figsize=(6, 3))
            ax.plot(values, label=f"{name} (Kernel {i})")
            ax.set_title(f"Kernel {i} - {name} over epochs")
            ax.set_xlabel('Epochs')
            ax.set_ylabel(name)
            ax.grid(True)
            ax.legend()
            plt.show()

# %%
report_out_parameters(mean_parameters_values, kernels_parameters_values)
# Out:
# Final Mean function parameters:
# Mean function 0:
# Mean function 1:
#
# Final Kernel parameters:
# Kernel 0:
# Kernel 1:

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# Predictions
# </div>

# %%
z_sampled = q_phi.rsample()  # (B, Dz, N)
z_sampled_p = z_sampled.transpose(-1, -2)  # (B, N, Dz)
print(f"z_sampled shape: {z_sampled.shape}")
# Out:
# z_sampled shape: torch.Size([1, 2, 100])

# %%
with torch.no_grad():
    # Decode the sampled z
    mu_x = decoder_mean(z_sampled_p)  # (B, N, Dx)
    L_x, covar_x = decoder_covariance(z_sampled_p) # + tolerance # (B, N, Dx, Dx)

    p_theta_x = torch.distributions.MultivariateNormal(
            loc=mu_x,
            scale_tril=L_x
    ) # batch_shape=(B, N), event_shape=(Dx,)

    print(f"p_theta_x: {p_theta_x}")
    print(f"\tp_theta_x batch shape: {p_theta_x.batch_shape}")
    print(f"\tp_theta_x event shape: {p_theta_x.event_shape}")
# Out:
# p_theta_x: MultivariateNormal(loc: torch.Size([1, 100, 4]), scale_tril: torch.Size([1, 100, 4, 4]))
# 	p_theta_x batch shape: torch.Size([1, 100])
# 	p_theta_x event shape: torch.Size([4])

# %%
x_hat = p_theta_x.rsample()  # (B, N, Dx)
print(f"x_hat shape: {x_hat.shape}")  # (B, N, Dx)
# Out:
# x_hat shape: torch.Size([1, 100, 4])

# %%
mu_x.size()
# Out:
# torch.Size([1, 100, 4])

# %%
id_in_batch = 0  # Index of the time serie to plot is the batch to plot

if Dx > 1:
    fig, axs = plt.subplots(Dx, 1, figsize=(10, 3 * Dx))
    for i in range(Dx):
        axs[i].plot(t[0].cpu().numpy(), x[id_in_batch, :, i].cpu().numpy(), label=f"x_{i+1} (original)", color='blue', marker='x', linewidth=1)
        axs[i].plot(t[0].cpu().numpy(), mu_x[id_in_batch, :, i].cpu().numpy(), label=f"x_{i+1} (mean reconstructed)", color='red', marker='.', linewidth=1)
        axs[i].plot(t[0].cpu().numpy(), x_hat[id_in_batch, :, i].cpu().numpy(), label=f"x_{i+1} (sampled)", color='green', marker='.', linewidth=1)
        axs[i].set_title(f"Time Series x_{i+1}")
        axs[i].legend()
        axs[i].grid()
else:
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(t[0].cpu().numpy(), x[id_in_batch, :, i].cpu().numpy(), label="x_1 (original)", color='blue', marker='x', linewidth=1)
    ax.plot(t[0].cpu().numpy(), mu_x[id_in_batch, :, i].cpu().numpy(), label="x_1 (mean reconstructed)", color='red', marker='.', linewidth=1)
    ax.plot(t[0].cpu().numpy(), x_hat[id_in_batch, :, i].cpu().numpy(), label="x_1 (sampled)", color='green', marker='.', linewidth=1)
    ax.set_title("Time Series x_1")
    ax.legend()
    ax.grid()
    
fig.tight_layout()
plt.show()
