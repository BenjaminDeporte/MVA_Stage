# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# This is a notebook to describe the step by step logic of training a GP-VAE
# </div>
#
# VAEs dynamiques : https://arxiv.org/abs/2008.12595
#
# Papiers GP-VAE :
# - Deep Probabilistic Time Series Imputation https://arxiv.org/abs/1907.04155
# - Gaussian Process Prior Variational Autoencoders : https://arxiv.org/abs/1810.11738
# - Bayesian Gaussian Process Latent Variable Model : https://proceedings.mlr.press/v9/titsias10a/titsias10a.pdf
# - Markovian Gaussian Process Variational Autoencoders : https://arxiv.org/abs/2207.05543

# %% [markdown]
# Imports and set up

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import sys
import os

# Add the parent directory to sys.path to find the libs module
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
    
# print(f"Added {parent_dir} to Python path")
# print(f"Current working directory: {os.getcwd()}")
# print(f"Python path: {sys.path}")

# %%
# Set seed for reproducibility

def seed_everything(seed=42):
    """
    Set seed for reproducibility.
    """
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
    
seed_everything(42)

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    dtype = torch.cuda.FloatTensor
else:
    device = torch.device('cpu')
    dtype = torch.FloatTensor

print(f"Using {device}")

torch.set_default_dtype(torch.float64)

if device.type == 'cuda':
    print('GPU Name:', torch.cuda.get_device_name(0))
    print('Total GPU Memory:', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
# Out:
# Using cuda
# GPU Name: NVIDIA GeForce RTX 3090
# Total GPU Memory: 23.7 GB

# %% [markdown]
# ### Synthetic data
#
# We assume here a batch of $B$ time series, each composed of $N$ points $x \in \mathbb{R}^{D_x}$.
#
# We will use a set of $D_z$ Gaussian Processes to encode the latent representation.

# %%
# Dimensions
Dx = 8
Dz = 4

# parameters
N = 200
B = 1

# %%
# Synthetic data
x = torch.randn((B,N,Dx)).to(device)
t = torch.linspace(0, 1, N).to(device).unsqueeze(0).repeat(B, 1)

# report
print(f"batch size: {B}")
print(f"time series length: {N}")
print(f"Dx: {Dx}, Dz: {Dz}")
print(f"x shape: {x.shape}")
print(f"t shape: {t.shape}")
# Out:
# batch size: 1
# time series length: 200
# Dx: 8, Dz: 4
# x shape: torch.Size([1, 200, 8])
# t shape: torch.Size([1, 200])

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# Generative model
# </div>

# %%
# Utility function to create a Multi-Layer Perceptron (MLP)

def make_mlp(
    input_dim, 
    output_dim, 
    n_layers=3, 
    inter_dim=128, 
    activation=nn.ReLU):
    """Create a Multi-Layer Perceptron (MLP) with specified parameters.
    
    Args:
        input_dim (int): Dimension of the input layer.
        output_dim (int): Dimension of the output layer.
        n_layers (int, optional): Number of layers in the MLP. Defaults to 3.
            - first layer is input_dim x inter_dim
            - last layer is inter_dim x output_dim
            - all other layers are inter_dim x inter_dim
        inter_dim (int, optional): Number of neurons in the hidden layers. Defaults to 128.
        activation (nn.Module, optional): Activation function to use. Defaults to nn.ReLU.
            the last layer does not have an activation function.
        
    Returns:
        nn.Sequential: A sequential model representing the MLP.
    """
    
    layers = []
    for i in range(n_layers):
        if i == 0:
            layers.append(nn.Linear(input_dim, inter_dim))
        elif i == n_layers - 1:
            layers.append(nn.Linear(inter_dim, output_dim))
        else:
            layers.append(nn.Linear(inter_dim, inter_dim))
        
        if i < n_layers - 1:
            layers.append(activation())
    
    return nn.Sequential(*layers)

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 20px; color: black; font-weight: bold;">
# Encoder
# </div>
#
# For a given time serie, the approximate posterior $q_{\phi}$ is a set of $D_z$ independent -but not identical- multivariate Gaussians of dimension $N$.
#
# This encodes a temporal dependency over each dimension of the latent variables, but no dependency between dimensions.
#
# $q_{\phi}$ is a tf.distribution.MultivariateNormal object with batch_shape = $(B, D_z)$ and event_shape = ($N$)
#
# \begin{align}
# q_{\phi}(z_{1:N} \vert x_{1:N}) &= \mathcal{N}(\mu_{\phi}(z_{1:N} \vert x_{1:N}), \Sigma_{\phi}(z_{1:N} \vert x_{1:N}))
# \end{align}

# %% [markdown]
# ### Encoder mean
#
# We output the mean $\mu_{\phi}(z_{1:N} \vert x_{1:N})$ of $q_{\phi}$ with a simple MLP.
#
# The neural net takes an input tensor $(B, N, D_x)$ and outputs a tensor $(B, D_z, N)$ - note the permutation between $D_z$ and $N$.

# %%
class EncoderMean(nn.Module):
    """ Neural Net to compute the mean of the Gaussian Encoder distribution.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(EncoderMean, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0 !"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
                
        self.mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,  # output is a vector of length sequence_length * z_dimension
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=self.activation
        )
        
    
    def forward(self, input):
        """
        Forward pass of the EncoderMean.
        Args:
            x (torch.Tensor): Input tensor (..., N, x_dimension) (possibly N=1, ie a single point)
        Returns:
            z (torch.Tensor): Output tensor (..., z_dimension, N)
        """
        
        assert input.size(-1) == self.x_dimension, f"Wrong x_dim in EncoderMean. Input tensor must have shape (..., {self.x_dimension})"
        assert input.dim() >= 2, "Input tensor must have at least 2 dimensions (sequence_length -possibly 1- and x_dimension)"
        
        output = self.mlp(input)  # (..., N, Dz)
        output = torch.transpose(output,-1, -2)  # (..., Dz, N)
            
        return output  # (..., Dz, N) : batch of Dz independent but not identical Gaussians of dimension N. (can have N=1).
    
    def __repr__(self):
        return (f"{self.__class__.__name__}, "
                f"x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}")

# %%
encoder_mean = EncoderMean(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=32,
    activation=nn.ReLU,
).to(device)

print(f"Encoder mean function: {encoder_mean}")

mu_phi = encoder_mean(x)

# report
print(f"Encoder input shape : (B,N,Dx) = {x.shape}")
print(f"Encoder mean output mu_phi shape : (B,Dz,N) = {mu_phi.shape}")
# Out:
# Encoder mean function: EncoderMean, x_dimension=8, z_dimension=4, n_layers=2, inter_dim=32, activation=ReLU
# Encoder input shape : (B,N,Dx) = torch.Size([1, 200, 8])
# Encoder mean output mu_phi shape : (B,Dz,N) = torch.Size([1, 4, 200])

# %% [markdown]
# ### Parametrizing the Gaussian Encoder with either precision matrix or covariance matrix
#
# We have the choice of parametrizing $q_{\phi}$ with covariance matrices, precision matrices, of Cholesky-lower triangular matrices.
#
# Precision matrices are formed following Deep Probabilistic Time Series Imputation https://arxiv.org/abs/1907.04155 :
#
# First, a bi-band upper triangular matrix $B$ is formed as the sum of a diagonal matrix $D$ (with $D_{ii} > 0$) and a upper-band matrix $U = U_{ij}$ with $U_{ij} = u_{ij}$ if $j \in [i, i+1]$.
#
# Then the precision matrix is assembled by $\Lambda = B^TB$ (this ensures positive definitiveness)
#
# We output a batch of precision matrices of shape $(B, Dz, N, N)$

# %%
# Encoder Precision

class EncoderPrecision(nn.Module):
    """Reprise de l'implémentation du papier GPVAE avec
    matrice de précision triangulaire supérieure à deux bandes
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 2,
                 inter_dim = 32,
                 activation = nn.ReLU,
                 epsilon = 1e-3
                 ):
        
        super(EncoderPrecision, self).__init__()
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        self.epsilon = float(epsilon) 
        
        self.diagonal_mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
        self.off_diagonal_mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
    def forward(self, x):
        """
        x : (B, N, Dx)
        return : (B, Dz, Dz)
        """
        N = x.size(-2)
        
        # Compute the diagonal part
        D = self.diagonal_mlp(x) # (B, N, Dz)
        D = torch.transpose(D, -1, -2)  # (B, Dz, N)
        D = torch.exp(D) # ensure > 0
        D = torch.diag_embed(D) # (B, Dz, N, N)
        
        # compute the upper band
        U = self.off_diagonal_mlp(x) # (B, N, Dz)
        U = torch.transpose(U, -1, -2)  # (B, Dz, N)
        U = torch.diag_embed(U[...,:-1], offset=1)  # (B, Dz, N, N)
        
        # Combine diagonal and upper band
        B = D + U # (B, Dz, N, N)

        precision_matrix = torch.transpose(B, -1, -2) @ B  # (B, N, Dz, Dz)        
        # Add epsilon to the diagonal to ensure PSD numerical stability
        epsilon_matrix = self.epsilon * torch.eye(N, device=device) # (N, N)
        precision_matrix = precision_matrix + epsilon_matrix # (B, Dz, N, N) with epsilon broacasted
        
        return D, B, precision_matrix  # (B, Dz, N, N)
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(x_dimension={self.x_dimension}, "
                f"z_dimension={self.z_dimension}, n_layers={self.n_layers}, "
                f"inter_dim={self.inter_dim}, activation={self.activation.__name__}, "
                f"epsilon={self.epsilon})")

# %%
encoder_precision = EncoderPrecision(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=32,
    activation=nn.ReLU,
).to(device)

D, B, precision_matrix_q_phi = encoder_precision(x)

print(f"EncoderPrecision: {encoder_precision}")
print()
print(f"batch size = {x.size(0)}")
print(f"longueur de la séquence = {x.size(1)}")
print(f"Dimension de l'entrée x = {x.size(-1)}")
print(f"Dimension de l'espace latent z = {Dz}")
print()
print(f"Input x shape: {x.shape}")  # (B, N, Dx)
print(f"Batch matrices diagonales D, shape (B,Dz,N,N): {D.shape}")  # (B, Dz, N, N)
print(f"Batch matrices bi-bandes B, shape (B,Dz,N,N): {B.shape}")  # (B, Dz, N, N)
print(f"Batch matrices precision, shape (B,Dz,N,N): {precision_matrix_q_phi.shape}")  # (B, Dz, N, N)
# Out:
# EncoderPrecision: EncoderPrecision(x_dimension=8, z_dimension=4, n_layers=2, inter_dim=32, activation=ReLU, epsilon=0.001)
#
# batch size = 1
# longueur de la séquence = 200
# Dimension de l'entrée x = 8
# Dimension de l'espace latent z = 4
#
# Input x shape: torch.Size([1, 200, 8])
# Batch matrices diagonales D, shape (B,Dz,N,N): torch.Size([1, 4, 200, 200])
# Batch matrices bi-bandes B, shape (B,Dz,N,N): torch.Size([1, 4, 200, 200])
# Batch matrices precision, shape (B,Dz,N,N): torch.Size([1, 4, 200, 200])

# %% [markdown]
# Covariance matrices are formed by using the Cholesky decomposition, $C = LL^T$, with $L$ lower traingular with stricly positive entries on the diagonal.

# %%
# Encoder Covariance

class EncoderCovariance(nn.Module):
    """ Neural Net to compute the covariance of the Gaussian Encoder distribution.
    Uses a MLP to compute the lower triangular matrix of the Cholesky decomposition of the covariance matrix.
    L is triangular inferior, with diagonal elements strictly positive.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 epsilon = 1e-3,  # small positive constant to ensure positive definiteness of the kernel matrix
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(EncoderCovariance, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0 !"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        self.epsilon = float(epsilon)  # small positive constant to ensure positive definiteness of the kernel matrix
        
        # this network to get the diagonal elements of the covariance matrix
        self.diagonal_mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
        # this network to get Dz elements that will be the lower triangular part (without the diagonal) of the covariance matrix                
        self.full_matrix_mlp = make_mlp(
            input_dim=self.x_dimension,
            output_dim=self.z_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
    
    def forward(self, x):
        """
        Forward pass of the EncoderCovariance.
        Args:
            x (torch.Tensor): Input tensor (..., N, x_dimension) 
                - N can be 1 (ie a single point) or the sequence length. Must be specified.

        Returns:
            L (torch.Tensor): Lower triangular matrix of shape (..., z_dimension, N, N) 
                L can be used as scale_tril in tf.distributions.MultivariateNormal
            C (torch.Tensor): Covariance matrix of shape (..., z_dimension, N, N) 
                C can be used as covariance_matrix in tf.distributions.MultivariateNormal. but this creates lots of numerical instabilities.
            C is computed as L @ L^T, where L is the lower triangular matrix. (Cholesky decomposition)
        """
        
        # basic check of shape of input x
        assert x.size(-1) == self.x_dimension, f"Wrong x_dim in EncoderCovariance. Input tensor must have shape (batch_size, {self.sequence_length}, {self.x_dimension}) or ({self.sequence_length}, {self.x_dimension})"
        assert x.dim() >= 2, "Input tensor must have at least 2 dimensions (sequence_length -possibly 1- and x_dimension)"
        
        # input is a tensor of shape (..., N, Dx)
        N = x.size(-2)  # sequence length
        
        # Compute the diagonal elements of the covariance matrix
        D = self.diagonal_mlp(x)  # out : (..., N, Dz)
        D = torch.transpose(D, -1, -2)  # out : (..., Dz, N)
        D = torch.exp(D) # out : (..., Dz, N). Ensure entries > 0.
        D = torch.diag_embed(D) # shape (..., Dz, N, N)
        
        # Get the elements outside the diagonal
        M = self.full_matrix_mlp(x) # shape (..., N, Dz)
        M = torch.transpose(M, -1, -2)  # shape (..., Dz, N)
        M1 = M.unsqueeze(-1)  # shape (..., Dz, N, 1)
        M2 = M.unsqueeze(-2)  # shape (..., Dz, 1, N)
        M = torch.matmul(M1, M2)  # shape (..., Dz, N, N)
        M = torch.tril(M, diagonal=-1)  # Keep only the lower triangular part of the matrix (excluding the diagonal) (..., Dz, N, N))
        
        # Assemble the lower triangular matrix L
        L = D + M # (..., Dz, N, N)
        
        # Assemble the covariance matrix C
        C = L @ L.transpose(-1, -2)  # C = L @ L^T # (..., Dz, N, N)
        C = C + self.epsilon * torch.eye(N, device=x.device) # Add a small value to the diagonal for numerical stability (use broadcasting)
            
        return L, C # (..., Dz, N, N) Covariance matrix C
    
    def __repr__(self):
        return (f"{self.__class__.__name__} : "
                f"(x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}, "
                f"epsilon (to ensure PSD)={self.epsilon:.3e})")

# %%
encoder_covariance = EncoderCovariance(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=32,
    activation=nn.ReLU,
).to(device)

L_q_phi, covariance_matrix_q_phi = encoder_covariance(x)

print(f"Encoder Covariance: {encoder_covariance}")
print()

print(f"batch size = {x.size(0)}")
print(f"longueur de la séquence = {x.size(1)}")
print(f"Dimension de l'entrée x = {x.size(-1)}")
print(f"Dimension de l'espace latent z = {Dz}")
print()

print(f"Input x shape (B,N,Dx): {x.shape}")  # (B, N, Dx)
print(f"Batch matrices triangulaires inférieures L, shape (B,Dz,N,N): {L_q_phi.shape}")  # (B, Dz, N, N)
print(f"Batch matrices covariance, shape (B,Dz,N,N): {covariance_matrix_q_phi.shape}")  # (B, Dz, N, N)
# Out:
# Encoder Covariance: EncoderCovariance : (x_dimension=8, z_dimension=4, n_layers=2, inter_dim=32, activation=ReLU, epsilon (to ensure PSD)=1.000e-03)
#
# batch size = 1
# longueur de la séquence = 200
# Dimension de l'entrée x = 8
# Dimension de l'espace latent z = 4
#
# Input x shape (B,N,Dx): torch.Size([1, 200, 8])
# Batch matrices triangulaires inférieures L, shape (B,Dz,N,N): torch.Size([1, 4, 200, 200])
# Batch matrices covariance, shape (B,Dz,N,N): torch.Size([1, 4, 200, 200])

# %% [markdown]
# We can form the approximate posterior (encoder) with either parametrization.

# %%
#------- CHOIX 1 : PRECISION MATRIX -------
q_phi_p = torch.distributions.MultivariateNormal(
    loc=mu_phi,  # (Dz, N)
    precision_matrix=precision_matrix_q_phi,  # (Dz, N, N)
)

# ------- CHOIX 2 : COVARIANCE MATRIX -------
q_phi_c = torch.distributions.MultivariateNormal(
    loc=mu_phi,  # (Dz, N)
    scale_tril=L_q_phi,  # (Dz, N, N)
)

# ----- Summary de l'encoder q_phi -----
print(f"q_phi with precision matrix : {q_phi_p}")
print(f"\tq_phi batch shape: {q_phi_p.batch_shape}")
print(f"\tq_phi event shape: {q_phi_p.event_shape}")

print()
print(f"q_phi with Cholesky matrix : {q_phi_c}")
print(f"\tq_phi batch shape: {q_phi_c.batch_shape}")
print(f"\tq_phi event shape: {q_phi_c.event_shape}")
# Out:
# q_phi with precision matrix : MultivariateNormal(loc: torch.Size([1, 4, 200]), precision_matrix: torch.Size([1, 4, 200, 200]))
# 	q_phi batch shape: torch.Size([1, 4])
# 	q_phi event shape: torch.Size([200])
#
# q_phi with Cholesky matrix : MultivariateNormal(loc: torch.Size([1, 4, 200]), scale_tril: torch.Size([1, 4, 200, 200]))
# 	q_phi batch shape: torch.Size([1, 4])
# 	q_phi event shape: torch.Size([200])

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 20px; color: black; font-weight: bold;">
# Decoder
# </div>
#
# By D-separation, we know that the decoder factorizes :
#
# \begin{align}
# p_{\theta_x}(x_{1:N} \vert z_{1:N}) &= \prod_{i=1}^{N} p_{\theta_x}(x_i \vert z_i)
# \end{align}
#
# When the decoder is chosen to be Gaussian, each $p_{\theta_x}(x_i \vert z_i)$ is a Gaussian distribution of dimension $D_x$ with a covariance matrix that can be any PSD matrix (as there are correlations between dimensions of $x$) :
#
# \begin{align}
# p_{\theta_x} (x_{i} \vert z_{i}) &= \mathcal{N}(\mu_{\theta_x}(x_{i} \vert z_{i}), (\Sigma_{\theta_x}(x_{i} \vert z_{i})))
# \end{align}
#
# We learn $\mu_{\theta_x}$ and $\Sigma_{\theta_x}$ with two MLPs.

# %%
class DecoderMean(nn.Module):
    """ Neural Net to compute the mean of the Gaussian Decoder distribution.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(DecoderMean, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        
        self.mlp = make_mlp(
            input_dim=z_dimension,
            output_dim=x_dimension,
            n_layers=n_layers,
            inter_dim=inter_dim,
            activation=activation
        )
    
    def forward(self, z):
        """
        Forward pass of the DecoderMean.
        Args:
            z (torch.Tensor): Input tensor of shape (..., z_dimension)
        Returns:
            torch.Tensor: mu_x : Output tensor of shape (..., x_dimension)
        """
              
        # mini check
        assert z.size(-1) == self.z_dimension, f"Incorrect latent dim. Input tensor z must have shape (..., {self.z_dimension})"
            
        return self.mlp(z)  # (..., Dx)
    
    def __repr__(self):
        return (f"{self.__class__.__name__} "
                f"x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}")

# %%
decoder_mean = DecoderMean(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=16,
    activation=nn.ReLU,
).to(device)

print(decoder_mean)

z = q_phi_c.sample()  # (B, Dz, N)
print()
print(f"z shape when sampled : {z.shape}")  # (B, Dz, N)
print(f"Note that we need to permute the last two dimensions of z to match the decoder_mean input shape (B, N, Dz)")

z = z.permute(0, 2, 1)  # (B, N, Dz) to match the decoder input shape
print(f"z shape after permutation for decoding : {z.shape}")  # (B, N, Dz)
decoder_mean_output = decoder_mean(z)  # (B, N, Dx)
# decoder_mean_output = decoder_mean_output.transpose(-1,-2)  # (B, Dx, N) to match the output shape

print()
print(f"decoder_mean_output shape (B,N,Dx): {decoder_mean_output.shape}")  # (B, Dx, N)
# Out:
# DecoderMean x_dimension=8, z_dimension=4, n_layers=2, inter_dim=16, activation=ReLU
#
# z shape when sampled : torch.Size([1, 4, 200])
# Note that we need to permute the last two dimensions of z to match the decoder_mean input shape (B, N, Dz)
# z shape after permutation for decoding : torch.Size([1, 200, 4])
#
# decoder_mean_output shape (B,N,Dx): torch.Size([1, 200, 8])

# %% [markdown]
# We get the decoder covariance matrix $D_x \times D_x$ as we did for the encoder covariance matrix (ie via bi-bande-based precision matrix or Cholesky-based covariance matrix)

# %%
# Decoder Covariance

class DecoderCovariance(nn.Module):
    """ Neural Net to compute the covariance of the Gaussian Decoder distribution.
    Uses a MLP to compute the lower triangular matrix of the Cholesky decomposition of the covariance matrix.
    L is triangular inferior, with diagonal elements strictly positive.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 epsilon = 1e-3,  # small positive constant to ensure positive definiteness of the kernel matrix
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(DecoderCovariance, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0 !"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        self.epsilon = float(epsilon)  # small positive constant to ensure positive definiteness of the kernel matrix
        
        # this network to get the diagonal elements of the covariance matrix
        self.diagonal_mlp = make_mlp(
            input_dim=self.z_dimension,
            output_dim=self.x_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
        # this network to get Dz elements that will be the lower triangular part (without the diagonal) of the covariance matrix                
        self.full_matrix_mlp = make_mlp(
            input_dim=self.z_dimension,
            output_dim=self.x_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
    
    def forward(self, z):
        """
        Forward pass of the EncoderCovariance.
        Args:
            z (torch.Tensor): Input tensor (..., N, z_dimension) 
                - N can be 1 (ie a single point) or the sequence length. Must be specified.

        Returns:
            L (torch.Tensor): Lower triangular matrix of shape (..., N, x_dimension, x_dimension) 
                L can be used as scale_tril in tf.distributions.MultivariateNormal
            C (torch.Tensor): Covariance matrix of shape (..., N, x_dimension, x_dimension) 
                C can be used as covariance_matrix in tf.distributions.MultivariateNormal. but this creates lots of numerical instabilities.
            C is computed as L @ L^T, where L is the lower triangular matrix. (Cholesky decomposition)
        """
        
        # basic check of shape of input x
        assert z.size(-1) == self.z_dimension, f"Wrong z_dim in DecoderCovariance. Input tensor must have shape (batch_size, {self.sequence_length}, {self.z_dimension}) or ({self.sequence_length}, {self.z_dimension})"
        assert z.dim() >= 2, "Input tensor must have at least 2 dimensions (sequence_length -possibly 1- and x_dimension)"
        
        # input is a tensor of shape (..., N, Dx)
        N = z.size(-2)  # sequence length
        
        # Compute the diagonal elements of the covariance matrix
        D = self.diagonal_mlp(z)  # out : (..., N,Dx)
        D = torch.exp(D) # out : (..., N,Dx). Ensure entries > 0.
        D = torch.diag_embed(D) # shape (...,N,Dx,Dx)
        
        # Get the elements outside the diagonal
        M = self.full_matrix_mlp(z) # shape (..., N,Dx)
        M1 = M.unsqueeze(-1)  # shape (...,N,Dx,1)
        M2 = M.unsqueeze(-2)  # shape (...,N,1,Dx)
        M = torch.matmul(M1, M2)  # shape (..., N,Dx,DX)
        # Keep only the lower triangular part of the matrix (excluding the diagonal)
        M = torch.tril(M, diagonal=-1)  # (...,N,Dx,Dx)
        
        # Assemble the lower triangular matrix L
        L = D + M # (...,N,Dx,Dx)
        
        # Assemble the covariance matrix C
        C = L @ L.transpose(-1, -2)  # C = L @ L^T # (...,N,Dx,Dx)
        C = C + self.epsilon * torch.eye(self.x_dimension, device=x.device) # Add a small value to the diagonal for numerical stability (use broadcasting)
        
        return L, C # (..., Dz, N, N) Covariance matrix C
    
    def __repr__(self):
        return (f"{self.__class__.__name__} : "
                f"(x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}, "
                f"epsilon (to ensure PSD)={self.epsilon:.3e})")

# %%
# Decoder Covariance

class DecoderCovarianceDiagonal(nn.Module):
    """ Neural Net to compute a Diagonal covariance of the Gaussian Decoder distribution.
    Uses a MLP to compute the lower triangular matrix of the Cholesky decomposition of the covariance matrix. 
    But does not use it :-)
    L is triangular inferior, with diagonal elements strictly positive.
    """
    
    def __init__(self,
                 x_dimension = 1,
                 z_dimension = 1,
                 n_layers = 3,
                 inter_dim = 128,
                 activation = nn.ReLU,
                 epsilon = 1e-3,  # small positive constant to ensure positive definiteness of the kernel matrix
                 ):
        """_summary_

        Args:
            x_dimension (_type_, optional): Dimension des observations. Defaults to 1.
            z_dimension (_type_, optional): Dimension de l'espace latent. Defaults to 1.
            n_layers (int, optional): Nombre total de layers du MLP. Defaults to 3.
            inter_dim (int, optional): Nombre de neurones des hidden layers. Defaults to 128.
            activation (_type_, optional): Activation. Defaults to nn.ReLU. NB : la dernière couche n'a pas d'activation.
        """
        super(DecoderCovarianceDiagonal, self).__init__()
        
        assert n_layers > 0, "n_layers must be greater than 0 !"
        
        self.x_dimension = int(x_dimension)
        self.z_dimension = int(z_dimension)
        self.n_layers = int(n_layers)
        self.inter_dim = int(inter_dim)
        self.activation = activation
        self.epsilon = float(epsilon)  # small positive constant to ensure positive definiteness of the kernel matrix
        
        # this network to get the diagonal elements of the covariance matrix
        self.diagonal_mlp = make_mlp(
            input_dim=self.z_dimension,
            output_dim=self.x_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
        
        # this network to get Dz elements that will be the lower triangular part (without the diagonal) of the covariance matrix                
        self.full_matrix_mlp = make_mlp(
            input_dim=self.z_dimension,
            output_dim=self.x_dimension,
            n_layers=self.n_layers,
            inter_dim=self.inter_dim,
            activation=activation
        )
    
    def forward(self, z):
        """
        Forward pass of the EncoderCovariance.
        Args:
            z (torch.Tensor): Input tensor (..., N, z_dimension) 
                - N can be 1 (ie a single point) or the sequence length. Must be specified.

        Returns:
            L (torch.Tensor): Diagonal covariance matrix of shape (..., N, x_dimension, x_dimension) 
                L can be used as scale_tril in tf.distributions.MultivariateNormal
            C (torch.Tensor): Covariance matrix of shape (..., N, x_dimension, x_dimension) 
                C can be used as covariance_matrix in tf.distributions.MultivariateNormal. but this creates lots of numerical instabilities.
            C is computed as L @ L^T, where L is the lower triangular matrix. (Cholesky decomposition)
        """
        
        # basic check of shape of input x
        assert z.size(-1) == self.z_dimension, f"Wrong z_dim in DecoderCovariance. Input tensor must have shape (batch_size, {self.sequence_length}, {self.z_dimension}) or ({self.sequence_length}, {self.z_dimension})"
        assert z.dim() >= 2, "Input tensor must have at least 2 dimensions (sequence_length -possibly 1- and x_dimension)"
        
        # input is a tensor of shape (..., N, Dx)
        N = z.size(-2)  # sequence length
        
        # Compute the diagonal elements of the covariance matrix
        D = self.diagonal_mlp(z)  # out : (..., N,Dx)
        D = torch.exp(D) # out : (..., N,Dx). Ensure entries > 0.
        D = torch.diag_embed(D) # shape (...,N,Dx,Dx)
        
        # Get the elements outside the diagonal
        M = self.full_matrix_mlp(z) # shape (..., N,Dx)
        M1 = M.unsqueeze(-1)  # shape (...,N,Dx,1)
        M2 = M.unsqueeze(-2)  # shape (...,N,1,Dx)
        M = torch.matmul(M1, M2)  # shape (..., N,Dx,DX)
        # Keep only the lower triangular part of the matrix (excluding the diagonal)
        M = torch.tril(M, diagonal=-1)  # (...,N,Dx,Dx)
        
        # Assemble the lower triangular matrix L
        # L = D + M # (...,N,Dx,Dx)
        L = D  # keep only the diagonal part
        
        # Assemble the covariance matrix C
        C = L @ L.transpose(-1, -2)  # C = L @ L^T # (...,N,Dx,Dx)
        C = C + self.epsilon * torch.eye(self.x_dimension, device=x.device) # Add a small value to the diagonal for numerical stability (use broadcasting)
        
        return L, C # (..., Dz, N, N) Covariance matrix C
    
    def __repr__(self):
        return (f"{self.__class__.__name__} : "
                f"(x_dimension={self.x_dimension}, z_dimension={self.z_dimension}, "
                f"n_layers={self.n_layers}, inter_dim={self.inter_dim}, "
                f"activation={self.activation.__name__}, "
                f"epsilon (to ensure PSD)={self.epsilon:.3e})")

# %%
# decoder_covariance = DecoderCovariance(
#     x_dimension=Dx,
#     z_dimension=Dz,
#     n_layers=2,
#     inter_dim=32,
#     activation=nn.ReLU,
# ).to(device)

decoder_covariance = DecoderCovarianceDiagonal(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=2,
    inter_dim=32,
    activation=nn.ReLU,
).to(device)

print(decoder_covariance)

z = q_phi_c.sample()  # (B, Dz, N)

print()
print(f"z shape when sampled (B,Dz,N): {z.shape}")  # (B, Dz, N)
z = z.permute(0, 2, 1)  # (B, N, Dz) to match the decoder input shape
print(f"Note that we need to permute the last two dimensions of z to match the decoder_mean input shape (B, N, Dz)")
print(f"z shape after permutation for decoding (B,N,Dz): {z.shape}")  # (B, N, Dz)

L, decoder_covar_output = decoder_covariance(z)  # (B,N,Dx,Dx)

print()
print(f"decoder_covar_output shape (B,N,Dx,Dx): {decoder_covar_output.shape}")  # (B,N,Dx,Dx)
# Out:
# DecoderCovarianceDiagonal : (x_dimension=8, z_dimension=4, n_layers=2, inter_dim=32, activation=ReLU, epsilon (to ensure PSD)=1.000e-03)
#
# z shape when sampled (B,Dz,N): torch.Size([1, 4, 200])
# Note that we need to permute the last two dimensions of z to match the decoder_mean input shape (B, N, Dz)
# z shape after permutation for decoding (B,N,Dz): torch.Size([1, 200, 4])
#
# decoder_covar_output shape (B,N,Dx,Dx): torch.Size([1, 200, 8, 8])

# %% [markdown]
# We form the decoder with a multivariate normal distribution

# %%
mu_x = decoder_mean_output  # (B,N,Dx)
print(f"mu_x shape (B,N,Dx): {mu_x.shape}")

covar_x = decoder_covar_output  # (B,N,Dx,Dx)
print(f"covar_x shape (B,N,Dx,Dx): {covar_x.shape}")

p_theta_x = torch.distributions.MultivariateNormal(
    loc=mu_x,
    covariance_matrix=covar_x
)

print(f"p_theta_x: {p_theta_x}")
print(f"\tp_theta_x batch shape (B,Dx): {p_theta_x.batch_shape}") # (B,Dx)
print(f"\tp_theta_x event shape (N): {p_theta_x.event_shape}") # (N,)
# Out:
# mu_x shape (B,N,Dx): torch.Size([1, 200, 8])
# covar_x shape (B,N,Dx,Dx): torch.Size([1, 200, 8, 8])
# p_theta_x: MultivariateNormal(loc: torch.Size([1, 200, 8]), covariance_matrix: torch.Size([1, 200, 8, 8]))
# 	p_theta_x batch shape (B,Dx): torch.Size([1, 200])
# 	p_theta_x event shape (N): torch.Size([8])

# %% [markdown]
# We will actually instantiate several ($K$) distributions $p_{\theta_x}$ by sampling $K$ times $z_{1:N}$, so we can average the reconstruction loss.

# %%
K = 30  # Number of samples to average the reconstruction loss
z_sampled = q_phi_c.sample((K,))  # (K,B,Dz,N)

print(f"z shape when sampled K={K} times (K,B,Dz,N): {z_sampled.shape}")  # (K, B, Dz, N)
z_sampled_p = z_sampled.transpose(-1, -2)
print(f"Permuting the last two dimensions of z to match the decoder covariance input shape (K,B,N,Dz)")
print(f"z shape after permutation for decoding mean (K,B,N,Dz) : {z_sampled_p.shape}")  # (K, B, N, Dz)

mu_x = decoder_mean(z_sampled_p)  # (K,B,N,Dx)
print()
print(f"mu_x shape (K,B,N,Dx): {mu_x.shape}")

L_x, covar_x = decoder_covariance(z_sampled_p)  # (K,B,N,Dx,Dx)
print(f"covar_x shape (K,B,N,Dx,Dx): {covar_x.shape}")

p_theta_x = torch.distributions.MultivariateNormal(
    loc=mu_x,
    covariance_matrix=covar_x
)

print()
print(f"p_theta_x: {p_theta_x}")
print(f"\tp_theta_x batch shape (K,B,N): {p_theta_x.batch_shape}")  # (K, B, N)
print(f"\tp_theta_x event shape (Dx): {p_theta_x.event_shape}")  # (Dx,)
# Out:
# z shape when sampled K=30 times (K,B,Dz,N): torch.Size([30, 1, 4, 200])
# Permuting the last two dimensions of z to match the decoder covariance input shape (K,B,N,Dz)
# z shape after permutation for decoding mean (K,B,N,Dz) : torch.Size([30, 1, 200, 4])
#
# mu_x shape (K,B,N,Dx): torch.Size([30, 1, 200, 8])
# covar_x shape (K,B,N,Dx,Dx): torch.Size([30, 1, 200, 8, 8])
#
# p_theta_x: MultivariateNormal(loc: torch.Size([30, 1, 200, 8]), covariance_matrix: torch.Size([30, 1, 200, 8, 8]))
# 	p_theta_x batch shape (K,B,N): torch.Size([30, 1, 200])
# 	p_theta_x event shape (Dx): torch.Size([8])

# %%
print(f"One covariance matrix for one x_t: ")
print(f"{covar_x[0,0,0]}")  # (Dx, Dx)
# Out:
# One covariance matrix for one x_t:
# tensor([[1.7054, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.8337, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.1426, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 1.4208, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 1.4737, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.2454, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.4354, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7696]],
#        device='cuda:0', grad_fn=<SelectBackward0>)

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 20px; color: black; font-weight: bold;">
# Gaussian Process priors
# </div>
#
# Each dimension $l$ of the latent variables (with $1 \leq l \leq D_z$) has a Gaussian Process prior over times:
#
# \begin{align}
# z_l \sim \mathcal{GP}(m_l(.), k_l(.,.))
# \end{align}
#
# The mean functions $m_l$ are usually constant null.
#
# The kernel functions $k_l(.,.)$ are a priori different along the dimensions. They encode the prior knowledge (if any) regarding the time series. They can either be fixed, or have learnable parameters.

# %% [markdown]
# Gaussian Kernel class with learnable parameters

# %%
class GaussianKernel(nn.Module):  
    """Gaussian kernel for one univariate Gaussian Process.
    The lengthscale and variance parameters are learnable (nn.Parameter).
    """
    
    # we need to add a small positive constant to ensure positive definiteness of the kernel matrix
    # 1e-3 is ok for time series up to 10,000 time points.
    # 1e-4 is ok for time series up to 2,880 time points. (ie 2 days @ 1 minute resolution).
    # 1e-4 is ok for time series up to 1,000 time points.
    # 1e-6 is ok for time series up to 100 time points.
    # the value can be decreased for shorter time series.
    # but it should not be too small, otherwise the Cholesky decomposition will fail.
    
    def __init__(self, lengthscale=1.0, sigma=1.0, epsilon=1e-3):
        super(GaussianKernel, self).__init__()
        
        # learnable parameters for the Gaussian kernel
        self.lengthscale = nn.Parameter(torch.tensor(lengthscale))  # learnable lengthscale parameter       
        self.sigma = nn.Parameter(torch.tensor(sigma))  # learnable variance parameter
        
        self.epsilon = torch.tensor(epsilon)  # tolerance to ensure positive definiteness of the kernel matrix
    
    def forward(self, t1, t2):
        """Compute the Gaussian kernel between two sets of time points.
        
        Args:
            t1 (torch.Tensor): First set of time points (..., N) - N is typically the sequence length.
            t2 (torch.Tensor): Second set of time points (..., M)
        
        Returns:
            torch.Tensor: Kernel matrix of shape (..., N, M)
        """
        
        assert t1.dim() == t2.dim(), "GaussianKernel object : Input tensors must have the same number of dimensions"
        
        # Compute the Gaussian kernel matrix
        if t1.dim() == 1:
            t1_b = t1.unsqueeze(-1)  # (N, 1)
            t2_b = t2.unsqueeze(0)   # (1, M)
            kernel = torch.exp(-0.5 * ((t1_b - t2_b) / self.lengthscale)**2)  # (N, M)
        else:
            t1_b = t1.unsqueeze(-1) # (...,N, 1)
            t2_b = t2.unsqueeze(-2) # (...,1, M)
            kernel = torch.exp(-0.5 * ((t1_b - t2_b) / self.lengthscale)**2)  # (..., N, M)
        
        gaussian_kernel_matrix = self.sigma**2 * kernel  # (..., N, M)

        if torch.equal(t1, t2):
            # If t1 and t2 are the same, the kernel matrix should be symmetric and positive definite
            # so we compute and return the Cholesky decomposition of the kernel matrix
            # to be used in forming the MultivariateNormal distribution, adding
            # a small value to the diagonal for numerical stability
            gaussian_kernel_matrix = gaussian_kernel_matrix + self.epsilon * torch.eye(t1.size(-1), device=t1.device, dtype=t1.dtype)

            try:
                L = torch.linalg.cholesky(gaussian_kernel_matrix)  # Cholesky decomposition to ensure positive definiteness
                return gaussian_kernel_matrix, L  # Return the kernel matrix and its Cholesky factor L
            
            except RuntimeError:
                # If the Cholesky decomposition fails, it means the matrix is not positive definite
                # We can return None or raise an error, depending on how we want to handle this case
                # print("Warning: Cholesky decomposition failed.")
                # print(f"Kernel : {gaussian_kernel_matrix}")
                # return gaussian_kernel_matrix, None  # Return the kernel matrix and None for L
                raise NameError("Cholesky decomposition of a supposedly PSD kernel matrix failed. Tolerance alpha is likely too low.") 
            
        else:
            # If t1 and t2 are different, do not try to compute the Cholesky decomposition
            return gaussian_kernel_matrix, None
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(lengthscale={self.lengthscale.item():.3e}, "
                f"variance (sigma**2)={self.sigma.item()**2:.3e}, "
                f"sigma={self.sigma.item():.3e}, "
                f"epsilon={self.epsilon.item():.3e})")

# %%
class GaussianKernelFixed(nn.Module):  
    """Gaussian kernel for one univariate Gaussian Process.
    The lengthscale and variance parameters are NOT learnable.
    """
    
    # we need to add a small positive constant to ensure positive definiteness of the kernel matrix
    # 1e-3 is ok for time series up to 10,000 time points.
    # 1e-4 is ok for time series up to 2,880 time points. (ie 2 days @ 1 minute resolution).
    # 1e-4 is ok for time series up to 1,000 time points.
    # 1e-6 is ok for time series up to 100 time points.
    # the value can be decreased for shorter time series.
    # but it should not be too small, otherwise the Cholesky decomposition will fail.
    
    def __init__(self, lengthscale=1.0, sigma=1.0, epsilon=1e-3):
        super(GaussianKernelFixed, self).__init__()
        
        # learnable parameters for the Gaussian kernel
        self.lengthscale = torch.tensor(lengthscale)  # learnable lengthscale parameter       
        self.sigma = torch.tensor(sigma)  # learnable variance parameter
        
        self.epsilon = torch.tensor(epsilon)  # tolerance to ensure positive definiteness of the kernel matrix
    
    def forward(self, t1, t2):
        """Compute the Gaussian kernel between two sets of time points.
        
        Args:
            t1 (torch.Tensor): First set of time points (..., N) - N is typically the sequence length.
            t2 (torch.Tensor): Second set of time points (..., M)
        
        Returns:
            torch.Tensor: Kernel matrix of shape (..., N, M)
        """
        
        assert t1.dim() == t2.dim(), "GaussianKernel object : Input tensors must have the same number of dimensions"
        
        # Compute the Gaussian kernel matrix
        if t1.dim() == 1:
            t1_b = t1.unsqueeze(-1)  # (N, 1)
            t2_b = t2.unsqueeze(0)   # (1, M)
            kernel = torch.exp(-0.5 * ((t1_b - t2_b) / self.lengthscale)**2)  # (N, M)
        else:
            t1_b = t1.unsqueeze(-1) # (...,N, 1)
            t2_b = t2.unsqueeze(-2) # (...,1, M)
            kernel = torch.exp(-0.5 * ((t1_b - t2_b) / self.lengthscale)**2)  # (..., N, M)
        
        gaussian_kernel_matrix = self.sigma**2 * kernel  # (..., N, M)

        if torch.equal(t1, t2):
            # If t1 and t2 are the same, the kernel matrix should be symmetric and positive definite
            # so we compute and return the Cholesky decomposition of the kernel matrix
            # to be used in forming the MultivariateNormal distribution, adding
            # a small value to the diagonal for numerical stability
            gaussian_kernel_matrix = gaussian_kernel_matrix + self.epsilon * torch.eye(t1.size(-1), device=t1.device, dtype=t1.dtype)

            try:
                L = torch.linalg.cholesky(gaussian_kernel_matrix)  # Cholesky decomposition to ensure positive definiteness
                return gaussian_kernel_matrix, L  # Return the kernel matrix and its Cholesky factor L
            
            except RuntimeError:
                # If the Cholesky decomposition fails, it means the matrix is not positive definite
                # We can return None or raise an error, depending on how we want to handle this case
                # print("Warning: Cholesky decomposition failed.")
                # print(f"Kernel : {gaussian_kernel_matrix}")
                # return gaussian_kernel_matrix, None  # Return the kernel matrix and None for L
                raise NameError("Cholesky decomposition of a supposedly PSD kernel matrix failed. Tolerance alpha is likely too low.") 
            
        else:
            # If t1 and t2 are different, do not try to compute the Cholesky decomposition
            return gaussian_kernel_matrix, None
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(lengthscale={self.lengthscale.item():.3e}, "
                f"variance (sigma**2)={self.sigma.item()**2:.3e}, "
                f"sigma={self.sigma.item():.3e}, "
                f"epsilon={self.epsilon.item():.3e})")

# %% [markdown]
# Matern Kernel class with learnable parameters

# %%
class MaternKernel(nn.Module):
    """Matern kernel for one univariate Gaussian Process.
    Takes nu = 0.5, 1.5, 2.5 in the constructor.
    The lengthscale, variance and alpha parameters are learnable (nn.Parameter).
    """
    
    def __init__(self, nu, lengthscale=1.0, sigma=1.0, epsilon=1e-3):
        super(MaternKernel, self).__init__()
        
        # check
        if nu not in [0.5, 1.5, 2.5]:
            raise ValueError("MaternKernel: nu must be one of [0.5, 1.5, 2.5]")
        self.nu = nu  # Matern parameter nu
        
        # learnable parameters for the RQ kernel
        self.lengthscale = nn.Parameter(torch.tensor(lengthscale))  # learnable alpha parameter (shape parameter)
        self.sigma = nn.Parameter(torch.tensor(sigma))  # learnable variance = sigma**2 parameter

        self.epsilon = epsilon  # small value to ensure positive definiteness of the kernel matrix
    
    def forward(self, t1, t2):
        """Compute the Matern kernel between two sets of time points.
        
        Args:
            t1 (torch.Tensor): First set of time points (..., N) - N is typically the sequence length.
            t2 (torch.Tensor): Second set of time points (..., M)
        
        Returns:
            torch.Tensor: Kernel matrix of shape (..., N, M)
        """
        
        assert t1.dim() == t2.dim(), "Matern Kernel object : Input tensors must have the same number of dimensions"
        
        if t1.dim() == 1:
            t1_b = t1.unsqueeze(-1)  # (N, 1)
            t2_b = t2.unsqueeze(0)   # (1, M)
        else:
            t1_b = t1.unsqueeze(-1) # (..., N, 1)
            t2_b = t2.unsqueeze(-2) # (..., 1, M)
        
        d = torch.abs(t1_b - t2_b)  # (..., N, M)
        
        if self.nu == 0.5:
            # Matern kernel with nu = 0.5
            matern_kernel = self.sigma**2 * torch.exp(-d / self.lengthscale)
        elif self.nu == 1.5:
            # Matern kernel with nu = 1.5
            matern_kernel = self.sigma**2 * (1 + (d * torch.sqrt(torch.tensor(3))) / self.lengthscale) * torch.exp(-d * torch.sqrt(torch.tensor(3)) / self.lengthscale)
        elif self.nu == 2.5:
            # Matern kernel with nu = 2.5
            matern_kernel = self.sigma**2 * (1 + ((d * torch.sqrt(torch.tensor(5))) / self.lengthscale) + (5 * d**2 / (3 * self.lengthscale**2))) * torch.exp(-d * torch.sqrt(torch.tensor(5)) / self.lengthscale)
        else:
            raise ValueError("MaternKernel: nu must be one of [0.5, 1.5, 2.5]")

        if torch.equal(t1, t2):
            # If t1 and t2 are the same, the kernel matrix should be symmetric and positive definite
            # so we compute and return the Cholesky decomposition of the kernel matrix
            # to be used in forming the MultivariateNormal distribution, adding
            # a small value to the diagonal for numerical stability
            matern_kernel += self.epsilon * torch.eye(t1.size(-1), device=t1.device, dtype=t1.dtype)
            try:
                L = torch.linalg.cholesky(matern_kernel)  # Cholesky decomposition to ensure positive definiteness
                return matern_kernel, L  # Return the kernel matrix and its Cholesky factor L
            except RuntimeError:
                # If the Cholesky decomposition fails, it means the matrix is not positive definite
                # We can return None or raise an error, depending on how we want to handle this case
                # print("Warning: Cholesky decomposition failed.")
                # print(f"Kernel : {gaussian_kernel_matrix}")
                # return gaussian_kernel_matrix, None  # Return the kernel matrix and None for L
                raise NameError("Cholesky decomposition of a supposedly PSD kernel matrix failed in Matern Kernel. Tolerance epsilon is likely too low.") 
        else:
            # If t1 and t2 are different, do not try to compute the Cholesky decomposition
            return matern_kernel, None
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(nu={self.nu}, "
                f"lengthscale={self.lengthscale.item():.3e}, "
                f"sigma={self.sigma.item():.3e}, "
                f"variance (sigma**2)={self.sigma.item()**2:.3e}, "
                f"epsilon={self.epsilon:.3e})")

# %%
class MaternKernelFixed(nn.Module):
    """Matern kernel for one univariate Gaussian Process.
    Takes nu = 0.5, 1.5, 2.5 in the constructor.
    The lengthscale, variance and alpha parameters are NOT learnable.
    """
    
    def __init__(self, nu, lengthscale=1.0, sigma=1.0, epsilon=1e-3):
        super(MaternKernelFixed, self).__init__()
        
        # check
        if nu not in [0.5, 1.5, 2.5]:
            raise ValueError("MaternKernel: nu must be one of [0.5, 1.5, 2.5]")
        self.nu = nu  # Matern parameter nu
        
        # learnable parameters for the RQ kernel
        self.lengthscale = torch.tensor(lengthscale)  # NOT learnable alpha parameter (shape parameter)
        self.sigma = torch.tensor(sigma)  # NOT learnable variance = sigma**2 parameter

        self.epsilon = epsilon  # small value to ensure positive definiteness of the kernel matrix
    
    def forward(self, t1, t2):
        """Compute the Matern kernel between two sets of time points.
        
        Args:
            t1 (torch.Tensor): First set of time points (..., N) - N is typically the sequence length.
            t2 (torch.Tensor): Second set of time points (..., M)
        
        Returns:
            torch.Tensor: Kernel matrix of shape (..., N, M)
        """
        
        assert t1.dim() == t2.dim(), "Matern Kernel object : Input tensors must have the same number of dimensions"
        
        if t1.dim() == 1:
            t1_b = t1.unsqueeze(-1)  # (N, 1)
            t2_b = t2.unsqueeze(0)   # (1, M)
        else:
            t1_b = t1.unsqueeze(-1) # (..., N, 1)
            t2_b = t2.unsqueeze(-2) # (..., 1, M)
        
        d = torch.abs(t1_b - t2_b)  # (..., N, M)
        
        if self.nu == 0.5:
            # Matern kernel with nu = 0.5
            matern_kernel = self.sigma**2 * torch.exp(-d / self.lengthscale)
        elif self.nu == 1.5:
            # Matern kernel with nu = 1.5
            matern_kernel = self.sigma**2 * (1 + (d * torch.sqrt(torch.tensor(3))) / self.lengthscale) * torch.exp(-d * torch.sqrt(torch.tensor(3)) / self.lengthscale)
        elif self.nu == 2.5:
            # Matern kernel with nu = 2.5
            matern_kernel = self.sigma**2 * (1 + ((d * torch.sqrt(torch.tensor(5))) / self.lengthscale) + (5 * d**2 / (3 * self.lengthscale**2))) * torch.exp(-d * torch.sqrt(torch.tensor(5)) / self.lengthscale)
        else:
            raise ValueError("MaternKernel: nu must be one of [0.5, 1.5, 2.5]")

        if torch.equal(t1, t2):
            # If t1 and t2 are the same, the kernel matrix should be symmetric and positive definite
            # so we compute and return the Cholesky decomposition of the kernel matrix
            # to be used in forming the MultivariateNormal distribution, adding
            # a small value to the diagonal for numerical stability
            matern_kernel += self.epsilon * torch.eye(t1.size(-1), device=t1.device, dtype=t1.dtype)
            try:
                L = torch.linalg.cholesky(matern_kernel)  # Cholesky decomposition to ensure positive definiteness
                return matern_kernel, L  # Return the kernel matrix and its Cholesky factor L
            except RuntimeError:
                # If the Cholesky decomposition fails, it means the matrix is not positive definite
                # We can return None or raise an error, depending on how we want to handle this case
                # print("Warning: Cholesky decomposition failed.")
                # print(f"Kernel : {gaussian_kernel_matrix}")
                # return gaussian_kernel_matrix, None  # Return the kernel matrix and None for L
                raise NameError("Cholesky decomposition of a supposedly PSD kernel matrix failed in Matern Kernel. Tolerance epsilon is likely too low.") 
        else:
            # If t1 and t2 are different, do not try to compute the Cholesky decomposition
            return matern_kernel, None
    
    def __repr__(self):
        return (f"{self.__class__.__name__}(nu={self.nu}, "
                f"lengthscale={self.lengthscale.item():.3e}, "
                f"sigma={self.sigma.item():.3e}, "
                f"variance (sigma**2)={self.sigma.item()**2:.3e}, "
                f"epsilon={self.epsilon:.3e})")

# %% [markdown]
# Null mean function class

# %%
class GPNullMean(nn.Module):
    """ Neural Net to compute the mean of one univariate Gaussian Process
    This is a null mean function, i.e. it returns a tensor of zeros...
    """
    
    def __init__(self):
        super(GPNullMean, self).__init__()
    
    def forward(self, t):
        """Forward pass of the GPNullMean.
        Just returns a tensor of zeros of shape identical to the input.
        
        Inputs:
            t (torch.Tensor): Input tensor of shape (..., N) - N is typically the sequence length.
        Returns:
            torch.Tensor: Output tensor of ZEROS of shape (..., N)
        """
        
        return torch.zeros_like(t, dtype=t.dtype, device=t.device)  # (..., N)
    
    def __repr__(self):
        return f"{self.__class__.__name__}"

# %% [markdown]
# Constant mean function class

# %%
class GPConstantMean(nn.Module):
    """ Neural Net to compute the mean of one univariate Gaussian Process
    This is a constant mean function, with a learnable parameter.
    """
    
    def __init__(self, constant_init=0.0):
        super(GPConstantMean, self).__init__()
        
        self.constant_value = nn.Parameter(torch.tensor(constant_init))  # learnable constant value
    
    def forward(self, t):
        """Forward pass of the GPNullMean.
        Just returns a tensor of zeros of shape identical to the input.
        
        Inputs:
            t (torch.Tensor): Input tensor of shape (..., N) - N is typically the sequence length.
        Returns:
            torch.Tensor: Output tensor of ZEROS of shape (..., N)
        """
        
        return self.constant_value * torch.ones_like(t, dtype=t.dtype, device=t.device)  # (..., N)
    
    def __repr__(self):
        return f"{self.__class__.__name__}, constant_value={self.constant_value.item():.3e})"

# %% [markdown]
# We assemble the $D_z$ Gaussian Process priors, for example with kernels with different lengthscales. (cf TF implementation of the GPVAE paper)

# %%
def compute_gp_priors_kernel(t, Dz, starting_lengthscale=0.1, verbose=False):
    """Compute the GP prior kernel matrices
    """
    
    # form the list of kernels and mean functions for the GP priors
    kernels_list = []
    mean_functions_list = []

    for i in range(Dz):
        # kernel = GaussianKernelFixed(lengthscale=starting_lengthscale / 2**i, sigma=1.0, epsilon=1e-12)  # diminishing lengthscale
        # kernel = GaussianKernelFixed(lengthscale=starting_lengthscale, sigma=1.0, epsilon=1e-12)  # same fixed lengthscale for all GK
        kernel = GaussianKernel(lengthscale=starting_lengthscale, sigma=1.0, epsilon=1e-12)  # same fixed lengthscale for all GK
        # kernel = MaternKernel(nu=0.5, lengthscale=starting_lengthscale / 2**i, sigma=1.0, epsilon=1e-3)
        # kernel = MaternKernel(nu=1.5, lengthscale=starting_lengthscale / 2**i, sigma=1.0, epsilon=1e-3)
        # kernel = MaternKernel(nu=2.5, lengthscale=starting_lengthscale / 2**i, sigma=1.0, epsilon=1e-3)
        kernels_list.append(kernel)
        # mean_function = GPConstantMean()
        mean_function = GPNullMean()
        mean_functions_list.append(mean_function)
        
    # compute the kernel matrices for each kernel
    kernel_matrices = []
    L_matrices = []
    means = []

    for i in range(Dz):
        mu_z_i = mean_functions_list[i](t)  # (B, N)
        kernel_matrix_i, L_i = kernels_list[i](t, t)
        kernel_matrices.append(kernel_matrix_i)  # (B, N, N)
        L_matrices.append(L_i)  # (B, N, N) or None
        means.append(mu_z_i)  # (B, N)
        
        if verbose:
            print()
            print(f"Computing Gaussian Process prior for z component {i+1} / {Dz}...")
            print(f"Kernel {i} is : {kernels_list[i]}")
            print(f"Mean function {i} is : {mean_functions_list[i]}")
            print(f"mu_z {i} shape (B,N): {mu_z_i.shape}")  # (B, N)
            print(f"Kernel matrix {i} shape (B,N,N): {kernel_matrix_i.shape}")  # (B, N, N)
        
    kernel_matrix = torch.stack(kernel_matrices, dim=0)  # (Dz, B, N, N)
    kernel_matrix = kernel_matrix.transpose(0, 1) # (B, Dz, N, N)
    L_matrix = torch.stack(L_matrices, dim=0) if L_matrices[0] is not None else None  # (Dz, B, N, N) or None
    L_matrix = L_matrix.transpose(0, 1) if L_matrix is not None else None  # (B, Dz, N, N)
    mean = torch.stack(means, dim=0)  # (Dz, B, N)
    mean = mean.transpose(0, 1)  # (B, Dz, N)
    
    if verbose:
        print()
        print(f"Full Kernel matrix shape after stack and transpose (B,Dz,N,N): {kernel_matrix.shape}")  # (Dz, B, N, N)
        print(f"Full L matrix shape after stack and transpose (B,Dz,N,N): {L_matrix.shape if L_matrix is not None else 'None'}")  # (B, Dz, N, N) or None
        print(f"Mean shape after stack and transpose (B,Dz,N): {mean.shape}")  # (B, Dz, N)
    
    return kernel_matrix, L_matrix, mean, kernels_list, mean_functions_list

# %%
kernel_matrix, L_matrix, mean, kernels_list, mean_functions_list = compute_gp_priors_kernel(t, Dz, verbose=True)
# Out:
# Computing Gaussian Process prior for z component 1 / 4...
# Kernel 0 is : GaussianKernel(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 0 is : GPNullMean
# mu_z 0 shape (B,N): torch.Size([1, 200])
# Kernel matrix 0 shape (B,N,N): torch.Size([1, 200, 200])
#
# Computing Gaussian Process prior for z component 2 / 4...
# Kernel 1 is : GaussianKernel(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 1 is : GPNullMean
# mu_z 1 shape (B,N): torch.Size([1, 200])
# Kernel matrix 1 shape (B,N,N): torch.Size([1, 200, 200])
#
# Computing Gaussian Process prior for z component 3 / 4...
# Kernel 2 is : GaussianKernel(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 2 is : GPNullMean
# mu_z 2 shape (B,N): torch.Size([1, 200])
# Kernel matrix 2 shape (B,N,N): torch.Size([1, 200, 200])
#
# Computing Gaussian Process prior for z component 4 / 4...
# Kernel 3 is : GaussianKernel(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 3 is : GPNullMean
# mu_z 3 shape (B,N): torch.Size([1, 200])
# Kernel matrix 3 shape (B,N,N): torch.Size([1, 200, 200])
#
# Full Kernel matrix shape after stack and transpose (B,Dz,N,N): torch.Size([1, 4, 200, 200])
# Full L matrix shape after stack and transpose (B,Dz,N,N): torch.Size([1, 4, 200, 200])
# Mean shape after stack and transpose (B,Dz,N): torch.Size([1, 4, 200])

# %% [markdown]
# And instantiate $p_{\theta_z}$

# %%
p_theta_z = torch.distributions.MultivariateNormal(
    loc=mean,  # (B, Dz, N)
    scale_tril=L_matrix,  # (B, Dz, N, N)
)

print(f"p_theta_z: {p_theta_z}")
print(f"\tp_theta_z batch shape (B,Dz): {p_theta_z.batch_shape}")  # (B, Dz)
print(f"\tp_theta_z event shape (N): {p_theta_z.event_shape}")  # (N)
# Out:
# p_theta_z: MultivariateNormal(loc: torch.Size([1, 4, 200]), scale_tril: torch.Size([1, 4, 200, 200]))
# 	p_theta_z batch shape (B,Dz): torch.Size([1, 4])
# 	p_theta_z event shape (N): torch.Size([200])

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 20px; color: black; font-weight: bold;">
# Computing the loss
# </div>
#
# The loss is
#
# \begin{align}
# \mathcal{L}(\theta_x, \theta_z, \phi, x_{1:N}) &= \sum_{i=1}^N \mathbb{E}_{z_i \sim q_{\phi}(z_i \vert x_{1:N})} \log{p_{\theta_x}(x_i \vert z_i)} - \sum_{l=1}^{D_z} \mathbb{KL} ( q_{\phi}(z_l \vert x_{1:N}) \vert\vert p_{\theta_z}(z_{l,1:N}))
# \end{align}
#
# Where the expectation $\mathbb{E}_{z_i \sim q_{\phi}(z_i \vert x_{1:N})}$ is approximated by averaging $K$ $p_{\theta_x}$ samples, and the $\mathbb{KL}$'s are computed analytically for two Gaussians.
#
# Remember that $p_{\theta_x}$ is a tf.distributions.MVN object of batch_shape $(K,B,N)$ and event_shape $D_x$. We adapt the original data $x$ of shape $(B,N,Dx)$ accordingly.

# %%
x_rec = torch.unsqueeze(x, 0).repeat(K,1,1,1)  # (K,B,N,Dx)
print(f"x_rec shape (K,B,N,Dx): {x_rec.shape}")  # (K, B, N, Dx)
# Out:
# x_rec shape (K,B,N,Dx): torch.Size([30, 1, 200, 8])

# %%
reconstruction_loss = -p_theta_x.log_prob(x_rec)  # (K,B,N)
print(f"Reconstruction loss tensor shape (K,B,N): {reconstruction_loss.shape}")

rec_loss = reconstruction_loss.sum(-1)  # Sum over the length N
# rec_loss = rec_loss.mean()  # Average over the batch size B and the K samples
rec_loss = rec_loss.sum()  # Sum over the batch size B and the K samples

kl = torch.distributions.kl_divergence(q_phi_c, p_theta_z)  # (B, Dz)
print(f"KL divergence tensor shape (B,Dz): {kl.shape}")  # (B, Dz)

kl_loss = kl.sum(-1)  # Sum over the dimensions Dz
# kl_loss = kl_loss.mean()  # Average over the batch size B
kl_loss = kl_loss.sum()  # Sum over the batch size B

print()
print(f"Summing the reconstruction loss over N and averaging over B and K")
print(f"Summing the KL divergence over Dz and averaging over B")
print(f"KL = {kl_loss.item():.4e}")
print(f"reconstruction = {rec_loss.item():.4e}")
print(f"total loss = {(kl_loss + rec_loss).item():.4e}")
# Out:
# Reconstruction loss tensor shape (K,B,N): torch.Size([30, 1, 200])
# KL divergence tensor shape (B,Dz): torch.Size([1, 4])
#
# Summing the reconstruction loss over N and averaging over B and K
# Summing the KL divergence over Dz and averaging over B
# KL = 3.3305e+14
# reconstruction = 7.5454e+04
# total loss = 3.3305e+14

# %% [markdown]
# Then we can backpropagate

# %%
loss = kl_loss + rec_loss  # Total loss
loss.backward()  # Backpropagation
print(f"Loss backpropagated. Gradients computed.")
# Out:
# Loss backpropagated. Gradients computed.

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# Data
# </div>
#
# We will create $Dx$ time series over $N$ points

# %%
# Dimensions
Dx = 4
Dz = 2

# parameters
N = 100
B = 1

# %%
t = torch.linspace(0, 1, N).to(device)
xs = [ t * torch.sin(2 * torch.pi * t * (4*(i+1))) for i in range(Dx) ] # (Dx,N)
x = torch.stack(xs, dim=-1)  # (N, Dx)
x = torch.unsqueeze(x,0)
x = x.repeat(B, 1, 1)  # (B, N, Dx)

t = t.unsqueeze(0).repeat(B, 1)  # (B, N)

print(f"t shape: {t.shape}")  # (B, N)
print(f"Input shape: {x.shape}")  # (B, N, Dx)

if Dx > 1:
    fig, axs = plt.subplots(Dx, 1, figsize=(10, 2 * Dx))
    for i in range(Dx):
        axs[i].plot(t[0].cpu().numpy(), x[0, :, i].cpu().numpy(), label=f"x_{i+1}")
        axs[i].set_title(f"Input x_{i+1}")
        axs[i].legend()
        axs[i].grid()
else:
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(t[0].cpu().numpy(), x[0, :, 0].cpu().numpy(), label="x_1")
    ax.set_title("Input x_1")
    ax.legend()
    ax.grid()
# Out:
# t shape: torch.Size([1, 100])
# Input shape: torch.Size([1, 100, 4])

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# Training
# </div>

# %% [markdown]
# Torch Encode and Decoder compoenents

# %%
encoder_mean = EncoderMean(        
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=4,
    inter_dim=32,
    activation=nn.Tanh,
).to(device)

print(encoder_mean)

encoder_precision = EncoderPrecision(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=4,
    inter_dim=32,
    activation=nn.Tanh, 
    epsilon=1e-6
).to(device)

print(encoder_precision)

encoder_covariance = EncoderCovariance(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=8,
    inter_dim=64,
    activation=nn.Tanh,
    epsilon=1e-6
).to(device)

print(encoder_covariance)

decoder_mean = DecoderMean(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=8,
    inter_dim=64,
    activation=nn.Tanh,
).to(device)

print(decoder_mean)

# decoder_covariance = DecoderCovariance(
#     x_dimension=Dx,
#     z_dimension=Dz,
#     n_layers=8,
#     inter_dim=64,
#     activation=nn.Tanh,
#     epsilon=1e-6,
# ).to(device)

decoder_covariance = DecoderCovarianceDiagonal(
    x_dimension=Dx,
    z_dimension=Dz,
    n_layers=8,
    inter_dim=64,
    activation=nn.Tanh,
    epsilon=1e-6,
).to(device)

print(decoder_covariance)
# Out:
# EncoderMean, x_dimension=4, z_dimension=2, n_layers=4, inter_dim=32, activation=Tanh
# EncoderPrecision(x_dimension=4, z_dimension=2, n_layers=4, inter_dim=32, activation=Tanh, epsilon=1e-06)
# EncoderCovariance : (x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh, epsilon (to ensure PSD)=1.000e-06)
# DecoderMean x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh
# DecoderCovarianceDiagonal : (x_dimension=4, z_dimension=2, n_layers=8, inter_dim=64, activation=Tanh, epsilon (to ensure PSD)=1.000e-06)

# %% [markdown]
# Gaussian Process priors

# %%
kernel_matrix, L_matrix, mean, kernels_list, mean_functions_list = compute_gp_priors_kernel(t, Dz, verbose=True)
# Out:
# Computing Gaussian Process prior for z component 1 / 2...
# Kernel 0 is : GaussianKernel(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 0 is : GPNullMean
# mu_z 0 shape (B,N): torch.Size([1, 100])
# Kernel matrix 0 shape (B,N,N): torch.Size([1, 100, 100])
#
# Computing Gaussian Process prior for z component 2 / 2...
# Kernel 1 is : GaussianKernel(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 1 is : GPNullMean
# mu_z 1 shape (B,N): torch.Size([1, 100])
# Kernel matrix 1 shape (B,N,N): torch.Size([1, 100, 100])
#
# Full Kernel matrix shape after stack and transpose (B,Dz,N,N): torch.Size([1, 2, 100, 100])
# Full L matrix shape after stack and transpose (B,Dz,N,N): torch.Size([1, 2, 100, 100])
# Mean shape after stack and transpose (B,Dz,N): torch.Size([1, 2, 100])

# %%
def compute_p_theta_z(t, kernels_list, mean_functions_list, verbose=False):
    """ Compute the Gaussian Process prior p_theta_z for each kernel and mean function.
    This function is used at each training step as the parameters of the kernels and mean functions are updated.
    """
    
    kernel_matrices = []
    L_matrices = []
    means = []

    for i in range(Dz):
        
        mu_z_i = mean_functions_list[i](t)  # (B, N)
        kernel_matrix_i, L_i = kernels_list[i](t, t)

        kernel_matrices.append(kernel_matrix_i)  # (B, N, N)
        L_matrices.append(L_i)  # (B, N, N) or None
        means.append(mu_z_i)  # (B, N)
        
        if verbose:
            print()
            print(f"Computing Gaussian Process prior for z component {i+1} / {Dz}...")
            print(f"Kernel {i} is : {kernels_list[i]}")
            print(f"Mean function {i} is : {mean_functions_list[i]}")
            print(f"mu_z {i} shape (B,N): {mu_z_i.shape}")  # (B, N)
            print(f"Kernel matrix {i} shape (B,N,N): {kernel_matrix_i.shape}")  # (B, N, N)
        
    kernel_matrix = torch.stack(kernel_matrices, dim=0)  # (Dz, B, N, N)
    kernel_matrix = kernel_matrix.transpose(0, 1) # (B, Dz, N, N)
    L_matrix = torch.stack(L_matrices, dim=0) if L_matrices[0] is not None else None  # (Dz, B, N, N) or None
    L_matrix = L_matrix.transpose(0, 1) if L_matrix is not None else None  # (B, Dz, N, N)
    mean = torch.stack(means, dim=0)  # (Dz, B, N)
    mean = mean.transpose(0, 1)  # (B, Dz, N)
    
    if verbose:
        print()
        print(f"Kernel matrix shape after stack and transpose: {kernel_matrix.shape}")  # (Dz, B, N, N)
        print(f"L matrix shape after stack transpose: {L_matrix.shape if L_matrix is not None else 'None'}")  # (B, Dz, N, N) or None
        print(f"Mean shape after transpose: {mean.shape}")  # (B, Dz, N)

    p_theta_z = torch.distributions.MultivariateNormal(
        loc=mean,  # (B, Dz, N)
        scale_tril=L_matrix,  # (B, Dz, N, N)
    )
    if verbose:
        print()
        print(f"p_theta_z: {p_theta_z}")
        print(f"\tp_theta_z batch shape: {p_theta_z.batch_shape}")  # (B, Dz)
        print(f"\tp_theta_z event shape: {p_theta_z.event_shape}")  # (N)

    return p_theta_z, kernel_matrix, L_matrix, mean

# %% [markdown]
# Training setup

# %%
kernel_parameters = [ param for kernel in kernels_list for param in kernel.parameters() ]
mean_functions_parameters = [ param for mean_function in mean_functions_list for param in mean_function.parameters() ]

optimizer = torch.optim.Adam(
    list(encoder_mean.parameters()) + list(encoder_precision.parameters()) + list(encoder_covariance.parameters()) +
    list(decoder_mean.parameters()) + list(decoder_covariance.parameters()) +
    kernel_parameters +
    mean_functions_parameters,
    lr = 5e-4
)

# %%
losses = []
kls = []
reconstruction_losses = []

# dictionnary to store the parameters of the prior Gaussian Processes
mean_parameters_values = {}  # to store mean parameters if any
for i in range(Dz):
    mean_parameters_values[f"mean_function_{i}"] = {}
    mean_function = mean_functions_list[i]
    for name, param in mean_function.named_parameters():
        mean_parameters_values[f"mean_function_{i}"][name] = []
    
kernels_parameters_values = {}  # to store kernel parameters if any
for i in range(Dz):
    kernels_parameters_values[f"kernel_{i}"] = {}
    kernel = kernels_list[i]
    for name, param in kernel.named_parameters():
        kernels_parameters_values[f"kernel_{i}"][name] = []

# %%
if len(kernel_parameters) == 0 and len(mean_functions_parameters) == 0:
    learnable_kernel = False
    print("Prior kernels are fixed (no learnable parameters).")
else:
    learnable_kernel = True
    if len(kernel_parameters) > 0:
        print("Prior kernels are learnable (has learnable parameters).")
        print(kernels_parameters_values)
    if len(mean_functions_parameters) > 0:
        print("Prior mean functions are learnable (has learnable parameters).")
        print(mean_parameters_values)
# Out:
# Prior kernels are learnable (has learnable parameters).
# {'kernel_0': {'lengthscale': [], 'sigma': []}, 'kernel_1': {'lengthscale': [], 'sigma': []}}

# %%
# initialize prior Gaussian Processes
# can be done once before the training loop if there are no learnable parameters

p_theta_z, kernel_matrix, L_matrix, mean = compute_p_theta_z(t, kernels_list, mean_functions_list, verbose=True)
# Out:
# Computing Gaussian Process prior for z component 1 / 2...
# Kernel 0 is : GaussianKernel(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 0 is : GPNullMean
# mu_z 0 shape (B,N): torch.Size([1, 100])
# Kernel matrix 0 shape (B,N,N): torch.Size([1, 100, 100])
#
# Computing Gaussian Process prior for z component 2 / 2...
# Kernel 1 is : GaussianKernel(lengthscale=1.000e-01, variance (sigma**2)=1.000e+00, sigma=1.000e+00, epsilon=1.000e-12)
# Mean function 1 is : GPNullMean
# mu_z 1 shape (B,N): torch.Size([1, 100])
# Kernel matrix 1 shape (B,N,N): torch.Size([1, 100, 100])
#
# Kernel matrix shape after stack and transpose: torch.Size([1, 2, 100, 100])
# L matrix shape after stack transpose: torch.Size([1, 2, 100, 100])
# Mean shape after transpose: torch.Size([1, 2, 100])
#
# p_theta_z: MultivariateNormal(loc: torch.Size([1, 2, 100]), scale_tril: torch.Size([1, 2, 100, 100]))
# 	p_theta_z batch shape: torch.Size([1, 2])
# 	p_theta_z event shape: torch.Size([100])

# %%
N_EPOCHS = int(50000)
K = 10

N = t.size(-1)  # number of time points
epsilon = 1e-12
tolerance = epsilon * torch.eye(N).to(device)

x_rec = torch.unsqueeze(x,0).repeat(K,1,1,1)

print(f"x_rec shape (K,B,N,Dx) for reconstruction loss computation : {x_rec.shape}")  # (K, B, N, Dx)
# Out:
# x_rec shape (K,B,N,Dx) for reconstruction loss computation : torch.Size([10, 1, 100, 4])

# %%
# Early stopping class to prevent overfitting

class EarlyStoppingCallback:
    def __init__(self, patience=1, min_delta=0):
        # how many epochs do we accept with validation loss non decreasing
        self.patience = patience
        # tolerance for non decrease
        self.min_delta = min_delta
        # how many epochs without validation loss decrease
        self.counter = 0
        # minimum validation loss to beat
        self.min_validation_loss = float('inf')
        self.status = False

    def early_stop(self, validation_loss):
        # is the last validation loss better than the current minimum ?
        # status = True means stop training
        if validation_loss < self.min_validation_loss:
            # yes : update minimum value and reset counter
            self.min_validation_loss = validation_loss
            self.counter = 0
            self.status = False
            # no : are we within tolerance ?
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            # no : increase counter (losing patience)
            self.counter += 1
            # have we lost patience ?
            if self.counter >= self.patience:
                # yes
                self.status = True
            else:
                # no
                self.status = False

        return self.status, self.counter
    
early_stopping = EarlyStoppingCallback(patience=200, min_delta=1e+2)

# %%
print(f"Training for {N_EPOCHS} epochs")
print(f"Dx = {Dx}, Dz = {Dz}, N = {N}, B = {B}, K = {K}")

for epoch in range(N_EPOCHS):
       
    # PRIOR pass --------------------------------------------------------------
    # if the kernel is learnable, we need to recompute the prior mean and kernel at each epoch
    if learnable_kernel:
        p_theta_z, kernel_matrix, L_matrix, mean = compute_p_theta_z(t, kernels_list, mean_functions_list, verbose=False)

    # ENCODER pass ------------------------------------------------------------
    # encode mean
    mu_phi = encoder_mean(x)  # (B, Dz, N)
    # encode precision or covariance
    # --- choice 1 : with precision matrix
    # _, _, precision_phi = encoder_precision(x)  # (B, Dz, N, N)
    # precision_phi = precision_phi  # (B, Dz, N, N)
    # q_phi = torch.distributions.MultivariateNormal(
    #     loc=mu_phi,  # (B, Dz, N)
    #     precision_matrix=precision_phi,  # (B, Dz, N, N)
    # )
    # -- choice 2 : with covariance matrix
    L_phi, covariance_phi = encoder_covariance(x)  # (B, Dz, N, N)
    covariance_phi = covariance_phi.squeeze(0)  # (B, Dz, N, N)
    # L_phi = L_phi.squeeze(0)  # (Dz, N, N)

    q_phi = torch.distributions.MultivariateNormal(
        loc=mu_phi,  # (B, Dz, N)
        scale_tril=L_phi,  # (B, Dz, N, N)
    )

    # DECODER pass ------------------------------------------------------------    
    # sample z
    z_sampled = q_phi.rsample((K,)) # (K, B, Dz, N)
    z_sampled_p = z_sampled.transpose(-1, -2)  # (K, B, N, Dz)
    
    # decode
    mu_x = decoder_mean(z_sampled_p)  # (K,B,N,Dx)
    L_x, covar_x = decoder_covariance(z_sampled_p) # + tolerance # (K,B,N,Dx,Dx)

    p_theta_x = torch.distributions.MultivariateNormal(
        loc=mu_x,
        scale_tril=L_x
    ) # batch_shape=(K,B,Dx), event_shape=(N,)
    # print(f"p_theta_x: {p_theta_x}")
    # print(f"\tp_theta_x batch shape: {p_theta_x.batch_shape}")  # (K,B,N)
    # print(f"\tp_theta_x event shape: {p_theta_x.event_shape}")  # (Dx,)
       
    # LOSS computation --------------------------------------------------------
    # compute loss
    kl = torch.distributions.kl_divergence(q_phi, p_theta_z).sum(-1).mean()  # (B,Dz,N) => scalar
    reconstruction_loss = p_theta_x.log_prob(x_rec).sum(-1).mean() # (K,B,N) => scalar
    # kl = torch.distributions.kl_divergence(q_phi, p_theta_z).sum(-1).sum()  # (B,Dz,N) => scalar
    # reconstruction_loss = p_theta_x.log_prob(x_rec).sum(-1).sum() # (K,B,N) => scalar
    # reconstruction_loss = p_theta_x.log_prob(x_rec).mean()
    loss = -reconstruction_loss + kl
        
    # optimization step
    optimizer.zero_grad()
    loss.backward()  
    optimizer.step()
    
    # log losses
    losses.append(loss.item())
    kls.append(kl.mean().item())
    reconstruction_losses.append(-reconstruction_loss.mean().item())
    
    # record parameters
    for i in range(Dz):
        # record mean function parameters
        mean_function = mean_functions_list[i]
        for name, param in mean_function.named_parameters():
            mean_parameters_values[f"mean_function_{i}"][name].append(param.item())
        # record kernel parameters
        kernel = kernels_list[i]
        for name, param in kernel.named_parameters():
            kernels_parameters_values[f"kernel_{i}"][name].append(param.item())
            
    # Early stopping check
    if early_stopping:
        stop, counter = early_stopping.early_stop(loss)
        if stop:
            msg = f'Early stopping at epoch {epoch+1} with counter {counter}'
        else:
            msg = f'Early stopping counter {counter} / {early_stopping.patience}'
        
    # print progress
    if (epoch + 1) % 10 == 0 or epoch == 0:
        print(f"Epoch [{epoch + 1:>6}/{N_EPOCHS:>6}], Loss: {loss.item():.4e}, "
              f"KL: {kl.mean().item():.4e}, "
              f"Reconstruction Loss (avg over {K} sample(s)): {-reconstruction_loss.mean().item():.4e}, "
              f"{msg}")
        
    if stop:
        break
# Out:
# Training for 50000 epochs
# Dx = 4, Dz = 2, N = 100, B = 1, K = 10
# Epoch [     1/ 50000], Loss: 5.8404e+13, KL: 5.8404e+13, Reconstruction Loss (avg over 10 sample(s)): 4.0603e+02, Early stopping counter 0 / 200
# Epoch [    10/ 50000], Loss: 3.2895e+13, KL: 3.2895e+13, Reconstruction Loss (avg over 10 sample(s)): 3.4886e+02, Early stopping counter 0 / 200
# Epoch [    20/ 50000], Loss: 6.7131e+12, KL: 6.7131e+12, Reconstruction Loss (avg over 10 sample(s)): 2.5950e+02, Early stopping counter 0 / 200
# Epoch [    30/ 50000], Loss: 1.8627e+12, KL: 1.8627e+12, Reconstruction Loss (avg over 10 sample(s)): 2.1110e+02, Early stopping counter 0 / 200
# Epoch [    40/ 50000], Loss: 8.1227e+11, KL: 8.1227e+11, Reconstruction Loss (avg over 10 sample(s)): 2.0035e+02, Early stopping counter 0 / 200
# Epoch [    50/ 50000], Loss: 4.6095e+11, KL: 4.6095e+11, Reconstruction Loss (avg over 10 sample(s)): 2.0268e+02, Early stopping counter 0 / 200
# Epoch [    60/ 50000], Loss: 3.4209e+11, KL: 3.4209e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9900e+02, Early stopping counter 0 / 200
# Epoch [    70/ 50000], Loss: 2.8204e+11, KL: 2.8204e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9794e+02, Early stopping counter 0 / 200
# Epoch [    80/ 50000], Loss: 2.4158e+11, KL: 2.4158e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9772e+02, Early stopping counter 0 / 200
# Epoch [    90/ 50000], Loss: 2.1232e+11, KL: 2.1232e+11, Reconstruction Loss (avg over 10 sample(s)): 2.0059e+02, Early stopping counter 0 / 200
# Epoch [   100/ 50000], Loss: 1.8984e+11, KL: 1.8984e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9409e+02, Early stopping counter 0 / 200
# Epoch [   110/ 50000], Loss: 1.7127e+11, KL: 1.7127e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9862e+02, Early stopping counter 0 / 200
# Epoch [   120/ 50000], Loss: 1.5544e+11, KL: 1.5544e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9966e+02, Early stopping counter 0 / 200
# Epoch [   130/ 50000], Loss: 1.4185e+11, KL: 1.4185e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9421e+02, Early stopping counter 0 / 200
# Epoch [   140/ 50000], Loss: 1.3008e+11, KL: 1.3008e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9761e+02, Early stopping counter 0 / 200
# Epoch [   150/ 50000], Loss: 1.1977e+11, KL: 1.1977e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9662e+02, Early stopping counter 0 / 200
# Epoch [   160/ 50000], Loss: 1.1067e+11, KL: 1.1067e+11, Reconstruction Loss (avg over 10 sample(s)): 1.9097e+02, Early stopping counter 0 / 200
# Epoch [   170/ 50000], Loss: 1.0263e+11, KL: 1.0263e+11, Reconstruction Loss (avg over 10 sample(s)): 1.8907e+02, Early stopping counter 0 / 200
# Epoch [   180/ 50000], Loss: 9.5470e+10, KL: 9.5470e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8840e+02, Early stopping counter 0 / 200
# Epoch [   190/ 50000], Loss: 8.9068e+10, KL: 8.9068e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9666e+02, Early stopping counter 0 / 200
# Epoch [   200/ 50000], Loss: 8.3328e+10, KL: 8.3328e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9532e+02, Early stopping counter 0 / 200
# Epoch [   210/ 50000], Loss: 7.8153e+10, KL: 7.8153e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8220e+02, Early stopping counter 0 / 200
# Epoch [   220/ 50000], Loss: 7.3466e+10, KL: 7.3466e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9573e+02, Early stopping counter 0 / 200
# Epoch [   230/ 50000], Loss: 6.9216e+10, KL: 6.9216e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8642e+02, Early stopping counter 0 / 200
# Epoch [   240/ 50000], Loss: 6.5340e+10, KL: 6.5340e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9746e+02, Early stopping counter 0 / 200
# Epoch [   250/ 50000], Loss: 6.1801e+10, KL: 6.1801e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8405e+02, Early stopping counter 0 / 200
# Epoch [   260/ 50000], Loss: 5.8556e+10, KL: 5.8556e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7783e+02, Early stopping counter 0 / 200
# Epoch [   270/ 50000], Loss: 5.5575e+10, KL: 5.5575e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8250e+02, Early stopping counter 0 / 200
# Epoch [   280/ 50000], Loss: 5.2831e+10, KL: 5.2831e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8815e+02, Early stopping counter 0 / 200
# Epoch [   290/ 50000], Loss: 5.0295e+10, KL: 5.0295e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9300e+02, Early stopping counter 0 / 200
# Epoch [   300/ 50000], Loss: 4.7941e+10, KL: 4.7941e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9091e+02, Early stopping counter 0 / 200
# Epoch [   310/ 50000], Loss: 4.5766e+10, KL: 4.5766e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8258e+02, Early stopping counter 0 / 200
# Epoch [   320/ 50000], Loss: 4.3737e+10, KL: 4.3737e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9990e+02, Early stopping counter 0 / 200
# Epoch [   330/ 50000], Loss: 4.1854e+10, KL: 4.1854e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9639e+02, Early stopping counter 0 / 200
# Epoch [   340/ 50000], Loss: 4.0091e+10, KL: 4.0091e+10, Reconstruction Loss (avg over 10 sample(s)): 2.0022e+02, Early stopping counter 0 / 200
# Epoch [   350/ 50000], Loss: 3.8448e+10, KL: 3.8448e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8046e+02, Early stopping counter 0 / 200
# Epoch [   360/ 50000], Loss: 3.6907e+10, KL: 3.6907e+10, Reconstruction Loss (avg over 10 sample(s)): 2.0287e+02, Early stopping counter 0 / 200
# Epoch [   370/ 50000], Loss: 3.5456e+10, KL: 3.5456e+10, Reconstruction Loss (avg over 10 sample(s)): 2.0144e+02, Early stopping counter 0 / 200
# Epoch [   380/ 50000], Loss: 3.4100e+10, KL: 3.4100e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9053e+02, Early stopping counter 0 / 200
# Epoch [   390/ 50000], Loss: 3.2821e+10, KL: 3.2821e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8538e+02, Early stopping counter 0 / 200
# Epoch [   400/ 50000], Loss: 3.1617e+10, KL: 3.1617e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8917e+02, Early stopping counter 0 / 200
# Epoch [   410/ 50000], Loss: 3.0478e+10, KL: 3.0478e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8000e+02, Early stopping counter 0 / 200
# Epoch [   420/ 50000], Loss: 2.9406e+10, KL: 2.9406e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9198e+02, Early stopping counter 0 / 200
# Epoch [   430/ 50000], Loss: 2.8388e+10, KL: 2.8388e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8359e+02, Early stopping counter 0 / 200
# Epoch [   440/ 50000], Loss: 2.7424e+10, KL: 2.7424e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7367e+02, Early stopping counter 0 / 200
# Epoch [   450/ 50000], Loss: 2.6514e+10, KL: 2.6514e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9770e+02, Early stopping counter 0 / 200
# Epoch [   460/ 50000], Loss: 2.5648e+10, KL: 2.5648e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8983e+02, Early stopping counter 0 / 200
# Epoch [   470/ 50000], Loss: 2.4823e+10, KL: 2.4823e+10, Reconstruction Loss (avg over 10 sample(s)): 2.1665e+02, Early stopping counter 0 / 200
# Epoch [   480/ 50000], Loss: 2.4040e+10, KL: 2.4040e+10, Reconstruction Loss (avg over 10 sample(s)): 2.2210e+02, Early stopping counter 0 / 200
# Epoch [   490/ 50000], Loss: 2.3297e+10, KL: 2.3297e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9304e+02, Early stopping counter 0 / 200
# Epoch [   500/ 50000], Loss: 2.2586e+10, KL: 2.2586e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8497e+02, Early stopping counter 0 / 200
# Epoch [   510/ 50000], Loss: 2.1910e+10, KL: 2.1910e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9239e+02, Early stopping counter 0 / 200
# Epoch [   520/ 50000], Loss: 2.1262e+10, KL: 2.1262e+10, Reconstruction Loss (avg over 10 sample(s)): 2.0075e+02, Early stopping counter 0 / 200
# Epoch [   530/ 50000], Loss: 2.0645e+10, KL: 2.0645e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8058e+02, Early stopping counter 0 / 200
# Epoch [   540/ 50000], Loss: 2.0054e+10, KL: 2.0054e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8823e+02, Early stopping counter 0 / 200
# Epoch [   550/ 50000], Loss: 1.9489e+10, KL: 1.9489e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7851e+02, Early stopping counter 0 / 200
# Epoch [   560/ 50000], Loss: 1.8949e+10, KL: 1.8949e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9594e+02, Early stopping counter 0 / 200
# Epoch [   570/ 50000], Loss: 1.8431e+10, KL: 1.8431e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7216e+02, Early stopping counter 0 / 200
# Epoch [   580/ 50000], Loss: 1.7936e+10, KL: 1.7936e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8270e+02, Early stopping counter 0 / 200
# Epoch [   590/ 50000], Loss: 1.7460e+10, KL: 1.7460e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8908e+02, Early stopping counter 0 / 200
# Epoch [   600/ 50000], Loss: 1.7001e+10, KL: 1.7001e+10, Reconstruction Loss (avg over 10 sample(s)): 2.1479e+02, Early stopping counter 0 / 200
# Epoch [   610/ 50000], Loss: 1.6564e+10, KL: 1.6564e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9283e+02, Early stopping counter 0 / 200
# Epoch [   620/ 50000], Loss: 1.6142e+10, KL: 1.6142e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8902e+02, Early stopping counter 0 / 200
# Epoch [   630/ 50000], Loss: 1.5735e+10, KL: 1.5735e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8810e+02, Early stopping counter 0 / 200
# Epoch [   640/ 50000], Loss: 1.5345e+10, KL: 1.5345e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7809e+02, Early stopping counter 0 / 200
# Epoch [   650/ 50000], Loss: 1.4972e+10, KL: 1.4972e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9147e+02, Early stopping counter 0 / 200
# Epoch [   660/ 50000], Loss: 1.4607e+10, KL: 1.4607e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9017e+02, Early stopping counter 0 / 200
# Epoch [   670/ 50000], Loss: 1.4260e+10, KL: 1.4260e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7519e+02, Early stopping counter 0 / 200
# Epoch [   680/ 50000], Loss: 1.3925e+10, KL: 1.3925e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8453e+02, Early stopping counter 0 / 200
# Epoch [   690/ 50000], Loss: 1.3600e+10, KL: 1.3600e+10, Reconstruction Loss (avg over 10 sample(s)): 2.0419e+02, Early stopping counter 0 / 200
# Epoch [   700/ 50000], Loss: 1.3288e+10, KL: 1.3288e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7494e+02, Early stopping counter 0 / 200
# Epoch [   710/ 50000], Loss: 1.2987e+10, KL: 1.2987e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7644e+02, Early stopping counter 0 / 200
# Epoch [   720/ 50000], Loss: 1.2696e+10, KL: 1.2696e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8693e+02, Early stopping counter 0 / 200
# Epoch [   730/ 50000], Loss: 1.2414e+10, KL: 1.2414e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7757e+02, Early stopping counter 0 / 200
# Epoch [   740/ 50000], Loss: 1.2142e+10, KL: 1.2142e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9644e+02, Early stopping counter 0 / 200
# Epoch [   750/ 50000], Loss: 1.1878e+10, KL: 1.1878e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8486e+02, Early stopping counter 0 / 200
# Epoch [   760/ 50000], Loss: 1.1625e+10, KL: 1.1625e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9744e+02, Early stopping counter 0 / 200
# Epoch [   770/ 50000], Loss: 1.1380e+10, KL: 1.1380e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9484e+02, Early stopping counter 0 / 200
# Epoch [   780/ 50000], Loss: 1.1141e+10, KL: 1.1141e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9126e+02, Early stopping counter 0 / 200
# Epoch [   790/ 50000], Loss: 1.0910e+10, KL: 1.0910e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8385e+02, Early stopping counter 0 / 200
# Epoch [   800/ 50000], Loss: 1.0687e+10, KL: 1.0687e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9104e+02, Early stopping counter 0 / 200
# Epoch [   810/ 50000], Loss: 1.0470e+10, KL: 1.0470e+10, Reconstruction Loss (avg over 10 sample(s)): 1.9497e+02, Early stopping counter 0 / 200
# Epoch [   820/ 50000], Loss: 1.0262e+10, KL: 1.0262e+10, Reconstruction Loss (avg over 10 sample(s)): 1.7233e+02, Early stopping counter 0 / 200
# Epoch [   830/ 50000], Loss: 1.0058e+10, KL: 1.0058e+10, Reconstruction Loss (avg over 10 sample(s)): 1.8144e+02, Early stopping counter 0 / 200
# Epoch [   840/ 50000], Loss: 9.8599e+09, KL: 9.8599e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7834e+02, Early stopping counter 0 / 200
# Epoch [   850/ 50000], Loss: 9.6695e+09, KL: 9.6695e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9009e+02, Early stopping counter 0 / 200
# Epoch [   860/ 50000], Loss: 9.4834e+09, KL: 9.4834e+09, Reconstruction Loss (avg over 10 sample(s)): 2.0025e+02, Early stopping counter 0 / 200
# Epoch [   870/ 50000], Loss: 9.3024e+09, KL: 9.3024e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7562e+02, Early stopping counter 0 / 200
# Epoch [   880/ 50000], Loss: 9.1275e+09, KL: 9.1275e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8047e+02, Early stopping counter 0 / 200
# Epoch [   890/ 50000], Loss: 8.9576e+09, KL: 8.9576e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8413e+02, Early stopping counter 0 / 200
# Epoch [   900/ 50000], Loss: 8.7920e+09, KL: 8.7920e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8877e+02, Early stopping counter 0 / 200
# Epoch [   910/ 50000], Loss: 8.6308e+09, KL: 8.6308e+09, Reconstruction Loss (avg over 10 sample(s)): 2.0019e+02, Early stopping counter 0 / 200
# Epoch [   920/ 50000], Loss: 8.4747e+09, KL: 8.4747e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9652e+02, Early stopping counter 0 / 200
# Epoch [   930/ 50000], Loss: 8.3223e+09, KL: 8.3223e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7386e+02, Early stopping counter 0 / 200
# Epoch [   940/ 50000], Loss: 8.1742e+09, KL: 8.1742e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8232e+02, Early stopping counter 0 / 200
# Epoch [   950/ 50000], Loss: 8.0307e+09, KL: 8.0307e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8984e+02, Early stopping counter 0 / 200
# Epoch [   960/ 50000], Loss: 7.8903e+09, KL: 7.8903e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7290e+02, Early stopping counter 0 / 200
# Epoch [   970/ 50000], Loss: 7.7537e+09, KL: 7.7537e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8773e+02, Early stopping counter 0 / 200
# Epoch [   980/ 50000], Loss: 7.6210e+09, KL: 7.6210e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7919e+02, Early stopping counter 0 / 200
# Epoch [   990/ 50000], Loss: 7.4911e+09, KL: 7.4911e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8167e+02, Early stopping counter 0 / 200
# Epoch [  1000/ 50000], Loss: 7.3651e+09, KL: 7.3651e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8239e+02, Early stopping counter 0 / 200
# Epoch [  1010/ 50000], Loss: 7.2422e+09, KL: 7.2422e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9059e+02, Early stopping counter 0 / 200
# Epoch [  1020/ 50000], Loss: 7.1229e+09, KL: 7.1229e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8641e+02, Early stopping counter 0 / 200
# Epoch [  1030/ 50000], Loss: 7.0058e+09, KL: 7.0058e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6969e+02, Early stopping counter 0 / 200
# Epoch [  1040/ 50000], Loss: 6.8920e+09, KL: 6.8920e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8446e+02, Early stopping counter 0 / 200
# Epoch [  1050/ 50000], Loss: 6.7796e+09, KL: 6.7796e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6271e+02, Early stopping counter 0 / 200
# Epoch [  1060/ 50000], Loss: 6.6713e+09, KL: 6.6713e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9988e+02, Early stopping counter 0 / 200
# Epoch [  1070/ 50000], Loss: 6.5658e+09, KL: 6.5658e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9030e+02, Early stopping counter 0 / 200
# Epoch [  1080/ 50000], Loss: 6.4622e+09, KL: 6.4622e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7794e+02, Early stopping counter 0 / 200
# Epoch [  1090/ 50000], Loss: 6.3609e+09, KL: 6.3609e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8896e+02, Early stopping counter 0 / 200
# Epoch [  1100/ 50000], Loss: 6.2631e+09, KL: 6.2631e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7347e+02, Early stopping counter 0 / 200
# Epoch [  1110/ 50000], Loss: 6.1657e+09, KL: 6.1657e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7921e+02, Early stopping counter 0 / 200
# Epoch [  1120/ 50000], Loss: 6.0721e+09, KL: 6.0721e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8023e+02, Early stopping counter 0 / 200
# Epoch [  1130/ 50000], Loss: 5.9796e+09, KL: 5.9796e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8276e+02, Early stopping counter 0 / 200
# Epoch [  1140/ 50000], Loss: 5.8897e+09, KL: 5.8897e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6634e+02, Early stopping counter 0 / 200
# Epoch [  1150/ 50000], Loss: 5.8025e+09, KL: 5.8025e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7864e+02, Early stopping counter 0 / 200
# Epoch [  1160/ 50000], Loss: 5.7160e+09, KL: 5.7160e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6854e+02, Early stopping counter 0 / 200
# Epoch [  1170/ 50000], Loss: 5.6316e+09, KL: 5.6316e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7524e+02, Early stopping counter 0 / 200
# Epoch [  1180/ 50000], Loss: 5.5496e+09, KL: 5.5496e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8057e+02, Early stopping counter 0 / 200
# Epoch [  1190/ 50000], Loss: 5.4694e+09, KL: 5.4694e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9218e+02, Early stopping counter 0 / 200
# Epoch [  1200/ 50000], Loss: 5.3899e+09, KL: 5.3899e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6370e+02, Early stopping counter 0 / 200
# Epoch [  1210/ 50000], Loss: 5.3136e+09, KL: 5.3136e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7222e+02, Early stopping counter 0 / 200
# Epoch [  1220/ 50000], Loss: 5.2376e+09, KL: 5.2376e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7357e+02, Early stopping counter 0 / 200
# Epoch [  1230/ 50000], Loss: 5.1638e+09, KL: 5.1638e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6502e+02, Early stopping counter 0 / 200
# Epoch [  1240/ 50000], Loss: 5.0916e+09, KL: 5.0916e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8860e+02, Early stopping counter 0 / 200
# Epoch [  1250/ 50000], Loss: 5.0209e+09, KL: 5.0209e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7631e+02, Early stopping counter 0 / 200
# Epoch [  1260/ 50000], Loss: 4.9515e+09, KL: 4.9515e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7493e+02, Early stopping counter 0 / 200
# Epoch [  1270/ 50000], Loss: 4.8833e+09, KL: 4.8833e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8838e+02, Early stopping counter 0 / 200
# Epoch [  1280/ 50000], Loss: 4.8168e+09, KL: 4.8168e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7890e+02, Early stopping counter 0 / 200
# Epoch [  1290/ 50000], Loss: 4.7518e+09, KL: 4.7518e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7946e+02, Early stopping counter 0 / 200
# Epoch [  1300/ 50000], Loss: 4.6872e+09, KL: 4.6872e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7159e+02, Early stopping counter 0 / 200
# Epoch [  1310/ 50000], Loss: 4.6244e+09, KL: 4.6244e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7604e+02, Early stopping counter 0 / 200
# Epoch [  1320/ 50000], Loss: 4.5633e+09, KL: 4.5633e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8500e+02, Early stopping counter 0 / 200
# Epoch [  1330/ 50000], Loss: 4.5031e+09, KL: 4.5031e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8160e+02, Early stopping counter 0 / 200
# Epoch [  1340/ 50000], Loss: 4.4442e+09, KL: 4.4442e+09, Reconstruction Loss (avg over 10 sample(s)): 2.0977e+02, Early stopping counter 0 / 200
# Epoch [  1350/ 50000], Loss: 4.3858e+09, KL: 4.3858e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8525e+02, Early stopping counter 0 / 200
# Epoch [  1360/ 50000], Loss: 4.3287e+09, KL: 4.3287e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7669e+02, Early stopping counter 0 / 200
# Epoch [  1370/ 50000], Loss: 4.2728e+09, KL: 4.2728e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8329e+02, Early stopping counter 0 / 200
# Epoch [  1380/ 50000], Loss: 4.2182e+09, KL: 4.2182e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7726e+02, Early stopping counter 0 / 200
# Epoch [  1390/ 50000], Loss: 4.1645e+09, KL: 4.1645e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9646e+02, Early stopping counter 0 / 200
# Epoch [  1400/ 50000], Loss: 4.1121e+09, KL: 4.1121e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7480e+02, Early stopping counter 0 / 200
# Epoch [  1410/ 50000], Loss: 4.0598e+09, KL: 4.0598e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6732e+02, Early stopping counter 0 / 200
# Epoch [  1420/ 50000], Loss: 4.0089e+09, KL: 4.0089e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9543e+02, Early stopping counter 0 / 200
# Epoch [  1430/ 50000], Loss: 3.9591e+09, KL: 3.9591e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9288e+02, Early stopping counter 0 / 200
# Epoch [  1440/ 50000], Loss: 3.9100e+09, KL: 3.9100e+09, Reconstruction Loss (avg over 10 sample(s)): 2.1554e+02, Early stopping counter 0 / 200
# Epoch [  1450/ 50000], Loss: 3.8617e+09, KL: 3.8617e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6409e+02, Early stopping counter 0 / 200
# Epoch [  1460/ 50000], Loss: 3.8145e+09, KL: 3.8145e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8036e+02, Early stopping counter 0 / 200
# Epoch [  1470/ 50000], Loss: 3.7679e+09, KL: 3.7679e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8341e+02, Early stopping counter 0 / 200
# Epoch [  1480/ 50000], Loss: 3.7225e+09, KL: 3.7225e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9233e+02, Early stopping counter 0 / 200
# Epoch [  1490/ 50000], Loss: 3.6772e+09, KL: 3.6772e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8001e+02, Early stopping counter 0 / 200
# Epoch [  1500/ 50000], Loss: 3.6338e+09, KL: 3.6338e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8555e+02, Early stopping counter 0 / 200
# Epoch [  1510/ 50000], Loss: 3.5901e+09, KL: 3.5901e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9750e+02, Early stopping counter 0 / 200
# Epoch [  1520/ 50000], Loss: 3.5473e+09, KL: 3.5473e+09, Reconstruction Loss (avg over 10 sample(s)): 2.0391e+02, Early stopping counter 0 / 200
# Epoch [  1530/ 50000], Loss: 3.5057e+09, KL: 3.5057e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8378e+02, Early stopping counter 0 / 200
# Epoch [  1540/ 50000], Loss: 3.4646e+09, KL: 3.4646e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8279e+02, Early stopping counter 0 / 200
# Epoch [  1550/ 50000], Loss: 3.4240e+09, KL: 3.4240e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8429e+02, Early stopping counter 0 / 200
# Epoch [  1560/ 50000], Loss: 3.3844e+09, KL: 3.3844e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7575e+02, Early stopping counter 0 / 200
# Epoch [  1570/ 50000], Loss: 3.3454e+09, KL: 3.3454e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8565e+02, Early stopping counter 0 / 200
# Epoch [  1580/ 50000], Loss: 3.3067e+09, KL: 3.3067e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8832e+02, Early stopping counter 0 / 200
# Epoch [  1590/ 50000], Loss: 3.2693e+09, KL: 3.2693e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8624e+02, Early stopping counter 0 / 200
# Epoch [  1600/ 50000], Loss: 3.2316e+09, KL: 3.2316e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8326e+02, Early stopping counter 0 / 200
# Epoch [  1610/ 50000], Loss: 3.1949e+09, KL: 3.1949e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9629e+02, Early stopping counter 0 / 200
# Epoch [  1620/ 50000], Loss: 3.1590e+09, KL: 3.1590e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7445e+02, Early stopping counter 0 / 200
# Epoch [  1630/ 50000], Loss: 3.1233e+09, KL: 3.1233e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7614e+02, Early stopping counter 0 / 200
# Epoch [  1640/ 50000], Loss: 3.0886e+09, KL: 3.0886e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8698e+02, Early stopping counter 0 / 200
# Epoch [  1650/ 50000], Loss: 3.0542e+09, KL: 3.0542e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8212e+02, Early stopping counter 0 / 200
# Epoch [  1660/ 50000], Loss: 3.0206e+09, KL: 3.0206e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8164e+02, Early stopping counter 0 / 200
# Epoch [  1670/ 50000], Loss: 2.9869e+09, KL: 2.9869e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8356e+02, Early stopping counter 0 / 200
# Epoch [  1680/ 50000], Loss: 2.9543e+09, KL: 2.9543e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8799e+02, Early stopping counter 0 / 200
# Epoch [  1690/ 50000], Loss: 2.9221e+09, KL: 2.9221e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8525e+02, Early stopping counter 0 / 200
# Epoch [  1700/ 50000], Loss: 2.8902e+09, KL: 2.8902e+09, Reconstruction Loss (avg over 10 sample(s)): 2.0315e+02, Early stopping counter 0 / 200
# Epoch [  1710/ 50000], Loss: 2.8592e+09, KL: 2.8592e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8374e+02, Early stopping counter 0 / 200
# Epoch [  1720/ 50000], Loss: 2.8281e+09, KL: 2.8281e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7468e+02, Early stopping counter 0 / 200
# Epoch [  1730/ 50000], Loss: 2.7977e+09, KL: 2.7977e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9645e+02, Early stopping counter 0 / 200
# Epoch [  1740/ 50000], Loss: 2.7680e+09, KL: 2.7680e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7930e+02, Early stopping counter 0 / 200
# Epoch [  1750/ 50000], Loss: 2.7385e+09, KL: 2.7385e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7779e+02, Early stopping counter 0 / 200
# Epoch [  1760/ 50000], Loss: 2.7094e+09, KL: 2.7094e+09, Reconstruction Loss (avg over 10 sample(s)): 2.0055e+02, Early stopping counter 0 / 200
# Epoch [  1770/ 50000], Loss: 2.6810e+09, KL: 2.6810e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8522e+02, Early stopping counter 0 / 200
# Epoch [  1780/ 50000], Loss: 2.6528e+09, KL: 2.6528e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8113e+02, Early stopping counter 0 / 200
# Epoch [  1790/ 50000], Loss: 2.6248e+09, KL: 2.6248e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7448e+02, Early stopping counter 0 / 200
# Epoch [  1800/ 50000], Loss: 2.5973e+09, KL: 2.5973e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9971e+02, Early stopping counter 0 / 200
# Epoch [  1810/ 50000], Loss: 2.5710e+09, KL: 2.5710e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8292e+02, Early stopping counter 0 / 200
# Epoch [  1820/ 50000], Loss: 2.5441e+09, KL: 2.5441e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6778e+02, Early stopping counter 0 / 200
# Epoch [  1830/ 50000], Loss: 2.5182e+09, KL: 2.5182e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8221e+02, Early stopping counter 0 / 200
# Epoch [  1840/ 50000], Loss: 2.4920e+09, KL: 2.4920e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8466e+02, Early stopping counter 0 / 200
# Epoch [  1850/ 50000], Loss: 2.4667e+09, KL: 2.4667e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9715e+02, Early stopping counter 0 / 200
# Epoch [  1860/ 50000], Loss: 2.4418e+09, KL: 2.4418e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9246e+02, Early stopping counter 0 / 200
# Epoch [  1870/ 50000], Loss: 2.4171e+09, KL: 2.4171e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7747e+02, Early stopping counter 0 / 200
# Epoch [  1880/ 50000], Loss: 2.3926e+09, KL: 2.3926e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9452e+02, Early stopping counter 0 / 200
# Epoch [  1890/ 50000], Loss: 2.3685e+09, KL: 2.3685e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7128e+02, Early stopping counter 0 / 200
# Epoch [  1900/ 50000], Loss: 2.3449e+09, KL: 2.3449e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7697e+02, Early stopping counter 0 / 200
# Epoch [  1910/ 50000], Loss: 2.3213e+09, KL: 2.3213e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8169e+02, Early stopping counter 0 / 200
# Epoch [  1920/ 50000], Loss: 2.2984e+09, KL: 2.2984e+09, Reconstruction Loss (avg over 10 sample(s)): 2.0321e+02, Early stopping counter 0 / 200
# Epoch [  1930/ 50000], Loss: 2.2756e+09, KL: 2.2756e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7855e+02, Early stopping counter 0 / 200
# Epoch [  1940/ 50000], Loss: 2.2530e+09, KL: 2.2530e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7856e+02, Early stopping counter 0 / 200
# Epoch [  1950/ 50000], Loss: 2.2313e+09, KL: 2.2313e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7597e+02, Early stopping counter 0 / 200
# Epoch [  1960/ 50000], Loss: 2.2093e+09, KL: 2.2093e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8101e+02, Early stopping counter 0 / 200
# Epoch [  1970/ 50000], Loss: 2.1879e+09, KL: 2.1879e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8278e+02, Early stopping counter 0 / 200
# Epoch [  1980/ 50000], Loss: 2.1665e+09, KL: 2.1665e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8594e+02, Early stopping counter 0 / 200
# Epoch [  1990/ 50000], Loss: 2.1454e+09, KL: 2.1454e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8989e+02, Early stopping counter 0 / 200
# Epoch [  2000/ 50000], Loss: 2.1247e+09, KL: 2.1247e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7887e+02, Early stopping counter 0 / 200
# Epoch [  2010/ 50000], Loss: 2.1041e+09, KL: 2.1041e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7992e+02, Early stopping counter 0 / 200
# Epoch [  2020/ 50000], Loss: 2.0840e+09, KL: 2.0840e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9965e+02, Early stopping counter 0 / 200
# Epoch [  2030/ 50000], Loss: 2.0640e+09, KL: 2.0640e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8285e+02, Early stopping counter 0 / 200
# Epoch [  2040/ 50000], Loss: 2.0445e+09, KL: 2.0445e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7801e+02, Early stopping counter 0 / 200
# Epoch [  2050/ 50000], Loss: 2.0251e+09, KL: 2.0251e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7375e+02, Early stopping counter 0 / 200
# Epoch [  2060/ 50000], Loss: 2.0058e+09, KL: 2.0058e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7626e+02, Early stopping counter 0 / 200
# Epoch [  2070/ 50000], Loss: 1.9869e+09, KL: 1.9869e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8372e+02, Early stopping counter 0 / 200
# Epoch [  2080/ 50000], Loss: 1.9686e+09, KL: 1.9686e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6545e+02, Early stopping counter 0 / 200
# Epoch [  2090/ 50000], Loss: 1.9499e+09, KL: 1.9499e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6900e+02, Early stopping counter 0 / 200
# Epoch [  2100/ 50000], Loss: 1.9318e+09, KL: 1.9318e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9505e+02, Early stopping counter 0 / 200
# Epoch [  2110/ 50000], Loss: 1.9137e+09, KL: 1.9137e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6289e+02, Early stopping counter 0 / 200
# Epoch [  2120/ 50000], Loss: 1.8960e+09, KL: 1.8960e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8968e+02, Early stopping counter 0 / 200
# Epoch [  2130/ 50000], Loss: 1.8785e+09, KL: 1.8785e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6189e+02, Early stopping counter 0 / 200
# Epoch [  2140/ 50000], Loss: 1.8613e+09, KL: 1.8613e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8004e+02, Early stopping counter 0 / 200
# Epoch [  2150/ 50000], Loss: 1.8442e+09, KL: 1.8442e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9091e+02, Early stopping counter 0 / 200
# Epoch [  2160/ 50000], Loss: 1.8274e+09, KL: 1.8274e+09, Reconstruction Loss (avg over 10 sample(s)): 2.0006e+02, Early stopping counter 0 / 200
# Epoch [  2170/ 50000], Loss: 1.8108e+09, KL: 1.8108e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6579e+02, Early stopping counter 0 / 200
# Epoch [  2180/ 50000], Loss: 1.7943e+09, KL: 1.7943e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9314e+02, Early stopping counter 0 / 200
# Epoch [  2190/ 50000], Loss: 1.7779e+09, KL: 1.7779e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9126e+02, Early stopping counter 0 / 200
# Epoch [  2200/ 50000], Loss: 1.7618e+09, KL: 1.7618e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7636e+02, Early stopping counter 0 / 200
# Epoch [  2210/ 50000], Loss: 1.7459e+09, KL: 1.7459e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8270e+02, Early stopping counter 0 / 200
# Epoch [  2220/ 50000], Loss: 1.7304e+09, KL: 1.7304e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8437e+02, Early stopping counter 0 / 200
# Epoch [  2230/ 50000], Loss: 1.7148e+09, KL: 1.7148e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8352e+02, Early stopping counter 0 / 200
# Epoch [  2240/ 50000], Loss: 1.6995e+09, KL: 1.6995e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8316e+02, Early stopping counter 0 / 200
# Epoch [  2250/ 50000], Loss: 1.6844e+09, KL: 1.6844e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7776e+02, Early stopping counter 0 / 200
# Epoch [  2260/ 50000], Loss: 1.6694e+09, KL: 1.6694e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8299e+02, Early stopping counter 0 / 200
# Epoch [  2270/ 50000], Loss: 1.6547e+09, KL: 1.6547e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7220e+02, Early stopping counter 0 / 200
# Epoch [  2280/ 50000], Loss: 1.6400e+09, KL: 1.6400e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6238e+02, Early stopping counter 0 / 200
# Epoch [  2290/ 50000], Loss: 1.6255e+09, KL: 1.6255e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7434e+02, Early stopping counter 0 / 200
# Epoch [  2300/ 50000], Loss: 1.6113e+09, KL: 1.6113e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8937e+02, Early stopping counter 0 / 200
# Epoch [  2310/ 50000], Loss: 1.5972e+09, KL: 1.5972e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7506e+02, Early stopping counter 0 / 200
# Epoch [  2320/ 50000], Loss: 1.5832e+09, KL: 1.5832e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8635e+02, Early stopping counter 0 / 200
# Epoch [  2330/ 50000], Loss: 1.5694e+09, KL: 1.5694e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8582e+02, Early stopping counter 0 / 200
# Epoch [  2340/ 50000], Loss: 1.5559e+09, KL: 1.5559e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9199e+02, Early stopping counter 0 / 200
# Epoch [  2350/ 50000], Loss: 1.5424e+09, KL: 1.5424e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8593e+02, Early stopping counter 0 / 200
# Epoch [  2360/ 50000], Loss: 1.5290e+09, KL: 1.5290e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7347e+02, Early stopping counter 0 / 200
# Epoch [  2370/ 50000], Loss: 1.5161e+09, KL: 1.5161e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8879e+02, Early stopping counter 0 / 200
# Epoch [  2380/ 50000], Loss: 1.5028e+09, KL: 1.5028e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7625e+02, Early stopping counter 0 / 200
# Epoch [  2390/ 50000], Loss: 1.4900e+09, KL: 1.4900e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9588e+02, Early stopping counter 0 / 200
# Epoch [  2400/ 50000], Loss: 1.4771e+09, KL: 1.4771e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7420e+02, Early stopping counter 0 / 200
# Epoch [  2410/ 50000], Loss: 1.4647e+09, KL: 1.4647e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7519e+02, Early stopping counter 0 / 200
# Epoch [  2420/ 50000], Loss: 1.4522e+09, KL: 1.4522e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8398e+02, Early stopping counter 0 / 200
# Epoch [  2430/ 50000], Loss: 1.4399e+09, KL: 1.4399e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7992e+02, Early stopping counter 0 / 200
# Epoch [  2440/ 50000], Loss: 1.4277e+09, KL: 1.4277e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9630e+02, Early stopping counter 0 / 200
# Epoch [  2450/ 50000], Loss: 1.4157e+09, KL: 1.4157e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8384e+02, Early stopping counter 0 / 200
# Epoch [  2460/ 50000], Loss: 1.4039e+09, KL: 1.4039e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8029e+02, Early stopping counter 0 / 200
# Epoch [  2470/ 50000], Loss: 1.3920e+09, KL: 1.3920e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9570e+02, Early stopping counter 0 / 200
# Epoch [  2480/ 50000], Loss: 1.3805e+09, KL: 1.3805e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9438e+02, Early stopping counter 0 / 200
# Epoch [  2490/ 50000], Loss: 1.3688e+09, KL: 1.3688e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7459e+02, Early stopping counter 0 / 200
# Epoch [  2500/ 50000], Loss: 1.3574e+09, KL: 1.3574e+09, Reconstruction Loss (avg over 10 sample(s)): 1.5415e+02, Early stopping counter 0 / 200
# Epoch [  2510/ 50000], Loss: 1.3462e+09, KL: 1.3462e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7864e+02, Early stopping counter 0 / 200
# Epoch [  2520/ 50000], Loss: 1.3350e+09, KL: 1.3350e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9888e+02, Early stopping counter 0 / 200
# Epoch [  2530/ 50000], Loss: 1.3240e+09, KL: 1.3240e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6251e+02, Early stopping counter 0 / 200
# Epoch [  2540/ 50000], Loss: 1.3130e+09, KL: 1.3130e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8752e+02, Early stopping counter 0 / 200
# Epoch [  2550/ 50000], Loss: 1.3022e+09, KL: 1.3022e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9426e+02, Early stopping counter 0 / 200
# Epoch [  2560/ 50000], Loss: 1.2917e+09, KL: 1.2917e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8034e+02, Early stopping counter 0 / 200
# Epoch [  2570/ 50000], Loss: 1.2810e+09, KL: 1.2810e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8236e+02, Early stopping counter 0 / 200
# Epoch [  2580/ 50000], Loss: 1.2704e+09, KL: 1.2704e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7678e+02, Early stopping counter 0 / 200
# Epoch [  2590/ 50000], Loss: 1.2601e+09, KL: 1.2601e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8174e+02, Early stopping counter 0 / 200
# Epoch [  2600/ 50000], Loss: 1.2498e+09, KL: 1.2498e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9446e+02, Early stopping counter 0 / 200
# Epoch [  2610/ 50000], Loss: 1.2398e+09, KL: 1.2398e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8495e+02, Early stopping counter 0 / 200
# Epoch [  2620/ 50000], Loss: 1.2298e+09, KL: 1.2298e+09, Reconstruction Loss (avg over 10 sample(s)): 2.1765e+02, Early stopping counter 0 / 200
# Epoch [  2630/ 50000], Loss: 1.2198e+09, KL: 1.2198e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8589e+02, Early stopping counter 0 / 200
# Epoch [  2640/ 50000], Loss: 1.2099e+09, KL: 1.2099e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9524e+02, Early stopping counter 0 / 200
# Epoch [  2650/ 50000], Loss: 1.2002e+09, KL: 1.2002e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8956e+02, Early stopping counter 0 / 200
# Epoch [  2660/ 50000], Loss: 1.1905e+09, KL: 1.1905e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9304e+02, Early stopping counter 0 / 200
# Epoch [  2670/ 50000], Loss: 1.1812e+09, KL: 1.1812e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9288e+02, Early stopping counter 0 / 200
# Epoch [  2680/ 50000], Loss: 1.1717e+09, KL: 1.1717e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7369e+02, Early stopping counter 0 / 200
# Epoch [  2690/ 50000], Loss: 1.1622e+09, KL: 1.1622e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8249e+02, Early stopping counter 0 / 200
# Epoch [  2700/ 50000], Loss: 1.1531e+09, KL: 1.1531e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9968e+02, Early stopping counter 0 / 200
# Epoch [  2710/ 50000], Loss: 1.1439e+09, KL: 1.1439e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7172e+02, Early stopping counter 0 / 200
# Epoch [  2720/ 50000], Loss: 1.1349e+09, KL: 1.1349e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9110e+02, Early stopping counter 0 / 200
# Epoch [  2730/ 50000], Loss: 1.1258e+09, KL: 1.1258e+09, Reconstruction Loss (avg over 10 sample(s)): 2.0271e+02, Early stopping counter 0 / 200
# Epoch [  2740/ 50000], Loss: 1.1169e+09, KL: 1.1169e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7554e+02, Early stopping counter 0 / 200
# Epoch [  2750/ 50000], Loss: 1.1083e+09, KL: 1.1083e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7424e+02, Early stopping counter 0 / 200
# Epoch [  2760/ 50000], Loss: 1.0995e+09, KL: 1.0995e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6498e+02, Early stopping counter 0 / 200
# Epoch [  2770/ 50000], Loss: 1.0909e+09, KL: 1.0909e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7556e+02, Early stopping counter 0 / 200
# Epoch [  2780/ 50000], Loss: 1.0823e+09, KL: 1.0823e+09, Reconstruction Loss (avg over 10 sample(s)): 1.8811e+02, Early stopping counter 0 / 200
# Epoch [  2790/ 50000], Loss: 1.0738e+09, KL: 1.0738e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7884e+02, Early stopping counter 0 / 200
# Epoch [  2800/ 50000], Loss: 1.0655e+09, KL: 1.0655e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7885e+02, Early stopping counter 0 / 200
# Epoch [  2810/ 50000], Loss: 1.0572e+09, KL: 1.0572e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6750e+02, Early stopping counter 0 / 200
# Epoch [  2820/ 50000], Loss: 1.0491e+09, KL: 1.0491e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6005e+02, Early stopping counter 0 / 200
# Epoch [  2830/ 50000], Loss: 1.0410e+09, KL: 1.0410e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7547e+02, Early stopping counter 0 / 200
# Epoch [  2840/ 50000], Loss: 1.0328e+09, KL: 1.0328e+09, Reconstruction Loss (avg over 10 sample(s)): 1.6894e+02, Early stopping counter 0 / 200
# Epoch [  2850/ 50000], Loss: 1.0249e+09, KL: 1.0249e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7726e+02, Early stopping counter 0 / 200
# Epoch [  2860/ 50000], Loss: 1.0171e+09, KL: 1.0171e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7986e+02, Early stopping counter 0 / 200
# Epoch [  2870/ 50000], Loss: 1.0092e+09, KL: 1.0092e+09, Reconstruction Loss (avg over 10 sample(s)): 1.7855e+02, Early stopping counter 0 / 200
# Epoch [  2880/ 50000], Loss: 1.0015e+09, KL: 1.0015e+09, Reconstruction Loss (avg over 10 sample(s)): 1.9973e+02, Early stopping counter 0 / 200
# Epoch [  2890/ 50000], Loss: 9.9379e+08, KL: 9.9379e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8477e+02, Early stopping counter 0 / 200
# Epoch [  2900/ 50000], Loss: 9.8610e+08, KL: 9.8610e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7361e+02, Early stopping counter 0 / 200
# Epoch [  2910/ 50000], Loss: 9.7872e+08, KL: 9.7872e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8869e+02, Early stopping counter 0 / 200
# Epoch [  2920/ 50000], Loss: 9.7116e+08, KL: 9.7116e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7140e+02, Early stopping counter 0 / 200
# Epoch [  2930/ 50000], Loss: 9.6384e+08, KL: 9.6384e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7740e+02, Early stopping counter 0 / 200
# Epoch [  2940/ 50000], Loss: 9.5652e+08, KL: 9.5652e+08, Reconstruction Loss (avg over 10 sample(s)): 1.9406e+02, Early stopping counter 0 / 200
# Epoch [  2950/ 50000], Loss: 9.4934e+08, KL: 9.4934e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7699e+02, Early stopping counter 0 / 200
# Epoch [  2960/ 50000], Loss: 9.4212e+08, KL: 9.4212e+08, Reconstruction Loss (avg over 10 sample(s)): 1.9645e+02, Early stopping counter 0 / 200
# Epoch [  2970/ 50000], Loss: 9.3504e+08, KL: 9.3504e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7459e+02, Early stopping counter 0 / 200
# Epoch [  2980/ 50000], Loss: 9.2797e+08, KL: 9.2797e+08, Reconstruction Loss (avg over 10 sample(s)): 1.6629e+02, Early stopping counter 0 / 200
# Epoch [  2990/ 50000], Loss: 9.2093e+08, KL: 9.2093e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7012e+02, Early stopping counter 0 / 200
# Epoch [  3000/ 50000], Loss: 9.1410e+08, KL: 9.1410e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7969e+02, Early stopping counter 0 / 200
# Epoch [  3010/ 50000], Loss: 9.0724e+08, KL: 9.0724e+08, Reconstruction Loss (avg over 10 sample(s)): 1.6558e+02, Early stopping counter 0 / 200
# Epoch [  3020/ 50000], Loss: 9.0045e+08, KL: 9.0045e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8867e+02, Early stopping counter 0 / 200
# Epoch [  3030/ 50000], Loss: 8.9373e+08, KL: 8.9373e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8062e+02, Early stopping counter 0 / 200
# Epoch [  3040/ 50000], Loss: 8.8703e+08, KL: 8.8703e+08, Reconstruction Loss (avg over 10 sample(s)): 1.6666e+02, Early stopping counter 0 / 200
# Epoch [  3050/ 50000], Loss: 8.8041e+08, KL: 8.8041e+08, Reconstruction Loss (avg over 10 sample(s)): 1.6823e+02, Early stopping counter 0 / 200
# Epoch [  3060/ 50000], Loss: 8.7389e+08, KL: 8.7389e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7447e+02, Early stopping counter 0 / 200
# Epoch [  3070/ 50000], Loss: 8.6743e+08, KL: 8.6743e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7796e+02, Early stopping counter 0 / 200
# Epoch [  3080/ 50000], Loss: 8.6103e+08, KL: 8.6103e+08, Reconstruction Loss (avg over 10 sample(s)): 1.9302e+02, Early stopping counter 0 / 200
# Epoch [  3090/ 50000], Loss: 8.5468e+08, KL: 8.5468e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7454e+02, Early stopping counter 0 / 200
# Epoch [  3100/ 50000], Loss: 8.4835e+08, KL: 8.4835e+08, Reconstruction Loss (avg over 10 sample(s)): 1.9716e+02, Early stopping counter 0 / 200
# Epoch [  3110/ 50000], Loss: 8.4213e+08, KL: 8.4213e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8390e+02, Early stopping counter 0 / 200
# Epoch [  3120/ 50000], Loss: 8.3593e+08, KL: 8.3593e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8004e+02, Early stopping counter 0 / 200
# Epoch [  3130/ 50000], Loss: 8.2981e+08, KL: 8.2981e+08, Reconstruction Loss (avg over 10 sample(s)): 1.9739e+02, Early stopping counter 0 / 200
# Epoch [  3140/ 50000], Loss: 8.2368e+08, KL: 8.2368e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8556e+02, Early stopping counter 0 / 200
# Epoch [  3150/ 50000], Loss: 8.1764e+08, KL: 8.1764e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8104e+02, Early stopping counter 0 / 200
# Epoch [  3160/ 50000], Loss: 8.1171e+08, KL: 8.1171e+08, Reconstruction Loss (avg over 10 sample(s)): 1.9190e+02, Early stopping counter 0 / 200
# Epoch [  3170/ 50000], Loss: 8.0578e+08, KL: 8.0578e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8597e+02, Early stopping counter 0 / 200
# Epoch [  3180/ 50000], Loss: 7.9993e+08, KL: 7.9993e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7599e+02, Early stopping counter 0 / 200
# Epoch [  3190/ 50000], Loss: 7.9411e+08, KL: 7.9411e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7578e+02, Early stopping counter 0 / 200
# Epoch [  3200/ 50000], Loss: 7.8830e+08, KL: 7.8830e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7435e+02, Early stopping counter 0 / 200
# Epoch [  3210/ 50000], Loss: 7.8259e+08, KL: 7.8259e+08, Reconstruction Loss (avg over 10 sample(s)): 1.9676e+02, Early stopping counter 0 / 200
# Epoch [  3220/ 50000], Loss: 7.7689e+08, KL: 7.7689e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7913e+02, Early stopping counter 0 / 200
# Epoch [  3230/ 50000], Loss: 7.7145e+08, KL: 7.7145e+08, Reconstruction Loss (avg over 10 sample(s)): 1.6950e+02, Early stopping counter 0 / 200
# Epoch [  3240/ 50000], Loss: 7.6577e+08, KL: 7.6577e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8141e+02, Early stopping counter 0 / 200
# Epoch [  3250/ 50000], Loss: 7.6028e+08, KL: 7.6028e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7163e+02, Early stopping counter 0 / 200
# Epoch [  3260/ 50000], Loss: 7.5479e+08, KL: 7.5479e+08, Reconstruction Loss (avg over 10 sample(s)): 1.6836e+02, Early stopping counter 0 / 200
# Epoch [  3270/ 50000], Loss: 7.4944e+08, KL: 7.4944e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7168e+02, Early stopping counter 0 / 200
# Epoch [  3280/ 50000], Loss: 7.4401e+08, KL: 7.4401e+08, Reconstruction Loss (avg over 10 sample(s)): 1.8404e+02, Early stopping counter 0 / 200
# Epoch [  3290/ 50000], Loss: 7.3870e+08, KL: 7.3870e+08, Reconstruction Loss (avg over 10 sample(s)): 1.7703e+02, Early stopping counter 0 / 200
# ...
# Epoch [ 32520/ 50000], Loss: -5.1170e+01, KL: 7.3131e+02, Reconstruction Loss (avg over 10 sample(s)): -7.8248e+02, Early stopping counter 109 / 200
# Epoch [ 32530/ 50000], Loss: -7.6123e+01, KL: 7.3200e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0813e+02, Early stopping counter 109 / 200
# Epoch [ 32540/ 50000], Loss: -8.9462e+01, KL: 7.3294e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2240e+02, Early stopping counter 109 / 200
# Epoch [ 32550/ 50000], Loss: 5.0767e+01, KL: 7.3031e+02, Reconstruction Loss (avg over 10 sample(s)): -6.7954e+02, Early stopping counter 114 / 200
# Epoch [ 32560/ 50000], Loss: -3.9721e+00, KL: 7.3134e+02, Reconstruction Loss (avg over 10 sample(s)): -7.3531e+02, Early stopping counter 124 / 200
# Epoch [ 32570/ 50000], Loss: -4.1675e+01, KL: 7.3259e+02, Reconstruction Loss (avg over 10 sample(s)): -7.7427e+02, Early stopping counter 128 / 200
# Epoch [ 32580/ 50000], Loss: -1.0491e+02, KL: 7.3184e+02, Reconstruction Loss (avg over 10 sample(s)): -8.3675e+02, Early stopping counter 128 / 200
# Epoch [ 32590/ 50000], Loss: -4.8545e+01, KL: 7.3046e+02, Reconstruction Loss (avg over 10 sample(s)): -7.7900e+02, Early stopping counter 132 / 200
# Epoch [ 32600/ 50000], Loss: -1.2231e+02, KL: 7.2968e+02, Reconstruction Loss (avg over 10 sample(s)): -8.5199e+02, Early stopping counter 132 / 200
# Epoch [ 32610/ 50000], Loss: -9.1287e+01, KL: 7.3125e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2254e+02, Early stopping counter 132 / 200
# Epoch [ 32620/ 50000], Loss: -6.1737e+01, KL: 7.3138e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9311e+02, Early stopping counter 133 / 200
# Epoch [ 32630/ 50000], Loss: -7.0512e+01, KL: 7.3113e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0165e+02, Early stopping counter 133 / 200
# Epoch [ 32640/ 50000], Loss: -4.2581e+01, KL: 7.2988e+02, Reconstruction Loss (avg over 10 sample(s)): -7.7246e+02, Early stopping counter 134 / 200
# Epoch [ 32650/ 50000], Loss: -3.5823e+01, KL: 7.3212e+02, Reconstruction Loss (avg over 10 sample(s)): -7.6794e+02, Early stopping counter 134 / 200
# Epoch [ 32660/ 50000], Loss: -9.0797e+00, KL: 7.3149e+02, Reconstruction Loss (avg over 10 sample(s)): -7.4057e+02, Early stopping counter 135 / 200
# Epoch [ 32670/ 50000], Loss: -9.0676e+01, KL: 7.3166e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2234e+02, Early stopping counter 135 / 200
# Epoch [ 32680/ 50000], Loss: -6.3562e+01, KL: 7.3092e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9448e+02, Early stopping counter 135 / 200
# Epoch [ 32690/ 50000], Loss: -6.3601e+01, KL: 7.3256e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9616e+02, Early stopping counter 135 / 200
# Epoch [ 32700/ 50000], Loss: -1.0722e+02, KL: 7.3034e+02, Reconstruction Loss (avg over 10 sample(s)): -8.3755e+02, Early stopping counter 135 / 200
# Epoch [ 32710/ 50000], Loss: -7.8046e+01, KL: 7.3046e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0851e+02, Early stopping counter 137 / 200
# Epoch [ 32720/ 50000], Loss: -1.0453e+02, KL: 7.3344e+02, Reconstruction Loss (avg over 10 sample(s)): -8.3798e+02, Early stopping counter 137 / 200
# Epoch [ 32730/ 50000], Loss: -8.4610e+01, KL: 7.3155e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1616e+02, Early stopping counter 137 / 200
# Epoch [ 32740/ 50000], Loss: -4.3530e+01, KL: 7.3079e+02, Reconstruction Loss (avg over 10 sample(s)): -7.7432e+02, Early stopping counter 138 / 200
# Epoch [ 32750/ 50000], Loss: -9.6632e+01, KL: 7.3118e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2781e+02, Early stopping counter 138 / 200
# Epoch [ 32760/ 50000], Loss: -4.7405e+01, KL: 7.3127e+02, Reconstruction Loss (avg over 10 sample(s)): -7.7868e+02, Early stopping counter 139 / 200
# Epoch [ 32770/ 50000], Loss: -6.0551e+01, KL: 7.3057e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9112e+02, Early stopping counter 139 / 200
# Epoch [ 32780/ 50000], Loss: -7.9538e+01, KL: 7.3093e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1047e+02, Early stopping counter 142 / 200
# Epoch [ 32790/ 50000], Loss: -9.6846e+01, KL: 7.3108e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2793e+02, Early stopping counter 142 / 200
# Epoch [ 32800/ 50000], Loss: -1.0454e+02, KL: 7.3124e+02, Reconstruction Loss (avg over 10 sample(s)): -8.3578e+02, Early stopping counter 142 / 200
# Epoch [ 32810/ 50000], Loss: -1.1034e+02, KL: 7.3120e+02, Reconstruction Loss (avg over 10 sample(s)): -8.4153e+02, Early stopping counter 142 / 200
# Epoch [ 32820/ 50000], Loss: -7.7178e+01, KL: 7.3149e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0866e+02, Early stopping counter 0 / 200
# Epoch [ 32830/ 50000], Loss: -7.1120e+01, KL: 7.3239e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0351e+02, Early stopping counter 4 / 200
# Epoch [ 32840/ 50000], Loss: -9.6913e+01, KL: 7.3301e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2992e+02, Early stopping counter 4 / 200
# Epoch [ 32850/ 50000], Loss: -6.4093e+01, KL: 7.3174e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9583e+02, Early stopping counter 7 / 200
# Epoch [ 32860/ 50000], Loss: -7.3966e+01, KL: 7.3212e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0608e+02, Early stopping counter 9 / 200
# Epoch [ 32870/ 50000], Loss: 3.2782e+01, KL: 8.3064e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9786e+02, Early stopping counter 12 / 200
# Epoch [ 32880/ 50000], Loss: -2.8296e+01, KL: 7.6444e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9274e+02, Early stopping counter 20 / 200
# Epoch [ 32890/ 50000], Loss: 2.3754e+00, KL: 7.4877e+02, Reconstruction Loss (avg over 10 sample(s)): -7.4640e+02, Early stopping counter 28 / 200
# Epoch [ 32900/ 50000], Loss: -6.5347e+01, KL: 7.3390e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9925e+02, Early stopping counter 32 / 200
# Epoch [ 32910/ 50000], Loss: -2.8596e+01, KL: 7.3530e+02, Reconstruction Loss (avg over 10 sample(s)): -7.6389e+02, Early stopping counter 34 / 200
# Epoch [ 32920/ 50000], Loss: -2.1142e+01, KL: 7.3462e+02, Reconstruction Loss (avg over 10 sample(s)): -7.5576e+02, Early stopping counter 38 / 200
# Epoch [ 32930/ 50000], Loss: -9.6226e+01, KL: 7.3187e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2809e+02, Early stopping counter 38 / 200
# Epoch [ 32940/ 50000], Loss: -8.9322e+01, KL: 7.3253e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2186e+02, Early stopping counter 0 / 200
# Epoch [ 32950/ 50000], Loss: 3.3794e+00, KL: 7.3235e+02, Reconstruction Loss (avg over 10 sample(s)): -7.2897e+02, Early stopping counter 5 / 200
# Epoch [ 32960/ 50000], Loss: -5.5324e+01, KL: 7.3277e+02, Reconstruction Loss (avg over 10 sample(s)): -7.8809e+02, Early stopping counter 8 / 200
# Epoch [ 32970/ 50000], Loss: -8.3472e+01, KL: 7.3313e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1661e+02, Early stopping counter 8 / 200
# Epoch [ 32980/ 50000], Loss: -9.7161e+01, KL: 7.3112e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2828e+02, Early stopping counter 9 / 200
# Epoch [ 32990/ 50000], Loss: -1.7744e+01, KL: 7.3766e+02, Reconstruction Loss (avg over 10 sample(s)): -7.5540e+02, Early stopping counter 15 / 200
# Epoch [ 33000/ 50000], Loss: -8.6041e+01, KL: 7.3161e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1765e+02, Early stopping counter 16 / 200
# Epoch [ 33010/ 50000], Loss: -7.4684e+01, KL: 7.3214e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0683e+02, Early stopping counter 16 / 200
# Epoch [ 33020/ 50000], Loss: -9.3900e+01, KL: 7.3127e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2517e+02, Early stopping counter 17 / 200
# Epoch [ 33030/ 50000], Loss: -7.8837e+01, KL: 7.3204e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1088e+02, Early stopping counter 17 / 200
# Epoch [ 33040/ 50000], Loss: -6.8300e+01, KL: 7.3487e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0317e+02, Early stopping counter 17 / 200
# Epoch [ 33050/ 50000], Loss: -8.0850e+01, KL: 7.3317e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1402e+02, Early stopping counter 17 / 200
# Epoch [ 33060/ 50000], Loss: -9.0169e+01, KL: 7.3593e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2610e+02, Early stopping counter 19 / 200
# Epoch [ 33070/ 50000], Loss: -7.4249e+01, KL: 7.3598e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1023e+02, Early stopping counter 19 / 200
# Epoch [ 33080/ 50000], Loss: -9.3466e+01, KL: 7.3469e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2815e+02, Early stopping counter 20 / 200
# Epoch [ 33090/ 50000], Loss: -8.7859e+01, KL: 7.3280e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2066e+02, Early stopping counter 20 / 200
# Epoch [ 33100/ 50000], Loss: -7.6117e+01, KL: 7.3194e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0806e+02, Early stopping counter 21 / 200
# Epoch [ 33110/ 50000], Loss: -9.0105e+01, KL: 7.3560e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2570e+02, Early stopping counter 22 / 200
# Epoch [ 33120/ 50000], Loss: -7.7580e+01, KL: 7.3373e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1131e+02, Early stopping counter 22 / 200
# Epoch [ 33130/ 50000], Loss: -8.8182e+01, KL: 7.3204e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2022e+02, Early stopping counter 23 / 200
# Epoch [ 33140/ 50000], Loss: -1.1843e+02, KL: 7.3406e+02, Reconstruction Loss (avg over 10 sample(s)): -8.5250e+02, Early stopping counter 23 / 200
# Epoch [ 33150/ 50000], Loss: -8.1265e+01, KL: 7.3277e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1403e+02, Early stopping counter 25 / 200
# Epoch [ 33160/ 50000], Loss: -4.1949e+01, KL: 7.3357e+02, Reconstruction Loss (avg over 10 sample(s)): -7.7552e+02, Early stopping counter 26 / 200
# Epoch [ 33170/ 50000], Loss: -7.0347e+01, KL: 7.3281e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0316e+02, Early stopping counter 29 / 200
# Epoch [ 33180/ 50000], Loss: -9.3170e+01, KL: 7.3224e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2541e+02, Early stopping counter 29 / 200
# Epoch [ 33190/ 50000], Loss: -9.2478e+01, KL: 7.3281e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2529e+02, Early stopping counter 30 / 200
# Epoch [ 33200/ 50000], Loss: -8.0950e+01, KL: 7.3610e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1705e+02, Early stopping counter 31 / 200
# Epoch [ 33210/ 50000], Loss: -7.0244e+01, KL: 7.3371e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0396e+02, Early stopping counter 32 / 200
# Epoch [ 33220/ 50000], Loss: -9.0723e+01, KL: 7.3254e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2327e+02, Early stopping counter 33 / 200
# Epoch [ 33230/ 50000], Loss: -8.6321e+01, KL: 7.3687e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2320e+02, Early stopping counter 34 / 200
# Epoch [ 33240/ 50000], Loss: -9.1815e+01, KL: 7.3457e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2639e+02, Early stopping counter 36 / 200
# Epoch [ 33250/ 50000], Loss: -8.1557e+01, KL: 7.3645e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1801e+02, Early stopping counter 36 / 200
# Epoch [ 33260/ 50000], Loss: -9.8874e+01, KL: 7.3271e+02, Reconstruction Loss (avg over 10 sample(s)): -8.3158e+02, Early stopping counter 36 / 200
# Epoch [ 33270/ 50000], Loss: -1.0075e+02, KL: 7.3567e+02, Reconstruction Loss (avg over 10 sample(s)): -8.3642e+02, Early stopping counter 0 / 200
# Epoch [ 33280/ 50000], Loss: -4.7360e+01, KL: 7.3268e+02, Reconstruction Loss (avg over 10 sample(s)): -7.8004e+02, Early stopping counter 0 / 200
# Epoch [ 33290/ 50000], Loss: -1.1859e+02, KL: 7.3571e+02, Reconstruction Loss (avg over 10 sample(s)): -8.5430e+02, Early stopping counter 0 / 200
# Epoch [ 33300/ 50000], Loss: -8.4082e+01, KL: 7.3309e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1717e+02, Early stopping counter 0 / 200
# Epoch [ 33310/ 50000], Loss: -1.0882e+02, KL: 7.3355e+02, Reconstruction Loss (avg over 10 sample(s)): -8.4237e+02, Early stopping counter 1 / 200
# Epoch [ 33320/ 50000], Loss: -1.3471e+01, KL: 7.3435e+02, Reconstruction Loss (avg over 10 sample(s)): -7.4782e+02, Early stopping counter 2 / 200
# Epoch [ 33330/ 50000], Loss: -7.5881e+01, KL: 7.3348e+02, Reconstruction Loss (avg over 10 sample(s)): -8.0936e+02, Early stopping counter 2 / 200
# Epoch [ 33340/ 50000], Loss: 5.0215e+02, KL: 7.4653e+02, Reconstruction Loss (avg over 10 sample(s)): -2.4438e+02, Early stopping counter 12 / 200
# Epoch [ 33350/ 50000], Loss: 5.0194e+02, KL: 7.4205e+02, Reconstruction Loss (avg over 10 sample(s)): -2.4011e+02, Early stopping counter 22 / 200
# Epoch [ 33360/ 50000], Loss: 3.5770e+02, KL: 7.3566e+02, Reconstruction Loss (avg over 10 sample(s)): -3.7795e+02, Early stopping counter 32 / 200
# Epoch [ 33370/ 50000], Loss: 2.4529e+02, KL: 7.3333e+02, Reconstruction Loss (avg over 10 sample(s)): -4.8804e+02, Early stopping counter 42 / 200
# Epoch [ 33380/ 50000], Loss: 1.4168e+02, KL: 7.3176e+02, Reconstruction Loss (avg over 10 sample(s)): -5.9008e+02, Early stopping counter 52 / 200
# Epoch [ 33390/ 50000], Loss: 7.6653e+01, KL: 7.3078e+02, Reconstruction Loss (avg over 10 sample(s)): -6.5413e+02, Early stopping counter 62 / 200
# Epoch [ 33400/ 50000], Loss: 4.9949e+01, KL: 7.2984e+02, Reconstruction Loss (avg over 10 sample(s)): -6.7989e+02, Early stopping counter 72 / 200
# Epoch [ 33410/ 50000], Loss: 7.5716e+00, KL: 7.3125e+02, Reconstruction Loss (avg over 10 sample(s)): -7.2367e+02, Early stopping counter 82 / 200
# Epoch [ 33420/ 50000], Loss: 5.3386e+00, KL: 7.2948e+02, Reconstruction Loss (avg over 10 sample(s)): -7.2414e+02, Early stopping counter 92 / 200
# Epoch [ 33430/ 50000], Loss: 2.0939e+00, KL: 7.2948e+02, Reconstruction Loss (avg over 10 sample(s)): -7.2739e+02, Early stopping counter 102 / 200
# Epoch [ 33440/ 50000], Loss: 3.2692e+01, KL: 7.3049e+02, Reconstruction Loss (avg over 10 sample(s)): -6.9780e+02, Early stopping counter 112 / 200
# Epoch [ 33450/ 50000], Loss: -1.8680e+01, KL: 7.3078e+02, Reconstruction Loss (avg over 10 sample(s)): -7.4946e+02, Early stopping counter 122 / 200
# Epoch [ 33460/ 50000], Loss: -3.0744e+01, KL: 7.3011e+02, Reconstruction Loss (avg over 10 sample(s)): -7.6085e+02, Early stopping counter 129 / 200
# Epoch [ 33470/ 50000], Loss: -2.6222e+01, KL: 7.3837e+02, Reconstruction Loss (avg over 10 sample(s)): -7.6459e+02, Early stopping counter 137 / 200
# Epoch [ 33480/ 50000], Loss: -2.4334e+01, KL: 7.3067e+02, Reconstruction Loss (avg over 10 sample(s)): -7.5501e+02, Early stopping counter 146 / 200
# Epoch [ 33490/ 50000], Loss: -4.9453e+01, KL: 7.3154e+02, Reconstruction Loss (avg over 10 sample(s)): -7.8099e+02, Early stopping counter 149 / 200
# Epoch [ 33500/ 50000], Loss: -4.7475e+01, KL: 7.3134e+02, Reconstruction Loss (avg over 10 sample(s)): -7.7882e+02, Early stopping counter 155 / 200
# Epoch [ 33510/ 50000], Loss: -2.6311e+01, KL: 7.3288e+02, Reconstruction Loss (avg over 10 sample(s)): -7.5919e+02, Early stopping counter 160 / 200
# Epoch [ 33520/ 50000], Loss: -5.1351e+01, KL: 7.3244e+02, Reconstruction Loss (avg over 10 sample(s)): -7.8379e+02, Early stopping counter 166 / 200
# Epoch [ 33530/ 50000], Loss: -3.7579e+01, KL: 7.3544e+02, Reconstruction Loss (avg over 10 sample(s)): -7.7302e+02, Early stopping counter 172 / 200
# Epoch [ 33540/ 50000], Loss: -8.0496e+01, KL: 7.3106e+02, Reconstruction Loss (avg over 10 sample(s)): -8.1155e+02, Early stopping counter 173 / 200
# Epoch [ 33550/ 50000], Loss: -6.7547e+01, KL: 7.3144e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9899e+02, Early stopping counter 176 / 200
# Epoch [ 33560/ 50000], Loss: -8.1055e+01, KL: 7.3921e+02, Reconstruction Loss (avg over 10 sample(s)): -8.2027e+02, Early stopping counter 180 / 200
# Epoch [ 33570/ 50000], Loss: -3.1517e+01, KL: 7.3127e+02, Reconstruction Loss (avg over 10 sample(s)): -7.6279e+02, Early stopping counter 186 / 200
# Epoch [ 33580/ 50000], Loss: -5.2785e+01, KL: 7.3074e+02, Reconstruction Loss (avg over 10 sample(s)): -7.8352e+02, Early stopping counter 192 / 200
# Epoch [ 33590/ 50000], Loss: -4.8911e+01, KL: 7.4330e+02, Reconstruction Loss (avg over 10 sample(s)): -7.9221e+02, Early stopping counter 196 / 200

# %%
def report_out_losses(losses, kls, reconstruction_losses):
    """ Report the losses and KL divergence.
    """
    
    print(f"Total Loss final: {losses[-1]:.4e}")
    print(f"KL Divergence final: {kls[-1]:.4e}")
    print(f"Reconstruction Loss (avg over {K} sample(s)) final: {reconstruction_losses[-1]:.4e}")

    fig, ax = plt.subplots(1,3, figsize=(18, 4))

    ax[0].plot(losses, label='Loss', color='blue')
    ax[0].set_title('Loss over epochs')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].set_yscale('log')
    ax[0].grid(True)
    ax[0].legend()

    ax[1].plot(kls, label='KL Divergence', color='orange')
    ax[1].set_title('KL Divergence over epochs')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('KL Divergence')
    ax[1].set_yscale('log')
    ax[1].grid(True)
    ax[1].legend()

    ax[2].plot(reconstruction_losses, label='Reconstruction Loss', color='green')
    ax[2].set_title(f'Reconstruction Loss over epochs (avg with {K} sample(s))')
    ax[2].set_xlabel('Epochs')      
    ax[2].set_ylabel('Reconstruction Loss')
    ax[2].set_yscale('log')
    ax[2].grid(True)
    ax[2].legend()

    plt.tight_layout()
    plt.show()
    
report_out_losses(losses, kls, reconstruction_losses)
# Out:
# Total Loss final: -3.8775e+01
# KL Divergence final: 7.3553e+02
# Reconstruction Loss (avg over 10 sample(s)) final: -7.7431e+02

# %%
def report_out_parameters(mean_parameters_values, kernels_parameters_values, Dz=Dz):
    """ Report the parameters of the prior Gaussian Processes.
    """
    
    print("Final Mean function parameters:")
    for i in range(Dz):
        print(f"Mean function {i}:")
        for name, values in mean_parameters_values[f"mean_function_{i}"].items():
            print(f"\t{name}: {values[-1]:.4e}")
            
    for i in range(Dz):
        mean_f = mean_functions_list[i]
        for name, param in mean_f.named_parameters():
            values = mean_parameters_values[f"mean_function_{i}"][name]
            fig, ax = plt.subplots(figsize=(6, 3))
            ax.plot(values, label=f"{name} (Mean function {i})")
            ax.set_title(f"Mean function {i} - {name} over epochs")
            ax.set_xlabel('Epochs')
            ax.set_ylabel(name)
            ax.grid(True)
            ax.legend()
            plt.show()
    
    print("\nFinal Kernel parameters:")
    for i in range(Dz):
        print(f"Kernel {i}:")
        for name, values in kernels_parameters_values[f"kernel_{i}"].items():
            print(f"\t{name}: {values[-1]:.4e}")
            
    for i in range(Dz):
        kernel = kernels_list[i]
        for name, param in kernel.named_parameters():
            values = kernels_parameters_values[f"kernel_{i}"][name]
            fig, ax = plt.subplots(figsize=(6, 3))
            ax.plot(values, label=f"{name} (Kernel {i})")
            ax.set_title(f"Kernel {i} - {name} over epochs")
            ax.set_xlabel('Epochs')
            ax.set_ylabel(name)
            ax.grid(True)
            ax.legend()
            plt.show()

# %%
report_out_parameters(mean_parameters_values, kernels_parameters_values)
# Out:
# Final Mean function parameters:
# Mean function 0:
# Mean function 1:
#
# Final Kernel parameters:
# Kernel 0:
# 	lengthscale: 2.2550e-02
# 	sigma: 1.0259e+00
# Kernel 1:
# 	lengthscale: 2.2446e-02
# 	sigma: 1.0247e+00

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 28px; color: black; font-weight: bold;">
# Predictions
# </div>

# %%
z_sampled = q_phi.rsample()  # (B, Dz, N)
z_sampled_p = z_sampled.transpose(-1, -2)  # (B, N, Dz)
print(f"z_sampled shape: {z_sampled.shape}")
# Out:
# z_sampled shape: torch.Size([1, 2, 100])

# %%
with torch.no_grad():
    # Decode the sampled z
    mu_x = decoder_mean(z_sampled_p)  # (B, N, Dx)
    L_x, covar_x = decoder_covariance(z_sampled_p) # + tolerance # (B, N, Dx, Dx)

    p_theta_x = torch.distributions.MultivariateNormal(
            loc=mu_x,
            scale_tril=L_x
    ) # batch_shape=(B, N), event_shape=(Dx,)

    print(f"p_theta_x: {p_theta_x}")
    print(f"\tp_theta_x batch shape: {p_theta_x.batch_shape}")
    print(f"\tp_theta_x event shape: {p_theta_x.event_shape}")
# Out:
# p_theta_x: MultivariateNormal(loc: torch.Size([1, 100, 4]), scale_tril: torch.Size([1, 100, 4, 4]))
# 	p_theta_x batch shape: torch.Size([1, 100])
# 	p_theta_x event shape: torch.Size([4])

# %%
x_hat = p_theta_x.rsample()  # (B, N, Dx)
print(f"x_hat shape: {x_hat.shape}")  # (B, N, Dx)
# Out:
# x_hat shape: torch.Size([1, 100, 4])

# %%
mu_x.size()
# Out:
# torch.Size([1, 100, 4])

# %%
id_in_batch = 0  # Index of the time serie to plot is the batch to plot

if Dx > 1:
    fig, axs = plt.subplots(Dx, 1, figsize=(10, 3 * Dx))
    for i in range(Dx):
        axs[i].plot(t[0].cpu().numpy(), x[id_in_batch, :, i].cpu().numpy(), label=f"x_{i+1} (original)", color='blue', marker='x', linewidth=1)
        axs[i].plot(t[0].cpu().numpy(), mu_x[id_in_batch, :, i].cpu().numpy(), label=f"x_{i+1} (mean reconstructed)", color='red', marker='.', linewidth=1)
        axs[i].plot(t[0].cpu().numpy(), x_hat[id_in_batch, :, i].cpu().numpy(), label=f"x_{i+1} (sampled)", color='green', marker='.', linewidth=1)
        axs[i].set_title(f"Time Series x_{i+1}")
        axs[i].legend()
        axs[i].grid()
else:
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(t[0].cpu().numpy(), x[id_in_batch, :, i].cpu().numpy(), label="x_1 (original)", color='blue', marker='x', linewidth=1)
    ax.plot(t[0].cpu().numpy(), mu_x[id_in_batch, :, i].cpu().numpy(), label="x_1 (mean reconstructed)", color='red', marker='.', linewidth=1)
    ax.plot(t[0].cpu().numpy(), x_hat[id_in_batch, :, i].cpu().numpy(), label="x_1 (sampled)", color='green', marker='.', linewidth=1)
    ax.set_title("Time Series x_1")
    ax.legend()
    ax.grid()
    
fig.tight_layout()
plt.show()
